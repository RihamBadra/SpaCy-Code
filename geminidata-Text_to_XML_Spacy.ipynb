# %% [markdown]
# # **Text to XML**

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.6.15)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
# Step 1: Import required libraries
import spacy
import xml.etree.ElementTree as ET
from google.colab import files

# Step 2: Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Step 3: Read the SLA text file
with open("geminiSLA.txt", "r", encoding="utf-8") as file:
    text = file.read()

# Step 4: Process the text using spaCy
doc = nlp(text)

# Step 5: Extract keywords (nouns and proper nouns, not stop words or punctuation)
keywords = {token.text.lower() for token in doc if token.pos_ in ("NOUN", "PROPN") and not token.is_stop and token.is_alpha}

# Step 6: Format the keywords line
keywords_line = 'keywords={ ' + ", ".join(f'"{kw}"' for kw in sorted(keywords)) + ' }'

# Step 7: Write formatted line to TXT file
output_filename = "Extracted_keywords.txt"
with open(output_filename, "w", encoding="utf-8") as f:
    f.write(keywords_line)

# Step 8: Download the TXT file (for Colab users)
files.download(output_filename)

# Step 9: Print extracted keywords
print("Extracted keywords:")
print(keywords_line)
# Out:
# Extracted keywords:
# keywords={ "access", "activities", "advance", "agreement", "amendment", "amendments", "anniversary", "appendix", "applications", "area", "availability", "b", "broadband", "capabilities", "capacity", "cards", "cell", "changes", "channels", "cloud", "communication", "computing", "conditions", "connectivity", "core", "coverage", "cpe", "credit", "credits", "critical", "customer", "daily", "data", "date", "days", "definition", "degradation", "description", "device", "devices", "dispute", "disputes", "downlink", "effective", "effort", "egress", "email", "embb", "end", "enhanced", "enterprise", "equipment", "esim", "event", "f", "faith", "fee", "file", "frequency", "function", "functioning", "g", "gateway", "gateways", "gbps", "general", "geographic", "gigabits", "guaranteed", "high", "hourly", "hours", "id", "ids", "incident", "incidents", "industrial", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "latency", "level", "levels", "loss", "low", "m", "maintenance", "management", "maps", "master", "maximum", "mbps", "measurement", "measurements", "mediation", "medium", "metric", "metrics", "metropolitan", "milliseconds", "minimum", "minute", "mobile", "monitor", "month", "ms", "negotiation", "network", "nexgen", "notice", "notify", "objective", "objectives", "online", "outage", "packet", "parties", "party", "penalties", "percentage", "performance", "period", "phone", "plane", "pm", "point", "policy", "portal", "premises", "prioritization", "priority", "profiles", "provider", "provision", "rate", "region", "reporting", "reports", "requirements", "resolution", "respond", "responsibilities", "review", "round", "rtt", "scope", "segment", "service", "sim", "sla", "slices", "slos", "smartphones", "solutions", "specific", "status", "streaming", "subset", "support", "tablets", "target", "telecom", "termination", "terms", "throughput", "time", "tolerated", "tracking", "traffic", "transfers", "trip", "trt", "type", "updates", "upf", "uplink", "uptime", "usage", "user", "users", "video", "windows", "writing", "x", "xxxx", "zone" }

# %%
import re
import xml.etree.ElementTree as ET

# Load the text
with open("geminiSLA.txt", "r") as file:
    lines = file.readlines()

# Create root element for XML
root = ET.Element("requirements")

# Define basic patterns to match requirements
patterns = [
    (r"latency.*?(less than|under|<)\s*(\d+\.?\d*)\s*ms", "latency"),
    (r"availability.*?(\d+\.?\d*)\s*%", "availability"),
    (r"jitter.*?(up to|less than|<)\s*(\d+\.?\d*)\s*ms", "jitter")
]

# Process each line
for line in lines:
    print(f"Processing line: {line.strip()}")
    for pattern, req_type in patterns:
        match = re.search(pattern, line, re.IGNORECASE)
        if match:
            print(f" Matched {req_type}: {match.groupdict()}")
            req_elem = ET.SubElement(root, "requirement")
            ET.SubElement(req_elem, "type").text = req_type

            # Safely extract named groups
            value = match.groupdict().get("value")
            operator = match.groupdict().get("operator")

            if value:
                ET.SubElement(req_elem, "constraint").text = value
            else:
                print(" No 'value' group found for match:", match.group())

            if operator:
                req_elem.set("operator", operator)

# Save to XML
tree = ET.ElementTree(root)
tree.write("output.xml", encoding="utf-8", xml_declaration=True)

print(" XML generated as 'output.xml'")
# Out:
# Processing line: Service Level Agreement (SLA) - 5G Enhanced Mobile Broadband (eMBB) Service
# Processing line:
# Processing line: Agreement ID: SLA-5G-eMBB-001-20250626
# Processing line: Effective Date: 2025-07-01
# Processing line: Service Provider: NexGen Telecom Inc.
# Processing line: Customer: Enterprise Solutions Corp.
# Processing line: Service Type: 5G Enhanced Mobile Broadband (eMBB) - High-Capacity Data Service
# Processing line:
# Processing line: 1. Service Description
# Processing line:
# Processing line: This SLA outlines the terms and conditions for the provision of a dedicated 5G Enhanced Mobile Broadband (eMBB) service to Enterprise Solutions Corp. This service is designed to deliver high-throughput, low-latency connectivity primarily for data-intensive applications, including but not limited to, cloud computing, high-definition video streaming, and large file transfers.
# Processing line:
# Processing line: 2. Service Scope
# Processing line:
# Processing line: Geographic Coverage: Primary service area: Metropolitan Region X, with secondary coverage in Industrial Zone Y. Specific cell IDs and coverage maps are attached as Appendix A.
# Processing line:
# Processing line: User Devices: Support for 5G-compliant devices (smartphones, tablets, IoT gateways) utilizing the designated SIM cards/eSIM profiles provided by NexGen Telecom Inc.
# Processing line:
# Processing line: Traffic Prioritization: eMBB traffic will receive priority over best-effort traffic within the defined service slices.
# Processing line:
# Processing line: 3. Service Level Objectives (SLOs) and Performance Metrics
# Processing line:
# Processing line: The following performance metrics will be measured and monitored to ensure the agreed-upon service levels are met. All measurements are based on aggregated data over 15-minute intervals, unless otherwise specified.
# Processing line:
# Processing line: 3.1. Throughput (Downlink)
# Processing line:
# Processing line: Objective: Average downlink throughput of 1 Gbps (Gigabits per second).
# Processing line:
# Processing line: Minimum Guaranteed: 750 Mbps.
# Processing line:
# Processing line: Measurement Point: User Plane Function (UPF) egress to customer premises equipment (CPE).
# Processing line:
# Processing line: Reporting Frequency: Daily aggregated reports, monthly detailed reports.
# Processing line:
# Processing line: 3.2. Throughput (Uplink)
# Processing line:
# Processing line: Objective: Average uplink throughput of 200 Mbps.
# Processing line:
# Processing line: Minimum Guaranteed: 150 Mbps.
# Processing line:
# Processing line: Measurement Point: CPE ingress to UPF ingress.
# Processing line:
# Processing line: Reporting Frequency: Daily aggregated reports, monthly detailed reports.
# Processing line:
# Processing line: 3.3. Latency (Round Trip Time - RTT)
# Processing line:
# Processing line: Objective: Average end-to-end latency of less than 10 ms (milliseconds).
#  Matched latency: {}
#  No 'value' group found for match: latency of less than 10 ms
# Processing line:
# Processing line: Maximum Tolerated: 15 ms for 99.9% of traffic.
# Processing line:
# Processing line: Measurement Point: From customer device to designated core network gateway.
# Processing line:
# Processing line: Reporting Frequency: Hourly aggregated reports, weekly detailed reports.
# Processing line:
# Processing line: 3.4. Jitter
# Processing line:
# Processing line: Objective: Maximum jitter of 2 ms.
# Processing line:
# Processing line: Measurement Point: From customer device to designated core network gateway.
# Processing line:
# Processing line: Reporting Frequency: Hourly aggregated reports, weekly detailed reports.
# Processing line:
# Processing line: 3.5. Packet Loss Rate
# Processing line:
# Processing line: Objective: Less than 0.01% packet loss.
# Processing line:
# Processing line: Maximum Tolerated: 0.05%.
# Processing line:
# Processing line: Measurement Point: End-to-end across the 5G network segment.
# Processing line:
# Processing line: Reporting Frequency: Daily aggregated reports.
# Processing line:
# Processing line: 3.6. Service Availability
# Processing line:
# Processing line: Objective: 99.99% availability of the 5G eMBB service within the primary service area.
# Processing line:
# Processing line: Definition: Uptime measured as the percentage of time the service is fully operational and accessible to the customer. Planned maintenance windows are excluded.
# Processing line:
# Processing line: Reporting Frequency: Monthly.
# Processing line:
# Processing line: 4. Service Credits and Penalties
# Processing line:
# Processing line: In the event that NexGen Telecom Inc. fails to meet the agreed-upon Service Level Objectives (SLOs) for a given month, the Customer shall be entitled to service credits as follows:
# Processing line:
# Processing line: Availability:
# Processing line:
# Processing line: 99.9% to < 99.99% availability: 5% service credit on monthly fee.
#  Matched availability: {}
#  No 'value' group found for match: availability: 5%
# Processing line:
# Processing line: 99.0% to < 99.9% availability: 10% service credit on monthly fee.
#  Matched availability: {}
#  No 'value' group found for match: availability: 10%
# Processing line:
# Processing line: < 99.0% availability: 20% service credit on monthly fee.
#  Matched availability: {}
#  No 'value' group found for match: availability: 20%
# Processing line:
# Processing line: Throughput (Downlink/Uplink) - if Minimum Guaranteed is not met for more than 5% of the reporting period: 5% service credit on monthly fee per metric.
# Processing line:
# Processing line: Latency/Packet Loss/Jitter - if Maximum Tolerated is exceeded for more than 1% of the reporting period: 5% service credit on monthly fee per metric.
# Processing line:
# Processing line: Service credits will be applied to the subsequent month's invoice. Total service credits in any given month shall not exceed 25% of the total monthly service fee.
# Processing line:
# Processing line: 5. Responsibilities of the Parties
# Processing line:
# Processing line: 5.1. NexGen Telecom Inc. (Service Provider):
# Processing line:
# Processing line: Maintain the 5G network infrastructure to meet the specified SLOs.
# Processing line:
# Processing line: Provide 24/7 technical support.
# Processing line:
# Processing line: Monitor service performance and provide regular reports to the Customer.
# Processing line:
# Processing line: Notify Customer of planned maintenance activities at least 72 hours in advance.
# Processing line:
# Processing line: Respond to and resolve service incidents within the defined support windows.
# Processing line:
# Processing line: 5.2. Enterprise Solutions Corp. (Customer):
# Processing line:
# Processing line: Provide necessary access to customer premises for equipment installation and maintenance.
# Processing line:
# Processing line: Ensure proper functioning of customer-owned equipment (CPE) and devices.
# Processing line:
# Processing line: Notify NexGen Telecom Inc. promptly of any service issues.
# Processing line:
# Processing line: Adhere to the fair usage policy (if applicable, detailed in Appendix B).
# Processing line:
# Processing line: 6. Support and Incident Management
# Processing line:
# Processing line: 6.1. Support Channels:
# Processing line:
# Processing line: Online Portal: Available 24/7 for incident reporting and tracking.
# Processing line:
# Processing line: Phone Support: [+XX XXXX XXXX] (24/7 for critical incidents, 9 AM - 5 PM M-F for general inquiries).
# Processing line:
# Processing line: Email Support: support@nexgentelecom.com (Monitored 9 AM - 5 PM M-F).
# Processing line:
# Processing line: 6.2. Incident Prioritization:
# Processing line:
# Processing line: Critical (P1): Complete service outage or severe degradation impacting all users. Target Resolution Time (TRT): 4 hours.
# Processing line:
# Processing line: High (P2): Significant service degradation impacting a subset of users or critical applications. TRT: 8 hours.
# Processing line:
# Processing line: Medium (P3): Minor service degradation or intermittent issues. TRT: 24 hours.
# Processing line:
# Processing line: Low (P4): General inquiries or non-service impacting issues. TRT: 48 hours.
# Processing line:
# Processing line: 6.3. Reporting and Communication: NexGen Telecom Inc. will provide regular updates on incident status until resolution.
# Processing line:
# Processing line: 7. Dispute Resolution
# Processing line:
# Processing line: Any disputes arising from this SLA shall first be attempted to be resolved through good-faith negotiation between the parties. If an amicable resolution cannot be reached within 30 days, either party may escalate the dispute to formal mediation.
# Processing line:
# Processing line: 8. Termination
# Processing line:
# Processing line: This SLA may be terminated by either party with 60 days' written notice, subject to the terms of the master service agreement between NexGen Telecom Inc. and Enterprise Solutions Corp.
# Processing line:
# Processing line: 9. Review and Amendment
# Processing line:
# Processing line: This SLA will be reviewed annually on the anniversary of the Effective Date or sooner if significant changes in service requirements or network capabilities occur. Any amendments must be mutually agreed upon in writing.
#  XML generated as 'output.xml'

# %%
for token in doc:
    print(f"Token: {token.text}, POS: {token.pos_}, Dependency: {token.dep_}")
for ent in doc.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Token: Service, POS: PROPN, Dependency: compound
# Token: Level, POS: PROPN, Dependency: compound
# Token: Agreement, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: SLA, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: -, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: nmod
# Token: Enhanced, POS: PROPN, Dependency: amod
# Token: Mobile, POS: PROPN, Dependency: compound
# Token: Broadband, POS: PROPN, Dependency: nmod
# Token: (, POS: PUNCT, Dependency: punct
# Token: eMBB, POS: PROPN, Dependency: nmod
# Token: ), POS: PUNCT, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Agreement, POS: PROPN, Dependency: compound
# Token: ID, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: SLA-5G, POS: PROPN, Dependency: nmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: eMBB-001, POS: NOUN, Dependency: nmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: 20250626, POS: NUM, Dependency: nummod
# Token:
# , POS: SPACE, Dependency: dep
# Token: Effective, POS: PROPN, Dependency: compound
# Token: Date, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 2025, POS: NUM, Dependency: nummod
# Token: -, POS: SYM, Dependency: punct
# Token: 07, POS: NUM, Dependency: nmod
# Token: -, POS: SYM, Dependency: punct
# Token: 01, POS: NUM, Dependency: nummod
# Token:
# , POS: SPACE, Dependency: dep
# Token: Service, POS: PROPN, Dependency: compound
# Token: Provider, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: nmod
# Token:
# , POS: SPACE, Dependency: dep
# Token: Customer, POS: NOUN, Dependency: nmod
# Token: :, POS: PUNCT, Dependency: punct
# Token: Enterprise, POS: PROPN, Dependency: compound
# Token: Solutions, POS: PROPN, Dependency: compound
# Token: Corp., POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Service, POS: PROPN, Dependency: compound
# Token: Type, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: compound
# Token: Enhanced, POS: PROPN, Dependency: amod
# Token: Mobile, POS: PROPN, Dependency: compound
# Token: Broadband, POS: PROPN, Dependency: appos
# Token: (, POS: PUNCT, Dependency: punct
# Token: eMBB, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: -, POS: PUNCT, Dependency: punct
# Token: High, POS: PROPN, Dependency: compound
# Token: -, POS: PUNCT, Dependency: punct
# Token: Capacity, POS: PROPN, Dependency: compound
# Token: Data, POS: PROPN, Dependency: compound
# Token: Service, POS: PROPN, Dependency: appos
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 1, POS: NUM, Dependency: appos
# Token: ., POS: X, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Description, POS: PROPN, Dependency: nsubj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: This, POS: DET, Dependency: det
# Token: SLA, POS: PROPN, Dependency: appos
# Token: outlines, POS: VERB, Dependency: ROOT
# Token: the, POS: DET, Dependency: det
# Token: terms, POS: NOUN, Dependency: dobj
# Token: and, POS: CCONJ, Dependency: cc
# Token: conditions, POS: NOUN, Dependency: conj
# Token: for, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: provision, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: a, POS: DET, Dependency: det
# Token: dedicated, POS: ADJ, Dependency: amod
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: nmod
# Token: Enhanced, POS: ADJ, Dependency: amod
# Token: Mobile, POS: PROPN, Dependency: nmod
# Token: Broadband, POS: PROPN, Dependency: nmod
# Token: (, POS: PUNCT, Dependency: punct
# Token: eMBB, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: service, POS: NOUN, Dependency: pobj
# Token: to, POS: ADP, Dependency: prep
# Token: Enterprise, POS: PROPN, Dependency: compound
# Token: Solutions, POS: PROPN, Dependency: compound
# Token: Corp., POS: PROPN, Dependency: punct
# Token: This, POS: DET, Dependency: det
# Token: service, POS: NOUN, Dependency: nsubjpass
# Token: is, POS: AUX, Dependency: auxpass
# Token: designed, POS: VERB, Dependency: ROOT
# Token: to, POS: PART, Dependency: aux
# Token: deliver, POS: VERB, Dependency: xcomp
# Token: high, POS: ADJ, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: throughput, POS: NOUN, Dependency: nmod
# Token: ,, POS: PUNCT, Dependency: punct
# Token: low, POS: ADJ, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: latency, POS: NOUN, Dependency: compound
# Token: connectivity, POS: NOUN, Dependency: dobj
# Token: primarily, POS: ADV, Dependency: advmod
# Token: for, POS: ADP, Dependency: prep
# Token: data, POS: NOUN, Dependency: npadvmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: intensive, POS: ADJ, Dependency: amod
# Token: applications, POS: NOUN, Dependency: pobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: including, POS: VERB, Dependency: prep
# Token: but, POS: CCONJ, Dependency: cc
# Token: not, POS: PART, Dependency: neg
# Token: limited, POS: VERB, Dependency: conj
# Token: to, POS: ADP, Dependency: prep
# Token: ,, POS: PUNCT, Dependency: punct
# Token: cloud, POS: PROPN, Dependency: compound
# Token: computing, POS: NOUN, Dependency: appos
# Token: ,, POS: PUNCT, Dependency: punct
# Token: high, POS: ADJ, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: definition, POS: NOUN, Dependency: compound
# Token: video, POS: NOUN, Dependency: compound
# Token: streaming, POS: NOUN, Dependency: conj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: and, POS: CCONJ, Dependency: cc
# Token: large, POS: ADJ, Dependency: amod
# Token: file, POS: NOUN, Dependency: compound
# Token: transfers, POS: NOUN, Dependency: conj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 2, POS: X, Dependency: meta
# Token: ., POS: X, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Scope, POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Geographic, POS: PROPN, Dependency: compound
# Token: Coverage, POS: PROPN, Dependency: nsubjpass
# Token: :, POS: PUNCT, Dependency: punct
# Token: Primary, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: area, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Metropolitan, POS: PROPN, Dependency: compound
# Token: Region, POS: PROPN, Dependency: compound
# Token: X, POS: PROPN, Dependency: appos
# Token: ,, POS: PUNCT, Dependency: punct
# Token: with, POS: ADP, Dependency: prep
# Token: secondary, POS: ADJ, Dependency: amod
# Token: coverage, POS: NOUN, Dependency: pobj
# Token: in, POS: ADP, Dependency: prep
# Token: Industrial, POS: PROPN, Dependency: compound
# Token: Zone, POS: PROPN, Dependency: compound
# Token: Y., POS: PROPN, Dependency: compound
# Token: Specific, POS: PROPN, Dependency: compound
# Token: cell, POS: NOUN, Dependency: compound
# Token: IDs, POS: NOUN, Dependency: pobj
# Token: and, POS: CCONJ, Dependency: cc
# Token: coverage, POS: NOUN, Dependency: compound
# Token: maps, POS: NOUN, Dependency: conj
# Token: are, POS: AUX, Dependency: auxpass
# Token: attached, POS: VERB, Dependency: ROOT
# Token: as, POS: ADP, Dependency: prep
# Token: Appendix, POS: PROPN, Dependency: compound
# Token: A., POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: User, POS: PROPN, Dependency: compound
# Token: Devices, POS: PROPN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Support, POS: NOUN, Dependency: appos
# Token: for, POS: ADP, Dependency: prep
# Token: 5G, POS: NOUN, Dependency: npadvmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: compliant, POS: ADJ, Dependency: amod
# Token: devices, POS: NOUN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: smartphones, POS: NOUN, Dependency: appos
# Token: ,, POS: PUNCT, Dependency: punct
# Token: tablets, POS: NOUN, Dependency: conj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: IoT, POS: ADJ, Dependency: amod
# Token: gateways, POS: NOUN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: utilizing, POS: VERB, Dependency: acl
# Token: the, POS: DET, Dependency: det
# Token: designated, POS: VERB, Dependency: amod
# Token: SIM, POS: PROPN, Dependency: nmod
# Token: cards, POS: NOUN, Dependency: nmod
# Token: /, POS: SYM, Dependency: punct
# Token: eSIM, POS: NOUN, Dependency: compound
# Token: profiles, POS: NOUN, Dependency: dobj
# Token: provided, POS: VERB, Dependency: acl
# Token: by, POS: ADP, Dependency: agent
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: nmod
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Traffic, POS: PROPN, Dependency: compound
# Token: Prioritization, POS: PROPN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: eMBB, POS: NOUN, Dependency: appos
# Token: traffic, POS: NOUN, Dependency: nsubj
# Token: will, POS: AUX, Dependency: aux
# Token: receive, POS: VERB, Dependency: conj
# Token: priority, POS: NOUN, Dependency: dobj
# Token: over, POS: ADP, Dependency: prep
# Token: best, POS: ADJ, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: effort, POS: NOUN, Dependency: compound
# Token: traffic, POS: NOUN, Dependency: pobj
# Token: within, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: defined, POS: VERB, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: slices, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3, POS: X, Dependency: ROOT
# Token: ., POS: X, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Level, POS: PROPN, Dependency: compound
# Token: Objectives, POS: PROPN, Dependency: nsubjpass
# Token: (, POS: PUNCT, Dependency: punct
# Token: SLOs, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: and, POS: CCONJ, Dependency: cc
# Token: Performance, POS: PROPN, Dependency: compound
# Token: Metrics, POS: PROPN, Dependency: conj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: The, POS: DET, Dependency: det
# Token: following, POS: VERB, Dependency: amod
# Token: performance, POS: NOUN, Dependency: compound
# Token: metrics, POS: NOUN, Dependency: appos
# Token: will, POS: AUX, Dependency: aux
# Token: be, POS: AUX, Dependency: auxpass
# Token: measured, POS: VERB, Dependency: ROOT
# Token: and, POS: CCONJ, Dependency: cc
# Token: monitored, POS: VERB, Dependency: conj
# Token: to, POS: PART, Dependency: aux
# Token: ensure, POS: VERB, Dependency: xcomp
# Token: the, POS: DET, Dependency: det
# Token: agreed, POS: VERB, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: upon, POS: ADP, Dependency: prt
# Token: service, POS: NOUN, Dependency: compound
# Token: levels, POS: NOUN, Dependency: nsubjpass
# Token: are, POS: AUX, Dependency: auxpass
# Token: met, POS: VERB, Dependency: ccomp
# Token: ., POS: PUNCT, Dependency: punct
# Token: All, POS: DET, Dependency: det
# Token: measurements, POS: NOUN, Dependency: nsubjpass
# Token: are, POS: AUX, Dependency: auxpass
# Token: based, POS: VERB, Dependency: ROOT
# Token: on, POS: ADP, Dependency: prep
# Token: aggregated, POS: VERB, Dependency: amod
# Token: data, POS: NOUN, Dependency: pobj
# Token: over, POS: ADP, Dependency: prep
# Token: 15, POS: NUM, Dependency: nummod
# Token: -, POS: PUNCT, Dependency: punct
# Token: minute, POS: NOUN, Dependency: compound
# Token: intervals, POS: NOUN, Dependency: pobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: unless, POS: SCONJ, Dependency: mark
# Token: otherwise, POS: ADV, Dependency: advmod
# Token: specified, POS: VERB, Dependency: advcl
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.1, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Throughput, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: Downlink, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Average, POS: ADJ, Dependency: amod
# Token: downlink, POS: NOUN, Dependency: compound
# Token: throughput, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: 1, POS: NUM, Dependency: nummod
# Token: Gbps, POS: PROPN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: Gigabits, POS: NOUN, Dependency: appos
# Token: per, POS: ADP, Dependency: prep
# Token: second, POS: ADJ, Dependency: pobj
# Token: ), POS: PUNCT, Dependency: punct
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Minimum, POS: PROPN, Dependency: compound
# Token: Guaranteed, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 750, POS: NUM, Dependency: nummod
# Token: Mbps, POS: PROPN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: compound
# Token: Point, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: User, POS: PROPN, Dependency: compound
# Token: Plane, POS: PROPN, Dependency: compound
# Token: Function, POS: PROPN, Dependency: nmod
# Token: (, POS: PUNCT, Dependency: punct
# Token: UPF, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: egress, POS: NOUN, Dependency: appos
# Token: to, POS: ADP, Dependency: prep
# Token: customer, POS: NOUN, Dependency: compound
# Token: premises, POS: NOUN, Dependency: compound
# Token: equipment, POS: NOUN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: CPE, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: VERB, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: nsubj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Daily, POS: PROPN, Dependency: nsubj
# Token: aggregated, POS: VERB, Dependency: ROOT
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: monthly, POS: ADJ, Dependency: advmod
# Token: detailed, POS: ADJ, Dependency: amod
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.2, POS: NUM, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token: Throughput, POS: PROPN, Dependency: nmod
# Token: (, POS: PUNCT, Dependency: punct
# Token: Uplink, POS: PROPN, Dependency: nmod
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Average, POS: ADJ, Dependency: amod
# Token: uplink, POS: ADJ, Dependency: amod
# Token: throughput, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: 200, POS: NUM, Dependency: nummod
# Token: Mbps, POS: PROPN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Minimum, POS: PROPN, Dependency: compound
# Token: Guaranteed, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 150, POS: NUM, Dependency: nummod
# Token: Mbps, POS: PROPN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: compound
# Token: Point, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: CPE, POS: PROPN, Dependency: compound
# Token: ingress, POS: NOUN, Dependency: appos
# Token: to, POS: ADP, Dependency: prep
# Token: UPF, POS: PROPN, Dependency: compound
# Token: ingress, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: PROPN, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: nsubj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Daily, POS: PROPN, Dependency: nsubj
# Token: aggregated, POS: VERB, Dependency: ROOT
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: monthly, POS: ADJ, Dependency: advmod
# Token: detailed, POS: ADJ, Dependency: amod
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.3, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Latency, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: Round, POS: PROPN, Dependency: compound
# Token: Trip, POS: PROPN, Dependency: compound
# Token: Time, POS: PROPN, Dependency: compound
# Token: -, POS: PUNCT, Dependency: punct
# Token: RTT, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Average, POS: ADJ, Dependency: amod
# Token: end, POS: NOUN, Dependency: nmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: to, POS: ADP, Dependency: prep
# Token: -, POS: PUNCT, Dependency: punct
# Token: end, POS: NOUN, Dependency: pobj
# Token: latency, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: less, POS: ADJ, Dependency: amod
# Token: than, POS: ADP, Dependency: quantmod
# Token: 10, POS: NUM, Dependency: nummod
# Token: ms, POS: NOUN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: milliseconds, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Maximum, POS: PROPN, Dependency: compound
# Token: Tolerated, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 15, POS: NUM, Dependency: nummod
# Token: ms, POS: NOUN, Dependency: appos
# Token: for, POS: ADP, Dependency: prep
# Token: 99.9, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: traffic, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: compound
# Token: Point, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: From, POS: ADP, Dependency: prep
# Token: customer, POS: NOUN, Dependency: compound
# Token: device, POS: NOUN, Dependency: pobj
# Token: to, POS: ADP, Dependency: prep
# Token: designated, POS: VERB, Dependency: amod
# Token: core, POS: NOUN, Dependency: amod
# Token: network, POS: NOUN, Dependency: compound
# Token: gateway, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: PROPN, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Hourly, POS: PROPN, Dependency: nsubj
# Token: aggregated, POS: VERB, Dependency: amod
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: weekly, POS: ADJ, Dependency: amod
# Token: detailed, POS: ADJ, Dependency: amod
# Token: reports, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.4, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Jitter, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Maximum, POS: ADJ, Dependency: amod
# Token: jitter, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: 2, POS: NUM, Dependency: nummod
# Token: ms, POS: PROPN, Dependency: compound
# Token: ., POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: compound
# Token: Point, POS: PROPN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: From, POS: ADP, Dependency: prep
# Token: customer, POS: NOUN, Dependency: compound
# Token: device, POS: NOUN, Dependency: pobj
# Token: to, POS: ADP, Dependency: prep
# Token: designated, POS: VERB, Dependency: amod
# Token: core, POS: NOUN, Dependency: amod
# Token: network, POS: NOUN, Dependency: compound
# Token: gateway, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: PROPN, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Hourly, POS: PROPN, Dependency: nsubj
# Token: aggregated, POS: VERB, Dependency: amod
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: weekly, POS: ADJ, Dependency: amod
# Token: detailed, POS: ADJ, Dependency: amod
# Token: reports, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.5, POS: NUM, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token: Packet, POS: PROPN, Dependency: compound
# Token: Loss, POS: PROPN, Dependency: compound
# Token: Rate, POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Less, POS: ADJ, Dependency: amod
# Token: than, POS: ADP, Dependency: quantmod
# Token: 0.01, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: nmod
# Token: packet, POS: NOUN, Dependency: compound
# Token: loss, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Maximum, POS: PROPN, Dependency: compound
# Token: Tolerated, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 0.05, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: compound
# Token: Point, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: End, POS: NOUN, Dependency: appos
# Token: -, POS: PUNCT, Dependency: punct
# Token: to, POS: ADP, Dependency: prep
# Token: -, POS: PUNCT, Dependency: punct
# Token: end, POS: NOUN, Dependency: pobj
# Token: across, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: compound
# Token: network, POS: NOUN, Dependency: compound
# Token: segment, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: PROPN, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: nsubj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Daily, POS: PROPN, Dependency: nsubj
# Token: aggregated, POS: VERB, Dependency: ROOT
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.6, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Availability, POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 99.99, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: availability, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: compound
# Token: eMBB, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: pobj
# Token: within, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: primary, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: area, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Definition, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Uptime, POS: PROPN, Dependency: nsubj
# Token: measured, POS: VERB, Dependency: acl
# Token: as, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: percentage, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: time, POS: NOUN, Dependency: pobj
# Token: the, POS: DET, Dependency: det
# Token: service, POS: NOUN, Dependency: nsubj
# Token: is, POS: AUX, Dependency: ccomp
# Token: fully, POS: ADV, Dependency: advmod
# Token: operational, POS: ADJ, Dependency: acomp
# Token: and, POS: CCONJ, Dependency: cc
# Token: accessible, POS: ADJ, Dependency: conj
# Token: to, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: customer, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token: Planned, POS: VERB, Dependency: amod
# Token: maintenance, POS: NOUN, Dependency: compound
# Token: windows, POS: NOUN, Dependency: nsubjpass
# Token: are, POS: AUX, Dependency: auxpass
# Token: excluded, POS: VERB, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: PROPN, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Monthly, POS: ADV, Dependency: advmod
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 4, POS: X, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Credits, POS: PROPN, Dependency: nsubjpass
# Token: and, POS: CCONJ, Dependency: cc
# Token: Penalties, POS: PROPN, Dependency: conj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: In, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: event, POS: NOUN, Dependency: pobj
# Token: that, POS: SCONJ, Dependency: mark
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: nsubj
# Token: fails, POS: VERB, Dependency: relcl
# Token: to, POS: PART, Dependency: aux
# Token: meet, POS: VERB, Dependency: xcomp
# Token: the, POS: DET, Dependency: det
# Token: agreed, POS: VERB, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: upon, POS: ADP, Dependency: prt
# Token: Service, POS: PROPN, Dependency: compound
# Token: Level, POS: PROPN, Dependency: compound
# Token: Objectives, POS: PROPN, Dependency: dobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: SLOs, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: for, POS: ADP, Dependency: prep
# Token: a, POS: DET, Dependency: det
# Token: given, POS: VERB, Dependency: amod
# Token: month, POS: NOUN, Dependency: pobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: the, POS: DET, Dependency: det
# Token: Customer, POS: PROPN, Dependency: nsubjpass
# Token: shall, POS: AUX, Dependency: aux
# Token: be, POS: AUX, Dependency: auxpass
# Token: entitled, POS: VERB, Dependency: ROOT
# Token: to, POS: ADP, Dependency: prep
# Token: service, POS: NOUN, Dependency: compound
# Token: credits, POS: NOUN, Dependency: pobj
# Token: as, POS: SCONJ, Dependency: mark
# Token: follows, POS: VERB, Dependency: advcl
# Token: :, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Availability, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 99.9, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: appos
# Token: to, POS: PART, Dependency: aux
# Token: <, POS: X, Dependency: punct
# Token: 99.99, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: availability, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: on, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 99.0, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: nmod
# Token: to, POS: AUX, Dependency: aux
# Token: <, POS: X, Dependency: appos
# Token: 99.9, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: availability, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 10, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: on, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: <, POS: X, Dependency: punct
# Token: 99.0, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: availability, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 20, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: on, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Throughput, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: Downlink, POS: PROPN, Dependency: nmod
# Token: /, POS: SYM, Dependency: punct
# Token: Uplink, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: -, POS: PUNCT, Dependency: punct
# Token: if, POS: SCONJ, Dependency: mark
# Token: Minimum, POS: ADJ, Dependency: compound
# Token: Guaranteed, POS: PROPN, Dependency: nsubjpass
# Token: is, POS: AUX, Dependency: auxpass
# Token: not, POS: PART, Dependency: neg
# Token: met, POS: VERB, Dependency: conj
# Token: for, POS: ADP, Dependency: prep
# Token: more, POS: ADJ, Dependency: amod
# Token: than, POS: ADP, Dependency: quantmod
# Token: 5, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: reporting, POS: NOUN, Dependency: compound
# Token: period, POS: NOUN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: on, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token: per, POS: ADP, Dependency: prep
# Token: metric, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Latency, POS: PROPN, Dependency: nmod
# Token: /, POS: SYM, Dependency: punct
# Token: Packet, POS: PROPN, Dependency: nmod
# Token: Loss, POS: PROPN, Dependency: nmod
# Token: /, POS: SYM, Dependency: punct
# Token: Jitter, POS: PROPN, Dependency: dep
# Token: -, POS: PUNCT, Dependency: punct
# Token: if, POS: SCONJ, Dependency: mark
# Token: Maximum, POS: PROPN, Dependency: compound
# Token: Tolerated, POS: PROPN, Dependency: nsubjpass
# Token: is, POS: AUX, Dependency: auxpass
# Token: exceeded, POS: VERB, Dependency: ROOT
# Token: for, POS: ADP, Dependency: prep
# Token: more, POS: ADJ, Dependency: amod
# Token: than, POS: ADP, Dependency: quantmod
# Token: 1, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: reporting, POS: NOUN, Dependency: compound
# Token: period, POS: NOUN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: on, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token: per, POS: ADP, Dependency: prep
# Token: metric, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Service, POS: NOUN, Dependency: compound
# Token: credits, POS: NOUN, Dependency: nsubjpass
# Token: will, POS: AUX, Dependency: aux
# Token: be, POS: AUX, Dependency: auxpass
# Token: applied, POS: VERB, Dependency: ROOT
# Token: to, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: subsequent, POS: ADJ, Dependency: amod
# Token: month, POS: NOUN, Dependency: poss
# Token: 's, POS: PART, Dependency: case
# Token: invoice, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token: Total, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: credits, POS: NOUN, Dependency: nsubj
# Token: in, POS: ADP, Dependency: prep
# Token: any, POS: DET, Dependency: det
# Token: given, POS: VERB, Dependency: amod
# Token: month, POS: NOUN, Dependency: pobj
# Token: shall, POS: AUX, Dependency: aux
# Token: not, POS: PART, Dependency: neg
# Token: exceed, POS: VERB, Dependency: ROOT
# Token: 25, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: dobj
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: total, POS: ADJ, Dependency: amod
# Token: monthly, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: fee, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 5, POS: X, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Responsibilities, POS: NOUN, Dependency: ROOT
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: Parties, POS: NOUN, Dependency: pobj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 5.1, POS: NUM, Dependency: nummod
# Token: ., POS: PUNCT, Dependency: punct
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: nsubj
# Token: (, POS: PUNCT, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Provider, POS: PROPN, Dependency: appos
# Token: ):, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Maintain, POS: VERB, Dependency: ROOT
# Token: the, POS: DET, Dependency: det
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: compound
# Token: network, POS: NOUN, Dependency: compound
# Token: infrastructure, POS: NOUN, Dependency: dobj
# Token: to, POS: PART, Dependency: aux
# Token: meet, POS: VERB, Dependency: relcl
# Token: the, POS: DET, Dependency: det
# Token: specified, POS: VERB, Dependency: amod
# Token: SLOs, POS: NOUN, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Provide, POS: VERB, Dependency: ROOT
# Token: 24/7, POS: NUM, Dependency: nummod
# Token: technical, POS: ADJ, Dependency: amod
# Token: support, POS: NOUN, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Monitor, POS: PROPN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: performance, POS: NOUN, Dependency: ROOT
# Token: and, POS: CCONJ, Dependency: cc
# Token: provide, POS: VERB, Dependency: conj
# Token: regular, POS: ADJ, Dependency: amod
# Token: reports, POS: NOUN, Dependency: dobj
# Token: to, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: Customer, POS: PROPN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Notify, POS: PROPN, Dependency: compound
# Token: Customer, POS: PROPN, Dependency: ROOT
# Token: of, POS: ADP, Dependency: prep
# Token: planned, POS: VERB, Dependency: amod
# Token: maintenance, POS: NOUN, Dependency: compound
# Token: activities, POS: NOUN, Dependency: pobj
# Token: at, POS: ADV, Dependency: advmod
# Token: least, POS: ADV, Dependency: advmod
# Token: 72, POS: NUM, Dependency: nummod
# Token: hours, POS: NOUN, Dependency: appos
# Token: in, POS: ADP, Dependency: prep
# Token: advance, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Respond, POS: PROPN, Dependency: ROOT
# Token: to, POS: ADP, Dependency: prep
# Token: and, POS: CCONJ, Dependency: cc
# Token: resolve, POS: VERB, Dependency: conj
# Token: service, POS: NOUN, Dependency: compound
# Token: incidents, POS: NOUN, Dependency: dobj
# Token: within, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: defined, POS: VERB, Dependency: amod
# Token: support, POS: NOUN, Dependency: compound
# Token: windows, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 5.2, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Enterprise, POS: PROPN, Dependency: compound
# Token: Solutions, POS: PROPN, Dependency: compound
# Token: Corp., POS: PROPN, Dependency: nsubj
# Token: (, POS: PUNCT, Dependency: punct
# Token: Customer, POS: PROPN, Dependency: appos
# Token: ):, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Provide, POS: VERB, Dependency: ROOT
# Token: necessary, POS: ADJ, Dependency: amod
# Token: access, POS: NOUN, Dependency: dobj
# Token: to, POS: ADP, Dependency: prep
# Token: customer, POS: NOUN, Dependency: compound
# Token: premises, POS: NOUN, Dependency: pobj
# Token: for, POS: ADP, Dependency: prep
# Token: equipment, POS: NOUN, Dependency: compound
# Token: installation, POS: NOUN, Dependency: pobj
# Token: and, POS: CCONJ, Dependency: cc
# Token: maintenance, POS: NOUN, Dependency: conj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Ensure, POS: VERB, Dependency: ROOT
# Token: proper, POS: ADJ, Dependency: amod
# Token: functioning, POS: NOUN, Dependency: dobj
# Token: of, POS: ADP, Dependency: prep
# Token: customer, POS: NOUN, Dependency: npadvmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: owned, POS: VERB, Dependency: amod
# Token: equipment, POS: NOUN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: CPE, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: and, POS: CCONJ, Dependency: cc
# Token: devices, POS: NOUN, Dependency: conj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Notify, POS: VERB, Dependency: ROOT
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: dobj
# Token: promptly, POS: ADV, Dependency: advmod
# Token: of, POS: ADP, Dependency: ROOT
# Token: any, POS: DET, Dependency: det
# Token: service, POS: NOUN, Dependency: compound
# Token: issues, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Adhere, POS: ADV, Dependency: ROOT
# Token: to, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: fair, POS: ADJ, Dependency: amod
# Token: usage, POS: NOUN, Dependency: compound
# Token: policy, POS: NOUN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: if, POS: SCONJ, Dependency: mark
# Token: applicable, POS: ADJ, Dependency: advcl
# Token: ,, POS: PUNCT, Dependency: punct
# Token: detailed, POS: VERB, Dependency: conj
# Token: in, POS: ADP, Dependency: prep
# Token: Appendix, POS: PROPN, Dependency: compound
# Token: B, POS: PROPN, Dependency: pobj
# Token: ), POS: PUNCT, Dependency: punct
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 6, POS: X, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Support, POS: PROPN, Dependency: nmod
# Token: and, POS: CCONJ, Dependency: cc
# Token: Incident, POS: PROPN, Dependency: conj
# Token: Management, POS: PROPN, Dependency: ROOT
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 6.1, POS: NUM, Dependency: nummod
# Token: ., POS: PUNCT, Dependency: punct
# Token: Support, POS: PROPN, Dependency: compound
# Token: Channels, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Online, POS: PROPN, Dependency: compound
# Token: Portal, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Available, POS: ADJ, Dependency: amod
# Token: 24/7, POS: NUM, Dependency: npadvmod
# Token: for, POS: ADP, Dependency: prep
# Token: incident, POS: NOUN, Dependency: compound
# Token: reporting, POS: NOUN, Dependency: pobj
# Token: and, POS: CCONJ, Dependency: cc
# Token: tracking, POS: NOUN, Dependency: conj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Phone, POS: PROPN, Dependency: compound
# Token: Support, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: [, POS: X, Dependency: nmod
# Token: +, POS: X, Dependency: nmod
# Token: XX, POS: X, Dependency: compound
# Token: XXXX, POS: NOUN, Dependency: compound
# Token: XXXX, POS: NOUN, Dependency: appos
# Token: ], POS: PUNCT, Dependency: punct
# Token: (, POS: PUNCT, Dependency: punct
# Token: 24/7, POS: NUM, Dependency: appos
# Token: for, POS: ADP, Dependency: prep
# Token: critical, POS: ADJ, Dependency: amod
# Token: incidents, POS: NOUN, Dependency: pobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: 9, POS: NUM, Dependency: nummod
# Token: AM, POS: NOUN, Dependency: nmod
# Token: -, POS: SYM, Dependency: punct
# Token: 5, POS: NUM, Dependency: prep
# Token: PM, POS: PROPN, Dependency: compound
# Token: M, POS: PROPN, Dependency: compound
# Token: -, POS: PUNCT, Dependency: punct
# Token: F, POS: PROPN, Dependency: conj
# Token: for, POS: ADP, Dependency: prep
# Token: general, POS: ADJ, Dependency: amod
# Token: inquiries, POS: NOUN, Dependency: pobj
# Token: ), POS: PUNCT, Dependency: punct
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Email, POS: PROPN, Dependency: compound
# Token: Support, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: support@nexgentelecom.com, POS: X, Dependency: appos
# Token: (, POS: PUNCT, Dependency: punct
# Token: Monitored, POS: VERB, Dependency: parataxis
# Token: 9, POS: NUM, Dependency: nummod
# Token: AM, POS: PROPN, Dependency: npadvmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: PM, POS: PROPN, Dependency: compound
# Token: M, POS: PROPN, Dependency: compound
# Token: -, POS: PUNCT, Dependency: punct
# Token: F, POS: PROPN, Dependency: npadvmod
# Token: ), POS: PUNCT, Dependency: punct
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 6.2, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Incident, POS: PROPN, Dependency: compound
# Token: Prioritization, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Critical, POS: PROPN, Dependency: appos
# Token: (, POS: PUNCT, Dependency: punct
# Token: P1, POS: PROPN, Dependency: appos
# Token: ):, POS: PUNCT, Dependency: punct
# Token: Complete, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: outage, POS: NOUN, Dependency: appos
# Token: or, POS: CCONJ, Dependency: cc
# Token: severe, POS: ADJ, Dependency: amod
# Token: degradation, POS: NOUN, Dependency: conj
# Token: impacting, POS: VERB, Dependency: acl
# Token: all, POS: DET, Dependency: det
# Token: users, POS: NOUN, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token: Target, POS: PROPN, Dependency: compound
# Token: Resolution, POS: PROPN, Dependency: compound
# Token: Time, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: TRT, POS: PROPN, Dependency: appos
# Token: ):, POS: PUNCT, Dependency: punct
# Token: 4, POS: NUM, Dependency: nummod
# Token: hours, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: High, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: P2, POS: NOUN, Dependency: appos
# Token: ):, POS: PUNCT, Dependency: punct
# Token: Significant, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: degradation, POS: NOUN, Dependency: appos
# Token: impacting, POS: VERB, Dependency: acl
# Token: a, POS: DET, Dependency: det
# Token: subset, POS: NOUN, Dependency: dobj
# Token: of, POS: ADP, Dependency: prep
# Token: users, POS: NOUN, Dependency: pobj
# Token: or, POS: CCONJ, Dependency: cc
# Token: critical, POS: ADJ, Dependency: amod
# Token: applications, POS: NOUN, Dependency: conj
# Token: ., POS: PUNCT, Dependency: punct
# Token: TRT, POS: PROPN, Dependency: nmod
# Token: :, POS: PUNCT, Dependency: punct
# Token: 8, POS: NUM, Dependency: nummod
# Token: hours, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Medium, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: P3, POS: PROPN, Dependency: appos
# Token: ):, POS: PUNCT, Dependency: punct
# Token: Minor, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: degradation, POS: NOUN, Dependency: appos
# Token: or, POS: CCONJ, Dependency: cc
# Token: intermittent, POS: ADJ, Dependency: amod
# Token: issues, POS: NOUN, Dependency: conj
# Token: ., POS: PUNCT, Dependency: punct
# Token: TRT, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 24, POS: NUM, Dependency: nummod
# Token: hours, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Low, POS: PROPN, Dependency: nmod
# Token: (, POS: PUNCT, Dependency: punct
# Token: P4, POS: NOUN, Dependency: nmod
# Token: ):, POS: PUNCT, Dependency: punct
# Token: General, POS: PROPN, Dependency: compound
# Token: inquiries, POS: NOUN, Dependency: ROOT
# Token: or, POS: CCONJ, Dependency: cc
# Token: non, POS: ADJ, Dependency: amod
# Token: -, POS: ADJ, Dependency: amod
# Token: service, POS: ADJ, Dependency: amod
# Token: impacting, POS: VERB, Dependency: amod
# Token: issues, POS: NOUN, Dependency: conj
# Token: ., POS: PUNCT, Dependency: punct
# Token: TRT, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 48, POS: NUM, Dependency: nummod
# Token: hours, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 6.3, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Reporting, POS: NOUN, Dependency: nsubj
# Token: and, POS: CCONJ, Dependency: cc
# Token: Communication, POS: PROPN, Dependency: conj
# Token: :, POS: PUNCT, Dependency: punct
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: nsubj
# Token: will, POS: AUX, Dependency: aux
# Token: provide, POS: VERB, Dependency: ROOT
# Token: regular, POS: ADJ, Dependency: amod
# Token: updates, POS: NOUN, Dependency: dobj
# Token: on, POS: ADP, Dependency: prep
# Token: incident, POS: NOUN, Dependency: compound
# Token: status, POS: NOUN, Dependency: pobj
# Token: until, POS: ADP, Dependency: prep
# Token: resolution, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 7, POS: X, Dependency: meta
# Token: ., POS: PUNCT, Dependency: punct
# Token: Dispute, POS: PROPN, Dependency: compound
# Token: Resolution, POS: PROPN, Dependency: ROOT
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Any, POS: DET, Dependency: det
# Token: disputes, POS: NOUN, Dependency: nsubjpass
# Token: arising, POS: VERB, Dependency: acl
# Token: from, POS: ADP, Dependency: prep
# Token: this, POS: DET, Dependency: det
# Token: SLA, POS: PROPN, Dependency: pobj
# Token: shall, POS: AUX, Dependency: aux
# Token: first, POS: ADV, Dependency: advmod
# Token: be, POS: AUX, Dependency: auxpass
# Token: attempted, POS: VERB, Dependency: relcl
# Token: to, POS: PART, Dependency: aux
# Token: be, POS: AUX, Dependency: auxpass
# Token: resolved, POS: VERB, Dependency: xcomp
# Token: through, POS: ADP, Dependency: prep
# Token: good, POS: ADJ, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: faith, POS: NOUN, Dependency: compound
# Token: negotiation, POS: NOUN, Dependency: pobj
# Token: between, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: parties, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token: If, POS: SCONJ, Dependency: mark
# Token: an, POS: DET, Dependency: det
# Token: amicable, POS: ADJ, Dependency: amod
# Token: resolution, POS: NOUN, Dependency: nsubjpass
# Token: can, POS: AUX, Dependency: aux
# Token: not, POS: PART, Dependency: neg
# Token: be, POS: AUX, Dependency: auxpass
# Token: reached, POS: VERB, Dependency: advcl
# Token: within, POS: ADP, Dependency: prep
# Token: 30, POS: NUM, Dependency: nummod
# Token: days, POS: NOUN, Dependency: pobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: either, POS: DET, Dependency: det
# Token: party, POS: NOUN, Dependency: nsubj
# Token: may, POS: AUX, Dependency: aux
# Token: escalate, POS: VERB, Dependency: ROOT
# Token: the, POS: DET, Dependency: det
# Token: dispute, POS: NOUN, Dependency: dobj
# Token: to, POS: ADP, Dependency: prep
# Token: formal, POS: ADJ, Dependency: amod
# Token: mediation, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 8, POS: X, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token: Termination, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: This, POS: DET, Dependency: det
# Token: SLA, POS: PROPN, Dependency: nsubjpass
# Token: may, POS: AUX, Dependency: aux
# Token: be, POS: AUX, Dependency: auxpass
# Token: terminated, POS: VERB, Dependency: ROOT
# Token: by, POS: ADP, Dependency: agent
# Token: either, POS: DET, Dependency: det
# Token: party, POS: NOUN, Dependency: pobj
# Token: with, POS: ADP, Dependency: prep
# Token: 60, POS: NUM, Dependency: nummod
# Token: days, POS: NOUN, Dependency: poss
# Token: ', POS: PART, Dependency: case
# Token: written, POS: VERB, Dependency: amod
# Token: notice, POS: NOUN, Dependency: pobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: subject, POS: ADJ, Dependency: oprd
# Token: to, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: terms, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: master, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: agreement, POS: NOUN, Dependency: pobj
# Token: between, POS: ADP, Dependency: prep
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: pobj
# Token: and, POS: CCONJ, Dependency: cc
# Token: Enterprise, POS: PROPN, Dependency: compound
# Token: Solutions, POS: PROPN, Dependency: compound
# Token: Corp., POS: PROPN, Dependency: conj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 9, POS: NUM, Dependency: npadvmod
# Token: ., POS: PUNCT, Dependency: punct
# Token: Review, POS: PROPN, Dependency: nsubjpass
# Token: and, POS: CCONJ, Dependency: cc
# Token: Amendment, POS: PROPN, Dependency: conj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: This, POS: DET, Dependency: det
# Token: SLA, POS: PROPN, Dependency: conj
# Token: will, POS: AUX, Dependency: aux
# Token: be, POS: AUX, Dependency: auxpass
# Token: reviewed, POS: VERB, Dependency: ROOT
# Token: annually, POS: ADV, Dependency: advmod
# Token: on, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: anniversary, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: Effective, POS: PROPN, Dependency: compound
# Token: Date, POS: PROPN, Dependency: pobj
# Token: or, POS: CCONJ, Dependency: cc
# Token: sooner, POS: ADV, Dependency: advmod
# Token: if, POS: SCONJ, Dependency: mark
# Token: significant, POS: ADJ, Dependency: amod
# Token: changes, POS: NOUN, Dependency: nsubj
# Token: in, POS: ADP, Dependency: prep
# Token: service, POS: NOUN, Dependency: compound
# Token: requirements, POS: NOUN, Dependency: pobj
# Token: or, POS: CCONJ, Dependency: cc
# Token: network, POS: NOUN, Dependency: compound
# Token: capabilities, POS: NOUN, Dependency: conj
# Token: occur, POS: VERB, Dependency: conj
# Token: ., POS: PUNCT, Dependency: punct
# Token: Any, POS: DET, Dependency: det
# Token: amendments, POS: NOUN, Dependency: nsubjpass
# Token: must, POS: AUX, Dependency: aux
# Token: be, POS: AUX, Dependency: auxpass
# Token: mutually, POS: ADV, Dependency: advmod
# Token: agreed, POS: VERB, Dependency: ROOT
# Token: upon, POS: SCONJ, Dependency: prep
# Token: in, POS: ADP, Dependency: prep
# Token: writing, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Entity: 5, Label: CARDINAL
# Entity: 20250626, Label: DATE
# Entity: Effective Date, Label: ORG
# Entity: 2025-07-01, Label: DATE
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 1, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: cloud computing, Label: PERSON
# Entity: 2, Label: CARDINAL
# Entity: Service Scope
#
# Geographic Coverage: Primary, Label: ORG
# Entity: Appendix A.
#
# User Devices: Support, Label: PERSON
# Entity: 5G, Label: CARDINAL
# Entity: IoT, Label: ORG
# Entity: SIM, Label: ORG
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 3, Label: CARDINAL
# Entity: Performance Metrics, Label: ORG
# Entity: 15-minute, Label: TIME
# Entity: 3.1, Label: CARDINAL
# Entity: Downlink, Label: PERSON
# Entity: 1, Label: CARDINAL
# Entity: second, Label: ORDINAL
# Entity: 750, Label: CARDINAL
# Entity: Mbps, Label: PERSON
# Entity: CPE, Label: ORG
# Entity: monthly, Label: DATE
# Entity: 3.2, Label: CARDINAL
# Entity: 200, Label: CARDINAL
# Entity: 150, Label: CARDINAL
# Entity: Mbps, Label: PERSON
# Entity: monthly, Label: DATE
# Entity: 3.3, Label: CARDINAL
# Entity: less than 10, Label: CARDINAL
# Entity: 15, Label: CARDINAL
# Entity: 99.9%, Label: PERCENT
# Entity: Hourly, Label: TIME
# Entity: weekly, Label: DATE
# Entity: 3.4, Label: CARDINAL
# Entity: 2, Label: CARDINAL
# Entity: Hourly, Label: TIME
# Entity: weekly, Label: DATE
# Entity: 3.5, Label: CARDINAL
# Entity: Packet Loss Rate
#
# , Label: ORG
# Entity: Less than 0.01%, Label: PERCENT
# Entity: 0.05%, Label: PERCENT
# Entity: 5, Label: CARDINAL
# Entity: 3.6, Label: CARDINAL
# Entity: 99.99%, Label: PERCENT
# Entity: 5, Label: CARDINAL
# Entity: Monthly, Label: DATE
# Entity: 4, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: Service Level Objectives, Label: ORG
# Entity: a given month, Label: DATE
# Entity: Customer, Label: ORG
# Entity: 99.9%, Label: PERCENT
# Entity: 99.99%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 99.0%, Label: PERCENT
# Entity: 99.9%, Label: PERCENT
# Entity: 10%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 99.0%, Label: PERCENT
# Entity: 20%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: more than 5%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: Maximum Tolerated, Label: PERSON
# Entity: more than 1%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: month, Label: DATE
# Entity: any given month, Label: DATE
# Entity: 25%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 5, Label: CARDINAL
# Entity: 5.1, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 24/7, Label: CARDINAL
# Entity: Customer, Label: ORG
# Entity: Respond, Label: PERSON
# Entity: 5.2, Label: CARDINAL
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: Customer, Label: ORG
# Entity: CPE, Label: ORG
# Entity: Notify NexGen Telecom Inc., Label: ORG
# Entity: Appendix, Label: NORP
# Entity: 6, Label: CARDINAL
# Entity: 6.1, Label: CARDINAL
# Entity: 9 AM - 5 PM M-F, Label: TIME
# Entity: Email Support, Label: PERSON
# Entity: 9 AM - 5 PM M-F, Label: TIME
# Entity: 6.2, Label: CARDINAL
# Entity: Target Resolution Time, Label: ORG
# Entity: TRT, Label: ORG
# Entity: 4 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 8 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 24 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 48 hours, Label: TIME
# Entity: 6.3, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 7, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: first, Label: ORDINAL
# Entity: 30 days, Label: DATE
# Entity: 8, Label: CARDINAL
# Entity: 60 days', Label: DATE
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: 9, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: annually, Label: DATE
# Entity: the Effective Date, Label: ORG

# %%
# First keyword set
keywords1 = {
   "availability", "db", "downlink", "environments", "hours", "jitter",
    "latency", "loss", "mbps", "milliseconds", "minutes", "mission", "network", "noise",
    "session", "setup", "signal", "streaming", "throughput", "time", "urllc", "reliability", "packet", "qos",
    "acceptance", "notifies", "Business Days", "requirements", "obligations", "agreement", "acme",
    "agreementid",  "coveragearea", "customer", "days", "deliverymethod", "edge",
    "effectivedate", "elements", "format", "frequency", "gbps", "general",
    "measurementperiod", "metrics", "mobile", "monitoring", "ms", "networks",
   "penalties", "performance", "priority", "provider",
   "recipient", "refund", "region", "release", "remedies", "renewal", "target", "termination",
   "terms", "threshold", "uplink", "usecases",
}

# Second keyword set
keywords2={ "access", "activities", "advance", "agreement",  "appendix", "applications", "area", "availability", "broadband", "capabilities", "capacity", "cards", "cell", "changes", "channels", "cloud", "communication", "computing", "conditions", "connectivity", "core", "coverage", "cpe", "credit", "credits", "critical", "customer", "daily", "data", "date", "days", "definition", "degradation", "description", "device", "devices", "dispute", "disputes", "downlink", "effective", "effort", "egress", "email", "embb", "end", "enhanced", "enterprise", "equipment", "esim", "event", "fee", "file", "frequency", "function", "functioning", "gateway", "gateways", "gbps", "general", "gigabits", "guaranteed", "high", "hourly", "hours", "id", "ids", "incident", "incidents", "industrial", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "latency", "level", "levels", "loss", "low", "maintenance", "management", "maximum", "mbps", "measurement", "measurements", "medium", "metric", "metrics", "metropolitan", "milliseconds", "minimum", "minute", "mobile", "monitor", "month", "ms", "negotiation", "network", "nexgen", "notice", "notify", "objective", "objectives", "online", "outage", "packet", "parties", "party", "penalties", "percentage", "performance", "period", "phone", "plane", "pm", "point", "policy", "portal", "premises", "prioritization", "priority", "profiles", "provider", "provision", "rate", "region", "reporting", "reports", "requirements", "resolution", "respond", "responsibilities", "review", "scope", "segment", "service", "sim", "sla", "slices", "slos", "solutions", "specific", "status", "streaming", "subset", "support", "target", "telecom", "termination", "terms", "throughput", "time", "traffic", "transfers", "type", "updates", "uplink", "uptime", "usage", "user", "users", "video" }

# Merge sets without duplicates
merged_keywords = keywords1.union(keywords2)

# Create a sorted list of quoted keywords
keywords = sorted(f'"{kw}"' for kw in merged_keywords)

# Format the final string
output_string = "keywords={ " + ", ".join(keywords) + " }"

# Print in desired format
print("keywords={ " + ", ".join(keywords) + " }")

# Save to a .txt file
with open("merged_keywords.txt", "w", encoding="utf-8") as file:
    file.write(output_string)

print("Keywords saved to merged_keywords.txt")
# Out:
# keywords={ "Business Days", "acceptance", "access", "acme", "activities", "advance", "agreement", "agreementid", "appendix", "applications", "area", "availability", "broadband", "capabilities", "capacity", "cards", "cell", "changes", "channels", "cloud", "communication", "computing", "conditions", "connectivity", "core", "coverage", "coveragearea", "cpe", "credit", "credits", "critical", "customer", "daily", "data", "date", "days", "db", "definition", "degradation", "deliverymethod", "description", "device", "devices", "dispute", "disputes", "downlink", "edge", "effective", "effectivedate", "effort", "egress", "elements", "email", "embb", "end", "enhanced", "enterprise", "environments", "equipment", "esim", "event", "fee", "file", "format", "frequency", "function", "functioning", "gateway", "gateways", "gbps", "general", "gigabits", "guaranteed", "high", "hourly", "hours", "id", "ids", "incident", "incidents", "industrial", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "latency", "level", "levels", "loss", "low", "maintenance", "management", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "medium", "metric", "metrics", "metropolitan", "milliseconds", "minimum", "minute", "minutes", "mission", "mobile", "monitor", "monitoring", "month", "ms", "negotiation", "network", "networks", "nexgen", "noise", "notice", "notifies", "notify", "objective", "objectives", "obligations", "online", "outage", "packet", "parties", "party", "penalties", "percentage", "performance", "period", "phone", "plane", "pm", "point", "policy", "portal", "premises", "prioritization", "priority", "profiles", "provider", "provision", "qos", "rate", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "reporting", "reports", "requirements", "resolution", "respond", "responsibilities", "review", "scope", "segment", "service", "session", "setup", "signal", "sim", "sla", "slices", "slos", "solutions", "specific", "status", "streaming", "subset", "support", "target", "telecom", "termination", "terms", "threshold", "throughput", "time", "traffic", "transfers", "type", "updates", "uplink", "uptime", "urllc", "usage", "usecases", "user", "users", "video" }
# Keywords saved to merged_keywords.txt

# %%
keywords={ "Business Days", "acceptance", "access", "acme", "activities", "advance", "agreement", "agreementid", "appendix", "applications", "area", "availability", "broadband", "capabilities", "capacity", "cards", "cell", "changes", "channels", "cloud", "communication", "computing", "conditions", "connectivity", "core", "coverage", "coveragearea", "cpe", "credit", "credits", "critical", "customer", "daily", "data", "date", "days", "db", "definition", "degradation", "deliverymethod", "description", "device", "devices", "dispute", "disputes", "downlink", "edge", "effective", "effectivedate", "effort", "egress", "elements", "email", "embb", "end", "enhanced", "enterprise", "environments", "equipment", "esim", "event", "fee", "file", "format", "frequency", "function", "functioning", "gateway", "gateways", "gbps", "general", "gigabits", "guaranteed", "high", "hourly", "hours", "id", "ids", "incident", "incidents", "industrial", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "latency", "level", "levels", "loss", "low", "maintenance", "management", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "medium", "metric", "metrics", "metropolitan", "milliseconds", "minimum", "minute", "minutes", "mission", "mobile", "monitor", "monitoring", "month", "ms", "negotiation", "network", "networks", "nexgen", "noise", "notice", "notifies", "notify", "objective", "objectives", "obligations", "online", "outage", "packet", "parties", "party", "penalties", "percentage", "performance", "period", "phone", "plane", "pm", "point", "policy", "portal", "premises", "prioritization", "priority", "profiles", "provider", "provision", "qos", "rate", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "reporting", "reports", "requirements", "resolution", "respond", "responsibilities", "review", "scope", "segment", "service", "session", "setup", "signal", "sim", "sla", "slices", "slos", "solutions", "specific", "status", "streaming", "subset", "support", "target", "telecom", "termination", "terms", "threshold", "throughput", "time", "traffic", "transfers", "type", "updates", "uplink", "uptime", "urllc", "usage", "usecases", "user", "users", "video" }


for token in doc:
    if token.text.lower() in keywords:
        print(f"\nKeyword: {token.text}")
        for child in token.children:
            print(f"  -> Child: {child.text} ({child.dep_}, {child.pos_})")
        for ancestor in token.ancestors:
            print(f"  <- Ancestor: {ancestor.text} ({ancestor.dep_}, {ancestor.pos_})")
# Out:
# Keyword: Service
#   <- Ancestor: Level (compound, PROPN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Level
#   -> Child: Service (compound, PROPN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Agreement
#   -> Child: Level (compound, PROPN)
#   -> Child: SLA (appos, PROPN)
#   -> Child: - (punct, PUNCT)
#   -> Child: ID (appos, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Date (appos, NOUN)
#   -> Child: 1 (appos, NUM)
#   -> Child: . (punct, X)
#
# Keyword: SLA
#   -> Child: ( (punct, PUNCT)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Enhanced
#   <- Ancestor: Broadband (nmod, PROPN)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Mobile
#   <- Ancestor: Broadband (nmod, PROPN)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Broadband
#   -> Child: Enhanced (amod, PROPN)
#   -> Child: Mobile (compound, PROPN)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: eMBB
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Service
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Agreement (compound, PROPN)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Agreement
#   -> Child: Service (compound, PROPN)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: ID
#   -> Child: G (nmod, NOUN)
#   -> Child: Broadband (nmod, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: eMBB (nmod, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: Agreement (compound, PROPN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Effective
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Date
#   -> Child: SLA-5G (nmod, PROPN)
#   -> Child: eMBB-001 (nmod, NOUN)
#   -> Child: Effective (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Provider (appos, PROPN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Service
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Provider
#   -> Child: 2025 (nummod, NUM)
#   -> Child: - (punct, SYM)
#   -> Child: 01 (nummod, NUM)
#   -> Child: Service (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Type (appos, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Broadband (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: NexGen
#   <- Ancestor: Inc. (nmod, PROPN)
#   <- Ancestor: Customer (nmod, NOUN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Telecom
#   <- Ancestor: Inc. (nmod, PROPN)
#   <- Ancestor: Customer (nmod, NOUN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Customer
#   -> Child: Inc. (nmod, PROPN)
#   -> Child: : (punct, PUNCT)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Enterprise
#   <- Ancestor: Corp. (compound, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Solutions
#   <- Ancestor: Corp. (compound, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Service
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Type
#   -> Child: Customer (nmod, NOUN)
#   -> Child: Corp. (compound, PROPN)
#   -> Child: Service (compound, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Enhanced
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Mobile
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Broadband
#   -> Child: G (compound, NOUN)
#   -> Child: Enhanced (amod, PROPN)
#   -> Child: Mobile (compound, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: eMBB (appos, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: - (punct, PUNCT)
#   -> Child: Service (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: eMBB
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: High
#   <- Ancestor: Capacity (compound, PROPN)
#   <- Ancestor: Service (appos, PROPN)
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Capacity
#   -> Child: High (compound, PROPN)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: Service (appos, PROPN)
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Data
#   <- Ancestor: Service (appos, PROPN)
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Service
#   -> Child: Capacity (compound, PROPN)
#   -> Child: Data (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (ROOT, PROPN)
#
# Keyword: Service
#   <- Ancestor: Description (nsubj, PROPN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Description
#   -> Child: Service (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: SLA (appos, PROPN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: SLA
#   -> Child: This (det, DET)
#   <- Ancestor: Description (nsubj, PROPN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: terms
#   -> Child: the (det, DET)
#   -> Child: and (cc, CCONJ)
#   -> Child: conditions (conj, NOUN)
#   -> Child: for (prep, ADP)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: conditions
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: provision
#   -> Child: the (det, DET)
#   -> Child: of (prep, ADP)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Enhanced
#   <- Ancestor: Broadband (nmod, PROPN)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Mobile
#   <- Ancestor: Broadband (nmod, PROPN)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Broadband
#   -> Child: Enhanced (amod, ADJ)
#   -> Child: Mobile (nmod, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: eMBB (appos, PROPN)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: eMBB
#   <- Ancestor: Broadband (nmod, PROPN)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: service
#   -> Child: a (det, DET)
#   -> Child: dedicated (amod, ADJ)
#   -> Child: G (nmod, NOUN)
#   -> Child: Broadband (nmod, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: to (prep, ADP)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Enterprise
#   <- Ancestor: Corp. (punct, PROPN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Solutions
#   <- Ancestor: Corp. (punct, PROPN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: service
#   -> Child: This (det, DET)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: high
#   <- Ancestor: throughput (nmod, NOUN)
#   <- Ancestor: connectivity (dobj, NOUN)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: throughput
#   -> Child: high (amod, ADJ)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: connectivity (dobj, NOUN)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: low
#   <- Ancestor: latency (compound, NOUN)
#   <- Ancestor: connectivity (dobj, NOUN)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: latency
#   -> Child: low (amod, ADJ)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: connectivity (dobj, NOUN)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: connectivity
#   -> Child: throughput (nmod, NOUN)
#   -> Child: , (punct, PUNCT)
#   -> Child: latency (compound, NOUN)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: data
#   <- Ancestor: intensive (amod, ADJ)
#   <- Ancestor: applications (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: applications
#   -> Child: intensive (amod, ADJ)
#   -> Child: , (punct, PUNCT)
#   -> Child: including (prep, VERB)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: cloud
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: computing
#   -> Child: cloud (compound, PROPN)
#   -> Child: , (punct, PUNCT)
#   -> Child: streaming (conj, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: high
#   <- Ancestor: definition (compound, NOUN)
#   <- Ancestor: streaming (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: definition
#   -> Child: high (amod, ADJ)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: streaming (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: video
#   <- Ancestor: streaming (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: streaming
#   -> Child: definition (compound, NOUN)
#   -> Child: video (compound, NOUN)
#   -> Child: , (punct, PUNCT)
#   -> Child: and (cc, CCONJ)
#   -> Child: transfers (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: file
#   <- Ancestor: transfers (conj, NOUN)
#   <- Ancestor: streaming (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: transfers
#   -> Child: large (amod, ADJ)
#   -> Child: file (compound, NOUN)
#   <- Ancestor: streaming (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: Service
#   <- Ancestor: Scope (compound, PROPN)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Scope
#   -> Child: Service (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Coverage
#   -> Child: 2 (meta, X)
#   -> Child: . (punct, X)
#   -> Child: Scope (compound, PROPN)
#   -> Child: Geographic (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: area (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: X (appos, PROPN)
#   -> Child: , (punct, PUNCT)
#   -> Child: with (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: area (appos, NOUN)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: area
#   -> Child: Primary (amod, ADJ)
#   -> Child: service (compound, NOUN)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Metropolitan
#   <- Ancestor: Region (compound, PROPN)
#   <- Ancestor: X (appos, PROPN)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Region
#   -> Child: Metropolitan (compound, PROPN)
#   <- Ancestor: X (appos, PROPN)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: coverage
#   -> Child: secondary (amod, ADJ)
#   -> Child: in (prep, ADP)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Industrial
#   <- Ancestor: Zone (compound, PROPN)
#   <- Ancestor: IDs (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Specific
#   -> Child: Y. (compound, PROPN)
#   <- Ancestor: IDs (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: cell
#   <- Ancestor: IDs (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: IDs
#   -> Child: Zone (compound, PROPN)
#   -> Child: Specific (compound, PROPN)
#   -> Child: cell (compound, NOUN)
#   -> Child: and (cc, CCONJ)
#   -> Child: maps (conj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: coverage
#   <- Ancestor: maps (conj, NOUN)
#   <- Ancestor: IDs (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Appendix
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: User
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Devices
#   -> Child: Appendix (compound, PROPN)
#   -> Child: A. (compound, NOUN)
#   -> Child: User (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Support (appos, NOUN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Support
#   -> Child: for (prep, ADP)
#   -> Child: utilizing (acl, VERB)
#   -> Child: : (punct, PUNCT)
#   -> Child: eMBB (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: devices
#   -> Child: compliant (amod, ADJ)
#   -> Child: ( (punct, PUNCT)
#   -> Child: smartphones (appos, NOUN)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: gateways
#   -> Child: IoT (amod, ADJ)
#   <- Ancestor: tablets (conj, NOUN)
#   <- Ancestor: smartphones (appos, NOUN)
#   <- Ancestor: devices (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: SIM
#   <- Ancestor: cards (nmod, NOUN)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: cards
#   -> Child: SIM (nmod, PROPN)
#   -> Child: / (punct, SYM)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: eSIM
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: profiles
#   -> Child: the (det, DET)
#   -> Child: designated (amod, VERB)
#   -> Child: cards (nmod, NOUN)
#   -> Child: eSIM (compound, NOUN)
#   -> Child: provided (acl, VERB)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: NexGen
#   <- Ancestor: Inc. (nmod, PROPN)
#   <- Ancestor: Prioritization (pobj, PROPN)
#   <- Ancestor: by (agent, ADP)
#   <- Ancestor: provided (acl, VERB)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Telecom
#   <- Ancestor: Inc. (nmod, PROPN)
#   <- Ancestor: Prioritization (pobj, PROPN)
#   <- Ancestor: by (agent, ADP)
#   <- Ancestor: provided (acl, VERB)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Traffic
#   <- Ancestor: Prioritization (pobj, PROPN)
#   <- Ancestor: by (agent, ADP)
#   <- Ancestor: provided (acl, VERB)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Prioritization
#   -> Child: Inc. (nmod, PROPN)
#   -> Child: Traffic (compound, PROPN)
#   <- Ancestor: by (agent, ADP)
#   <- Ancestor: provided (acl, VERB)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: eMBB
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: traffic
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: priority
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: effort
#   -> Child: best (amod, ADJ)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: traffic (pobj, NOUN)
#   <- Ancestor: over (prep, ADP)
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: traffic
#   -> Child: effort (compound, NOUN)
#   <- Ancestor: over (prep, ADP)
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: slices (pobj, NOUN)
#   <- Ancestor: within (prep, ADP)
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: slices
#   -> Child: the (det, DET)
#   -> Child: defined (amod, VERB)
#   -> Child: service (compound, NOUN)
#   <- Ancestor: within (prep, ADP)
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Service
#   <- Ancestor: Level (compound, PROPN)
#   <- Ancestor: Objectives (nsubjpass, PROPN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: Level
#   -> Child: Service (compound, PROPN)
#   <- Ancestor: Objectives (nsubjpass, PROPN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: Objectives
#   -> Child: Level (compound, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: SLOs (appos, PROPN)
#   -> Child: metrics (appos, NOUN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: SLOs
#   -> Child: ) (punct, PUNCT)
#   -> Child: and (cc, CCONJ)
#   -> Child: Metrics (conj, PROPN)
#   <- Ancestor: Objectives (nsubjpass, PROPN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: Performance
#   <- Ancestor: Metrics (conj, PROPN)
#   <- Ancestor: SLOs (appos, PROPN)
#   <- Ancestor: Objectives (nsubjpass, PROPN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: Metrics
#   -> Child: Performance (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: SLOs (appos, PROPN)
#   <- Ancestor: Objectives (nsubjpass, PROPN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: performance
#   <- Ancestor: metrics (appos, NOUN)
#   <- Ancestor: Objectives (nsubjpass, PROPN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: metrics
#   -> Child: The (det, DET)
#   -> Child: following (amod, VERB)
#   -> Child: performance (compound, NOUN)
#   <- Ancestor: Objectives (nsubjpass, PROPN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: levels (nsubjpass, NOUN)
#   <- Ancestor: met (ccomp, VERB)
#   <- Ancestor: ensure (xcomp, VERB)
#   <- Ancestor: monitored (conj, VERB)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: levels
#   -> Child: the (det, DET)
#   -> Child: agreed (amod, VERB)
#   -> Child: service (compound, NOUN)
#   <- Ancestor: met (ccomp, VERB)
#   <- Ancestor: ensure (xcomp, VERB)
#   <- Ancestor: monitored (conj, VERB)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: measurements
#   -> Child: All (det, DET)
#   <- Ancestor: based (ROOT, VERB)
#
# Keyword: data
#   -> Child: aggregated (amod, VERB)
#   -> Child: over (prep, ADP)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: based (ROOT, VERB)
#
# Keyword: minute
#   -> Child: 15 (nummod, NUM)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: intervals (pobj, NOUN)
#   <- Ancestor: over (prep, ADP)
#   <- Ancestor: data (pobj, NOUN)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: based (ROOT, VERB)
#
# Keyword: intervals
#   -> Child: minute (compound, NOUN)
#   <- Ancestor: over (prep, ADP)
#   <- Ancestor: data (pobj, NOUN)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: based (ROOT, VERB)
#
# Keyword: Throughput
#   -> Child: ( (punct, PUNCT)
#   -> Child: Downlink (appos, PROPN)
#
# Keyword: Downlink
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: Objective
#   -> Child: : (punct, PUNCT)
#   -> Child: throughput (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: downlink
#   <- Ancestor: throughput (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: throughput
#   -> Child: Average (amod, ADJ)
#   -> Child: downlink (compound, NOUN)
#   -> Child: of (prep, ADP)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Gbps
#   -> Child: 1 (nummod, NUM)
#   -> Child: ( (punct, PUNCT)
#   -> Child: Gigabits (appos, NOUN)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: throughput (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Gigabits
#   -> Child: per (prep, ADP)
#   <- Ancestor: Gbps (pobj, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: throughput (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Minimum
#   <- Ancestor: Guaranteed (ROOT, PROPN)
#
# Keyword: Guaranteed
#   -> Child: Minimum (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Mbps (appos, PROPN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Mbps
#   -> Child: 750 (nummod, NUM)
#   <- Ancestor: Guaranteed (ROOT, PROPN)
#
# Keyword: Measurement
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: Point
#   -> Child: Measurement (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: egress (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: User
#   <- Ancestor: Function (nmod, PROPN)
#   <- Ancestor: egress (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: Plane
#   <- Ancestor: Function (nmod, PROPN)
#   <- Ancestor: egress (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: Function
#   -> Child: User (compound, PROPN)
#   -> Child: Plane (compound, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: UPF (appos, PROPN)
#   <- Ancestor: egress (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: egress
#   -> Child: Function (nmod, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: to (prep, ADP)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: customer
#   <- Ancestor: premises (compound, NOUN)
#   <- Ancestor: equipment (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: egress (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: premises
#   -> Child: customer (compound, NOUN)
#   <- Ancestor: equipment (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: egress (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: equipment
#   -> Child: premises (compound, NOUN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: CPE (appos, PROPN)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: egress (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: CPE
#   <- Ancestor: equipment (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: egress (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: Reporting
#   <- Ancestor: Frequency (nsubj, PROPN)
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: Frequency
#   -> Child: Reporting (compound, VERB)
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: Daily
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: reports
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: reports
#   -> Child: detailed (amod, ADJ)
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: Throughput
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Uplink
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Objective
#   -> Child: Throughput (nmod, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: Uplink (nmod, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: throughput (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: uplink
#   <- Ancestor: throughput (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: throughput
#   -> Child: Average (amod, ADJ)
#   -> Child: uplink (amod, ADJ)
#   -> Child: of (prep, ADP)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Mbps
#   -> Child: 200 (nummod, NUM)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: throughput (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Minimum
#   <- Ancestor: Guaranteed (ROOT, PROPN)
#
# Keyword: Guaranteed
#   -> Child: Minimum (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Mbps (appos, PROPN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Mbps
#   -> Child: 150 (nummod, NUM)
#   <- Ancestor: Guaranteed (ROOT, PROPN)
#
# Keyword: Measurement
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: Point
#   -> Child: Measurement (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: ingress (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: CPE
#   <- Ancestor: ingress (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: ingress
#   -> Child: CPE (compound, PROPN)
#   -> Child: to (prep, ADP)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: ingress
#   -> Child: UPF (compound, PROPN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: ingress (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: Reporting
#   <- Ancestor: Frequency (nsubj, PROPN)
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: Frequency
#   -> Child: Reporting (compound, PROPN)
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: Daily
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: reports
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: reports
#   -> Child: detailed (amod, ADJ)
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: Latency
#   -> Child: RTT (appos, PROPN)
#
# Keyword: Time
#   <- Ancestor: RTT (appos, PROPN)
#   <- Ancestor: Latency (ROOT, PROPN)
#
# Keyword: Objective
#   -> Child: : (punct, PUNCT)
#   -> Child: latency (appos, NOUN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: . (punct, PUNCT)
#
# Keyword: end
#   -> Child: - (punct, PUNCT)
#   -> Child: to (prep, ADP)
#   <- Ancestor: latency (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: end
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: end (nmod, NOUN)
#   <- Ancestor: latency (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: latency
#   -> Child: Average (amod, ADJ)
#   -> Child: end (nmod, NOUN)
#   -> Child: of (prep, ADP)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: ms
#   -> Child: 10 (nummod, NUM)
#   -> Child: milliseconds (appos, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: latency (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: milliseconds
#   -> Child: ( (punct, PUNCT)
#   <- Ancestor: ms (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: latency (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Maximum
#   <- Ancestor: Tolerated (ROOT, PROPN)
#
# Keyword: ms
#   -> Child: 15 (nummod, NUM)
#   -> Child: for (prep, ADP)
#   <- Ancestor: Tolerated (ROOT, PROPN)
#
# Keyword: traffic
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: ms (appos, NOUN)
#   <- Ancestor: Tolerated (ROOT, PROPN)
#
# Keyword: Measurement
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: Point
#   -> Child: Measurement (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: From (prep, ADP)
#   -> Child: . (punct, PUNCT)
#
# Keyword: customer
#   <- Ancestor: device (pobj, NOUN)
#   <- Ancestor: From (prep, ADP)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: device
#   -> Child: customer (compound, NOUN)
#   <- Ancestor: From (prep, ADP)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: core
#   <- Ancestor: gateway (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: From (prep, ADP)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: network
#   <- Ancestor: gateway (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: From (prep, ADP)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: gateway
#   -> Child: designated (amod, VERB)
#   -> Child: core (amod, NOUN)
#   -> Child: network (compound, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: From (prep, ADP)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: Reporting
#   <- Ancestor: Frequency (ROOT, PROPN)
#
# Keyword: Frequency
#   -> Child: Reporting (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: reports (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Hourly
#   <- Ancestor: aggregated (amod, VERB)
#   <- Ancestor: reports (appos, NOUN)
#   <- Ancestor: Frequency (ROOT, PROPN)
#
# Keyword: reports
#   <- Ancestor: aggregated (amod, VERB)
#   <- Ancestor: reports (appos, NOUN)
#   <- Ancestor: Frequency (ROOT, PROPN)
#
# Keyword: reports
#   -> Child: aggregated (amod, VERB)
#   -> Child: weekly (amod, ADJ)
#   -> Child: detailed (amod, ADJ)
#   <- Ancestor: Frequency (ROOT, PROPN)
#
# Keyword: Jitter
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Objective
#   -> Child: Jitter (compound, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: jitter (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: From (prep, ADP)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Maximum
#   <- Ancestor: jitter (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: jitter
#   -> Child: Maximum (amod, ADJ)
#   -> Child: of (prep, ADP)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: ms
#   <- Ancestor: Point (pobj, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: jitter (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Measurement
#   <- Ancestor: Point (pobj, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: jitter (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Point
#   -> Child: 2 (nummod, NUM)
#   -> Child: ms (compound, PROPN)
#   -> Child: . (compound, PROPN)
#   -> Child: Measurement (compound, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: jitter (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: customer
#   <- Ancestor: device (pobj, NOUN)
#   <- Ancestor: From (prep, ADP)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: device
#   -> Child: customer (compound, NOUN)
#   <- Ancestor: From (prep, ADP)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: core
#   <- Ancestor: gateway (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: From (prep, ADP)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: network
#   <- Ancestor: gateway (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: From (prep, ADP)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: gateway
#   -> Child: designated (amod, VERB)
#   -> Child: core (amod, NOUN)
#   -> Child: network (compound, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: From (prep, ADP)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Reporting
#   <- Ancestor: Frequency (ROOT, PROPN)
#
# Keyword: Frequency
#   -> Child: Reporting (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: reports (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#   -> Child: 3.5 (appos, NUM)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Hourly
#   <- Ancestor: aggregated (amod, VERB)
#   <- Ancestor: reports (appos, NOUN)
#   <- Ancestor: Frequency (ROOT, PROPN)
#
# Keyword: reports
#   <- Ancestor: aggregated (amod, VERB)
#   <- Ancestor: reports (appos, NOUN)
#   <- Ancestor: Frequency (ROOT, PROPN)
#
# Keyword: reports
#   -> Child: aggregated (amod, VERB)
#   -> Child: weekly (amod, ADJ)
#   -> Child: detailed (amod, ADJ)
#   <- Ancestor: Frequency (ROOT, PROPN)
#
# Keyword: Packet
#   <- Ancestor: Loss (compound, PROPN)
#   <- Ancestor: Rate (compound, PROPN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Loss
#   -> Child: Packet (compound, PROPN)
#   <- Ancestor: Rate (compound, PROPN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Rate
#   -> Child: Loss (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Objective
#   -> Child: Rate (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: loss (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: packet
#   <- Ancestor: loss (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: loss
#   -> Child: % (nmod, NOUN)
#   -> Child: packet (compound, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Maximum
#   <- Ancestor: Tolerated (ROOT, PROPN)
#
# Keyword: Measurement
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: Point
#   -> Child: Measurement (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: End (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: End
#   -> Child: - (punct, PUNCT)
#   -> Child: to (prep, ADP)
#   -> Child: across (prep, ADP)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: end
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: End (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: network
#   <- Ancestor: segment (pobj, NOUN)
#   <- Ancestor: across (prep, ADP)
#   <- Ancestor: End (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: segment
#   -> Child: the (det, DET)
#   -> Child: G (compound, NOUN)
#   -> Child: network (compound, NOUN)
#   <- Ancestor: across (prep, ADP)
#   <- Ancestor: End (appos, NOUN)
#   <- Ancestor: Point (ROOT, PROPN)
#
# Keyword: Reporting
#   <- Ancestor: Frequency (nsubj, PROPN)
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: Frequency
#   -> Child: Reporting (compound, PROPN)
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: Daily
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: reports
#   <- Ancestor: aggregated (ROOT, VERB)
#
# Keyword: Service
#   <- Ancestor: Availability (compound, PROPN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Availability
#   -> Child: Service (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Objective
#   -> Child: Availability (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: availability (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: availability
#   -> Child: % (compound, NOUN)
#   -> Child: of (prep, ADP)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: eMBB
#   -> Child: G (compound, NOUN)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: availability (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: service
#   -> Child: the (det, DET)
#   -> Child: eMBB (compound, NOUN)
#   -> Child: within (prep, ADP)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: availability (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: service
#   <- Ancestor: area (pobj, NOUN)
#   <- Ancestor: within (prep, ADP)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: availability (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: area
#   -> Child: the (det, DET)
#   -> Child: primary (amod, ADJ)
#   -> Child: service (compound, NOUN)
#   <- Ancestor: within (prep, ADP)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: availability (appos, NOUN)
#   <- Ancestor: Objective (ROOT, NOUN)
#
# Keyword: Definition
#   -> Child: : (punct, PUNCT)
#   -> Child: measured (acl, VERB)
#
# Keyword: Uptime
#   <- Ancestor: measured (acl, VERB)
#   <- Ancestor: Definition (ROOT, NOUN)
#
# Keyword: percentage
#   -> Child: the (det, DET)
#   -> Child: of (prep, ADP)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: measured (acl, VERB)
#   <- Ancestor: Definition (ROOT, NOUN)
#
# Keyword: time
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: percentage (pobj, NOUN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: measured (acl, VERB)
#   <- Ancestor: Definition (ROOT, NOUN)
#
# Keyword: service
#   -> Child: the (det, DET)
#   <- Ancestor: is (ccomp, AUX)
#   <- Ancestor: measured (acl, VERB)
#   <- Ancestor: Definition (ROOT, NOUN)
#
# Keyword: customer
#   -> Child: the (det, DET)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: accessible (conj, ADJ)
#   <- Ancestor: operational (acomp, ADJ)
#   <- Ancestor: is (ccomp, AUX)
#   <- Ancestor: measured (acl, VERB)
#   <- Ancestor: Definition (ROOT, NOUN)
#
# Keyword: maintenance
#   <- Ancestor: windows (nsubjpass, NOUN)
#   <- Ancestor: excluded (ROOT, VERB)
#
# Keyword: Reporting
#   <- Ancestor: Frequency (ROOT, PROPN)
#
# Keyword: Frequency
#   -> Child: Reporting (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Monthly (advmod, ADV)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Service
#   <- Ancestor: Credits (nsubjpass, PROPN)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: Credits
#   -> Child: Service (compound, PROPN)
#   -> Child: and (cc, CCONJ)
#   -> Child: Penalties (conj, PROPN)
#   -> Child: In (prep, ADP)
#   -> Child: fails (relcl, VERB)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: Penalties
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Credits (nsubjpass, PROPN)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: event
#   -> Child: the (det, DET)
#   <- Ancestor: In (prep, ADP)
#   <- Ancestor: Credits (nsubjpass, PROPN)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: NexGen
#   <- Ancestor: Inc. (nsubj, PROPN)
#   <- Ancestor: fails (relcl, VERB)
#   <- Ancestor: Credits (nsubjpass, PROPN)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: Telecom
#   <- Ancestor: Inc. (nsubj, PROPN)
#   <- Ancestor: fails (relcl, VERB)
#   <- Ancestor: Credits (nsubjpass, PROPN)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: Service
#   <- Ancestor: Level (compound, PROPN)
#   <- Ancestor: Objectives (dobj, PROPN)
#   <- Ancestor: meet (xcomp, VERB)
#   <- Ancestor: fails (relcl, VERB)
#   <- Ancestor: Credits (nsubjpass, PROPN)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: Level
#   -> Child: Service (compound, PROPN)
#   <- Ancestor: Objectives (dobj, PROPN)
#   <- Ancestor: meet (xcomp, VERB)
#   <- Ancestor: fails (relcl, VERB)
#   <- Ancestor: Credits (nsubjpass, PROPN)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: Objectives
#   -> Child: the (det, DET)
#   -> Child: agreed (amod, VERB)
#   -> Child: Level (compound, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: SLOs (appos, PROPN)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: meet (xcomp, VERB)
#   <- Ancestor: fails (relcl, VERB)
#   <- Ancestor: Credits (nsubjpass, PROPN)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: SLOs
#   <- Ancestor: Objectives (dobj, PROPN)
#   <- Ancestor: meet (xcomp, VERB)
#   <- Ancestor: fails (relcl, VERB)
#   <- Ancestor: Credits (nsubjpass, PROPN)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: month
#   -> Child: a (det, DET)
#   -> Child: given (amod, VERB)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: meet (xcomp, VERB)
#   <- Ancestor: fails (relcl, VERB)
#   <- Ancestor: Credits (nsubjpass, PROPN)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: Customer
#   -> Child: the (det, DET)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: credits (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: credits
#   -> Child: service (compound, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: entitled (ROOT, VERB)
#
# Keyword: Availability
#   -> Child: : (punct, PUNCT)
#   -> Child: % (appos, NOUN)
#   -> Child: < (punct, X)
#   -> Child: availability (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: availability
#   -> Child: % (compound, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: credit (appos, NOUN)
#   <- Ancestor: Availability (ROOT, NOUN)
#
# Keyword: service
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: availability (appos, NOUN)
#   <- Ancestor: Availability (ROOT, NOUN)
#
# Keyword: credit
#   -> Child: % (compound, NOUN)
#   -> Child: service (compound, NOUN)
#   -> Child: on (prep, ADP)
#   <- Ancestor: availability (appos, NOUN)
#   <- Ancestor: Availability (ROOT, NOUN)
#
# Keyword: fee
#   -> Child: monthly (amod, ADJ)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: availability (appos, NOUN)
#   <- Ancestor: Availability (ROOT, NOUN)
#
# Keyword: availability
#   -> Child: % (compound, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: credit (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#   <- Ancestor: % (nmod, NOUN)
#   <- Ancestor: availability (ROOT, NOUN)
#
# Keyword: service
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: availability (appos, NOUN)
#   <- Ancestor: % (nmod, NOUN)
#   <- Ancestor: availability (ROOT, NOUN)
#
# Keyword: credit
#   -> Child: % (compound, NOUN)
#   -> Child: service (compound, NOUN)
#   -> Child: on (prep, ADP)
#   <- Ancestor: availability (appos, NOUN)
#   <- Ancestor: % (nmod, NOUN)
#   <- Ancestor: availability (ROOT, NOUN)
#
# Keyword: fee
#   -> Child: monthly (amod, ADJ)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: availability (appos, NOUN)
#   <- Ancestor: % (nmod, NOUN)
#   <- Ancestor: availability (ROOT, NOUN)
#
# Keyword: availability
#   -> Child: % (nmod, NOUN)
#   -> Child: % (compound, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: credit (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: service
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: availability (ROOT, NOUN)
#
# Keyword: credit
#   -> Child: % (compound, NOUN)
#   -> Child: service (compound, NOUN)
#   -> Child: on (prep, ADP)
#   <- Ancestor: availability (ROOT, NOUN)
#
# Keyword: fee
#   -> Child: monthly (amod, ADJ)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: availability (ROOT, NOUN)
#
# Keyword: Throughput
#   -> Child: ( (punct, PUNCT)
#   -> Child: Uplink (appos, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: - (punct, PUNCT)
#   -> Child: met (conj, VERB)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Downlink
#   <- Ancestor: Uplink (appos, PROPN)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: Uplink
#   -> Child: Downlink (nmod, PROPN)
#   -> Child: / (punct, SYM)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: Minimum
#   <- Ancestor: Guaranteed (nsubjpass, PROPN)
#   <- Ancestor: met (conj, VERB)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: Guaranteed
#   -> Child: Minimum (compound, ADJ)
#   <- Ancestor: met (conj, VERB)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: reporting
#   <- Ancestor: period (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: met (conj, VERB)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: period
#   -> Child: the (det, DET)
#   -> Child: reporting (compound, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: met (conj, VERB)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: service
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: met (conj, VERB)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: credit
#   -> Child: % (compound, NOUN)
#   -> Child: service (compound, NOUN)
#   -> Child: on (prep, ADP)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: met (conj, VERB)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: fee
#   -> Child: monthly (amod, ADJ)
#   -> Child: per (prep, ADP)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: met (conj, VERB)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: metric
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: fee (pobj, NOUN)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: met (conj, VERB)
#   <- Ancestor: Throughput (ROOT, PROPN)
#
# Keyword: Latency
#   <- Ancestor: Jitter (dep, PROPN)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: Packet
#   <- Ancestor: Jitter (dep, PROPN)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: Loss
#   <- Ancestor: Jitter (dep, PROPN)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: Jitter
#   -> Child: Latency (nmod, PROPN)
#   -> Child: / (punct, SYM)
#   -> Child: Packet (nmod, PROPN)
#   -> Child: Loss (nmod, PROPN)
#   -> Child: / (punct, SYM)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: Maximum
#   <- Ancestor: Tolerated (nsubjpass, PROPN)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: reporting
#   <- Ancestor: period (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: period
#   -> Child: the (det, DET)
#   -> Child: reporting (compound, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: credit
#   -> Child: % (compound, NOUN)
#   -> Child: service (compound, NOUN)
#   -> Child: on (prep, ADP)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: fee
#   -> Child: monthly (amod, ADJ)
#   -> Child: per (prep, ADP)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: metric
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: fee (pobj, NOUN)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: exceeded (ROOT, VERB)
#
# Keyword: Service
#   <- Ancestor: credits (nsubjpass, NOUN)
#   <- Ancestor: applied (ROOT, VERB)
#
# Keyword: credits
#   -> Child: Service (compound, NOUN)
#   <- Ancestor: applied (ROOT, VERB)
#
# Keyword: month
#   -> Child: the (det, DET)
#   -> Child: subsequent (amod, ADJ)
#   -> Child: 's (case, PART)
#   <- Ancestor: invoice (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: applied (ROOT, VERB)
#
# Keyword: invoice
#   -> Child: month (poss, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: applied (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: credits (nsubj, NOUN)
#   <- Ancestor: exceed (ROOT, VERB)
#
# Keyword: credits
#   -> Child: Total (amod, ADJ)
#   -> Child: service (compound, NOUN)
#   -> Child: in (prep, ADP)
#   <- Ancestor: exceed (ROOT, VERB)
#
# Keyword: month
#   -> Child: any (det, DET)
#   -> Child: given (amod, VERB)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: credits (nsubj, NOUN)
#   <- Ancestor: exceed (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: fee (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (dobj, NOUN)
#   <- Ancestor: exceed (ROOT, VERB)
#
# Keyword: fee
#   -> Child: the (det, DET)
#   -> Child: total (amod, ADJ)
#   -> Child: monthly (amod, ADJ)
#   -> Child: service (compound, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (dobj, NOUN)
#   <- Ancestor: exceed (ROOT, VERB)
#
# Keyword: Responsibilities
#   -> Child: of (prep, ADP)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Parties
#   -> Child: the (det, DET)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: 5.1 (nummod, NUM)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: Responsibilities (ROOT, NOUN)
#
# Keyword: NexGen
# ...
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: access (dobj, NOUN)
#   <- Ancestor: Provide (ROOT, VERB)
#
# Keyword: functioning
#   -> Child: proper (amod, ADJ)
#   -> Child: of (prep, ADP)
#   <- Ancestor: Ensure (ROOT, VERB)
#
# Keyword: customer
#   <- Ancestor: owned (amod, VERB)
#   <- Ancestor: equipment (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: functioning (dobj, NOUN)
#   <- Ancestor: Ensure (ROOT, VERB)
#
# Keyword: equipment
#   -> Child: owned (amod, VERB)
#   -> Child: ( (punct, PUNCT)
#   -> Child: CPE (appos, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: and (cc, CCONJ)
#   -> Child: devices (conj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: functioning (dobj, NOUN)
#   <- Ancestor: Ensure (ROOT, VERB)
#
# Keyword: CPE
#   <- Ancestor: equipment (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: functioning (dobj, NOUN)
#   <- Ancestor: Ensure (ROOT, VERB)
#
# Keyword: devices
#   <- Ancestor: equipment (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: functioning (dobj, NOUN)
#   <- Ancestor: Ensure (ROOT, VERB)
#
# Keyword: Notify
#   -> Child: Inc. (dobj, PROPN)
#
# Keyword: NexGen
#   <- Ancestor: Inc. (dobj, PROPN)
#   <- Ancestor: Notify (ROOT, VERB)
#
# Keyword: Telecom
#   <- Ancestor: Inc. (dobj, PROPN)
#   <- Ancestor: Notify (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: issues (pobj, NOUN)
#   <- Ancestor: of (ROOT, ADP)
#
# Keyword: issues
#   -> Child: any (det, DET)
#   -> Child: service (compound, NOUN)
#   <- Ancestor: of (ROOT, ADP)
#
# Keyword: usage
#   <- Ancestor: policy (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: Adhere (ROOT, ADV)
#
# Keyword: policy
#   -> Child: the (det, DET)
#   -> Child: fair (amod, ADJ)
#   -> Child: usage (compound, NOUN)
#   -> Child: ( (punct, PUNCT)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: Adhere (ROOT, ADV)
#
# Keyword: Appendix
#   <- Ancestor: B (pobj, PROPN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: detailed (conj, VERB)
#   <- Ancestor: applicable (advcl, ADJ)
#   <- Ancestor: Adhere (ROOT, ADV)
#
# Keyword: Support
#   -> Child: and (cc, CCONJ)
#   -> Child: Incident (conj, PROPN)
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: Incident
#   <- Ancestor: Support (nmod, PROPN)
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: Management
#   -> Child: Support (nmod, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: 6.1 (nummod, NUM)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Support
#   <- Ancestor: Channels (ROOT, PROPN)
#
# Keyword: Channels
#   -> Child: Support (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Portal (appos, PROPN)
#   -> Child: Available (amod, ADJ)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Online
#   <- Ancestor: Portal (appos, PROPN)
#   <- Ancestor: Channels (ROOT, PROPN)
#
# Keyword: Portal
#   -> Child: Online (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   <- Ancestor: Channels (ROOT, PROPN)
#
# Keyword: incident
#   <- Ancestor: reporting (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: Available (amod, ADJ)
#   <- Ancestor: Channels (ROOT, PROPN)
#
# Keyword: reporting
#   -> Child: incident (compound, NOUN)
#   -> Child: and (cc, CCONJ)
#   -> Child: tracking (conj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: Available (amod, ADJ)
#   <- Ancestor: Channels (ROOT, PROPN)
#
# Keyword: Phone
#   <- Ancestor: Support (ROOT, NOUN)
#
# Keyword: Support
#   -> Child: Phone (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: XXXX (appos, NOUN)
#   -> Child: ] (punct, PUNCT)
#   -> Child: 24/7 (appos, NUM)
#   -> Child: . (punct, PUNCT)
#
# Keyword: critical
#   <- Ancestor: incidents (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: 24/7 (appos, NUM)
#   <- Ancestor: Support (ROOT, NOUN)
#
# Keyword: incidents
#   -> Child: critical (amod, ADJ)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: 24/7 (appos, NUM)
#   <- Ancestor: Support (ROOT, NOUN)
#
# Keyword: PM
#   <- Ancestor: F (conj, PROPN)
#   <- Ancestor: 24/7 (appos, NUM)
#   <- Ancestor: Support (ROOT, NOUN)
#
# Keyword: general
#   <- Ancestor: inquiries (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: F (conj, PROPN)
#   <- Ancestor: 24/7 (appos, NUM)
#   <- Ancestor: Support (ROOT, NOUN)
#
# Keyword: inquiries
#   -> Child: general (amod, ADJ)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: F (conj, PROPN)
#   <- Ancestor: 24/7 (appos, NUM)
#   <- Ancestor: Support (ROOT, NOUN)
#
# Keyword: Email
#   <- Ancestor: Support (ROOT, PROPN)
#
# Keyword: Support
#   -> Child: Email (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: support@nexgentelecom.com (appos, X)
#   -> Child: . (punct, PUNCT)
#
# Keyword: PM
#   <- Ancestor: F (npadvmod, PROPN)
#   <- Ancestor: Monitored (parataxis, VERB)
#   <- Ancestor: support@nexgentelecom.com (appos, X)
#   <- Ancestor: Support (ROOT, PROPN)
#
# Keyword: Incident
#   <- Ancestor: Prioritization (ROOT, PROPN)
#
# Keyword: Prioritization
#   -> Child: Incident (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Critical (appos, PROPN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Critical
#   -> Child: P1 (appos, PROPN)
#   -> Child: outage (appos, NOUN)
#   <- Ancestor: Prioritization (ROOT, PROPN)
#
# Keyword: service
#   <- Ancestor: outage (appos, NOUN)
#   <- Ancestor: Critical (appos, PROPN)
#   <- Ancestor: Prioritization (ROOT, PROPN)
#
# Keyword: outage
#   -> Child: Complete (amod, ADJ)
#   -> Child: service (compound, NOUN)
#   -> Child: or (cc, CCONJ)
#   -> Child: degradation (conj, NOUN)
#   <- Ancestor: Critical (appos, PROPN)
#   <- Ancestor: Prioritization (ROOT, PROPN)
#
# Keyword: degradation
#   -> Child: severe (amod, ADJ)
#   -> Child: impacting (acl, VERB)
#   <- Ancestor: outage (appos, NOUN)
#   <- Ancestor: Critical (appos, PROPN)
#   <- Ancestor: Prioritization (ROOT, PROPN)
#
# Keyword: users
#   -> Child: all (det, DET)
#   <- Ancestor: impacting (acl, VERB)
#   <- Ancestor: degradation (conj, NOUN)
#   <- Ancestor: outage (appos, NOUN)
#   <- Ancestor: Critical (appos, PROPN)
#   <- Ancestor: Prioritization (ROOT, PROPN)
#
# Keyword: Target
#   <- Ancestor: Time (ROOT, PROPN)
#
# Keyword: Resolution
#   <- Ancestor: Time (ROOT, PROPN)
#
# Keyword: Time
#   -> Child: Target (compound, PROPN)
#   -> Child: Resolution (compound, PROPN)
#   -> Child: TRT (appos, PROPN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: hours
#   -> Child: 4 (nummod, NUM)
#   <- Ancestor: TRT (appos, PROPN)
#   <- Ancestor: Time (ROOT, PROPN)
#
# Keyword: High
#   -> Child: P2 (appos, NOUN)
#   -> Child: degradation (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: service
#   <- Ancestor: degradation (appos, NOUN)
#   <- Ancestor: High (ROOT, PROPN)
#
# Keyword: degradation
#   -> Child: Significant (amod, ADJ)
#   -> Child: service (compound, NOUN)
#   -> Child: impacting (acl, VERB)
#   <- Ancestor: High (ROOT, PROPN)
#
# Keyword: subset
#   -> Child: a (det, DET)
#   -> Child: of (prep, ADP)
#   <- Ancestor: impacting (acl, VERB)
#   <- Ancestor: degradation (appos, NOUN)
#   <- Ancestor: High (ROOT, PROPN)
#
# Keyword: users
#   -> Child: or (cc, CCONJ)
#   -> Child: applications (conj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: subset (dobj, NOUN)
#   <- Ancestor: impacting (acl, VERB)
#   <- Ancestor: degradation (appos, NOUN)
#   <- Ancestor: High (ROOT, PROPN)
#
# Keyword: critical
#   <- Ancestor: applications (conj, NOUN)
#   <- Ancestor: users (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: subset (dobj, NOUN)
#   <- Ancestor: impacting (acl, VERB)
#   <- Ancestor: degradation (appos, NOUN)
#   <- Ancestor: High (ROOT, PROPN)
#
# Keyword: applications
#   -> Child: critical (amod, ADJ)
#   <- Ancestor: users (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: subset (dobj, NOUN)
#   <- Ancestor: impacting (acl, VERB)
#   <- Ancestor: degradation (appos, NOUN)
#   <- Ancestor: High (ROOT, PROPN)
#
# Keyword: hours
#   -> Child: 8 (nummod, NUM)
#   <- Ancestor: TRT (nmod, PROPN)
#   <- Ancestor: Medium (ROOT, PROPN)
#
# Keyword: Medium
#   -> Child: TRT (nmod, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: P3 (appos, PROPN)
#   -> Child: degradation (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: service
#   <- Ancestor: degradation (appos, NOUN)
#   <- Ancestor: Medium (ROOT, PROPN)
#
# Keyword: degradation
#   -> Child: Minor (amod, ADJ)
#   -> Child: service (compound, NOUN)
#   -> Child: or (cc, CCONJ)
#   -> Child: issues (conj, NOUN)
#   <- Ancestor: Medium (ROOT, PROPN)
#
# Keyword: issues
#   -> Child: intermittent (amod, ADJ)
#   <- Ancestor: degradation (appos, NOUN)
#   <- Ancestor: Medium (ROOT, PROPN)
#
# Keyword: hours
#   -> Child: 24 (nummod, NUM)
#   <- Ancestor: TRT (ROOT, PROPN)
#
# Keyword: Low
#   <- Ancestor: inquiries (ROOT, NOUN)
#
# Keyword: General
#   <- Ancestor: inquiries (ROOT, NOUN)
#
# Keyword: inquiries
#   -> Child: Low (nmod, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: P4 (nmod, NOUN)
#   -> Child: General (compound, PROPN)
#   -> Child: or (cc, CCONJ)
#   -> Child: issues (conj, NOUN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: service
#   <- Ancestor: issues (conj, NOUN)
#   <- Ancestor: inquiries (ROOT, NOUN)
#
# Keyword: issues
#   -> Child: non (amod, ADJ)
#   -> Child: - (amod, ADJ)
#   -> Child: service (amod, ADJ)
#   -> Child: impacting (amod, VERB)
#   <- Ancestor: inquiries (ROOT, NOUN)
#
# Keyword: hours
#   -> Child: 48 (nummod, NUM)
#   <- Ancestor: TRT (ROOT, PROPN)
#
# Keyword: Reporting
#   -> Child: and (cc, CCONJ)
#   -> Child: Communication (conj, PROPN)
#   -> Child: : (punct, PUNCT)
#   <- Ancestor: provide (ROOT, VERB)
#
# Keyword: Communication
#   <- Ancestor: Reporting (nsubj, NOUN)
#   <- Ancestor: provide (ROOT, VERB)
#
# Keyword: NexGen
#   <- Ancestor: Inc. (nsubj, PROPN)
#   <- Ancestor: provide (ROOT, VERB)
#
# Keyword: Telecom
#   <- Ancestor: Inc. (nsubj, PROPN)
#   <- Ancestor: provide (ROOT, VERB)
#
# Keyword: updates
#   -> Child: regular (amod, ADJ)
#   -> Child: on (prep, ADP)
#   <- Ancestor: provide (ROOT, VERB)
#
# Keyword: incident
#   <- Ancestor: status (pobj, NOUN)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: updates (dobj, NOUN)
#   <- Ancestor: provide (ROOT, VERB)
#
# Keyword: status
#   -> Child: incident (compound, NOUN)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: updates (dobj, NOUN)
#   <- Ancestor: provide (ROOT, VERB)
#
# Keyword: resolution
#   <- Ancestor: until (prep, ADP)
#   <- Ancestor: provide (ROOT, VERB)
#
# Keyword: Dispute
#   <- Ancestor: Resolution (ROOT, PROPN)
#
# Keyword: Resolution
#   -> Child: 7 (meta, X)
#   -> Child: . (punct, PUNCT)
#   -> Child: Dispute (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: attempted (relcl, VERB)
#   -> Child: . (punct, PUNCT)
#
# Keyword: disputes
#   -> Child: Any (det, DET)
#   -> Child: arising (acl, VERB)
#   <- Ancestor: attempted (relcl, VERB)
#   <- Ancestor: Resolution (ROOT, PROPN)
#
# Keyword: SLA
#   -> Child: this (det, DET)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: arising (acl, VERB)
#   <- Ancestor: disputes (nsubjpass, NOUN)
#   <- Ancestor: attempted (relcl, VERB)
#   <- Ancestor: Resolution (ROOT, PROPN)
#
# Keyword: negotiation
#   -> Child: faith (compound, NOUN)
#   -> Child: between (prep, ADP)
#   <- Ancestor: through (prep, ADP)
#   <- Ancestor: resolved (xcomp, VERB)
#   <- Ancestor: attempted (relcl, VERB)
#   <- Ancestor: Resolution (ROOT, PROPN)
#
# Keyword: parties
#   -> Child: the (det, DET)
#   <- Ancestor: between (prep, ADP)
#   <- Ancestor: negotiation (pobj, NOUN)
#   <- Ancestor: through (prep, ADP)
#   <- Ancestor: resolved (xcomp, VERB)
#   <- Ancestor: attempted (relcl, VERB)
#   <- Ancestor: Resolution (ROOT, PROPN)
#
# Keyword: resolution
#   -> Child: an (det, DET)
#   -> Child: amicable (amod, ADJ)
#   <- Ancestor: reached (advcl, VERB)
#   <- Ancestor: escalate (ROOT, VERB)
#
# Keyword: days
#   -> Child: 30 (nummod, NUM)
#   <- Ancestor: within (prep, ADP)
#   <- Ancestor: reached (advcl, VERB)
#   <- Ancestor: escalate (ROOT, VERB)
#
# Keyword: party
#   -> Child: either (det, DET)
#   <- Ancestor: escalate (ROOT, VERB)
#
# Keyword: dispute
#   -> Child: the (det, DET)
#   -> Child: to (prep, ADP)
#   <- Ancestor: escalate (ROOT, VERB)
#
# Keyword: Termination
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: SLA (nsubjpass, PROPN)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: SLA
#   -> Child: Termination (compound, NOUN)
#   -> Child: This (det, DET)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: party
#   -> Child: either (det, DET)
#   <- Ancestor: by (agent, ADP)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: days
#   -> Child: 60 (nummod, NUM)
#   -> Child: ' (case, PART)
#   <- Ancestor: notice (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: notice
#   -> Child: days (poss, NOUN)
#   -> Child: written (amod, VERB)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: terms
#   -> Child: the (det, DET)
#   -> Child: of (prep, ADP)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: subject (oprd, ADJ)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: service
#   -> Child: master (compound, NOUN)
#   <- Ancestor: agreement (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: terms (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: subject (oprd, ADJ)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: agreement
#   -> Child: the (det, DET)
#   -> Child: service (compound, NOUN)
#   -> Child: between (prep, ADP)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: terms (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: subject (oprd, ADJ)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: NexGen
#   <- Ancestor: Inc. (pobj, PROPN)
#   <- Ancestor: between (prep, ADP)
#   <- Ancestor: agreement (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: terms (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: subject (oprd, ADJ)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: Telecom
#   <- Ancestor: Inc. (pobj, PROPN)
#   <- Ancestor: between (prep, ADP)
#   <- Ancestor: agreement (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: terms (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: subject (oprd, ADJ)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: Enterprise
#   <- Ancestor: Corp. (conj, PROPN)
#   <- Ancestor: Inc. (pobj, PROPN)
#   <- Ancestor: between (prep, ADP)
#   <- Ancestor: agreement (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: terms (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: subject (oprd, ADJ)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: Solutions
#   <- Ancestor: Corp. (conj, PROPN)
#   <- Ancestor: Inc. (pobj, PROPN)
#   <- Ancestor: between (prep, ADP)
#   <- Ancestor: agreement (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: terms (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: subject (oprd, ADJ)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: Review
#   -> Child: and (cc, CCONJ)
#   -> Child: Amendment (conj, PROPN)
#   -> Child: SLA (conj, PROPN)
#   <- Ancestor: reviewed (ROOT, VERB)
#
# Keyword: SLA
#   -> Child: This (det, DET)
#   <- Ancestor: Review (nsubjpass, PROPN)
#   <- Ancestor: reviewed (ROOT, VERB)
#
# Keyword: Effective
#   <- Ancestor: Date (pobj, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: anniversary (pobj, NOUN)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: reviewed (ROOT, VERB)
#
# Keyword: Date
#   -> Child: the (det, DET)
#   -> Child: Effective (compound, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: anniversary (pobj, NOUN)
#   <- Ancestor: on (prep, ADP)
#   <- Ancestor: reviewed (ROOT, VERB)
#
# Keyword: changes
#   -> Child: significant (amod, ADJ)
#   -> Child: in (prep, ADP)
#   <- Ancestor: occur (conj, VERB)
#   <- Ancestor: reviewed (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: requirements (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: changes (nsubj, NOUN)
#   <- Ancestor: occur (conj, VERB)
#   <- Ancestor: reviewed (ROOT, VERB)
#
# Keyword: requirements
#   -> Child: service (compound, NOUN)
#   -> Child: or (cc, CCONJ)
#   -> Child: capabilities (conj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: changes (nsubj, NOUN)
#   <- Ancestor: occur (conj, VERB)
#   <- Ancestor: reviewed (ROOT, VERB)
#
# Keyword: network
#   <- Ancestor: capabilities (conj, NOUN)
#   <- Ancestor: requirements (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: changes (nsubj, NOUN)
#   <- Ancestor: occur (conj, VERB)
#   <- Ancestor: reviewed (ROOT, VERB)
#
# Keyword: capabilities
#   -> Child: network (compound, NOUN)
#   <- Ancestor: requirements (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: changes (nsubj, NOUN)
#   <- Ancestor: occur (conj, VERB)
#   <- Ancestor: reviewed (ROOT, VERB)

# %%
for ent in doc.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Entity: 5, Label: CARDINAL
# Entity: 20250626, Label: DATE
# Entity: Effective Date, Label: ORG
# Entity: 2025-07-01, Label: DATE
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 1, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: cloud computing, Label: PERSON
# Entity: 2, Label: CARDINAL
# Entity: Service Scope
#
# Geographic Coverage: Primary, Label: ORG
# Entity: Appendix A.
#
# User Devices: Support, Label: PERSON
# Entity: 5G, Label: CARDINAL
# Entity: IoT, Label: ORG
# Entity: SIM, Label: ORG
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 3, Label: CARDINAL
# Entity: Performance Metrics, Label: ORG
# Entity: 15-minute, Label: TIME
# Entity: 3.1, Label: CARDINAL
# Entity: Downlink, Label: PERSON
# Entity: 1, Label: CARDINAL
# Entity: second, Label: ORDINAL
# Entity: 750, Label: CARDINAL
# Entity: Mbps, Label: PERSON
# Entity: CPE, Label: ORG
# Entity: monthly, Label: DATE
# Entity: 3.2, Label: CARDINAL
# Entity: 200, Label: CARDINAL
# Entity: 150, Label: CARDINAL
# Entity: Mbps, Label: PERSON
# Entity: monthly, Label: DATE
# Entity: 3.3, Label: CARDINAL
# Entity: less than 10, Label: CARDINAL
# Entity: 15, Label: CARDINAL
# Entity: 99.9%, Label: PERCENT
# Entity: Hourly, Label: TIME
# Entity: weekly, Label: DATE
# Entity: 3.4, Label: CARDINAL
# Entity: 2, Label: CARDINAL
# Entity: Hourly, Label: TIME
# Entity: weekly, Label: DATE
# Entity: 3.5, Label: CARDINAL
# Entity: Packet Loss Rate
#
# , Label: ORG
# Entity: Less than 0.01%, Label: PERCENT
# Entity: 0.05%, Label: PERCENT
# Entity: 5, Label: CARDINAL
# Entity: 3.6, Label: CARDINAL
# Entity: 99.99%, Label: PERCENT
# Entity: 5, Label: CARDINAL
# Entity: Monthly, Label: DATE
# Entity: 4, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: Service Level Objectives, Label: ORG
# Entity: a given month, Label: DATE
# Entity: Customer, Label: ORG
# Entity: 99.9%, Label: PERCENT
# Entity: 99.99%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 99.0%, Label: PERCENT
# Entity: 99.9%, Label: PERCENT
# Entity: 10%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 99.0%, Label: PERCENT
# Entity: 20%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: more than 5%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: Maximum Tolerated, Label: PERSON
# Entity: more than 1%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: month, Label: DATE
# Entity: any given month, Label: DATE
# Entity: 25%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 5, Label: CARDINAL
# Entity: 5.1, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 24/7, Label: CARDINAL
# Entity: Customer, Label: ORG
# Entity: Respond, Label: PERSON
# Entity: 5.2, Label: CARDINAL
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: Customer, Label: ORG
# Entity: CPE, Label: ORG
# Entity: Notify NexGen Telecom Inc., Label: ORG
# Entity: Appendix, Label: NORP
# Entity: 6, Label: CARDINAL
# Entity: 6.1, Label: CARDINAL
# Entity: 9 AM - 5 PM M-F, Label: TIME
# Entity: Email Support, Label: PERSON
# Entity: 9 AM - 5 PM M-F, Label: TIME
# Entity: 6.2, Label: CARDINAL
# Entity: Target Resolution Time, Label: ORG
# Entity: TRT, Label: ORG
# Entity: 4 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 8 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 24 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 48 hours, Label: TIME
# Entity: 6.3, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 7, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: first, Label: ORDINAL
# Entity: 30 days, Label: DATE
# Entity: 8, Label: CARDINAL
# Entity: 60 days', Label: DATE
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: 9, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: annually, Label: DATE
# Entity: the Effective Date, Label: ORG

# %%
from spacy.matcher import Matcher
from collections import defaultdict

# Assume: `doc = nlp(text)` is already run
matcher = Matcher(nlp.vocab)

# --- Define static patterns ---
availability_pattern = [
    {'LIKE_NUM': True}, {'TEXT': '%'}, {'LOWER': 'uptime'}
]
response_time_pattern = [
    {'LOWER': 'response'}, {'LOWER': 'time'}, {'LOWER': 'should'},
    {'LOWER': 'not'}, {'LOWER': 'exceed'}, {'LIKE_NUM': True}, {'LOWER': 'hours'}
]

matcher.add('AVAILABILITY', [availability_pattern])
matcher.add('RESPONSE_TIME', [response_time_pattern])

keywords={ "Business Days", "acceptance", "access", "acme", "activities", "advance", "agreement", "agreementid", "appendix", "applications", "area", "availability", "broadband", "capabilities", "capacity", "cards", "cell", "changes", "channels", "cloud", "communication", "computing", "conditions", "connectivity", "core", "coverage", "coveragearea", "cpe", "credit", "credits", "critical", "customer", "daily", "data", "date", "days", "db", "definition", "degradation", "deliverymethod", "description", "device", "devices", "dispute", "disputes", "downlink", "edge", "effective", "effectivedate", "effort", "egress", "elements", "email", "embb", "end", "enhanced", "enterprise", "environments", "equipment", "esim", "event", "fee", "file", "format", "frequency", "function", "functioning", "gateway", "gateways", "gbps", "general", "gigabits", "guaranteed", "high", "hourly", "hours", "id", "ids", "incident", "incidents", "industrial", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "latency", "level", "levels", "loss", "low", "maintenance", "management", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "medium", "metric", "metrics", "metropolitan", "milliseconds", "minimum", "minute", "minutes", "mission", "mobile", "monitor", "monitoring", "month", "ms", "negotiation", "network", "networks", "nexgen", "noise", "notice", "notifies", "notify", "objective", "objectives", "obligations", "online", "outage", "packet", "parties", "party", "penalties", "percentage", "performance", "period", "phone", "plane", "pm", "point", "policy", "portal", "premises", "prioritization", "priority", "profiles", "provider", "provision", "qos", "rate", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "reporting", "reports", "requirements", "resolution", "respond", "responsibilities", "review", "scope", "segment", "service", "session", "setup", "signal", "sim", "sla", "slices", "slos", "solutions", "specific", "status", "streaming", "subset", "support", "target", "telecom", "termination", "terms", "threshold", "throughput", "time", "traffic", "transfers", "type", "updates", "uplink", "uptime", "urllc", "usage", "usecases", "user", "users", "video" }


for kw in keywords:
    matcher.add(f"KEYWORD_{kw.lower()}", [[{"LOWER": kw.lower()}]])

# --- Apply matcher ---
matches = matcher(doc)

# --- Initialize storage ---
availability = None
response_time = None
matched_keywords = defaultdict(list)

# --- Process matches ---
for match_id, start, end in matches:
    span = doc[start:end]
    match_label = nlp.vocab.strings[match_id]

    if match_label == 'AVAILABILITY':
        availability = span.text
    elif match_label == 'RESPONSE_TIME':
        response_time = span.text
    elif match_label.startswith("KEYWORD_"):
        keyword = span.text.lower()

        # Look for number or units around the keyword
        window_start = max(0, start - 3)
        window_end = min(len(doc), end + 4)
        context = doc[window_start:window_end]

        # Look for nearby values: numbers, %, ms, etc.
        values = [
            token.text for token in context
            if token.like_num or token.text.lower() in {'%', 'ms', 'mbps', 'milliseconds', 'minutes', 'hours', 'ratio'}
        ]

        if values:
            matched_keywords[keyword].extend(values)

# --- Print results ---
print(f"Availability Match: {availability}")
print(f"Response Time Match: {response_time}\n")

print("Keyword-Value Pairs Found in Text:")
for kw, vals in sorted(matched_keywords.items()):
    vals_clean = ", ".join(set(vals))  # Remove duplicates
    print(f"- {kw}: {vals_clean}")
# Out:
# Availability Match: None
# Response Time Match: None
#
# Keyword-Value Pairs Found in Text:
# - activities: hours, 72
# - advance: hours, 72
# - applications: 8
# - availability: 99.0, 5, 10, 20, 99.99, 3.6, %, 99.9
# - capacity: 1
# - channels: 6.1
# - credit: %, 10, 5, 20
# - credits: 4
# - critical: 9, 24/7
# - data: 15, 1
# - date: 2025, 20250626, 07
# - days: 30, 60
# - description: 1
# - dispute: 7
# - downlink: 1
# - effective: 2025, 20250626
# - embb: 5
# - end: 5
# - enhanced: 5
# - enterprise: 5.2, 9
# - fee: %, 99.0, 5
# - file: 2
# - gbps: 1, second
# - gigabits: 1, second
# - guaranteed: Mbps, 150, 750
# - high: hours
# - hours: 48, 8, 24, 4, hours, 72, 6.3
# - incident: 6.2, 6.1, 24/7
# - incidents: 9, 24/7
# - infrastructure: 5
# - intervals: 15
# - issues: 48, 24
# - jitter: 2, 3.4, ms
# - latency: 3.3, 10
# - level: 3
# - loss: 0.01, %, 3.5
# - low: hours
# - maintenance: 72
# - management: 6.1
# - maximum: 0.05, 2, ms, %, 15
# - mbps: 200, Mbps, 150, 750
# - measurement: %, ms, Mbps
# - medium: hours
# - milliseconds: milliseconds, ms, 10
# - minimum: Mbps, 150, 750
# - minute: 15
# - mobile: 5
# - month: 25
# - ms: 10, 2, ms, milliseconds, %, 15, 99.9
# - network: 5
# - nexgen: 5.1
# - objective: 99.99, %, 0.01
# - online: 24/7
# - packet: 0.01, %, 3.5
# - parties: 5.1
# - party: 60
# - period: %, 5
# - pm: 5
# - portal: 24/7
# - prioritization: 6.2
# - provider: 01
# - provision: 5
# - reporting: %, 6.3, 5, 24/7
# - reports: 3.2, 3.3, 3.4, 3.6, 3.5
# - resolution: 7
# - responsibilities: 5
# - review: 9
# - scope: 2
# - segment: 5
# - service: 01, 10, 20, 2, 1, 4, 3.6, %, 5, 3
# - sla: first, 5
# - slices: 3
# - slos: 24/7
# - solutions: 5.2, 9
# - support: 5.2, 6, 6.1, 24/7
# - telecom: 5.1
# - termination: 8
# - throughput: Mbps, 3.1, 3.2, 1, 200
# - time: 4
# - traffic: %, 99.9
# - transfers: 2
# - type: 5
# - uplink: 200, Mbps

# %%
for keyword in keywords:
    words = keyword.lower().split()
    pattern = [{'LOWER': word.strip(",")} for word in words]
    matcher.add(keyword.upper().replace(" ", "_"), [pattern])

# Apply the matcher
matches = matcher(doc)

# Print matches
for match_id, start, end in matches:
    span = doc[start:end]
    print(f"Matched '{span.text}' with label '{nlp.vocab.strings[match_id]}' at position {start}-{end}")
# Out:
# Matched 'Service' with label 'KEYWORD_service' at position 0-1
# Matched 'Service' with label 'SERVICE' at position 0-1
# Matched 'Level' with label 'KEYWORD_level' at position 1-2
# Matched 'Level' with label 'LEVEL' at position 1-2
# Matched 'Agreement' with label 'KEYWORD_agreement' at position 2-3
# Matched 'Agreement' with label 'AGREEMENT' at position 2-3
# Matched 'SLA' with label 'KEYWORD_sla' at position 4-5
# Matched 'SLA' with label 'SLA' at position 4-5
# Matched 'Enhanced' with label 'KEYWORD_enhanced' at position 9-10
# Matched 'Enhanced' with label 'ENHANCED' at position 9-10
# Matched 'Mobile' with label 'KEYWORD_mobile' at position 10-11
# Matched 'Mobile' with label 'MOBILE' at position 10-11
# Matched 'Broadband' with label 'KEYWORD_broadband' at position 11-12
# Matched 'Broadband' with label 'BROADBAND' at position 11-12
# Matched 'eMBB' with label 'KEYWORD_embb' at position 13-14
# Matched 'eMBB' with label 'EMBB' at position 13-14
# Matched 'Service' with label 'KEYWORD_service' at position 15-16
# Matched 'Service' with label 'SERVICE' at position 15-16
# Matched 'Agreement' with label 'KEYWORD_agreement' at position 17-18
# Matched 'Agreement' with label 'AGREEMENT' at position 17-18
# Matched 'ID' with label 'KEYWORD_id' at position 18-19
# Matched 'ID' with label 'ID' at position 18-19
# Matched 'Effective' with label 'KEYWORD_effective' at position 26-27
# Matched 'Effective' with label 'EFFECTIVE' at position 26-27
# Matched 'Date' with label 'KEYWORD_date' at position 27-28
# Matched 'Date' with label 'DATE' at position 27-28
# Matched 'Service' with label 'KEYWORD_service' at position 35-36
# Matched 'Service' with label 'SERVICE' at position 35-36
# Matched 'Provider' with label 'KEYWORD_provider' at position 36-37
# Matched 'Provider' with label 'PROVIDER' at position 36-37
# Matched 'NexGen' with label 'KEYWORD_nexgen' at position 38-39
# Matched 'NexGen' with label 'NEXGEN' at position 38-39
# Matched 'Telecom' with label 'KEYWORD_telecom' at position 39-40
# Matched 'Telecom' with label 'TELECOM' at position 39-40
# Matched 'Customer' with label 'KEYWORD_customer' at position 42-43
# Matched 'Customer' with label 'CUSTOMER' at position 42-43
# Matched 'Enterprise' with label 'KEYWORD_enterprise' at position 44-45
# Matched 'Enterprise' with label 'ENTERPRISE' at position 44-45
# Matched 'Solutions' with label 'KEYWORD_solutions' at position 45-46
# Matched 'Solutions' with label 'SOLUTIONS' at position 45-46
# Matched 'Service' with label 'KEYWORD_service' at position 48-49
# Matched 'Service' with label 'SERVICE' at position 48-49
# Matched 'Type' with label 'KEYWORD_type' at position 49-50
# Matched 'Type' with label 'TYPE' at position 49-50
# Matched 'Enhanced' with label 'KEYWORD_enhanced' at position 53-54
# Matched 'Enhanced' with label 'ENHANCED' at position 53-54
# Matched 'Mobile' with label 'KEYWORD_mobile' at position 54-55
# Matched 'Mobile' with label 'MOBILE' at position 54-55
# Matched 'Broadband' with label 'KEYWORD_broadband' at position 55-56
# Matched 'Broadband' with label 'BROADBAND' at position 55-56
# Matched 'eMBB' with label 'KEYWORD_embb' at position 57-58
# Matched 'eMBB' with label 'EMBB' at position 57-58
# Matched 'High' with label 'KEYWORD_high' at position 60-61
# Matched 'High' with label 'HIGH' at position 60-61
# Matched 'Capacity' with label 'KEYWORD_capacity' at position 62-63
# Matched 'Capacity' with label 'CAPACITY' at position 62-63
# Matched 'Data' with label 'KEYWORD_data' at position 63-64
# Matched 'Data' with label 'DATA' at position 63-64
# Matched 'Service' with label 'KEYWORD_service' at position 64-65
# Matched 'Service' with label 'SERVICE' at position 64-65
# Matched 'Service' with label 'KEYWORD_service' at position 68-69
# Matched 'Service' with label 'SERVICE' at position 68-69
# Matched 'Description' with label 'KEYWORD_description' at position 69-70
# Matched 'Description' with label 'DESCRIPTION' at position 69-70
# Matched 'SLA' with label 'KEYWORD_sla' at position 72-73
# Matched 'SLA' with label 'SLA' at position 72-73
# Matched 'terms' with label 'KEYWORD_terms' at position 75-76
# Matched 'terms' with label 'TERMS' at position 75-76
# Matched 'conditions' with label 'KEYWORD_conditions' at position 77-78
# Matched 'conditions' with label 'CONDITIONS' at position 77-78
# Matched 'provision' with label 'KEYWORD_provision' at position 80-81
# Matched 'provision' with label 'PROVISION' at position 80-81
# Matched 'Enhanced' with label 'KEYWORD_enhanced' at position 86-87
# Matched 'Enhanced' with label 'ENHANCED' at position 86-87
# Matched 'Mobile' with label 'KEYWORD_mobile' at position 87-88
# Matched 'Mobile' with label 'MOBILE' at position 87-88
# Matched 'Broadband' with label 'KEYWORD_broadband' at position 88-89
# Matched 'Broadband' with label 'BROADBAND' at position 88-89
# Matched 'eMBB' with label 'KEYWORD_embb' at position 90-91
# Matched 'eMBB' with label 'EMBB' at position 90-91
# Matched 'service' with label 'KEYWORD_service' at position 92-93
# Matched 'service' with label 'SERVICE' at position 92-93
# Matched 'Enterprise' with label 'KEYWORD_enterprise' at position 94-95
# Matched 'Enterprise' with label 'ENTERPRISE' at position 94-95
# Matched 'Solutions' with label 'KEYWORD_solutions' at position 95-96
# Matched 'Solutions' with label 'SOLUTIONS' at position 95-96
# Matched 'service' with label 'KEYWORD_service' at position 98-99
# Matched 'service' with label 'SERVICE' at position 98-99
# Matched 'high' with label 'KEYWORD_high' at position 103-104
# Matched 'high' with label 'HIGH' at position 103-104
# Matched 'throughput' with label 'KEYWORD_throughput' at position 105-106
# Matched 'throughput' with label 'THROUGHPUT' at position 105-106
# Matched 'low' with label 'KEYWORD_low' at position 107-108
# Matched 'low' with label 'LOW' at position 107-108
# Matched 'latency' with label 'KEYWORD_latency' at position 109-110
# Matched 'latency' with label 'LATENCY' at position 109-110
# Matched 'connectivity' with label 'KEYWORD_connectivity' at position 110-111
# Matched 'connectivity' with label 'CONNECTIVITY' at position 110-111
# Matched 'data' with label 'KEYWORD_data' at position 113-114
# Matched 'data' with label 'DATA' at position 113-114
# Matched 'applications' with label 'KEYWORD_applications' at position 116-117
# Matched 'applications' with label 'APPLICATIONS' at position 116-117
# Matched 'cloud' with label 'KEYWORD_cloud' at position 124-125
# Matched 'cloud' with label 'CLOUD' at position 124-125
# Matched 'computing' with label 'KEYWORD_computing' at position 125-126
# Matched 'computing' with label 'COMPUTING' at position 125-126
# Matched 'high' with label 'KEYWORD_high' at position 127-128
# Matched 'high' with label 'HIGH' at position 127-128
# Matched 'definition' with label 'KEYWORD_definition' at position 129-130
# Matched 'definition' with label 'DEFINITION' at position 129-130
# Matched 'video' with label 'KEYWORD_video' at position 130-131
# Matched 'video' with label 'VIDEO' at position 130-131
# Matched 'streaming' with label 'KEYWORD_streaming' at position 131-132
# Matched 'streaming' with label 'STREAMING' at position 131-132
# Matched 'file' with label 'KEYWORD_file' at position 135-136
# Matched 'file' with label 'FILE' at position 135-136
# Matched 'transfers' with label 'KEYWORD_transfers' at position 136-137
# Matched 'transfers' with label 'TRANSFERS' at position 136-137
# Matched 'Service' with label 'KEYWORD_service' at position 141-142
# Matched 'Service' with label 'SERVICE' at position 141-142
# Matched 'Scope' with label 'KEYWORD_scope' at position 142-143
# Matched 'Scope' with label 'SCOPE' at position 142-143
# Matched 'Coverage' with label 'KEYWORD_coverage' at position 145-146
# Matched 'Coverage' with label 'COVERAGE' at position 145-146
# Matched 'service' with label 'KEYWORD_service' at position 148-149
# Matched 'service' with label 'SERVICE' at position 148-149
# Matched 'area' with label 'KEYWORD_area' at position 149-150
# Matched 'area' with label 'AREA' at position 149-150
# Matched 'Metropolitan' with label 'KEYWORD_metropolitan' at position 151-152
# Matched 'Metropolitan' with label 'METROPOLITAN' at position 151-152
# Matched 'Region' with label 'KEYWORD_region' at position 152-153
# Matched 'Region' with label 'REGION' at position 152-153
# Matched 'coverage' with label 'KEYWORD_coverage' at position 157-158
# Matched 'coverage' with label 'COVERAGE' at position 157-158
# Matched 'Industrial' with label 'KEYWORD_industrial' at position 159-160
# Matched 'Industrial' with label 'INDUSTRIAL' at position 159-160
# Matched 'Specific' with label 'KEYWORD_specific' at position 162-163
# Matched 'Specific' with label 'SPECIFIC' at position 162-163
# Matched 'cell' with label 'KEYWORD_cell' at position 163-164
# Matched 'cell' with label 'CELL' at position 163-164
# Matched 'IDs' with label 'KEYWORD_ids' at position 164-165
# Matched 'IDs' with label 'IDS' at position 164-165
# Matched 'coverage' with label 'KEYWORD_coverage' at position 166-167
# Matched 'coverage' with label 'COVERAGE' at position 166-167
# Matched 'Appendix' with label 'KEYWORD_appendix' at position 171-172
# Matched 'Appendix' with label 'APPENDIX' at position 171-172
# Matched 'User' with label 'KEYWORD_user' at position 174-175
# Matched 'User' with label 'USER' at position 174-175
# Matched 'Devices' with label 'KEYWORD_devices' at position 175-176
# Matched 'Devices' with label 'DEVICES' at position 175-176
# Matched 'Support' with label 'KEYWORD_support' at position 177-178
# Matched 'Support' with label 'SUPPORT' at position 177-178
# Matched 'devices' with label 'KEYWORD_devices' at position 182-183
# Matched 'devices' with label 'DEVICES' at position 182-183
# Matched 'gateways' with label 'KEYWORD_gateways' at position 189-190
# Matched 'gateways' with label 'GATEWAYS' at position 189-190
# Matched 'SIM' with label 'KEYWORD_sim' at position 194-195
# Matched 'SIM' with label 'SIM' at position 194-195
# Matched 'cards' with label 'KEYWORD_cards' at position 195-196
# Matched 'cards' with label 'CARDS' at position 195-196
# Matched 'eSIM' with label 'KEYWORD_esim' at position 197-198
# Matched 'eSIM' with label 'ESIM' at position 197-198
# Matched 'profiles' with label 'KEYWORD_profiles' at position 198-199
# Matched 'profiles' with label 'PROFILES' at position 198-199
# Matched 'NexGen' with label 'KEYWORD_nexgen' at position 201-202
# Matched 'NexGen' with label 'NEXGEN' at position 201-202
# Matched 'Telecom' with label 'KEYWORD_telecom' at position 202-203
# Matched 'Telecom' with label 'TELECOM' at position 202-203
# Matched 'Traffic' with label 'KEYWORD_traffic' at position 205-206
# Matched 'Traffic' with label 'TRAFFIC' at position 205-206
# Matched 'Prioritization' with label 'KEYWORD_prioritization' at position 206-207
# Matched 'Prioritization' with label 'PRIORITIZATION' at position 206-207
# Matched 'eMBB' with label 'KEYWORD_embb' at position 208-209
# Matched 'eMBB' with label 'EMBB' at position 208-209
# Matched 'traffic' with label 'KEYWORD_traffic' at position 209-210
# Matched 'traffic' with label 'TRAFFIC' at position 209-210
# Matched 'priority' with label 'KEYWORD_priority' at position 212-213
# Matched 'priority' with label 'PRIORITY' at position 212-213
# Matched 'effort' with label 'KEYWORD_effort' at position 216-217
# Matched 'effort' with label 'EFFORT' at position 216-217
# Matched 'traffic' with label 'KEYWORD_traffic' at position 217-218
# Matched 'traffic' with label 'TRAFFIC' at position 217-218
# Matched 'service' with label 'KEYWORD_service' at position 221-222
# Matched 'service' with label 'SERVICE' at position 221-222
# Matched 'slices' with label 'KEYWORD_slices' at position 222-223
# Matched 'slices' with label 'SLICES' at position 222-223
# Matched 'Service' with label 'KEYWORD_service' at position 227-228
# Matched 'Service' with label 'SERVICE' at position 227-228
# Matched 'Level' with label 'KEYWORD_level' at position 228-229
# Matched 'Level' with label 'LEVEL' at position 228-229
# Matched 'Objectives' with label 'KEYWORD_objectives' at position 229-230
# Matched 'Objectives' with label 'OBJECTIVES' at position 229-230
# Matched 'SLOs' with label 'KEYWORD_slos' at position 231-232
# Matched 'SLOs' with label 'SLOS' at position 231-232
# Matched 'Performance' with label 'KEYWORD_performance' at position 234-235
# Matched 'Performance' with label 'PERFORMANCE' at position 234-235
# Matched 'Metrics' with label 'KEYWORD_metrics' at position 235-236
# Matched 'Metrics' with label 'METRICS' at position 235-236
# Matched 'performance' with label 'KEYWORD_performance' at position 239-240
# Matched 'performance' with label 'PERFORMANCE' at position 239-240
# Matched 'metrics' with label 'KEYWORD_metrics' at position 240-241
# Matched 'metrics' with label 'METRICS' at position 240-241
# Matched 'service' with label 'KEYWORD_service' at position 252-253
# Matched 'service' with label 'SERVICE' at position 252-253
# Matched 'levels' with label 'KEYWORD_levels' at position 253-254
# Matched 'levels' with label 'LEVELS' at position 253-254
# Matched 'measurements' with label 'KEYWORD_measurements' at position 258-259
# Matched 'measurements' with label 'MEASUREMENTS' at position 258-259
# Matched 'data' with label 'KEYWORD_data' at position 263-264
# Matched 'data' with label 'DATA' at position 263-264
# Matched 'minute' with label 'KEYWORD_minute' at position 267-268
# Matched 'minute' with label 'MINUTE' at position 267-268
# Matched 'intervals' with label 'KEYWORD_intervals' at position 268-269
# Matched 'intervals' with label 'INTERVALS' at position 268-269
# Matched 'Throughput' with label 'KEYWORD_throughput' at position 277-278
# Matched 'Throughput' with label 'THROUGHPUT' at position 277-278
# Matched 'Downlink' with label 'KEYWORD_downlink' at position 279-280
# Matched 'Downlink' with label 'DOWNLINK' at position 279-280
# Matched 'Objective' with label 'KEYWORD_objective' at position 282-283
# Matched 'Objective' with label 'OBJECTIVE' at position 282-283
# Matched 'downlink' with label 'KEYWORD_downlink' at position 285-286
# Matched 'downlink' with label 'DOWNLINK' at position 285-286
# Matched 'throughput' with label 'KEYWORD_throughput' at position 286-287
# Matched 'throughput' with label 'THROUGHPUT' at position 286-287
# Matched 'Gbps' with label 'KEYWORD_gbps' at position 289-290
# Matched 'Gbps' with label 'GBPS' at position 289-290
# Matched 'Gigabits' with label 'KEYWORD_gigabits' at position 291-292
# Matched 'Gigabits' with label 'GIGABITS' at position 291-292
# Matched 'Minimum' with label 'KEYWORD_minimum' at position 297-298
# Matched 'Minimum' with label 'MINIMUM' at position 297-298
# Matched 'Guaranteed' with label 'KEYWORD_guaranteed' at position 298-299
# Matched 'Guaranteed' with label 'GUARANTEED' at position 298-299
# Matched 'Mbps' with label 'KEYWORD_mbps' at position 301-302
# Matched 'Mbps' with label 'MBPS' at position 301-302
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 304-305
# Matched 'Measurement' with label 'MEASUREMENT' at position 304-305
# Matched 'Point' with label 'KEYWORD_point' at position 305-306
# Matched 'Point' with label 'POINT' at position 305-306
# Matched 'User' with label 'KEYWORD_user' at position 307-308
# Matched 'User' with label 'USER' at position 307-308
# Matched 'Plane' with label 'KEYWORD_plane' at position 308-309
# Matched 'Plane' with label 'PLANE' at position 308-309
# Matched 'Function' with label 'KEYWORD_function' at position 309-310
# Matched 'Function' with label 'FUNCTION' at position 309-310
# Matched 'egress' with label 'KEYWORD_egress' at position 313-314
# Matched 'egress' with label 'EGRESS' at position 313-314
# Matched 'customer' with label 'KEYWORD_customer' at position 315-316
# Matched 'customer' with label 'CUSTOMER' at position 315-316
# Matched 'premises' with label 'KEYWORD_premises' at position 316-317
# Matched 'premises' with label 'PREMISES' at position 316-317
# Matched 'equipment' with label 'KEYWORD_equipment' at position 317-318
# Matched 'equipment' with label 'EQUIPMENT' at position 317-318
# Matched 'CPE' with label 'KEYWORD_cpe' at position 319-320
# Matched 'CPE' with label 'CPE' at position 319-320
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 323-324
# Matched 'Reporting' with label 'REPORTING' at position 323-324
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 324-325
# Matched 'Frequency' with label 'FREQUENCY' at position 324-325
# Matched 'Daily' with label 'KEYWORD_daily' at position 326-327
# Matched 'Daily' with label 'DAILY' at position 326-327
# Matched 'reports' with label 'KEYWORD_reports' at position 328-329
# Matched 'reports' with label 'REPORTS' at position 328-329
# Matched 'reports' with label 'KEYWORD_reports' at position 332-333
# Matched 'reports' with label 'REPORTS' at position 332-333
# Matched 'Throughput' with label 'KEYWORD_throughput' at position 337-338
# Matched 'Throughput' with label 'THROUGHPUT' at position 337-338
# Matched 'Uplink' with label 'KEYWORD_uplink' at position 339-340
# Matched 'Uplink' with label 'UPLINK' at position 339-340
# Matched 'Objective' with label 'KEYWORD_objective' at position 342-343
# Matched 'Objective' with label 'OBJECTIVE' at position 342-343
# Matched 'uplink' with label 'KEYWORD_uplink' at position 345-346
# Matched 'uplink' with label 'UPLINK' at position 345-346
# Matched 'throughput' with label 'KEYWORD_throughput' at position 346-347
# Matched 'throughput' with label 'THROUGHPUT' at position 346-347
# Matched 'Mbps' with label 'KEYWORD_mbps' at position 349-350
# Matched 'Mbps' with label 'MBPS' at position 349-350
# Matched 'Minimum' with label 'KEYWORD_minimum' at position 352-353
# Matched 'Minimum' with label 'MINIMUM' at position 352-353
# Matched 'Guaranteed' with label 'KEYWORD_guaranteed' at position 353-354
# Matched 'Guaranteed' with label 'GUARANTEED' at position 353-354
# Matched 'Mbps' with label 'KEYWORD_mbps' at position 356-357
# Matched 'Mbps' with label 'MBPS' at position 356-357
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 359-360
# Matched 'Measurement' with label 'MEASUREMENT' at position 359-360
# Matched 'Point' with label 'KEYWORD_point' at position 360-361
# Matched 'Point' with label 'POINT' at position 360-361
# Matched 'CPE' with label 'KEYWORD_cpe' at position 362-363
# Matched 'CPE' with label 'CPE' at position 362-363
# Matched 'ingress' with label 'KEYWORD_ingress' at position 363-364
# Matched 'ingress' with label 'INGRESS' at position 363-364
# Matched 'ingress' with label 'KEYWORD_ingress' at position 366-367
# Matched 'ingress' with label 'INGRESS' at position 366-367
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 369-370
# Matched 'Reporting' with label 'REPORTING' at position 369-370
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 370-371
# Matched 'Frequency' with label 'FREQUENCY' at position 370-371
# Matched 'Daily' with label 'KEYWORD_daily' at position 372-373
# Matched 'Daily' with label 'DAILY' at position 372-373
# Matched 'reports' with label 'KEYWORD_reports' at position 374-375
# Matched 'reports' with label 'REPORTS' at position 374-375
# Matched 'reports' with label 'KEYWORD_reports' at position 378-379
# Matched 'reports' with label 'REPORTS' at position 378-379
# Matched 'Latency' with label 'KEYWORD_latency' at position 383-384
# Matched 'Latency' with label 'LATENCY' at position 383-384
# Matched 'Time' with label 'KEYWORD_time' at position 387-388
# Matched 'Time' with label 'TIME' at position 387-388
# Matched 'Objective' with label 'KEYWORD_objective' at position 392-393
# Matched 'Objective' with label 'OBJECTIVE' at position 392-393
# Matched 'end' with label 'KEYWORD_end' at position 395-396
# Matched 'end' with label 'END' at position 395-396
# Matched 'end' with label 'KEYWORD_end' at position 399-400
# Matched 'end' with label 'END' at position 399-400
# Matched 'latency' with label 'KEYWORD_latency' at position 400-401
# Matched 'latency' with label 'LATENCY' at position 400-401
# Matched 'ms' with label 'KEYWORD_ms' at position 405-406
# Matched 'ms' with label 'MS' at position 405-406
# Matched 'milliseconds' with label 'KEYWORD_milliseconds' at position 407-408
# Matched 'milliseconds' with label 'MILLISECONDS' at position 407-408
# Matched 'Maximum' with label 'KEYWORD_maximum' at position 411-412
# Matched 'Maximum' with label 'MAXIMUM' at position 411-412
# Matched 'ms' with label 'KEYWORD_ms' at position 415-416
# Matched 'ms' with label 'MS' at position 415-416
# Matched 'traffic' with label 'KEYWORD_traffic' at position 420-421
# Matched 'traffic' with label 'TRAFFIC' at position 420-421
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 423-424
# Matched 'Measurement' with label 'MEASUREMENT' at position 423-424
# Matched 'Point' with label 'KEYWORD_point' at position 424-425
# Matched 'Point' with label 'POINT' at position 424-425
# Matched 'customer' with label 'KEYWORD_customer' at position 427-428
# Matched 'customer' with label 'CUSTOMER' at position 427-428
# Matched 'device' with label 'KEYWORD_device' at position 428-429
# Matched 'device' with label 'DEVICE' at position 428-429
# Matched 'core' with label 'KEYWORD_core' at position 431-432
# Matched 'core' with label 'CORE' at position 431-432
# Matched 'network' with label 'KEYWORD_network' at position 432-433
# Matched 'network' with label 'NETWORK' at position 432-433
# Matched 'gateway' with label 'KEYWORD_gateway' at position 433-434
# Matched 'gateway' with label 'GATEWAY' at position 433-434
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 436-437
# Matched 'Reporting' with label 'REPORTING' at position 436-437
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 437-438
# Matched 'Frequency' with label 'FREQUENCY' at position 437-438
# Matched 'Hourly' with label 'KEYWORD_hourly' at position 439-440
# Matched 'Hourly' with label 'HOURLY' at position 439-440
# Matched 'reports' with label 'KEYWORD_reports' at position 441-442
# Matched 'reports' with label 'REPORTS' at position 441-442
# Matched 'reports' with label 'KEYWORD_reports' at position 445-446
# Matched 'reports' with label 'REPORTS' at position 445-446
# Matched 'Jitter' with label 'KEYWORD_jitter' at position 450-451
# Matched 'Jitter' with label 'JITTER' at position 450-451
# Matched 'Objective' with label 'KEYWORD_objective' at position 452-453
# Matched 'Objective' with label 'OBJECTIVE' at position 452-453
# Matched 'Maximum' with label 'KEYWORD_maximum' at position 454-455
# Matched 'Maximum' with label 'MAXIMUM' at position 454-455
# Matched 'jitter' with label 'KEYWORD_jitter' at position 455-456
# Matched 'jitter' with label 'JITTER' at position 455-456
# Matched 'ms' with label 'KEYWORD_ms' at position 458-459
# Matched 'ms' with label 'MS' at position 458-459
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 461-462
# Matched 'Measurement' with label 'MEASUREMENT' at position 461-462
# Matched 'Point' with label 'KEYWORD_point' at position 462-463
# Matched 'Point' with label 'POINT' at position 462-463
# Matched 'customer' with label 'KEYWORD_customer' at position 465-466
# Matched 'customer' with label 'CUSTOMER' at position 465-466
# Matched 'device' with label 'KEYWORD_device' at position 466-467
# Matched 'device' with label 'DEVICE' at position 466-467
# Matched 'core' with label 'KEYWORD_core' at position 469-470
# Matched 'core' with label 'CORE' at position 469-470
# Matched 'network' with label 'KEYWORD_network' at position 470-471
# Matched 'network' with label 'NETWORK' at position 470-471
# Matched 'gateway' with label 'KEYWORD_gateway' at position 471-472
# Matched 'gateway' with label 'GATEWAY' at position 471-472
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 474-475
# Matched 'Reporting' with label 'REPORTING' at position 474-475
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 475-476
# Matched 'Frequency' with label 'FREQUENCY' at position 475-476
# Matched 'Hourly' with label 'KEYWORD_hourly' at position 477-478
# Matched 'Hourly' with label 'HOURLY' at position 477-478
# Matched 'reports' with label 'KEYWORD_reports' at position 479-480
# Matched 'reports' with label 'REPORTS' at position 479-480
# Matched 'reports' with label 'KEYWORD_reports' at position 483-484
# Matched 'reports' with label 'REPORTS' at position 483-484
# Matched 'Packet' with label 'KEYWORD_packet' at position 488-489
# Matched 'Packet' with label 'PACKET' at position 488-489
# Matched 'Loss' with label 'KEYWORD_loss' at position 489-490
# Matched 'Loss' with label 'LOSS' at position 489-490
# Matched 'Rate' with label 'KEYWORD_rate' at position 490-491
# Matched 'Rate' with label 'RATE' at position 490-491
# Matched 'Objective' with label 'KEYWORD_objective' at position 492-493
# Matched 'Objective' with label 'OBJECTIVE' at position 492-493
# Matched 'packet' with label 'KEYWORD_packet' at position 498-499
# Matched 'packet' with label 'PACKET' at position 498-499
# Matched 'loss' with label 'KEYWORD_loss' at position 499-500
# Matched 'loss' with label 'LOSS' at position 499-500
# Matched 'Maximum' with label 'KEYWORD_maximum' at position 502-503
# Matched 'Maximum' with label 'MAXIMUM' at position 502-503
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 509-510
# Matched 'Measurement' with label 'MEASUREMENT' at position 509-510
# Matched 'Point' with label 'KEYWORD_point' at position 510-511
# Matched 'Point' with label 'POINT' at position 510-511
# Matched 'End' with label 'KEYWORD_end' at position 512-513
# Matched 'End' with label 'END' at position 512-513
# Matched 'end' with label 'KEYWORD_end' at position 516-517
# Matched 'end' with label 'END' at position 516-517
# Matched 'network' with label 'KEYWORD_network' at position 521-522
# Matched 'network' with label 'NETWORK' at position 521-522
# Matched 'segment' with label 'KEYWORD_segment' at position 522-523
# Matched 'segment' with label 'SEGMENT' at position 522-523
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 525-526
# Matched 'Reporting' with label 'REPORTING' at position 525-526
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 526-527
# Matched 'Frequency' with label 'FREQUENCY' at position 526-527
# Matched 'Daily' with label 'KEYWORD_daily' at position 528-529
# Matched 'Daily' with label 'DAILY' at position 528-529
# Matched 'reports' with label 'KEYWORD_reports' at position 530-531
# Matched 'reports' with label 'REPORTS' at position 530-531
# Matched 'Service' with label 'KEYWORD_service' at position 535-536
# Matched 'Service' with label 'SERVICE' at position 535-536
# Matched 'Availability' with label 'KEYWORD_availability' at position 536-537
# Matched 'Availability' with label 'AVAILABILITY' at position 536-537
# Matched 'Objective' with label 'KEYWORD_objective' at position 538-539
# Matched 'Objective' with label 'OBJECTIVE' at position 538-539
# Matched 'availability' with label 'KEYWORD_availability' at position 542-543
# Matched 'availability' with label 'AVAILABILITY' at position 542-543
# Matched 'eMBB' with label 'KEYWORD_embb' at position 547-548
# Matched 'eMBB' with label 'EMBB' at position 547-548
# Matched 'service' with label 'KEYWORD_service' at position 548-549
# Matched 'service' with label 'SERVICE' at position 548-549
# Matched 'service' with label 'KEYWORD_service' at position 552-553
# Matched 'service' with label 'SERVICE' at position 552-553
# Matched 'area' with label 'KEYWORD_area' at position 553-554
# Matched 'area' with label 'AREA' at position 553-554
# Matched 'Definition' with label 'KEYWORD_definition' at position 556-557
# Matched 'Definition' with label 'DEFINITION' at position 556-557
# Matched 'Uptime' with label 'KEYWORD_uptime' at position 558-559
# Matched 'Uptime' with label 'UPTIME' at position 558-559
# Matched 'percentage' with label 'KEYWORD_percentage' at position 562-563
# Matched 'percentage' with label 'PERCENTAGE' at position 562-563
# Matched 'time' with label 'KEYWORD_time' at position 564-565
# Matched 'time' with label 'TIME' at position 564-565
# Matched 'service' with label 'KEYWORD_service' at position 566-567
# Matched 'service' with label 'SERVICE' at position 566-567
# Matched 'customer' with label 'KEYWORD_customer' at position 574-575
# Matched 'customer' with label 'CUSTOMER' at position 574-575
# Matched 'maintenance' with label 'KEYWORD_maintenance' at position 577-578
# Matched 'maintenance' with label 'MAINTENANCE' at position 577-578
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 583-584
# Matched 'Reporting' with label 'REPORTING' at position 583-584
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 584-585
# Matched 'Frequency' with label 'FREQUENCY' at position 584-585
# Matched 'Service' with label 'KEYWORD_service' at position 591-592
# Matched 'Service' with label 'SERVICE' at position 591-592
# Matched 'Credits' with label 'KEYWORD_credits' at position 592-593
# Matched 'Credits' with label 'CREDITS' at position 592-593
# Matched 'Penalties' with label 'KEYWORD_penalties' at position 594-595
# Matched 'Penalties' with label 'PENALTIES' at position 594-595
# Matched 'event' with label 'KEYWORD_event' at position 598-599
# Matched 'event' with label 'EVENT' at position 598-599
# Matched 'NexGen' with label 'KEYWORD_nexgen' at position 600-601
# Matched 'NexGen' with label 'NEXGEN' at position 600-601
# Matched 'Telecom' with label 'KEYWORD_telecom' at position 601-602
# Matched 'Telecom' with label 'TELECOM' at position 601-602
# Matched 'Service' with label 'KEYWORD_service' at position 610-611
# Matched 'Service' with label 'SERVICE' at position 610-611
# Matched 'Level' with label 'KEYWORD_level' at position 611-612
# Matched 'Level' with label 'LEVEL' at position 611-612
# Matched 'Objectives' with label 'KEYWORD_objectives' at position 612-613
# Matched 'Objectives' with label 'OBJECTIVES' at position 612-613
# Matched 'SLOs' with label 'KEYWORD_slos' at position 614-615
# Matched 'SLOs' with label 'SLOS' at position 614-615
# Matched 'month' with label 'KEYWORD_month' at position 619-620
# Matched 'month' with label 'MONTH' at position 619-620
# Matched 'Customer' with label 'KEYWORD_customer' at position 622-623
# Matched 'Customer' with label 'CUSTOMER' at position 622-623
# Matched 'service' with label 'KEYWORD_service' at position 627-628
# Matched 'service' with label 'SERVICE' at position 627-628
# Matched 'credits' with label 'KEYWORD_credits' at position 628-629
# Matched 'credits' with label 'CREDITS' at position 628-629
# Matched 'Availability' with label 'KEYWORD_availability' at position 633-634
# Matched 'Availability' with label 'AVAILABILITY' at position 633-634
# Matched 'availability' with label 'KEYWORD_availability' at position 642-643
# Matched 'availability' with label 'AVAILABILITY' at position 642-643
# Matched 'service' with label 'KEYWORD_service' at position 646-647
# Matched 'service' with label 'SERVICE' at position 646-647
# Matched 'credit' with label 'KEYWORD_credit' at position 647-648
# Matched 'credit' with label 'CREDIT' at position 647-648
# Matched 'fee' with label 'KEYWORD_fee' at position 650-651
# Matched 'fee' with label 'FEE' at position 650-651
# Matched 'availability' with label 'KEYWORD_availability' at position 659-660
# Matched 'availability' with label 'AVAILABILITY' at position 659-660
# Matched 'service' with label 'KEYWORD_service' at position 663-664
# Matched 'service' with label 'SERVICE' at position 663-664
# Matched 'credit' with label 'KEYWORD_credit' at position 664-665
# Matched 'credit' with label 'CREDIT' at position 664-665
# Matched 'fee' with label 'KEYWORD_fee' at position 667-668
# Matched 'fee' with label 'FEE' at position 667-668
# Matched 'availability' with label 'KEYWORD_availability' at position 673-674
# Matched 'availability' with label 'AVAILABILITY' at position 673-674
# Matched 'service' with label 'KEYWORD_service' at position 677-678
# Matched 'service' with label 'SERVICE' at position 677-678
# Matched 'credit' with label 'KEYWORD_credit' at position 678-679
# Matched 'credit' with label 'CREDIT' at position 678-679
# Matched 'fee' with label 'KEYWORD_fee' at position 681-682
# Matched 'fee' with label 'FEE' at position 681-682
# Matched 'Throughput' with label 'KEYWORD_throughput' at position 684-685
# Matched 'Throughput' with label 'THROUGHPUT' at position 684-685
# Matched 'Downlink' with label 'KEYWORD_downlink' at position 686-687
# Matched 'Downlink' with label 'DOWNLINK' at position 686-687
# Matched 'Uplink' with label 'KEYWORD_uplink' at position 688-689
# Matched 'Uplink' with label 'UPLINK' at position 688-689
# Matched 'Minimum' with label 'KEYWORD_minimum' at position 692-693
# Matched 'Minimum' with label 'MINIMUM' at position 692-693
# Matched 'Guaranteed' with label 'KEYWORD_guaranteed' at position 693-694
# Matched 'Guaranteed' with label 'GUARANTEED' at position 693-694
# Matched 'reporting' with label 'KEYWORD_reporting' at position 704-705
# Matched 'reporting' with label 'REPORTING' at position 704-705
# Matched 'period' with label 'KEYWORD_period' at position 705-706
# Matched 'period' with label 'PERIOD' at position 705-706
# Matched 'service' with label 'KEYWORD_service' at position 709-710
# Matched 'service' with label 'SERVICE' at position 709-710
# Matched 'credit' with label 'KEYWORD_credit' at position 710-711
# Matched 'credit' with label 'CREDIT' at position 710-711
# Matched 'fee' with label 'KEYWORD_fee' at position 713-714
# Matched 'fee' with label 'FEE' at position 713-714
# Matched 'metric' with label 'KEYWORD_metric' at position 715-716
# Matched 'metric' with label 'METRIC' at position 715-716
# Matched 'Latency' with label 'KEYWORD_latency' at position 718-719
# Matched 'Latency' with label 'LATENCY' at position 718-719
# Matched 'Packet' with label 'KEYWORD_packet' at position 720-721
# Matched 'Packet' with label 'PACKET' at position 720-721
# Matched 'Loss' with label 'KEYWORD_loss' at position 721-722
# Matched 'Loss' with label 'LOSS' at position 721-722
# Matched 'Jitter' with label 'KEYWORD_jitter' at position 723-724
# Matched 'Jitter' with label 'JITTER' at position 723-724
# Matched 'Maximum' with label 'KEYWORD_maximum' at position 726-727
# Matched 'Maximum' with label 'MAXIMUM' at position 726-727
# Matched 'reporting' with label 'KEYWORD_reporting' at position 737-738
# Matched 'reporting' with label 'REPORTING' at position 737-738
# Matched 'period' with label 'KEYWORD_period' at position 738-739
# Matched 'period' with label 'PERIOD' at position 738-739
# Matched 'service' with label 'KEYWORD_service' at position 742-743
# Matched 'service' with label 'SERVICE' at position 742-743
# Matched 'credit' with label 'KEYWORD_credit' at position 743-744
# Matched 'credit' with label 'CREDIT' at position 743-744
# Matched 'fee' with label 'KEYWORD_fee' at position 746-747
# Matched 'fee' with label 'FEE' at position 746-747
# Matched 'metric' with label 'KEYWORD_metric' at position 748-749
# Matched 'metric' with label 'METRIC' at position 748-749
# Matched 'Service' with label 'KEYWORD_service' at position 751-752
# Matched 'Service' with label 'SERVICE' at position 751-752
# Matched 'credits' with label 'KEYWORD_credits' at position 752-753
# Matched 'credits' with label 'CREDITS' at position 752-753
# Matched 'month' with label 'KEYWORD_month' at position 759-760
# Matched 'month' with label 'MONTH' at position 759-760
# Matched 'invoice' with label 'KEYWORD_invoice' at position 761-762
# Matched 'invoice' with label 'INVOICE' at position 761-762
# Matched 'service' with label 'KEYWORD_service' at position 764-765
# Matched 'service' with label 'SERVICE' at position 764-765
# Matched 'credits' with label 'KEYWORD_credits' at position 765-766
# Matched 'credits' with label 'CREDITS' at position 765-766
# Matched 'month' with label 'KEYWORD_month' at position 769-770
# Matched 'month' with label 'MONTH' at position 769-770
# Matched 'service' with label 'KEYWORD_service' at position 779-780
# Matched 'service' with label 'SERVICE' at position 779-780
# Matched 'fee' with label 'KEYWORD_fee' at position 780-781
# Matched 'fee' with label 'FEE' at position 780-781
# Matched 'Responsibilities' with label 'KEYWORD_responsibilities' at position 785-786
# Matched 'Responsibilities' with label 'RESPONSIBILITIES' at position 785-786
# Matched 'Parties' with label 'KEYWORD_parties' at position 788-789
# Matched 'Parties' with label 'PARTIES' at position 788-789
# Matched 'NexGen' with label 'KEYWORD_nexgen' at position 792-793
# Matched 'NexGen' with label 'NEXGEN' at position 792-793
# Matched 'Telecom' with label 'KEYWORD_telecom' at position 793-794
# Matched 'Telecom' with label 'TELECOM' at position 793-794
# Matched 'Service' with label 'KEYWORD_service' at position 796-797
# Matched 'Service' with label 'SERVICE' at position 796-797
# Matched 'Provider' with label 'KEYWORD_provider' at position 797-798
# Matched 'Provider' with label 'PROVIDER' at position 797-798
# Matched 'network' with label 'KEYWORD_network' at position 804-805
# Matched 'network' with label 'NETWORK' at position 804-805
# Matched 'infrastructure' with label 'KEYWORD_infrastructure' at position 805-806
# Matched 'infrastructure' with label 'INFRASTRUCTURE' at position 805-806
# Matched 'SLOs' with label 'KEYWORD_slos' at position 810-811
# Matched 'SLOs' with label 'SLOS' at position 810-811
# Matched 'support' with label 'KEYWORD_support' at position 816-817
# Matched 'support' with label 'SUPPORT' at position 816-817
# Matched 'Monitor' with label 'KEYWORD_monitor' at position 819-820
# Matched 'Monitor' with label 'MONITOR' at position 819-820
# Matched 'service' with label 'KEYWORD_service' at position 820-821
# Matched 'service' with label 'SERVICE' at position 820-821
# Matched 'performance' with label 'KEYWORD_performance' at position 821-822
# Matched 'performance' with label 'PERFORMANCE' at position 821-822
# Matched 'reports' with label 'KEYWORD_reports' at position 825-826
# Matched 'reports' with label 'REPORTS' at position 825-826
# Matched 'Customer' with label 'KEYWORD_customer' at position 828-829
# Matched 'Customer' with label 'CUSTOMER' at position 828-829
# Matched 'Notify' with label 'KEYWORD_notify' at position 831-832
# Matched 'Notify' with label 'NOTIFY' at position 831-832
# Matched 'Customer' with label 'KEYWORD_customer' at position 832-833
# Matched 'Customer' with label 'CUSTOMER' at position 832-833
# Matched 'maintenance' with label 'KEYWORD_maintenance' at position 835-836
# Matched 'maintenance' with label 'MAINTENANCE' at position 835-836
# Matched 'activities' with label 'KEYWORD_activities' at position 836-837
# Matched 'activities' with label 'ACTIVITIES' at position 836-837
# Matched 'hours' with label 'KEYWORD_hours' at position 840-841
# Matched 'hours' with label 'HOURS' at position 840-841
# Matched 'advance' with label 'KEYWORD_advance' at position 842-843
# Matched 'advance' with label 'ADVANCE' at position 842-843
# Matched 'Respond' with label 'KEYWORD_respond' at position 845-846
# Matched 'Respond' with label 'RESPOND' at position 845-846
# Matched 'service' with label 'KEYWORD_service' at position 849-850
# Matched 'service' with label 'SERVICE' at position 849-850
# Matched 'incidents' with label 'KEYWORD_incidents' at position 850-851
# Matched 'incidents' with label 'INCIDENTS' at position 850-851
# Matched 'support' with label 'KEYWORD_support' at position 854-855
# Matched 'support' with label 'SUPPORT' at position 854-855
# Matched 'Enterprise' with label 'KEYWORD_enterprise' at position 860-861
# Matched 'Enterprise' with label 'ENTERPRISE' at position 860-861
# Matched 'Solutions' with label 'KEYWORD_solutions' at position 861-862
# Matched 'Solutions' with label 'SOLUTIONS' at position 861-862
# Matched 'Customer' with label 'KEYWORD_customer' at position 864-865
# Matched 'Customer' with label 'CUSTOMER' at position 864-865
# Matched 'access' with label 'KEYWORD_access' at position 869-870
# Matched 'access' with label 'ACCESS' at position 869-870
# Matched 'customer' with label 'KEYWORD_customer' at position 871-872
# Matched 'customer' with label 'CUSTOMER' at position 871-872
# Matched 'premises' with label 'KEYWORD_premises' at position 872-873
# Matched 'premises' with label 'PREMISES' at position 872-873
# Matched 'equipment' with label 'KEYWORD_equipment' at position 874-875
# Matched 'equipment' with label 'EQUIPMENT' at position 874-875
# Matched 'installation' with label 'KEYWORD_installation' at position 875-876
# Matched 'installation' with label 'INSTALLATION' at position 875-876
# Matched 'maintenance' with label 'KEYWORD_maintenance' at position 877-878
# Matched 'maintenance' with label 'MAINTENANCE' at position 877-878
# Matched 'functioning' with label 'KEYWORD_functioning' at position 882-883
# Matched 'functioning' with label 'FUNCTIONING' at position 882-883
# Matched 'customer' with label 'KEYWORD_customer' at position 884-885
# Matched 'customer' with label 'CUSTOMER' at position 884-885
# Matched 'equipment' with label 'KEYWORD_equipment' at position 887-888
# Matched 'equipment' with label 'EQUIPMENT' at position 887-888
# Matched 'CPE' with label 'KEYWORD_cpe' at position 889-890
# Matched 'CPE' with label 'CPE' at position 889-890
# Matched 'devices' with label 'KEYWORD_devices' at position 892-893
# Matched 'devices' with label 'DEVICES' at position 892-893
# Matched 'Notify' with label 'KEYWORD_notify' at position 895-896
# Matched 'Notify' with label 'NOTIFY' at position 895-896
# Matched 'NexGen' with label 'KEYWORD_nexgen' at position 896-897
# Matched 'NexGen' with label 'NEXGEN' at position 896-897
# Matched 'Telecom' with label 'KEYWORD_telecom' at position 897-898
# Matched 'Telecom' with label 'TELECOM' at position 897-898
# Matched 'service' with label 'KEYWORD_service' at position 902-903
# Matched 'service' with label 'SERVICE' at position 902-903
# Matched 'issues' with label 'KEYWORD_issues' at position 903-904
# Matched 'issues' with label 'ISSUES' at position 903-904
# Matched 'usage' with label 'KEYWORD_usage' at position 910-911
# Matched 'usage' with label 'USAGE' at position 910-911
# Matched 'policy' with label 'KEYWORD_policy' at position 911-912
# Matched 'policy' with label 'POLICY' at position 911-912
# Matched 'Appendix' with label 'KEYWORD_appendix' at position 918-919
# Matched 'Appendix' with label 'APPENDIX' at position 918-919
# Matched 'Support' with label 'KEYWORD_support' at position 925-926
# Matched 'Support' with label 'SUPPORT' at position 925-926
# Matched 'Incident' with label 'KEYWORD_incident' at position 927-928
# Matched 'Incident' with label 'INCIDENT' at position 927-928
# Matched 'Management' with label 'KEYWORD_management' at position 928-929
# Matched 'Management' with label 'MANAGEMENT' at position 928-929
# Matched 'Support' with label 'KEYWORD_support' at position 932-933
# Matched 'Support' with label 'SUPPORT' at position 932-933
# Matched 'Channels' with label 'KEYWORD_channels' at position 933-934
# Matched 'Channels' with label 'CHANNELS' at position 933-934
# Matched 'Online' with label 'KEYWORD_online' at position 936-937
# Matched 'Online' with label 'ONLINE' at position 936-937
# Matched 'Portal' with label 'KEYWORD_portal' at position 937-938
# Matched 'Portal' with label 'PORTAL' at position 937-938
# Matched 'incident' with label 'KEYWORD_incident' at position 942-943
# Matched 'incident' with label 'INCIDENT' at position 942-943
# Matched 'reporting' with label 'KEYWORD_reporting' at position 943-944
# Matched 'reporting' with label 'REPORTING' at position 943-944
# Matched 'Phone' with label 'KEYWORD_phone' at position 948-949
# Matched 'Phone' with label 'PHONE' at position 948-949
# Matched 'Support' with label 'KEYWORD_support' at position 949-950
# Matched 'Support' with label 'SUPPORT' at position 949-950
# Matched 'critical' with label 'KEYWORD_critical' at position 960-961
# Matched 'critical' with label 'CRITICAL' at position 960-961
# Matched 'incidents' with label 'KEYWORD_incidents' at position 961-962
# Matched 'incidents' with label 'INCIDENTS' at position 961-962
# Matched 'PM' with label 'KEYWORD_pm' at position 967-968
# Matched 'PM' with label 'PM' at position 967-968
# Matched 'general' with label 'KEYWORD_general' at position 972-973
# Matched 'general' with label 'GENERAL' at position 972-973
# Matched 'inquiries' with label 'KEYWORD_inquiries' at position 973-974
# Matched 'inquiries' with label 'INQUIRIES' at position 973-974
# Matched 'Email' with label 'KEYWORD_email' at position 977-978
# Matched 'Email' with label 'EMAIL' at position 977-978
# Matched 'Support' with label 'KEYWORD_support' at position 978-979
# Matched 'Support' with label 'SUPPORT' at position 978-979
# Matched 'PM' with label 'KEYWORD_pm' at position 987-988
# Matched 'PM' with label 'PM' at position 987-988
# Matched 'Incident' with label 'KEYWORD_incident' at position 996-997
# Matched 'Incident' with label 'INCIDENT' at position 996-997
# Matched 'Prioritization' with label 'KEYWORD_prioritization' at position 997-998
# Matched 'Prioritization' with label 'PRIORITIZATION' at position 997-998
# Matched 'Critical' with label 'KEYWORD_critical' at position 1000-1001
# Matched 'Critical' with label 'CRITICAL' at position 1000-1001
# Matched 'service' with label 'KEYWORD_service' at position 1005-1006
# Matched 'service' with label 'SERVICE' at position 1005-1006
# Matched 'outage' with label 'KEYWORD_outage' at position 1006-1007
# Matched 'outage' with label 'OUTAGE' at position 1006-1007
# Matched 'degradation' with label 'KEYWORD_degradation' at position 1009-1010
# Matched 'degradation' with label 'DEGRADATION' at position 1009-1010
# Matched 'users' with label 'KEYWORD_users' at position 1012-1013
# Matched 'users' with label 'USERS' at position 1012-1013
# Matched 'Target' with label 'KEYWORD_target' at position 1014-1015
# Matched 'Target' with label 'TARGET' at position 1014-1015
# Matched 'Resolution' with label 'KEYWORD_resolution' at position 1015-1016
# Matched 'Resolution' with label 'RESOLUTION' at position 1015-1016
# Matched 'Time' with label 'KEYWORD_time' at position 1016-1017
# Matched 'Time' with label 'TIME' at position 1016-1017
# Matched 'hours' with label 'KEYWORD_hours' at position 1021-1022
# Matched 'hours' with label 'HOURS' at position 1021-1022
# Matched 'High' with label 'KEYWORD_high' at position 1024-1025
# Matched 'High' with label 'HIGH' at position 1024-1025
# Matched 'service' with label 'KEYWORD_service' at position 1029-1030
# Matched 'service' with label 'SERVICE' at position 1029-1030
# Matched 'degradation' with label 'KEYWORD_degradation' at position 1030-1031
# Matched 'degradation' with label 'DEGRADATION' at position 1030-1031
# Matched 'subset' with label 'KEYWORD_subset' at position 1033-1034
# Matched 'subset' with label 'SUBSET' at position 1033-1034
# Matched 'users' with label 'KEYWORD_users' at position 1035-1036
# Matched 'users' with label 'USERS' at position 1035-1036
# Matched 'critical' with label 'KEYWORD_critical' at position 1037-1038
# Matched 'critical' with label 'CRITICAL' at position 1037-1038
# Matched 'applications' with label 'KEYWORD_applications' at position 1038-1039
# Matched 'applications' with label 'APPLICATIONS' at position 1038-1039
# Matched 'hours' with label 'KEYWORD_hours' at position 1043-1044
# Matched 'hours' with label 'HOURS' at position 1043-1044
# Matched 'Medium' with label 'KEYWORD_medium' at position 1046-1047
# Matched 'Medium' with label 'MEDIUM' at position 1046-1047
# Matched 'service' with label 'KEYWORD_service' at position 1051-1052
# Matched 'service' with label 'SERVICE' at position 1051-1052
# Matched 'degradation' with label 'KEYWORD_degradation' at position 1052-1053
# Matched 'degradation' with label 'DEGRADATION' at position 1052-1053
# Matched 'issues' with label 'KEYWORD_issues' at position 1055-1056
# Matched 'issues' with label 'ISSUES' at position 1055-1056
# Matched 'hours' with label 'KEYWORD_hours' at position 1060-1061
# Matched 'hours' with label 'HOURS' at position 1060-1061
# Matched 'Low' with label 'KEYWORD_low' at position 1063-1064
# Matched 'Low' with label 'LOW' at position 1063-1064
# Matched 'General' with label 'KEYWORD_general' at position 1067-1068
# Matched 'General' with label 'GENERAL' at position 1067-1068
# Matched 'inquiries' with label 'KEYWORD_inquiries' at position 1068-1069
# Matched 'inquiries' with label 'INQUIRIES' at position 1068-1069
# Matched 'service' with label 'KEYWORD_service' at position 1072-1073
# Matched 'service' with label 'SERVICE' at position 1072-1073
# Matched 'issues' with label 'KEYWORD_issues' at position 1074-1075
# Matched 'issues' with label 'ISSUES' at position 1074-1075
# Matched 'hours' with label 'KEYWORD_hours' at position 1079-1080
# Matched 'hours' with label 'HOURS' at position 1079-1080
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 1084-1085
# Matched 'Reporting' with label 'REPORTING' at position 1084-1085
# Matched 'Communication' with label 'KEYWORD_communication' at position 1086-1087
# Matched 'Communication' with label 'COMMUNICATION' at position 1086-1087
# Matched 'NexGen' with label 'KEYWORD_nexgen' at position 1088-1089
# Matched 'NexGen' with label 'NEXGEN' at position 1088-1089
# Matched 'Telecom' with label 'KEYWORD_telecom' at position 1089-1090
# Matched 'Telecom' with label 'TELECOM' at position 1089-1090
# Matched 'updates' with label 'KEYWORD_updates' at position 1094-1095
# Matched 'updates' with label 'UPDATES' at position 1094-1095
# Matched 'incident' with label 'KEYWORD_incident' at position 1096-1097
# Matched 'incident' with label 'INCIDENT' at position 1096-1097
# Matched 'status' with label 'KEYWORD_status' at position 1097-1098
# Matched 'status' with label 'STATUS' at position 1097-1098
# Matched 'resolution' with label 'KEYWORD_resolution' at position 1099-1100
# Matched 'resolution' with label 'RESOLUTION' at position 1099-1100
# Matched 'Dispute' with label 'KEYWORD_dispute' at position 1104-1105
# Matched 'Dispute' with label 'DISPUTE' at position 1104-1105
# Matched 'Resolution' with label 'KEYWORD_resolution' at position 1105-1106
# Matched 'Resolution' with label 'RESOLUTION' at position 1105-1106
# Matched 'disputes' with label 'KEYWORD_disputes' at position 1108-1109
# Matched 'disputes' with label 'DISPUTES' at position 1108-1109
# Matched 'SLA' with label 'KEYWORD_sla' at position 1112-1113
# Matched 'SLA' with label 'SLA' at position 1112-1113
# Matched 'negotiation' with label 'KEYWORD_negotiation' at position 1124-1125
# Matched 'negotiation' with label 'NEGOTIATION' at position 1124-1125
# Matched 'parties' with label 'KEYWORD_parties' at position 1127-1128
# Matched 'parties' with label 'PARTIES' at position 1127-1128
# Matched 'resolution' with label 'KEYWORD_resolution' at position 1132-1133
# Matched 'resolution' with label 'RESOLUTION' at position 1132-1133
# Matched 'days' with label 'KEYWORD_days' at position 1139-1140
# Matched 'days' with label 'DAYS' at position 1139-1140
# Matched 'party' with label 'KEYWORD_party' at position 1142-1143
# Matched 'party' with label 'PARTY' at position 1142-1143
# Matched 'dispute' with label 'KEYWORD_dispute' at position 1146-1147
# Matched 'dispute' with label 'DISPUTE' at position 1146-1147
# Matched 'Termination' with label 'KEYWORD_termination' at position 1154-1155
# Matched 'Termination' with label 'TERMINATION' at position 1154-1155
# Matched 'SLA' with label 'KEYWORD_sla' at position 1157-1158
# Matched 'SLA' with label 'SLA' at position 1157-1158
# Matched 'party' with label 'KEYWORD_party' at position 1163-1164
# Matched 'party' with label 'PARTY' at position 1163-1164
# Matched 'days' with label 'KEYWORD_days' at position 1166-1167
# Matched 'days' with label 'DAYS' at position 1166-1167
# Matched 'notice' with label 'KEYWORD_notice' at position 1169-1170
# Matched 'notice' with label 'NOTICE' at position 1169-1170
# Matched 'terms' with label 'KEYWORD_terms' at position 1174-1175
# Matched 'terms' with label 'TERMS' at position 1174-1175
# Matched 'service' with label 'KEYWORD_service' at position 1178-1179
# Matched 'service' with label 'SERVICE' at position 1178-1179
# Matched 'agreement' with label 'KEYWORD_agreement' at position 1179-1180
# Matched 'agreement' with label 'AGREEMENT' at position 1179-1180
# Matched 'NexGen' with label 'KEYWORD_nexgen' at position 1181-1182
# Matched 'NexGen' with label 'NEXGEN' at position 1181-1182
# Matched 'Telecom' with label 'KEYWORD_telecom' at position 1182-1183
# Matched 'Telecom' with label 'TELECOM' at position 1182-1183
# Matched 'Enterprise' with label 'KEYWORD_enterprise' at position 1185-1186
# Matched 'Enterprise' with label 'ENTERPRISE' at position 1185-1186
# Matched 'Solutions' with label 'KEYWORD_solutions' at position 1186-1187
# Matched 'Solutions' with label 'SOLUTIONS' at position 1186-1187
# Matched 'Review' with label 'KEYWORD_review' at position 1191-1192
# Matched 'Review' with label 'REVIEW' at position 1191-1192
# Matched 'SLA' with label 'KEYWORD_sla' at position 1196-1197
# Matched 'SLA' with label 'SLA' at position 1196-1197
# Matched 'Effective' with label 'KEYWORD_effective' at position 1206-1207
# Matched 'Effective' with label 'EFFECTIVE' at position 1206-1207
# Matched 'Date' with label 'KEYWORD_date' at position 1207-1208
# Matched 'Date' with label 'DATE' at position 1207-1208
# Matched 'changes' with label 'KEYWORD_changes' at position 1212-1213
# Matched 'changes' with label 'CHANGES' at position 1212-1213
# Matched 'service' with label 'KEYWORD_service' at position 1214-1215
# Matched 'service' with label 'SERVICE' at position 1214-1215
# Matched 'requirements' with label 'KEYWORD_requirements' at position 1215-1216
# Matched 'requirements' with label 'REQUIREMENTS' at position 1215-1216
# Matched 'network' with label 'KEYWORD_network' at position 1217-1218
# Matched 'network' with label 'NETWORK' at position 1217-1218
# Matched 'capabilities' with label 'KEYWORD_capabilities' at position 1218-1219
# Matched 'capabilities' with label 'CAPABILITIES' at position 1218-1219

# %%
# Optional: define custom overrides for certain proper nouns
custom_lemma_map = {
    "Licensor": "license",
    "Licensee": "license"
}

# Print tokens and their lemmas
for token in doc:
    if token.text in custom_lemma_map:
        lemma = custom_lemma_map[token.text]
    else:
        lemma = token.lemma_
    print(f"Token: {token.text} -> Lemma: {lemma}")
# Out:
# Token: Service -> Lemma: Service
# Token: Level -> Lemma: Level
# Token: Agreement -> Lemma: Agreement
# Token: ( -> Lemma: (
# Token: SLA -> Lemma: SLA
# Token: ) -> Lemma: )
# Token: - -> Lemma: -
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: Enhanced -> Lemma: Enhanced
# Token: Mobile -> Lemma: Mobile
# Token: Broadband -> Lemma: Broadband
# Token: ( -> Lemma: (
# Token: eMBB -> Lemma: eMBB
# Token: ) -> Lemma: )
# Token: Service -> Lemma: Service
# Token:
#
#  -> Lemma:
#
#
# Token: Agreement -> Lemma: Agreement
# Token: ID -> Lemma: ID
# Token: : -> Lemma: :
# Token: SLA-5G -> Lemma: SLA-5G
# Token: - -> Lemma: -
# Token: eMBB-001 -> Lemma: embb-001
# Token: - -> Lemma: -
# Token: 20250626 -> Lemma: 20250626
# Token:
#  -> Lemma:
#
# Token: Effective -> Lemma: Effective
# Token: Date -> Lemma: date
# Token: : -> Lemma: :
# Token: 2025 -> Lemma: 2025
# Token: - -> Lemma: -
# Token: 07 -> Lemma: 07
# Token: - -> Lemma: -
# Token: 01 -> Lemma: 01
# Token:
#  -> Lemma:
#
# Token: Service -> Lemma: Service
# Token: Provider -> Lemma: Provider
# Token: : -> Lemma: :
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token:
#  -> Lemma:
#
# Token: Customer -> Lemma: customer
# Token: : -> Lemma: :
# Token: Enterprise -> Lemma: Enterprise
# Token: Solutions -> Lemma: Solutions
# Token: Corp. -> Lemma: Corp.
# Token:
#  -> Lemma:
#
# Token: Service -> Lemma: Service
# Token: Type -> Lemma: Type
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: Enhanced -> Lemma: Enhanced
# Token: Mobile -> Lemma: Mobile
# Token: Broadband -> Lemma: Broadband
# Token: ( -> Lemma: (
# Token: eMBB -> Lemma: eMBB
# Token: ) -> Lemma: )
# Token: - -> Lemma: -
# Token: High -> Lemma: High
# Token: - -> Lemma: -
# Token: Capacity -> Lemma: Capacity
# Token: Data -> Lemma: Data
# Token: Service -> Lemma: Service
# Token:
#
#  -> Lemma:
#
#
# Token: 1 -> Lemma: 1
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Description -> Lemma: Description
# Token:
#
#  -> Lemma:
#
#
# Token: This -> Lemma: this
# Token: SLA -> Lemma: SLA
# Token: outlines -> Lemma: outline
# Token: the -> Lemma: the
# Token: terms -> Lemma: term
# Token: and -> Lemma: and
# Token: conditions -> Lemma: condition
# Token: for -> Lemma: for
# Token: the -> Lemma: the
# Token: provision -> Lemma: provision
# Token: of -> Lemma: of
# Token: a -> Lemma: a
# Token: dedicated -> Lemma: dedicated
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: Enhanced -> Lemma: enhanced
# Token: Mobile -> Lemma: Mobile
# Token: Broadband -> Lemma: Broadband
# Token: ( -> Lemma: (
# Token: eMBB -> Lemma: eMBB
# Token: ) -> Lemma: )
# Token: service -> Lemma: service
# Token: to -> Lemma: to
# Token: Enterprise -> Lemma: Enterprise
# Token: Solutions -> Lemma: Solutions
# Token: Corp. -> Lemma: Corp.
# Token: This -> Lemma: this
# Token: service -> Lemma: service
# Token: is -> Lemma: be
# Token: designed -> Lemma: design
# Token: to -> Lemma: to
# Token: deliver -> Lemma: deliver
# Token: high -> Lemma: high
# Token: - -> Lemma: -
# Token: throughput -> Lemma: throughput
# Token: , -> Lemma: ,
# Token: low -> Lemma: low
# Token: - -> Lemma: -
# Token: latency -> Lemma: latency
# Token: connectivity -> Lemma: connectivity
# Token: primarily -> Lemma: primarily
# Token: for -> Lemma: for
# Token: data -> Lemma: data
# Token: - -> Lemma: -
# Token: intensive -> Lemma: intensive
# Token: applications -> Lemma: application
# Token: , -> Lemma: ,
# Token: including -> Lemma: include
# Token: but -> Lemma: but
# Token: not -> Lemma: not
# Token: limited -> Lemma: limit
# Token: to -> Lemma: to
# Token: , -> Lemma: ,
# Token: cloud -> Lemma: cloud
# Token: computing -> Lemma: computing
# Token: , -> Lemma: ,
# Token: high -> Lemma: high
# Token: - -> Lemma: -
# Token: definition -> Lemma: definition
# Token: video -> Lemma: video
# Token: streaming -> Lemma: streaming
# Token: , -> Lemma: ,
# Token: and -> Lemma: and
# Token: large -> Lemma: large
# Token: file -> Lemma: file
# Token: transfers -> Lemma: transfer
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 2 -> Lemma: 2
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Scope -> Lemma: Scope
# Token:
#
#  -> Lemma:
#
#
# Token: Geographic -> Lemma: Geographic
# Token: Coverage -> Lemma: Coverage
# Token: : -> Lemma: :
# Token: Primary -> Lemma: primary
# Token: service -> Lemma: service
# Token: area -> Lemma: area
# Token: : -> Lemma: :
# Token: Metropolitan -> Lemma: Metropolitan
# Token: Region -> Lemma: Region
# Token: X -> Lemma: X
# Token: , -> Lemma: ,
# Token: with -> Lemma: with
# Token: secondary -> Lemma: secondary
# Token: coverage -> Lemma: coverage
# Token: in -> Lemma: in
# Token: Industrial -> Lemma: Industrial
# Token: Zone -> Lemma: Zone
# Token: Y. -> Lemma: Y.
# Token: Specific -> Lemma: Specific
# Token: cell -> Lemma: cell
# Token: IDs -> Lemma: id
# Token: and -> Lemma: and
# Token: coverage -> Lemma: coverage
# Token: maps -> Lemma: map
# Token: are -> Lemma: be
# Token: attached -> Lemma: attach
# Token: as -> Lemma: as
# Token: Appendix -> Lemma: Appendix
# Token: A. -> Lemma: a.
# Token:
#
#  -> Lemma:
#
#
# Token: User -> Lemma: User
# Token: Devices -> Lemma: Devices
# Token: : -> Lemma: :
# Token: Support -> Lemma: support
# Token: for -> Lemma: for
# Token: 5G -> Lemma: 5g
# Token: - -> Lemma: -
# Token: compliant -> Lemma: compliant
# Token: devices -> Lemma: device
# Token: ( -> Lemma: (
# Token: smartphones -> Lemma: smartphone
# Token: , -> Lemma: ,
# Token: tablets -> Lemma: tablet
# Token: , -> Lemma: ,
# Token: IoT -> Lemma: iot
# Token: gateways -> Lemma: gateway
# Token: ) -> Lemma: )
# Token: utilizing -> Lemma: utilize
# Token: the -> Lemma: the
# Token: designated -> Lemma: designate
# Token: SIM -> Lemma: SIM
# Token: cards -> Lemma: card
# Token: / -> Lemma: /
# Token: eSIM -> Lemma: esim
# Token: profiles -> Lemma: profile
# Token: provided -> Lemma: provide
# Token: by -> Lemma: by
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token:
#
#  -> Lemma:
#
#
# Token: Traffic -> Lemma: Traffic
# Token: Prioritization -> Lemma: Prioritization
# Token: : -> Lemma: :
# Token: eMBB -> Lemma: embb
# Token: traffic -> Lemma: traffic
# Token: will -> Lemma: will
# Token: receive -> Lemma: receive
# Token: priority -> Lemma: priority
# Token: over -> Lemma: over
# Token: best -> Lemma: good
# Token: - -> Lemma: -
# Token: effort -> Lemma: effort
# Token: traffic -> Lemma: traffic
# Token: within -> Lemma: within
# Token: the -> Lemma: the
# Token: defined -> Lemma: define
# Token: service -> Lemma: service
# Token: slices -> Lemma: slice
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3 -> Lemma: 3
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Level -> Lemma: Level
# Token: Objectives -> Lemma: Objectives
# Token: ( -> Lemma: (
# Token: SLOs -> Lemma: SLOs
# Token: ) -> Lemma: )
# Token: and -> Lemma: and
# Token: Performance -> Lemma: Performance
# Token: Metrics -> Lemma: Metrics
# Token:
#
#  -> Lemma:
#
#
# Token: The -> Lemma: the
# Token: following -> Lemma: follow
# Token: performance -> Lemma: performance
# Token: metrics -> Lemma: metric
# Token: will -> Lemma: will
# Token: be -> Lemma: be
# Token: measured -> Lemma: measure
# Token: and -> Lemma: and
# Token: monitored -> Lemma: monitor
# Token: to -> Lemma: to
# Token: ensure -> Lemma: ensure
# Token: the -> Lemma: the
# Token: agreed -> Lemma: agree
# Token: - -> Lemma: -
# Token: upon -> Lemma: upon
# Token: service -> Lemma: service
# Token: levels -> Lemma: level
# Token: are -> Lemma: be
# Token: met -> Lemma: meet
# Token: . -> Lemma: .
# Token: All -> Lemma: all
# Token: measurements -> Lemma: measurement
# Token: are -> Lemma: be
# Token: based -> Lemma: base
# Token: on -> Lemma: on
# Token: aggregated -> Lemma: aggregate
# Token: data -> Lemma: datum
# Token: over -> Lemma: over
# Token: 15 -> Lemma: 15
# Token: - -> Lemma: -
# Token: minute -> Lemma: minute
# Token: intervals -> Lemma: interval
# Token: , -> Lemma: ,
# Token: unless -> Lemma: unless
# Token: otherwise -> Lemma: otherwise
# Token: specified -> Lemma: specify
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.1 -> Lemma: 3.1
# Token: . -> Lemma: .
# Token: Throughput -> Lemma: Throughput
# Token: ( -> Lemma: (
# Token: Downlink -> Lemma: Downlink
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: Average -> Lemma: average
# Token: downlink -> Lemma: downlink
# Token: throughput -> Lemma: throughput
# Token: of -> Lemma: of
# Token: 1 -> Lemma: 1
# Token: Gbps -> Lemma: Gbps
# Token: ( -> Lemma: (
# Token: Gigabits -> Lemma: gigabit
# Token: per -> Lemma: per
# Token: second -> Lemma: second
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Minimum -> Lemma: Minimum
# Token: Guaranteed -> Lemma: Guaranteed
# Token: : -> Lemma: :
# Token: 750 -> Lemma: 750
# Token: Mbps -> Lemma: Mbps
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: Point -> Lemma: Point
# Token: : -> Lemma: :
# Token: User -> Lemma: User
# Token: Plane -> Lemma: Plane
# Token: Function -> Lemma: Function
# Token: ( -> Lemma: (
# Token: UPF -> Lemma: UPF
# Token: ) -> Lemma: )
# Token: egress -> Lemma: egress
# Token: to -> Lemma: to
# Token: customer -> Lemma: customer
# Token: premises -> Lemma: premise
# Token: equipment -> Lemma: equipment
# Token: ( -> Lemma: (
# Token: CPE -> Lemma: CPE
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: report
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Daily -> Lemma: Daily
# Token: aggregated -> Lemma: aggregate
# Token: reports -> Lemma: report
# Token: , -> Lemma: ,
# Token: monthly -> Lemma: monthly
# Token: detailed -> Lemma: detailed
# Token: reports -> Lemma: report
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.2 -> Lemma: 3.2
# Token: . -> Lemma: .
# Token: Throughput -> Lemma: Throughput
# Token: ( -> Lemma: (
# Token: Uplink -> Lemma: Uplink
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: Average -> Lemma: average
# Token: uplink -> Lemma: uplink
# Token: throughput -> Lemma: throughput
# Token: of -> Lemma: of
# Token: 200 -> Lemma: 200
# Token: Mbps -> Lemma: Mbps
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Minimum -> Lemma: Minimum
# Token: Guaranteed -> Lemma: Guaranteed
# Token: : -> Lemma: :
# Token: 150 -> Lemma: 150
# Token: Mbps -> Lemma: Mbps
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: Point -> Lemma: Point
# Token: : -> Lemma: :
# Token: CPE -> Lemma: CPE
# Token: ingress -> Lemma: ingress
# Token: to -> Lemma: to
# Token: UPF -> Lemma: UPF
# Token: ingress -> Lemma: ingress
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Daily -> Lemma: Daily
# Token: aggregated -> Lemma: aggregate
# Token: reports -> Lemma: report
# Token: , -> Lemma: ,
# Token: monthly -> Lemma: monthly
# Token: detailed -> Lemma: detailed
# Token: reports -> Lemma: report
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.3 -> Lemma: 3.3
# Token: . -> Lemma: .
# Token: Latency -> Lemma: Latency
# Token: ( -> Lemma: (
# Token: Round -> Lemma: Round
# Token: Trip -> Lemma: Trip
# Token: Time -> Lemma: Time
# Token: - -> Lemma: -
# Token: RTT -> Lemma: RTT
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: Average -> Lemma: average
# Token: end -> Lemma: end
# Token: - -> Lemma: -
# Token: to -> Lemma: to
# Token: - -> Lemma: -
# Token: end -> Lemma: end
# Token: latency -> Lemma: latency
# Token: of -> Lemma: of
# Token: less -> Lemma: less
# Token: than -> Lemma: than
# Token: 10 -> Lemma: 10
# Token: ms -> Lemma: ms
# Token: ( -> Lemma: (
# Token: milliseconds -> Lemma: milliseconds
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Maximum -> Lemma: Maximum
# Token: Tolerated -> Lemma: Tolerated
# Token: : -> Lemma: :
# Token: 15 -> Lemma: 15
# Token: ms -> Lemma: ms
# Token: for -> Lemma: for
# Token: 99.9 -> Lemma: 99.9
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: traffic -> Lemma: traffic
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: Point -> Lemma: Point
# Token: : -> Lemma: :
# Token: From -> Lemma: from
# Token: customer -> Lemma: customer
# Token: device -> Lemma: device
# Token: to -> Lemma: to
# Token: designated -> Lemma: designate
# Token: core -> Lemma: core
# Token: network -> Lemma: network
# Token: gateway -> Lemma: gateway
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Hourly -> Lemma: Hourly
# Token: aggregated -> Lemma: aggregate
# Token: reports -> Lemma: report
# Token: , -> Lemma: ,
# Token: weekly -> Lemma: weekly
# Token: detailed -> Lemma: detailed
# Token: reports -> Lemma: report
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.4 -> Lemma: 3.4
# Token: . -> Lemma: .
# Token: Jitter -> Lemma: jitter
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: Maximum -> Lemma: maximum
# Token: jitter -> Lemma: jitter
# Token: of -> Lemma: of
# Token: 2 -> Lemma: 2
# Token: ms -> Lemma: ms
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: Point -> Lemma: Point
# Token: : -> Lemma: :
# Token: From -> Lemma: from
# Token: customer -> Lemma: customer
# Token: device -> Lemma: device
# Token: to -> Lemma: to
# Token: designated -> Lemma: designate
# Token: core -> Lemma: core
# Token: network -> Lemma: network
# Token: gateway -> Lemma: gateway
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Hourly -> Lemma: Hourly
# Token: aggregated -> Lemma: aggregate
# Token: reports -> Lemma: report
# Token: , -> Lemma: ,
# Token: weekly -> Lemma: weekly
# Token: detailed -> Lemma: detailed
# Token: reports -> Lemma: report
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.5 -> Lemma: 3.5
# Token: . -> Lemma: .
# Token: Packet -> Lemma: Packet
# Token: Loss -> Lemma: Loss
# Token: Rate -> Lemma: Rate
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: Less -> Lemma: Less
# Token: than -> Lemma: than
# Token: 0.01 -> Lemma: 0.01
# Token: % -> Lemma: %
# Token: packet -> Lemma: packet
# Token: loss -> Lemma: loss
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Maximum -> Lemma: Maximum
# Token: Tolerated -> Lemma: Tolerated
# Token: : -> Lemma: :
# Token: 0.05 -> Lemma: 0.05
# Token: % -> Lemma: %
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: Point -> Lemma: Point
# Token: : -> Lemma: :
# Token: End -> Lemma: end
# Token: - -> Lemma: -
# Token: to -> Lemma: to
# Token: - -> Lemma: -
# Token: end -> Lemma: end
# Token: across -> Lemma: across
# Token: the -> Lemma: the
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: network -> Lemma: network
# Token: segment -> Lemma: segment
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Daily -> Lemma: Daily
# Token: aggregated -> Lemma: aggregate
# Token: reports -> Lemma: report
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.6 -> Lemma: 3.6
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Availability -> Lemma: Availability
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: 99.99 -> Lemma: 99.99
# Token: % -> Lemma: %
# Token: availability -> Lemma: availability
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: eMBB -> Lemma: embb
# Token: service -> Lemma: service
# Token: within -> Lemma: within
# Token: the -> Lemma: the
# Token: primary -> Lemma: primary
# Token: service -> Lemma: service
# Token: area -> Lemma: area
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Definition -> Lemma: definition
# Token: : -> Lemma: :
# Token: Uptime -> Lemma: Uptime
# Token: measured -> Lemma: measure
# Token: as -> Lemma: as
# Token: the -> Lemma: the
# Token: percentage -> Lemma: percentage
# Token: of -> Lemma: of
# Token: time -> Lemma: time
# Token: the -> Lemma: the
# Token: service -> Lemma: service
# Token: is -> Lemma: be
# Token: fully -> Lemma: fully
# Token: operational -> Lemma: operational
# Token: and -> Lemma: and
# Token: accessible -> Lemma: accessible
# Token: to -> Lemma: to
# Token: the -> Lemma: the
# Token: customer -> Lemma: customer
# Token: . -> Lemma: .
# Token: Planned -> Lemma: plan
# Token: maintenance -> Lemma: maintenance
# Token: windows -> Lemma: window
# Token: are -> Lemma: be
# Token: excluded -> Lemma: exclude
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Monthly -> Lemma: monthly
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 4 -> Lemma: 4
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Credits -> Lemma: Credits
# Token: and -> Lemma: and
# Token: Penalties -> Lemma: Penalties
# Token:
#
#  -> Lemma:
#
#
# Token: In -> Lemma: in
# Token: the -> Lemma: the
# Token: event -> Lemma: event
# Token: that -> Lemma: that
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token: fails -> Lemma: fail
# Token: to -> Lemma: to
# Token: meet -> Lemma: meet
# Token: the -> Lemma: the
# Token: agreed -> Lemma: agree
# Token: - -> Lemma: -
# Token: upon -> Lemma: upon
# Token: Service -> Lemma: Service
# Token: Level -> Lemma: Level
# Token: Objectives -> Lemma: Objectives
# Token: ( -> Lemma: (
# Token: SLOs -> Lemma: SLOs
# Token: ) -> Lemma: )
# Token: for -> Lemma: for
# Token: a -> Lemma: a
# Token: given -> Lemma: give
# Token: month -> Lemma: month
# Token: , -> Lemma: ,
# Token: the -> Lemma: the
# Token: Customer -> Lemma: Customer
# Token: shall -> Lemma: shall
# Token: be -> Lemma: be
# Token: entitled -> Lemma: entitle
# Token: to -> Lemma: to
# Token: service -> Lemma: service
# Token: credits -> Lemma: credit
# Token: as -> Lemma: as
# Token: follows -> Lemma: follow
# Token: : -> Lemma: :
# Token:
#
#  -> Lemma:
#
#
# Token: Availability -> Lemma: availability
# Token: : -> Lemma: :
# Token:
#
#  -> Lemma:
#
#
# Token: 99.9 -> Lemma: 99.9
# Token: % -> Lemma: %
# Token: to -> Lemma: to
# Token: < -> Lemma: <
# Token: 99.99 -> Lemma: 99.99
# Token: % -> Lemma: %
# Token: availability -> Lemma: availability
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: on -> Lemma: on
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 99.0 -> Lemma: 99.0
# Token: % -> Lemma: %
# Token: to -> Lemma: to
# Token: < -> Lemma: <
# Token: 99.9 -> Lemma: 99.9
# Token: % -> Lemma: %
# Token: availability -> Lemma: availability
# Token: : -> Lemma: :
# Token: 10 -> Lemma: 10
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: on -> Lemma: on
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: < -> Lemma: <
# Token: 99.0 -> Lemma: 99.0
# Token: % -> Lemma: %
# Token: availability -> Lemma: availability
# Token: : -> Lemma: :
# Token: 20 -> Lemma: 20
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: on -> Lemma: on
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Throughput -> Lemma: Throughput
# Token: ( -> Lemma: (
# Token: Downlink -> Lemma: Downlink
# Token: / -> Lemma: /
# Token: Uplink -> Lemma: Uplink
# Token: ) -> Lemma: )
# Token: - -> Lemma: -
# Token: if -> Lemma: if
# Token: Minimum -> Lemma: minimum
# Token: Guaranteed -> Lemma: Guaranteed
# Token: is -> Lemma: be
# Token: not -> Lemma: not
# Token: met -> Lemma: meet
# Token: for -> Lemma: for
# Token: more -> Lemma: more
# Token: than -> Lemma: than
# Token: 5 -> Lemma: 5
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: reporting -> Lemma: reporting
# Token: period -> Lemma: period
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: on -> Lemma: on
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: per -> Lemma: per
# Token: metric -> Lemma: metric
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Latency -> Lemma: Latency
# Token: / -> Lemma: /
# Token: Packet -> Lemma: Packet
# Token: Loss -> Lemma: Loss
# Token: / -> Lemma: /
# Token: Jitter -> Lemma: Jitter
# Token: - -> Lemma: -
# Token: if -> Lemma: if
# Token: Maximum -> Lemma: Maximum
# Token: Tolerated -> Lemma: Tolerated
# Token: is -> Lemma: be
# Token: exceeded -> Lemma: exceed
# Token: for -> Lemma: for
# Token: more -> Lemma: more
# Token: than -> Lemma: than
# Token: 1 -> Lemma: 1
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: reporting -> Lemma: reporting
# Token: period -> Lemma: period
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: on -> Lemma: on
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: per -> Lemma: per
# Token: metric -> Lemma: metric
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Service -> Lemma: service
# Token: credits -> Lemma: credit
# Token: will -> Lemma: will
# Token: be -> Lemma: be
# Token: applied -> Lemma: apply
# Token: to -> Lemma: to
# Token: the -> Lemma: the
# Token: subsequent -> Lemma: subsequent
# Token: month -> Lemma: month
# Token: 's -> Lemma: 's
# Token: invoice -> Lemma: invoice
# Token: . -> Lemma: .
# Token: Total -> Lemma: total
# Token: service -> Lemma: service
# Token: credits -> Lemma: credit
# Token: in -> Lemma: in
# Token: any -> Lemma: any
# Token: given -> Lemma: give
# Token: month -> Lemma: month
# Token: shall -> Lemma: shall
# Token: not -> Lemma: not
# Token: exceed -> Lemma: exceed
# Token: 25 -> Lemma: 25
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: total -> Lemma: total
# Token: monthly -> Lemma: monthly
# Token: service -> Lemma: service
# Token: fee -> Lemma: fee
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 5 -> Lemma: 5
# Token: . -> Lemma: .
# Token: Responsibilities -> Lemma: responsibility
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: Parties -> Lemma: party
# Token:
#
#  -> Lemma:
#
#
# Token: 5.1 -> Lemma: 5.1
# Token: . -> Lemma: .
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token: ( -> Lemma: (
# Token: Service -> Lemma: Service
# Token: Provider -> Lemma: Provider
# Token: ): -> Lemma: ):
# Token:
#
#  -> Lemma:
#
#
# Token: Maintain -> Lemma: maintain
# Token: the -> Lemma: the
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: network -> Lemma: network
# Token: infrastructure -> Lemma: infrastructure
# Token: to -> Lemma: to
# Token: meet -> Lemma: meet
# Token: the -> Lemma: the
# Token: specified -> Lemma: specify
# Token: SLOs -> Lemma: slo
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Provide -> Lemma: provide
# Token: 24/7 -> Lemma: 24/7
# Token: technical -> Lemma: technical
# Token: support -> Lemma: support
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Monitor -> Lemma: Monitor
# Token: service -> Lemma: service
# Token: performance -> Lemma: performance
# Token: and -> Lemma: and
# Token: provide -> Lemma: provide
# Token: regular -> Lemma: regular
# Token: reports -> Lemma: report
# Token: to -> Lemma: to
# Token: the -> Lemma: the
# Token: Customer -> Lemma: Customer
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Notify -> Lemma: Notify
# Token: Customer -> Lemma: Customer
# Token: of -> Lemma: of
# Token: planned -> Lemma: plan
# Token: maintenance -> Lemma: maintenance
# Token: activities -> Lemma: activity
# Token: at -> Lemma: at
# Token: least -> Lemma: least
# Token: 72 -> Lemma: 72
# Token: hours -> Lemma: hour
# Token: in -> Lemma: in
# Token: advance -> Lemma: advance
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Respond -> Lemma: Respond
# Token: to -> Lemma: to
# Token: and -> Lemma: and
# Token: resolve -> Lemma: resolve
# Token: service -> Lemma: service
# Token: incidents -> Lemma: incident
# Token: within -> Lemma: within
# Token: the -> Lemma: the
# Token: defined -> Lemma: define
# Token: support -> Lemma: support
# Token: windows -> Lemma: window
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 5.2 -> Lemma: 5.2
# Token: . -> Lemma: .
# Token: Enterprise -> Lemma: Enterprise
# Token: Solutions -> Lemma: Solutions
# Token: Corp. -> Lemma: Corp.
# Token: ( -> Lemma: (
# Token: Customer -> Lemma: Customer
# Token: ): -> Lemma: ):
# Token:
#
#  -> Lemma:
#
#
# Token: Provide -> Lemma: provide
# Token: necessary -> Lemma: necessary
# Token: access -> Lemma: access
# Token: to -> Lemma: to
# Token: customer -> Lemma: customer
# Token: premises -> Lemma: premise
# Token: for -> Lemma: for
# Token: equipment -> Lemma: equipment
# Token: installation -> Lemma: installation
# Token: and -> Lemma: and
# Token: maintenance -> Lemma: maintenance
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Ensure -> Lemma: ensure
# Token: proper -> Lemma: proper
# Token: functioning -> Lemma: functioning
# Token: of -> Lemma: of
# Token: customer -> Lemma: customer
# Token: - -> Lemma: -
# Token: owned -> Lemma: own
# Token: equipment -> Lemma: equipment
# Token: ( -> Lemma: (
# Token: CPE -> Lemma: CPE
# Token: ) -> Lemma: )
# Token: and -> Lemma: and
# Token: devices -> Lemma: device
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Notify -> Lemma: notify
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token: promptly -> Lemma: promptly
# Token: of -> Lemma: of
# Token: any -> Lemma: any
# Token: service -> Lemma: service
# Token: issues -> Lemma: issue
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Adhere -> Lemma: adhere
# Token: to -> Lemma: to
# Token: the -> Lemma: the
# Token: fair -> Lemma: fair
# Token: usage -> Lemma: usage
# Token: policy -> Lemma: policy
# Token: ( -> Lemma: (
# Token: if -> Lemma: if
# Token: applicable -> Lemma: applicable
# Token: , -> Lemma: ,
# Token: detailed -> Lemma: detail
# Token: in -> Lemma: in
# Token: Appendix -> Lemma: Appendix
# Token: B -> Lemma: B
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 6 -> Lemma: 6
# Token: . -> Lemma: .
# Token: Support -> Lemma: Support
# Token: and -> Lemma: and
# Token: Incident -> Lemma: Incident
# Token: Management -> Lemma: Management
# Token:
#
#  -> Lemma:
#
#
# Token: 6.1 -> Lemma: 6.1
# Token: . -> Lemma: .
# Token: Support -> Lemma: Support
# Token: Channels -> Lemma: Channels
# Token: : -> Lemma: :
# Token:
#
#  -> Lemma:
#
#
# Token: Online -> Lemma: Online
# Token: Portal -> Lemma: Portal
# Token: : -> Lemma: :
# Token: Available -> Lemma: available
# Token: 24/7 -> Lemma: 24/7
# Token: for -> Lemma: for
# Token: incident -> Lemma: incident
# Token: reporting -> Lemma: reporting
# Token: and -> Lemma: and
# Token: tracking -> Lemma: tracking
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Phone -> Lemma: Phone
# Token: Support -> Lemma: support
# Token: : -> Lemma: :
# Token: [ -> Lemma: [
# Token: + -> Lemma: +
# Token: XX -> Lemma: xx
# Token: XXXX -> Lemma: xxxx
# Token: XXXX -> Lemma: xxxx
# Token: ] -> Lemma: ]
# Token: ( -> Lemma: (
# Token: 24/7 -> Lemma: 24/7
# Token: for -> Lemma: for
# Token: critical -> Lemma: critical
# Token: incidents -> Lemma: incident
# Token: , -> Lemma: ,
# Token: 9 -> Lemma: 9
# Token: AM -> Lemma: am
# Token: - -> Lemma: -
# Token: 5 -> Lemma: 5
# Token: PM -> Lemma: PM
# Token: M -> Lemma: M
# Token: - -> Lemma: -
# Token: F -> Lemma: F
# Token: for -> Lemma: for
# Token: general -> Lemma: general
# Token: inquiries -> Lemma: inquiry
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Email -> Lemma: Email
# Token: Support -> Lemma: Support
# Token: : -> Lemma: :
# Token: support@nexgentelecom.com -> Lemma: support@nexgentelecom.com
# Token: ( -> Lemma: (
# Token: Monitored -> Lemma: monitor
# Token: 9 -> Lemma: 9
# Token: AM -> Lemma: AM
# Token: - -> Lemma: -
# Token: 5 -> Lemma: 5
# Token: PM -> Lemma: PM
# Token: M -> Lemma: M
# Token: - -> Lemma: -
# Token: F -> Lemma: F
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 6.2 -> Lemma: 6.2
# Token: . -> Lemma: .
# Token: Incident -> Lemma: Incident
# Token: Prioritization -> Lemma: Prioritization
# Token: : -> Lemma: :
# Token:
#
#  -> Lemma:
#
#
# Token: Critical -> Lemma: Critical
# Token: ( -> Lemma: (
# Token: P1 -> Lemma: P1
# Token: ): -> Lemma: ):
# Token: Complete -> Lemma: complete
# Token: service -> Lemma: service
# Token: outage -> Lemma: outage
# Token: or -> Lemma: or
# Token: severe -> Lemma: severe
# Token: degradation -> Lemma: degradation
# Token: impacting -> Lemma: impact
# Token: all -> Lemma: all
# Token: users -> Lemma: user
# Token: . -> Lemma: .
# Token: Target -> Lemma: Target
# Token: Resolution -> Lemma: Resolution
# Token: Time -> Lemma: Time
# Token: ( -> Lemma: (
# Token: TRT -> Lemma: TRT
# Token: ): -> Lemma: ):
# Token: 4 -> Lemma: 4
# Token: hours -> Lemma: hour
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: High -> Lemma: High
# Token: ( -> Lemma: (
# Token: P2 -> Lemma: p2
# Token: ): -> Lemma: ):
# Token: Significant -> Lemma: significant
# Token: service -> Lemma: service
# Token: degradation -> Lemma: degradation
# Token: impacting -> Lemma: impact
# Token: a -> Lemma: a
# Token: subset -> Lemma: subset
# Token: of -> Lemma: of
# Token: users -> Lemma: user
# Token: or -> Lemma: or
# Token: critical -> Lemma: critical
# Token: applications -> Lemma: application
# Token: . -> Lemma: .
# Token: TRT -> Lemma: TRT
# Token: : -> Lemma: :
# Token: 8 -> Lemma: 8
# Token: hours -> Lemma: hour
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Medium -> Lemma: Medium
# Token: ( -> Lemma: (
# Token: P3 -> Lemma: P3
# Token: ): -> Lemma: ):
# Token: Minor -> Lemma: minor
# Token: service -> Lemma: service
# Token: degradation -> Lemma: degradation
# Token: or -> Lemma: or
# Token: intermittent -> Lemma: intermittent
# Token: issues -> Lemma: issue
# Token: . -> Lemma: .
# Token: TRT -> Lemma: TRT
# Token: : -> Lemma: :
# Token: 24 -> Lemma: 24
# Token: hours -> Lemma: hour
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Low -> Lemma: Low
# Token: ( -> Lemma: (
# Token: P4 -> Lemma: p4
# Token: ): -> Lemma: ):
# Token: General -> Lemma: General
# Token: inquiries -> Lemma: inquiry
# Token: or -> Lemma: or
# Token: non -> Lemma: non
# Token: - -> Lemma: -
# Token: service -> Lemma: service
# Token: impacting -> Lemma: impact
# Token: issues -> Lemma: issue
# Token: . -> Lemma: .
# Token: TRT -> Lemma: TRT
# Token: : -> Lemma: :
# Token: 48 -> Lemma: 48
# Token: hours -> Lemma: hour
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 6.3 -> Lemma: 6.3
# Token: . -> Lemma: .
# Token: Reporting -> Lemma: reporting
# Token: and -> Lemma: and
# Token: Communication -> Lemma: Communication
# Token: : -> Lemma: :
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token: will -> Lemma: will
# Token: provide -> Lemma: provide
# Token: regular -> Lemma: regular
# Token: updates -> Lemma: update
# Token: on -> Lemma: on
# Token: incident -> Lemma: incident
# Token: status -> Lemma: status
# Token: until -> Lemma: until
# Token: resolution -> Lemma: resolution
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 7 -> Lemma: 7
# Token: . -> Lemma: .
# Token: Dispute -> Lemma: Dispute
# Token: Resolution -> Lemma: Resolution
# Token:
#
#  -> Lemma:
#
#
# Token: Any -> Lemma: any
# Token: disputes -> Lemma: dispute
# Token: arising -> Lemma: arise
# Token: from -> Lemma: from
# Token: this -> Lemma: this
# Token: SLA -> Lemma: SLA
# Token: shall -> Lemma: shall
# Token: first -> Lemma: first
# Token: be -> Lemma: be
# Token: attempted -> Lemma: attempt
# Token: to -> Lemma: to
# Token: be -> Lemma: be
# Token: resolved -> Lemma: resolve
# Token: through -> Lemma: through
# Token: good -> Lemma: good
# Token: - -> Lemma: -
# Token: faith -> Lemma: faith
# Token: negotiation -> Lemma: negotiation
# Token: between -> Lemma: between
# Token: the -> Lemma: the
# Token: parties -> Lemma: party
# Token: . -> Lemma: .
# Token: If -> Lemma: if
# Token: an -> Lemma: an
# Token: amicable -> Lemma: amicable
# Token: resolution -> Lemma: resolution
# Token: can -> Lemma: can
# Token: not -> Lemma: not
# Token: be -> Lemma: be
# Token: reached -> Lemma: reach
# Token: within -> Lemma: within
# Token: 30 -> Lemma: 30
# Token: days -> Lemma: day
# Token: , -> Lemma: ,
# Token: either -> Lemma: either
# Token: party -> Lemma: party
# Token: may -> Lemma: may
# Token: escalate -> Lemma: escalate
# Token: the -> Lemma: the
# Token: dispute -> Lemma: dispute
# Token: to -> Lemma: to
# Token: formal -> Lemma: formal
# Token: mediation -> Lemma: mediation
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 8 -> Lemma: 8
# Token: . -> Lemma: .
# Token: Termination -> Lemma: termination
# Token:
#
#  -> Lemma:
#
#
# Token: This -> Lemma: this
# Token: SLA -> Lemma: SLA
# Token: may -> Lemma: may
# Token: be -> Lemma: be
# Token: terminated -> Lemma: terminate
# Token: by -> Lemma: by
# Token: either -> Lemma: either
# Token: party -> Lemma: party
# Token: with -> Lemma: with
# Token: 60 -> Lemma: 60
# Token: days -> Lemma: day
# Token: ' -> Lemma: '
# Token: written -> Lemma: write
# Token: notice -> Lemma: notice
# Token: , -> Lemma: ,
# Token: subject -> Lemma: subject
# Token: to -> Lemma: to
# Token: the -> Lemma: the
# Token: terms -> Lemma: term
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: master -> Lemma: master
# Token: service -> Lemma: service
# Token: agreement -> Lemma: agreement
# Token: between -> Lemma: between
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token: and -> Lemma: and
# Token: Enterprise -> Lemma: Enterprise
# Token: Solutions -> Lemma: Solutions
# Token: Corp. -> Lemma: Corp.
# Token:
#
#  -> Lemma:
#
#
# Token: 9 -> Lemma: 9
# Token: . -> Lemma: .
# Token: Review -> Lemma: Review
# Token: and -> Lemma: and
# Token: Amendment -> Lemma: Amendment
# Token:
#
#  -> Lemma:
#
#
# Token: This -> Lemma: this
# Token: SLA -> Lemma: SLA
# Token: will -> Lemma: will
# Token: be -> Lemma: be
# Token: reviewed -> Lemma: review
# Token: annually -> Lemma: annually
# Token: on -> Lemma: on
# Token: the -> Lemma: the
# Token: anniversary -> Lemma: anniversary
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: Effective -> Lemma: Effective
# Token: Date -> Lemma: Date
# Token: or -> Lemma: or
# Token: sooner -> Lemma: soon
# Token: if -> Lemma: if
# Token: significant -> Lemma: significant
# Token: changes -> Lemma: change
# Token: in -> Lemma: in
# Token: service -> Lemma: service
# Token: requirements -> Lemma: requirement
# Token: or -> Lemma: or
# Token: network -> Lemma: network
# Token: capabilities -> Lemma: capability
# Token: occur -> Lemma: occur
# Token: . -> Lemma: .
# Token: Any -> Lemma: any
# Token: amendments -> Lemma: amendment
# Token: must -> Lemma: must
# Token: be -> Lemma: be
# Token: mutually -> Lemma: mutually
# Token: agreed -> Lemma: agree
# Token: upon -> Lemma: upon
# Token: in -> Lemma: in
# Token: writing -> Lemma: writing
# Token: . -> Lemma: .

# %%
import xml.etree.ElementTree as ET

# Create root XML element
root = ET.Element("keywords")

# Populate XML with keywords and values
for kw, values in matched_keywords.items():
    keyword_elem = ET.SubElement(root, "keyword", name=kw)
    for val in set(values):  # Use set() to avoid duplicates
        ET.SubElement(keyword_elem, "value").text = val

# Save to file
tree = ET.ElementTree(root)
output_filename = "geminiSLA_keyword_values.xml"
tree.write(output_filename, encoding="utf-8", xml_declaration=True)

# Optional: Pretty print to console
xml_str = ET.tostring(root, encoding="unicode")
print("\nGenerated XML:\n")
print(xml_str)
# Out:
# Generated XML:
#
# <keywords><keyword name="sla"><value>first</value><value>5</value></keyword><keyword name="enhanced"><value>5</value></keyword><keyword name="mobile"><value>5</value></keyword><keyword name="effective"><value>2025</value><value>20250626</value></keyword><keyword name="date"><value>2025</value><value>20250626</value><value>07</value></keyword><keyword name="service"><value>01</value><value>10</value><value>20</value><value>2</value><value>1</value><value>4</value><value>3.6</value><value>%</value><value>5</value><value>3</value></keyword><keyword name="provider"><value>01</value></keyword><keyword name="type"><value>5</value></keyword><keyword name="capacity"><value>1</value></keyword><keyword name="data"><value>15</value><value>1</value></keyword><keyword name="description"><value>1</value></keyword><keyword name="provision"><value>5</value></keyword><keyword name="file"><value>2</value></keyword><keyword name="transfers"><value>2</value></keyword><keyword name="scope"><value>2</value></keyword><keyword name="slices"><value>3</value></keyword><keyword name="level"><value>3</value></keyword><keyword name="minute"><value>15</value></keyword><keyword name="intervals"><value>15</value></keyword><keyword name="throughput"><value>Mbps</value><value>3.1</value><value>3.2</value><value>1</value><value>200</value></keyword><keyword name="downlink"><value>1</value></keyword><keyword name="gbps"><value>1</value><value>second</value></keyword><keyword name="gigabits"><value>1</value><value>second</value></keyword><keyword name="minimum"><value>Mbps</value><value>150</value><value>750</value></keyword><keyword name="guaranteed"><value>Mbps</value><value>150</value><value>750</value></keyword><keyword name="mbps"><value>200</value><value>Mbps</value><value>150</value><value>750</value></keyword><keyword name="measurement"><value>%</value><value>ms</value><value>Mbps</value></keyword><keyword name="reports"><value>3.2</value><value>3.3</value><value>3.4</value><value>3.6</value><value>3.5</value></keyword><keyword name="uplink"><value>200</value><value>Mbps</value></keyword><keyword name="latency"><value>3.3</value><value>10</value></keyword><keyword name="ms"><value>10</value><value>2</value><value>ms</value><value>milliseconds</value><value>%</value><value>15</value><value>99.9</value></keyword><keyword name="milliseconds"><value>milliseconds</value><value>ms</value><value>10</value></keyword><keyword name="maximum"><value>0.05</value><value>2</value><value>ms</value><value>%</value><value>15</value></keyword><keyword name="traffic"><value>%</value><value>99.9</value></keyword><keyword name="jitter"><value>2</value><value>3.4</value><value>ms</value></keyword><keyword name="packet"><value>0.01</value><value>%</value><value>3.5</value></keyword><keyword name="loss"><value>0.01</value><value>%</value><value>3.5</value></keyword><keyword name="objective"><value>99.99</value><value>%</value><value>0.01</value></keyword><keyword name="end"><value>5</value></keyword><keyword name="network"><value>5</value></keyword><keyword name="segment"><value>5</value></keyword><keyword name="availability"><value>99.0</value><value>5</value><value>10</value><value>20</value><value>99.99</value><value>3.6</value><value>%</value><value>99.9</value></keyword><keyword name="embb"><value>5</value></keyword><keyword name="credits"><value>4</value></keyword><keyword name="credit"><value>%</value><value>10</value><value>5</value><value>20</value></keyword><keyword name="fee"><value>%</value><value>99.0</value><value>5</value></keyword><keyword name="reporting"><value>%</value><value>6.3</value><value>5</value><value>24/7</value></keyword><keyword name="period"><value>%</value><value>5</value></keyword><keyword name="month"><value>25</value></keyword><keyword name="responsibilities"><value>5</value></keyword><keyword name="parties"><value>5.1</value></keyword><keyword name="nexgen"><value>5.1</value></keyword><keyword name="telecom"><value>5.1</value></keyword><keywor ...

# %%
import time
import matplotlib.pyplot as plt

# Create a temporary matcher to test individual keyword timing
timings = []

for kw in sorted(keywords):
    temp_matcher = Matcher(nlp.vocab)
    temp_matcher.add("KEYWORD_TEMP", [[{"LOWER": kw.lower()}]])

    start_time = time.perf_counter()
    temp_matcher(doc)
    elapsed_time = time.perf_counter() - start_time

    timings.append((kw, elapsed_time))

# %%
# Sort by time
timings.sort(key=lambda x: x[1], reverse=True)

# Prepare data
keywords_sorted, times_sorted = zip(*timings)

# Plot
plt.figure(figsize=(15, 15))
plt.barh(keywords_sorted, times_sorted, color="skyblue")
plt.xlabel("Time (seconds)")
plt.ylabel("Keyword")
plt.title("Matching Time per Keyword")
plt.gca().invert_yaxis()  # Show slowest at the top
plt.tight_layout()
plt.show()

# %%
docs = text.split("\n\n")  # Assuming paragraphs are separated by double newlines

total_docs = len(docs)
docs_with_matches = 0

for para in docs:
    doc = nlp(para)
    matches = matcher(doc)
    if matches:
        docs_with_matches += 1

match_rate = (docs_with_matches / total_docs) * 100
print(f"Match Rate: {match_rate:.2f}%")
# Out:
# Match Rate: 100.00%

# %%
import time

total_time = 0.0
# time per match (not per doc), if per doc , set to 0 : match_counts=0
match_counts = len(matches)

for para in docs:
    doc = nlp(para)

    start = time.perf_counter()
    matches = matcher(doc)
    end = time.perf_counter()

    total_time += (end - start)
    match_counts += 1  # or only count if matches found: if matches: match_counts += 1

avg_time_per_match = total_time / match_counts if match_counts > 0 else 0
print(f"Average Time per Match: {avg_time_per_match:.6f} seconds")
# Out:
# Average Time per Match: 0.000192 seconds

# %%
# Create PhraseMatcher
from spacy.matcher import PhraseMatcher
timings = []
for kw in sorted(keywords):
    matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
    keyword_doc = nlp.make_doc(kw)
    matcher.add("KEYWORD", [keyword_doc])

    start_time = time.perf_counter()
    matches = matcher(doc)
    elapsed_time = time.perf_counter() - start_time

    timings.append((kw, elapsed_time))

# (Optional) Sort by elapsed time
timings.sort(key=lambda x: x[1], reverse=True)

# (Optional) Plot top 20 slowest
top_k = 20
top_timings = timings[:top_k]
keywords_top = [x[0] for x in top_timings]
times_top = [x[1] for x in top_timings]

plt.figure(figsize=(10, 6))
plt.barh(keywords_top[::-1], times_top[::-1])
plt.xlabel("Time (seconds)")
plt.title(f"Top {top_k} Slowest Keyword Match Times")
plt.tight_layout()
plt.show()

# %%
# Sort timings by elapsed time (ascending = fastest first)
timings.sort(key=lambda x: x[1])  # No reverse

# Get the 20 fastest matches
top_k = 20
fastest_timings = timings[:top_k]
keywords_top = [x[0] for x in fastest_timings]
times_top = [x[1] for x in fastest_timings]

# Plot
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(keywords_top[::-1], times_top[::-1])  # Reverse for top-down plot
plt.xlabel("Time (seconds)")
plt.title(f"Top {top_k} Fastest Keyword Match Times")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import pandas as pd

# Count matches per keyword
keyword_counts = Counter(keywords2)

# Make sure the matcher has been defined and doc exists
if 'matcher' in locals() and 'doc' in locals():
    for match_id, start, end in matcher(doc):
        label = nlp.vocab.strings[match_id]
        if label.startswith("KEYWORD_"):
            keyword = label.replace("KEYWORD_", "")
            keyword_counts[keyword] += 1

# Convert to DataFrame
if keyword_counts:
    df = pd.DataFrame.from_dict(keyword_counts, orient='index', columns=['frequency']).sort_values(by='frequency', ascending=False)

    plt.figure(figsize=(10, len(df) * 0.5))
    sns.heatmap(df, annot=True, fmt='d', cmap="YlGnBu", cbar=False)
    plt.title("Keyword Match Frequency Heatmap")
    plt.xlabel("Frequency")
    plt.ylabel("Keyword")
    plt.tight_layout()
    plt.show()
else:
    print("No keyword matches found. Heatmap not generated.")

# %%
import time

timings = []

for para in text.split("\n\n"):  # or other sections
    doc = nlp(para)
    start = time.perf_counter()
    matcher(doc)
    end = time.perf_counter()
    timings.append(end - start)

# Plot histogram
plt.figure(figsize=(8, 4))
plt.hist(timings, bins=20, color="skyblue", edgecolor="black")
plt.title("Time Distribution of Matches per Paragraph")
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# Span Overlap Visualization (with displacy)
# spaCy's built-in displacy visualizer to highlight matched spans

from spacy import displacy

# Get matches and convert to "entities" for displacy
ents = []

for match_id, start, end in matcher(doc):
    label = nlp.vocab.strings[match_id]
    span = doc[start:end]
    ents.append({
        "start": span.start_char,
        "end": span.end_char,
        "label": label.replace("KEYWORD_", "")
    })

# Render visualization
doc_user_data = {"text": doc.text, "ents": ents, "title": None}
displacy.render(doc_user_data, style="ent", manual=True, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">This SLA will be reviewed annually on the anniversary of the Effective Date or sooner if significant changes in service requirements or network capabilities occur. Any amendments must be mutually agreed upon in writing.</div></span>

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Define your sets
ground_truth={ "access", "agreement", "agreementid", "annual", "appendix", "applications","area", "audit", "auto", "availability", "availabilitybreach", "average", "basic", "breach", "broadband", "calendar", "capabilities",  "channels", "claim", "client",  "communication", "computing", "conditions", "confidentiality", "connectivity", "contact",  "coverage", "credit",  "critical", "customer", "customercontact", "cycle", "daily", "dashboard", "data", "date", "days", "definition", "degradation", "delay", "delivery", "deliverymethod", "description", "deviation", "device", "devices", "dispute", "disputes", "downlink", "downtime", "edge", "effective", "effectivedate", "effort", "egress", "email", "embb", "end", "enhanced", "enterprise", "equipment", "esim", "event", "exclusions", "expirationdate", "fault", "faults", "fee", "file", "format", "formula", "frequency", "function", "functioning", "g", "gateway", "gateways", "gbps", "general", "geographic", "gigabits", "governing", "guaranteed", "helpdesk", "high", "hour", "hourly", "hours", "id", "ids", "incident", "incidentresolutiontime", "incidentresponsetime", "incidents", "industrial", "information", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "jurisdiction", "kpi", "latency", "latencybreach", "law", "level", "levels", "locations", "loss", "low", "maintenance", "major", "management", "map", "maps", "master", "max", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "mediation", "medium", "method", "metric", "metrics", "metropolitan", "milliseconds", "min", "minimum", "minor", "minute", "minutes", "mobile", "monitor", "monitoring", "month", "monthly", "months", "ms", "negotiation", "network", "networks", "new", "nexgen", "nextgen", "notice", "notification", "notify", "objective", "objectives", "online", "outage", "packet", "parties", "party", "pdf", "peak", "penalties", "penalty", "percentage", "percentile", "performance", "period", "phone", "plane", "planned", "pm", "point", "policy", "portal", "premises", "premium", "prioritization", "priority", "probes", "profiles", "provider", "providersupportemail", "provision", "quarterly", "radio", "rate", "receipt", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "report", "reporting", "reports", "requirements", "resolution", "respond", "response", "responsibilities", "restoration", "review", "rights", "round","scope", "segment", "service", "servicename", "sim", "sla", "slices", "slos", "smartphones", "solutions", "specific", "speed", "status", "streaming", "subset", "support", "supporteddevices", "tablets", "target", "technology", "telco", "telecom", "termination", "terminationnoticeperiod", "terms", "tests", "threshold", "throughput", "tickets", "tiers", "time", "tolerated", "tools", "total", "tracking", "traffic", "transfers", "trip", "trt", "type", "ue", "ues", "updates", "upf", "uplink", "uptime", "usage", "usecases", "user", "users", "workdays", "writing", "zone", "zones" }


# ground_truth = {"latency", "availability", "jitter", "throughput", "reliability", "uptime", "accessibility", "scalability", "encryption",
#                 "qos", "support", "data", "management", "rights", "obligation", "review", "penalty"}  # proposed sla schema

predicted_keywords = keywords2       # from your matcher

# Build the union set of all unique keywords seen
all_keywords = sorted(ground_truth.union(predicted_keywords))

# Create binary vectors
y_true = [1 if kw in ground_truth else 0 for kw in all_keywords]
y_pred = [1 if kw in predicted_keywords else 0 for kw in all_keywords]

# Now compute scores
precision = precision_score(y_true, y_pred, zero_division=0)
recall = recall_score(y_true, y_pred, zero_division=0)
f1 = f1_score(y_true, y_pred, zero_division=0)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.9333333333333333
# Recall: 0.5877862595419847
# F1 Score: 0.7213114754098361

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Predicted', 'Predicted'],
            yticklabels=['Not Ground Truth', 'Ground Truth'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **large English NLP model provided by spaCy**

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 4.4 MB/s eta 0:00:00
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from google.colab import files

# Load the large English model with word vectors
nlp = spacy.load("en_core_web_lg")


# Step 3: Read the SLA text file
with open("geminiSLA.txt", "r", encoding="utf-8") as file:
    text = file.read()

# Step 4: Process the text using spaCy
doc = nlp(text)


# SLA-related keywords to compare against

keywords={ "Business Days", "acceptance", "access", "acme", "activities", "advance", "agreement", "agreementid", "amendment", "amendments", "anniversary", "appendix", "applications", "area", "auto", "availability", "availabilitybreach", "average", "b", "broadband", "capabilities", "capacity", "cards", "cell", "cells", "changes", "channels", "cloud", "communication", "computing", "conditions", "connectivity", "contact", "core", "corp", "coverage", "coveragearea", "cpe", "credit", "credits", "critical", "customer", "customercontact", "daily", "data", "date", "day", "days", "db", "definition", "degradation", "deliverymethod", "description", "device", "devices", "dispute", "disputes", "downlink", "edge", "effective", "effectivedate", "effort", "egress", "elements", "email", "embb", "end", "enhanced", "enterprise", "environments", "equipment", "esim", "event", "expirationdate", "f", "faith", "fault", "fee", "file", "format", "frequency", "function", "functioning", "g", "gateway", "gateways", "gbps", "general", "geographic", "gigabits", "guaranteed", "handover", "high", "hourly", "hours", "id", "ids", "incident", "incidentresolutiontime", "incidentresponsetime", "incidents", "industrial", "information", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "iot", "issues", "jitter", "latency", "latencybreach", "level", "levels", "loss", "low", "m", "maintenance", "management", "maps", "master", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "mediation", "medium", "metric", "metrics", "metropolitan", "milliseconds", "minimum", "minute", "minutes", "mission", "mobile", "monitor", "monitoring", "month", "ms", "negotiation", "network", "networks", "nexgen", "nextgen", "noc", "noise", "notice", "notifies", "notify", "objective", "objectives", "obligations", "online", "outage", "packet", "parties", "parts", "party", "pdf", "peak", "penalties", "percentage", "performance", "period", "phone", "plane", "pm", "point", "policy", "portal", "premises", "prioritization", "priority", "profiles", "provider", "providersupportemail", "provision", "qos", "rate", "ratio", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "reporting", "reports", "requests", "requirements", "resolution", "respond", "responsibilities", "restoration", "review", "round", "rtt", "sample", "scope", "segment", "service", "servicename", "services", "session", "setup", "signal", "sim", "sla", "slices", "slos", "smartphones", "snr", "solutions", "specific", "status", "streaming", "subset", "support", "supporteddevices", "tablets", "target", "telecom", "termination", "terminationnoticeperiod", "terms", "threshold", "throughput", "time", "tolerated", "tracking", "traffic", "transfers", "trip", "trt", "type", "updates", "upf", "uplink", "uptime", "urllc", "usage", "usecases", "user", "users", "video", "windows", "writing", "x", "xxxx", "zone", "zones" }

# Convert keywords to spaCy tokens (handle phrases properly)
keyword_tokens = {kw: nlp(kw)[0] if len(nlp(kw)) == 1 else nlp(kw) for kw in keywords}


# Compare each token in the doc to each keyword
for token in doc:
    if token.has_vector:
        for kw, kw_token in keyword_tokens.items():
            if isinstance(kw_token, spacy.tokens.Token):
                # Single-word keyword
                similarity = token.similarity(kw_token)
            else:
                # Multi-word keyword (e.g., "Business Days") — average similarity
                similarity = sum(token.similarity(t) for t in kw_token) / len(kw_token)

            if similarity > 0.6:
                print(f"Doc token '{token.text}' is similar to keyword '{kw}' (Similarity: {similarity:.2f})")
# Out:
# /tmp/ipython-input-24-982793031.py:30: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   similarity = token.similarity(kw_token)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Level' is similar to keyword 'level' (Similarity: 1.00)
# Doc token 'Level' is similar to keyword 'levels' (Similarity: 0.85)
# Doc token 'Level' is similar to keyword 'high' (Similarity: 0.60)
# Doc token 'Agreement' is similar to keyword 'negotiation' (Similarity: 0.60)
# Doc token 'Agreement' is similar to keyword 'dispute' (Similarity: 0.65)
# Doc token 'Agreement' is similar to keyword 'agreement' (Similarity: 1.00)
# Doc token 'SLA' is similar to keyword 'sla' (Similarity: 1.00)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'Enhanced' is similar to keyword 'capabilities' (Similarity: 0.63)
# Doc token 'Enhanced' is similar to keyword 'enhanced' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'smartphones' (Similarity: 0.69)
# Doc token 'Mobile' is similar to keyword 'phone' (Similarity: 0.70)
# Doc token 'Mobile' is similar to keyword 'mobile' (Similarity: 1.00)
# Doc token 'Broadband' is similar to keyword 'broadband' (Similarity: 1.00)
# Doc token 'Broadband' is similar to keyword 'connectivity' (Similarity: 0.60)
# Doc token 'Broadband' is similar to keyword 'telecom' (Similarity: 0.63)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Agreement' is similar to keyword 'negotiation' (Similarity: 0.60)
# Doc token 'Agreement' is similar to keyword 'dispute' (Similarity: 0.65)
# Doc token 'Agreement' is similar to keyword 'agreement' (Similarity: 1.00)
# Doc token 'Effective' is similar to keyword 'effective' (Similarity: 1.00)
# Doc token 'Date' is similar to keyword 'date' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Provider' is similar to keyword 'services' (Similarity: 0.73)
# Doc token 'Provider' is similar to keyword 'service' (Similarity: 0.66)
# Doc token 'Provider' is similar to keyword 'provider' (Similarity: 1.00)
# Doc token 'NexGen' is similar to keyword 'nexgen' (Similarity: 1.00)
# Doc token 'Telecom' is similar to keyword 'broadband' (Similarity: 0.63)
# Doc token 'Telecom' is similar to keyword 'telecom' (Similarity: 1.00)
# Doc token 'Customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'Customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'Enterprise' is similar to keyword 'solutions' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'enterprise' (Similarity: 1.00)
# Doc token 'Enterprise' is similar to keyword 'computing' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'management' (Similarity: 0.63)
# Doc token 'Enterprise' is similar to keyword 'infrastructure' (Similarity: 0.63)
# Doc token 'Solutions' is similar to keyword 'services' (Similarity: 0.61)
# Doc token 'Solutions' is similar to keyword 'solutions' (Similarity: 1.00)
# Doc token 'Solutions' is similar to keyword 'enterprise' (Similarity: 0.60)
# Doc token 'Solutions' is similar to keyword 'management' (Similarity: 0.60)
# Doc token 'Corp.' is similar to keyword 'corp' (Similarity: 0.78)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Type' is similar to keyword 'type' (Similarity: 1.00)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'Enhanced' is similar to keyword 'capabilities' (Similarity: 0.63)
# Doc token 'Enhanced' is similar to keyword 'enhanced' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'smartphones' (Similarity: 0.69)
# Doc token 'Mobile' is similar to keyword 'phone' (Similarity: 0.70)
# Doc token 'Mobile' is similar to keyword 'mobile' (Similarity: 1.00)
# Doc token 'Broadband' is similar to keyword 'broadband' (Similarity: 1.00)
# Doc token 'Broadband' is similar to keyword 'connectivity' (Similarity: 0.60)
# Doc token 'Broadband' is similar to keyword 'telecom' (Similarity: 0.63)
# Doc token 'High' is similar to keyword 'level' (Similarity: 0.60)
# Doc token 'High' is similar to keyword 'low' (Similarity: 0.76)
# Doc token 'High' is similar to keyword 'high' (Similarity: 1.00)
# Doc token 'Capacity' is similar to keyword 'capacity' (Similarity: 1.00)
# Doc token 'Data' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'Data' is similar to keyword 'data' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Description' is similar to keyword 'description' (Similarity: 1.00)
# Doc token 'SLA' is similar to keyword 'sla' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'terms' is similar to keyword 'terms' (Similarity: 1.00)
# Doc token 'terms' is similar to keyword 'specific' (Similarity: 0.61)
# Doc token 'terms' is similar to keyword 'general' (Similarity: 0.62)
# Doc token 'conditions' is similar to keyword 'conditions' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'provision' is similar to keyword 'amendments' (Similarity: 0.60)
# Doc token 'provision' is similar to keyword 'amendment' (Similarity: 0.63)
# Doc token 'provision' is similar to keyword 'provision' (Similarity: 1.00)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'Enhanced' is similar to keyword 'capabilities' (Similarity: 0.63)
# Doc token 'Enhanced' is similar to keyword 'enhanced' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'smartphones' (Similarity: 0.69)
# Doc token 'Mobile' is similar to keyword 'phone' (Similarity: 0.70)
# Doc token 'Mobile' is similar to keyword 'mobile' (Similarity: 1.00)
# Doc token 'Broadband' is similar to keyword 'broadband' (Similarity: 1.00)
# Doc token 'Broadband' is similar to keyword 'connectivity' (Similarity: 0.60)
# Doc token 'Broadband' is similar to keyword 'telecom' (Similarity: 0.63)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Enterprise' is similar to keyword 'solutions' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'enterprise' (Similarity: 1.00)
# Doc token 'Enterprise' is similar to keyword 'computing' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'management' (Similarity: 0.63)
# Doc token 'Enterprise' is similar to keyword 'infrastructure' (Similarity: 0.63)
# Doc token 'Solutions' is similar to keyword 'services' (Similarity: 0.61)
# Doc token 'Solutions' is similar to keyword 'solutions' (Similarity: 1.00)
# Doc token 'Solutions' is similar to keyword 'enterprise' (Similarity: 0.60)
# Doc token 'Solutions' is similar to keyword 'management' (Similarity: 0.60)
# Doc token 'Corp.' is similar to keyword 'corp' (Similarity: 0.78)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'high' is similar to keyword 'level' (Similarity: 0.60)
# Doc token 'high' is similar to keyword 'low' (Similarity: 0.76)
# Doc token 'high' is similar to keyword 'high' (Similarity: 1.00)
# Doc token 'throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'low' is similar to keyword 'low' (Similarity: 1.00)
# Doc token 'low' is similar to keyword 'rate' (Similarity: 0.60)
# Doc token 'low' is similar to keyword 'high' (Similarity: 0.76)
# Doc token 'latency' is similar to keyword 'throughput' (Similarity: 0.63)
# Doc token 'latency' is similar to keyword 'jitter' (Similarity: 0.65)
# Doc token 'latency' is similar to keyword 'latency' (Similarity: 1.00)
# Doc token 'connectivity' is similar to keyword 'network' (Similarity: 0.62)
# Doc token 'connectivity' is similar to keyword 'capabilities' (Similarity: 0.62)
# Doc token 'connectivity' is similar to keyword 'broadband' (Similarity: 0.60)
# Doc token 'connectivity' is similar to keyword 'connectivity' (Similarity: 1.00)
# Doc token 'connectivity' is similar to keyword 'networks' (Similarity: 0.61)
# Doc token 'data' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'data' is similar to keyword 'data' (Similarity: 1.00)
# Doc token 'applications' is similar to keyword 'capabilities' (Similarity: 0.61)
# Doc token 'applications' is similar to keyword 'applications' (Similarity: 1.00)
# Doc token 'but' is similar to keyword 'point' (Similarity: 0.62)
# Doc token 'but' is similar to keyword 'time' (Similarity: 0.62)
# Doc token 'but' is similar to keyword 'end' (Similarity: 0.61)
# Doc token 'not' is similar to keyword 'notice' (Similarity: 0.60)
# Doc token 'not' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'cloud' is similar to keyword 'cloud' (Similarity: 1.00)
# Doc token 'computing' is similar to keyword 'enterprise' (Similarity: 0.60)
# Doc token 'computing' is similar to keyword 'computing' (Similarity: 1.00)
# Doc token 'high' is similar to keyword 'level' (Similarity: 0.60)
# Doc token 'high' is similar to keyword 'low' (Similarity: 0.76)
# Doc token 'high' is similar to keyword 'high' (Similarity: 1.00)
# Doc token 'definition' is similar to keyword 'definition' (Similarity: 1.00)
# Doc token 'video' is similar to keyword 'video' (Similarity: 1.00)
# Doc token 'streaming' is similar to keyword 'streaming' (Similarity: 1.00)
# Doc token 'file' is similar to keyword 'file' (Similarity: 1.00)
# Doc token 'file' is similar to keyword 'format' (Similarity: 0.66)
# Doc token 'transfers' is similar to keyword 'transfers' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Scope' is similar to keyword 'scope' (Similarity: 1.00)
# Doc token 'Geographic' is similar to keyword 'geographic' (Similarity: 1.00)
# Doc token 'Coverage' is similar to keyword 'coverage' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'area' is similar to keyword 'area' (Similarity: 1.00)
# Doc token 'area' is similar to keyword 'region' (Similarity: 0.66)
# Doc token 'Metropolitan' is similar to keyword 'metropolitan' (Similarity: 1.00)
# Doc token 'Region' is similar to keyword 'area' (Similarity: 0.66)
# Doc token 'Region' is similar to keyword 'region' (Similarity: 1.00)
# Doc token 'X' is similar to keyword 'x' (Similarity: 1.00)
# Doc token 'coverage' is similar to keyword 'coverage' (Similarity: 1.00)
# Doc token 'Industrial' is similar to keyword 'industrial' (Similarity: 1.00)
# Doc token 'Zone' is similar to keyword 'zone' (Similarity: 1.00)
# Doc token 'Zone' is similar to keyword 'zones' (Similarity: 0.75)
# Doc token 'Specific' is similar to keyword 'terms' (Similarity: 0.61)
# Doc token 'Specific' is similar to keyword 'information' (Similarity: 0.64)
# Doc token 'Specific' is similar to keyword 'requirements' (Similarity: 0.61)
# Doc token 'Specific' is similar to keyword 'specific' (Similarity: 1.00)
# Doc token 'cell' is similar to keyword 'cells' (Similarity: 0.81)
# Doc token 'cell' is similar to keyword 'phone' (Similarity: 0.62)
# Doc token 'cell' is similar to keyword 'cell' (Similarity: 1.00)
# Doc token 'IDs' is similar to keyword 'ids' (Similarity: 1.00)
# Doc token 'coverage' is similar to keyword 'coverage' (Similarity: 1.00)
# Doc token 'maps' is similar to keyword 'maps' (Similarity: 1.00)
# Doc token 'Appendix' is similar to keyword 'appendix' (Similarity: 1.00)
# Doc token 'User' is similar to keyword 'user' (Similarity: 1.00)
# Doc token 'User' is similar to keyword 'users' (Similarity: 0.79)
# Doc token 'Devices' is similar to keyword 'device' (Similarity: 0.86)
# Doc token 'Devices' is similar to keyword 'smartphones' (Similarity: 0.63)
# Doc token 'Devices' is similar to keyword 'devices' (Similarity: 1.00)
# Doc token 'Support' is similar to keyword 'support' (Similarity: 1.00)
# Doc token 'devices' is similar to keyword 'device' (Similarity: 0.86)
# Doc token 'devices' is similar to keyword 'smartphones' (Similarity: 0.63)
# Doc token 'devices' is similar to keyword 'devices' (Similarity: 1.00)
# Doc token 'smartphones' is similar to keyword 'smartphones' (Similarity: 1.00)
# Doc token 'smartphones' is similar to keyword 'devices' (Similarity: 0.63)
# Doc token 'smartphones' is similar to keyword 'mobile' (Similarity: 0.69)
# Doc token 'tablets' is similar to keyword 'tablets' (Similarity: 1.00)
# Doc token 'IoT' is similar to keyword 'iot' (Similarity: 1.00)
# Doc token 'gateways' is similar to keyword 'gateways' (Similarity: 1.00)
# Doc token 'gateways' is similar to keyword 'gateway' (Similarity: 0.77)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'SIM' is similar to keyword 'sim' (Similarity: 1.00)
# Doc token 'cards' is similar to keyword 'cards' (Similarity: 1.00)
# Doc token 'profiles' is similar to keyword 'profiles' (Similarity: 1.00)
# Doc token 'provided' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'NexGen' is similar to keyword 'nexgen' (Similarity: 1.00)
# Doc token 'Telecom' is similar to keyword 'broadband' (Similarity: 0.63)
# Doc token 'Telecom' is similar to keyword 'telecom' (Similarity: 1.00)
# Doc token 'Traffic' is similar to keyword 'traffic' (Similarity: 1.00)
# Doc token 'Prioritization' is similar to keyword 'prioritization' (Similarity: 1.00)
# Doc token 'traffic' is similar to keyword 'traffic' (Similarity: 1.00)
# Doc token 'receive' is similar to keyword 'recipient' (Similarity: 0.62)
# Doc token 'priority' is similar to keyword 'priority' (Similarity: 1.00)
# Doc token 'effort' is similar to keyword 'effort' (Similarity: 1.00)
# Doc token 'traffic' is similar to keyword 'traffic' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'defined' is similar to keyword 'definition' (Similarity: 0.63)
# Doc token 'defined' is similar to keyword 'subset' (Similarity: 0.60)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'slices' is similar to keyword 'slices' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Level' is similar to keyword 'level' (Similarity: 1.00)
# Doc token 'Level' is similar to keyword 'levels' (Similarity: 0.85)
# Doc token 'Level' is similar to keyword 'high' (Similarity: 0.60)
# Doc token 'Objectives' is similar to keyword 'responsibilities' (Similarity: 0.61)
# Doc token 'Objectives' is similar to keyword 'objective' (Similarity: 0.78)
# Doc token 'Objectives' is similar to keyword 'objectives' (Similarity: 1.00)
# Doc token 'Performance' is similar to keyword 'performance' (Similarity: 1.00)
# Doc token 'Metrics' is similar to keyword 'metrics' (Similarity: 1.00)
# Doc token 'The' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'following' is similar to keyword 'specific' (Similarity: 0.60)
# Doc token 'performance' is similar to keyword 'performance' (Similarity: 1.00)
# Doc token 'metrics' is similar to keyword 'metrics' (Similarity: 1.00)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'measured' is similar to keyword 'measurement' (Similarity: 0.75)
# Doc token 'measured' is similar to keyword 'measurements' (Similarity: 0.76)
# Doc token 'monitored' is similar to keyword 'monitoring' (Similarity: 0.74)
# Doc token 'monitored' is similar to keyword 'monitor' (Similarity: 0.61)
# Doc token 'ensure' is similar to keyword 'requirements' (Similarity: 0.63)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'agreed' is similar to keyword 'agreement' (Similarity: 0.75)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'levels' is similar to keyword 'level' (Similarity: 0.85)
# Doc token 'levels' is similar to keyword 'levels' (Similarity: 1.00)
# Doc token 'measurements' is similar to keyword 'measurement' (Similarity: 0.86)
# Doc token 'measurements' is similar to keyword 'measurements' (Similarity: 1.00)
# Doc token 'data' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'data' is similar to keyword 'data' (Similarity: 1.00)
# Doc token 'minute' is similar to keyword 'minute' (Similarity: 1.00)
# Doc token 'minute' is similar to keyword 'minutes' (Similarity: 0.80)
# Doc token 'intervals' is similar to keyword 'intervals' (Similarity: 1.00)
# Doc token 'unless' is similar to keyword 'notice' (Similarity: 0.66)
# Doc token 'otherwise' is similar to keyword 'notice' (Similarity: 0.61)
# Doc token 'specified' is similar to keyword 'specific' (Similarity: 0.63)
# Doc token 'Throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'Throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Downlink' is similar to keyword 'uplink' (Similarity: 0.89)
# Doc token 'Downlink' is similar to keyword 'downlink' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objective' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objectives' (Similarity: 0.78)
# Doc token 'Average' is similar to keyword 'rate' (Similarity: 0.61)
# Doc token 'Average' is similar to keyword 'percentage' (Similarity: 0.73)
# Doc token 'Average' is similar to keyword 'average' (Similarity: 1.00)
# Doc token 'downlink' is similar to keyword 'uplink' (Similarity: 0.89)
# Doc token 'downlink' is similar to keyword 'downlink' (Similarity: 1.00)
# Doc token 'throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Gbps' is similar to keyword 'gbps' (Similarity: 1.00)
# Doc token 'Gigabits' is similar to keyword 'gigabits' (Similarity: 1.00)
# Doc token 'second' is similar to keyword 'end' (Similarity: 0.63)
# Doc token 'Minimum' is similar to keyword 'minimum' (Similarity: 1.00)
# Doc token 'Minimum' is similar to keyword 'maximum' (Similarity: 0.78)
# Doc token 'Guaranteed' is similar to keyword 'guaranteed' (Similarity: 1.00)
# Doc token 'Mbps' is similar to keyword 'mbps' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Point' is similar to keyword 'point' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'end' (Similarity: 0.62)
# Doc token 'User' is similar to keyword 'user' (Similarity: 1.00)
# Doc token 'User' is similar to keyword 'users' (Similarity: 0.79)
# Doc token 'Plane' is similar to keyword 'plane' (Similarity: 1.00)
# Doc token 'Function' is similar to keyword 'function' (Similarity: 1.00)
# Doc token 'Function' is similar to keyword 'functioning' (Similarity: 0.60)
# Doc token 'UPF' is similar to keyword 'upf' (Similarity: 1.00)
# Doc token 'egress' is similar to keyword 'egress' (Similarity: 1.00)
# Doc token 'egress' is similar to keyword 'ingress' (Similarity: 0.79)
# Doc token 'customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'premises' is similar to keyword 'premises' (Similarity: 1.00)
# Doc token 'equipment' is similar to keyword 'equipment' (Similarity: 1.00)
# Doc token 'CPE' is similar to keyword 'cpe' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'Frequency' is similar to keyword 'signal' (Similarity: 0.69)
# Doc token 'Frequency' is similar to keyword 'frequency' (Similarity: 1.00)
# Doc token 'Daily' is similar to keyword 'day' (Similarity: 0.60)
# Doc token 'Daily' is similar to keyword 'daily' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'detailed' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'Throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'Throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Uplink' is similar to keyword 'uplink' (Similarity: 1.00)
# Doc token 'Uplink' is similar to keyword 'downlink' (Similarity: 0.89)
# Doc token 'Objective' is similar to keyword 'objective' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objectives' (Similarity: 0.78)
# Doc token 'Average' is similar to keyword 'rate' (Similarity: 0.61)
# Doc token 'Average' is similar to keyword 'percentage' (Similarity: 0.73)
# Doc token 'Average' is similar to keyword 'average' (Similarity: 1.00)
# Doc token 'uplink' is similar to keyword 'uplink' (Similarity: 1.00)
# Doc token 'uplink' is similar to keyword 'downlink' (Similarity: 0.89)
# Doc token 'throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Mbps' is similar to keyword 'mbps' (Similarity: 1.00)
# Doc token 'Minimum' is similar to keyword 'minimum' (Similarity: 1.00)
# Doc token 'Minimum' is similar to keyword 'maximum' (Similarity: 0.78)
# Doc token 'Guaranteed' is similar to keyword 'guaranteed' (Similarity: 1.00)
# Doc token 'Mbps' is similar to keyword 'mbps' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Point' is similar to keyword 'point' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'end' (Similarity: 0.62)
# Doc token 'CPE' is similar to keyword 'cpe' (Similarity: 1.00)
# Doc token 'ingress' is similar to keyword 'egress' (Similarity: 0.79)
# Doc token 'ingress' is similar to keyword 'ingress' (Similarity: 1.00)
# Doc token 'UPF' is similar to keyword 'upf' (Similarity: 1.00)
# Doc token 'ingress' is similar to keyword 'egress' (Similarity: 0.79)
# Doc token 'ingress' is similar to keyword 'ingress' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'Frequency' is similar to keyword 'signal' (Similarity: 0.69)
# Doc token 'Frequency' is similar to keyword 'frequency' (Similarity: 1.00)
# Doc token 'Daily' is similar to keyword 'day' (Similarity: 0.60)
# Doc token 'Daily' is similar to keyword 'daily' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'detailed' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'Latency' is similar to keyword 'throughput' (Similarity: 0.63)
# Doc token 'Latency' is similar to keyword 'jitter' (Similarity: 0.65)
# Doc token 'Latency' is similar to keyword 'latency' (Similarity: 1.00)
# Doc token 'Round' is similar to keyword 'round' (Similarity: 1.00)
# Doc token 'Trip' is similar to keyword 'trip' (Similarity: 1.00)
# Doc token 'Time' is similar to keyword 'day' (Similarity: 0.73)
# Doc token 'Time' is similar to keyword 'days' (Similarity: 0.65)
# Doc token 'Time' is similar to keyword 'time' (Similarity: 1.00)
# Doc token 'Time' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'RTT' is similar to keyword 'rtt' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objective' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objectives' (Similarity: 0.78)
# Doc token 'Average' is similar to keyword 'rate' (Similarity: 0.61)
# Doc token 'Average' is similar to keyword 'percentage' (Similarity: 0.73)
# Doc token 'Average' is similar to keyword 'average' (Similarity: 1.00)
# Doc token 'end' is similar to keyword 'point' (Similarity: 0.62)
# Doc token 'end' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'end' is similar to keyword 'end' (Similarity: 1.00)
# Doc token 'end' is similar to keyword 'point' (Similarity: 0.62)
# Doc token 'end' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'end' is similar to keyword 'end' (Similarity: 1.00)
# Doc token 'latency' is similar to keyword 'throughput' (Similarity: 0.63)
# Doc token 'latency' is similar to keyword 'jitter' (Similarity: 0.65)
# Doc token 'latency' is similar to keyword 'latency' (Similarity: 1.00)
# Doc token 'ms' is similar to keyword 'ms' (Similarity: 1.00)
# Doc token 'milliseconds' is similar to keyword 'milliseconds' (Similarity: 1.00)
# Doc token 'Maximum' is similar to keyword 'minimum' (Similarity: 0.78)
# Doc token 'Maximum' is similar to keyword 'maximum' (Similarity: 1.00)
# Doc token 'Tolerated' is similar to keyword 'tolerated' (Similarity: 1.00)
# Doc token 'ms' is similar to keyword 'ms' (Similarity: 1.00)
# Doc token 'traffic' is similar to keyword 'traffic' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Point' is similar to keyword 'point' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'end' (Similarity: 0.62)
# Doc token 'customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'device' is similar to keyword 'device' (Similarity: 1.00)
# Doc token 'device' is similar to keyword 'devices' (Similarity: 0.86)
# Doc token 'core' is similar to keyword 'core' (Similarity: 1.00)
# Doc token 'network' is similar to keyword 'network' (Similarity: 1.00)
# Doc token 'network' is similar to keyword 'connectivity' (Similarity: 0.62)
# Doc token 'network' is similar to keyword 'networks' (Similarity: 0.88)
# Doc token 'gateway' is similar to keyword 'gateways' (Similarity: 0.77)
# Doc token 'gateway' is similar to keyword 'gateway' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'Frequency' is similar to keyword 'signal' (Similarity: 0.69)
# Doc token 'Frequency' is similar to keyword 'frequency' (Similarity: 1.00)
# Doc token 'Hourly' is similar to keyword 'hourly' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'weekly' is similar to keyword 'daily' (Similarity: 0.78)
# Doc token 'detailed' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'Jitter' is similar to keyword 'jitter' (Similarity: 1.00)
# Doc token 'Jitter' is similar to keyword 'latency' (Similarity: 0.65)
# Doc token 'Objective' is similar to keyword 'objective' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objectives' (Similarity: 0.78)
# Doc token 'Maximum' is similar to keyword 'minimum' (Similarity: 0.78)
# Doc token 'Maximum' is similar to keyword 'maximum' (Similarity: 1.00)
# Doc token 'jitter' is similar to keyword 'jitter' (Similarity: 1.00)
# Doc token 'jitter' is similar to keyword 'latency' (Similarity: 0.65)
# Doc token 'ms' is similar to keyword 'ms' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Point' is similar to keyword 'point' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'end' (Similarity: 0.62)
# Doc token 'customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'device' is similar to keyword 'device' (Similarity: 1.00)
# Doc token 'device' is similar to keyword 'devices' (Similarity: 0.86)
# Doc token 'core' is similar to keyword 'core' (Similarity: 1.00)
# Doc token 'network' is similar to keyword 'network' (Similarity: 1.00)
# Doc token 'network' is similar to keyword 'connectivity' (Similarity: 0.62)
# Doc token 'network' is similar to keyword 'networks' (Similarity: 0.88)
# Doc token 'gateway' is similar to keyword 'gateways' (Similarity: 0.77)
# Doc token 'gateway' is similar to keyword 'gateway' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'Frequency' is similar to keyword 'signal' (Similarity: 0.69)
# Doc token 'Frequency' is similar to keyword 'frequency' (Similarity: 1.00)
# Doc token 'Hourly' is similar to keyword 'hourly' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'weekly' is similar to keyword 'daily' (Similarity: 0.78)
# Doc token 'detailed' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'Packet' is similar to keyword 'packet' (Similarity: 1.00)
# Doc token 'Loss' is similar to keyword 'loss' (Similarity: 1.00)
# Doc token 'Rate' is similar to keyword 'low' (Similarity: 0.60)
# Doc token 'Rate' is similar to keyword 'rate' (Similarity: 1.00)
# Doc token 'Rate' is similar to keyword 'average' (Similarity: 0.61)
# Doc token 'Objective' is similar to keyword 'objective' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objectives' (Similarity: 0.78)
# Doc token 'packet' is similar to keyword 'packet' (Similarity: 1.00)
# Doc token 'loss' is similar to keyword 'loss' (Similarity: 1.00)
# Doc token 'Maximum' is similar to keyword 'minimum' (Similarity: 0.78)
# Doc token 'Maximum' is similar to keyword 'maximum' (Similarity: 1.00)
# Doc token 'Tolerated' is similar to keyword 'tolerated' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Point' is similar to keyword 'point' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'end' (Similarity: 0.62)
# Doc token 'End' is similar to keyword 'point' (Similarity: 0.62)
# Doc token 'End' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'End' is similar to keyword 'end' (Similarity: 1.00)
# Doc token 'end' is similar to keyword 'point' (Similarity: 0.62)
# Doc token 'end' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'end' is similar to keyword 'end' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'network' is similar to keyword 'network' (Similarity: 1.00)
# Doc token 'network' is similar to keyword 'connectivity' (Similarity: 0.62)
# Doc token 'network' is similar to keyword 'networks' (Similarity: 0.88)
# Doc token 'segment' is similar to keyword 'segment' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'Frequency' is similar to keyword 'signal' (Similarity: 0.69)
# Doc token 'Frequency' is similar to keyword 'frequency' (Similarity: 1.00)
# Doc token 'Daily' is similar to keyword 'day' (Similarity: 0.60)
# Doc token 'Daily' is similar to keyword 'daily' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Availability' is similar to keyword 'availability' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objective' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objectives' (Similarity: 0.78)
# Doc token 'availability' is similar to keyword 'availability' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'area' is similar to keyword 'area' (Similarity: 1.00)
# Doc token 'area' is similar to keyword 'region' (Similarity: 0.66)
# Doc token 'Definition' is similar to keyword 'definition' (Similarity: 1.00)
# Doc token 'Uptime' is similar to keyword 'uptime' (Similarity: 1.00)
# Doc token 'measured' is similar to keyword 'measurement' (Similarity: 0.75)
# Doc token 'measured' is similar to keyword 'measurements' (Similarity: 0.76)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'percentage' is similar to keyword 'percentage' (Similarity: 1.00)
# Doc token 'percentage' is similar to keyword 'average' (Similarity: 0.73)
# Doc token 'time' is similar to keyword 'day' (Similarity: 0.73)
# Doc token 'time' is similar to keyword 'days' (Similarity: 0.65)
# Doc token 'time' is similar to keyword 'time' (Similarity: 1.00)
# Doc token 'time' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'operational' is similar to keyword 'capabilities' (Similarity: 0.62)
# Doc token 'operational' is similar to keyword 'infrastructure' (Similarity: 0.62)
# Doc token 'operational' is similar to keyword 'objectives' (Similarity: 0.62)
# Doc token 'accessible' is similar to keyword 'access' (Similarity: 0.69)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'maintenance' is similar to keyword 'maintenance' (Similarity: 1.00)
# Doc token 'maintenance' is similar to keyword 'installation' (Similarity: 0.61)
# Doc token 'windows' is similar to keyword 'windows' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'Frequency' is similar to keyword 'signal' (Similarity: 0.69)
# Doc token 'Frequency' is similar to keyword 'frequency' (Similarity: 1.00)
# Doc token 'Monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Credits' is similar to keyword 'credit' (Similarity: 0.62)
# Doc token 'Credits' is similar to keyword 'credits' (Similarity: 1.00)
# Doc token 'Penalties' is similar to keyword 'penalties' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'event' is similar to keyword 'event' (Similarity: 1.00)
# Doc token 'that' is similar to keyword 'point' (Similarity: 0.63)
# Doc token 'that' is similar to keyword 'end' (Similarity: 0.61)
# Doc token 'NexGen' is similar to keyword 'nexgen' (Similarity: 1.00)
# Doc token 'Telecom' is similar to keyword 'broadband' (Similarity: 0.63)
# Doc token 'Telecom' is similar to keyword 'telecom' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'agreed' is similar to keyword 'agreement' (Similarity: 0.75)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Level' is similar to keyword 'level' (Similarity: 1.00)
# Doc token 'Level' is similar to keyword 'levels' (Similarity: 0.85)
# Doc token 'Level' is similar to keyword 'high' (Similarity: 0.60)
# Doc token 'Objectives' is similar to keyword 'responsibilities' (Similarity: 0.61)
# Doc token 'Objectives' is similar to keyword 'objective' (Similarity: 0.78)
# Doc token 'Objectives' is similar to keyword 'objectives' (Similarity: 1.00)
# Doc token 'given' is similar to keyword 'terms' (Similarity: 0.61)
# Doc token 'month' is similar to keyword 'day' (Similarity: 0.71)
# Doc token 'month' is similar to keyword 'days' (Similarity: 0.70)
# Doc token 'month' is similar to keyword 'month' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'Customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'Customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credits' is similar to keyword 'credit' (Similarity: 0.62)
# Doc token 'credits' is similar to keyword 'credits' (Similarity: 1.00)
# Doc token 'Availability' is similar to keyword 'availability' (Similarity: 1.00)
# Doc token 'availability' is similar to keyword 'availability' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'fee' is similar to keyword 'fee' (Similarity: 1.00)
# Doc token 'fee' is similar to keyword 'refund' (Similarity: 0.68)
# Doc token 'availability' is similar to keyword 'availability' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'fee' is similar to keyword 'fee' (Similarity: 1.00)
# Doc token 'fee' is similar to keyword 'refund' (Similarity: 0.68)
# Doc token 'availability' is similar to keyword 'availability' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'fee' is similar to keyword 'fee' (Similarity: 1.00)
# Doc token 'fee' is similar to keyword 'refund' (Similarity: 0.68)
# Doc token 'Throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'Throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Downlink' is similar to keyword 'uplink' (Similarity: 0.89)
# Doc token 'Downlink' is similar to keyword 'downlink' (Similarity: 1.00)
# Doc token 'Uplink' is similar to keyword 'uplink' (Similarity: 1.00)
# Doc token 'Uplink' is similar to keyword 'downlink' (Similarity: 0.89)
# Doc token 'if' is similar to keyword 'notice' (Similarity: 0.63)
# Doc token 'if' is similar to keyword 'time' (Similarity: 0.64)
# Doc token 'Minimum' is similar to keyword 'minimum' (Similarity: 1.00)
# Doc token 'Minimum' is similar to keyword 'maximum' (Similarity: 0.78)
# Doc token 'Guaranteed' is similar to keyword 'guaranteed' (Similarity: 1.00)
# Doc token 'not' is similar to keyword 'notice' (Similarity: 0.60)
# Doc token 'not' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'period' is similar to keyword 'period' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'fee' is similar to keyword 'fee' (Similarity: 1.00)
# Doc token 'fee' is similar to keyword 'refund' (Similarity: 0.68)
# Doc token 'metric' is similar to keyword 'metric' (Similarity: 1.00)
# Doc token 'Latency' is similar to keyword 'throughput' (Similarity: 0.63)
# Doc token 'Latency' is similar to keyword 'jitter' (Similarity: 0.65)
# Doc token 'Latency' is similar to keyword 'latency' (Similarity: 1.00)
# Doc token 'Packet' is similar to keyword 'packet' (Similarity: 1.00)
# Doc token 'Loss' is similar to keyword 'loss' (Similarity: 1.00)
# Doc token 'Jitter' is similar to keyword 'jitter' (Similarity: 1.00)
# Doc token 'Jitter' is similar to keyword 'latency' (Similarity: 0.65)
# Doc token 'if' is similar to keyword 'notice' (Similarity: 0.63)
# Doc token 'if' is similar to keyword 'time' (Similarity: 0.64)
# Doc token 'Maximum' is similar to keyword 'minimum' (Similarity: 0.78)
# Doc token 'Maximum' is similar to keyword 'maximum' (Similarity: 1.00)
# Doc token 'Tolerated' is similar to keyword 'tolerated' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'period' is similar to keyword 'period' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'fee' is similar to keyword 'fee' (Similarity: 1.00)
# Doc token 'fee' is similar to keyword 'refund' (Similarity: 0.68)
# Doc token 'metric' is similar to keyword 'metric' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credits' is similar to keyword 'credit' (Similarity: 0.62)
# Doc token 'credits' is similar to keyword 'credits' (Similarity: 1.00)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'month' is similar to keyword 'day' (Similarity: 0.71)
# Doc token 'month' is similar to keyword 'days' (Similarity: 0.70)
# Doc token 'month' is similar to keyword 'month' (Similarity: 1.00)
# Doc token 'invoice' is similar to keyword 'invoice' (Similarity: 1.00)
# Doc token 'invoice' is similar to keyword 'refund' (Similarity: 0.61)
# Doc token 'Total' is similar to keyword 'average' (Similarity: 0.63)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# ...
# Doc token 'general' is similar to keyword 'terms' (Similarity: 0.62)
# Doc token 'general' is similar to keyword 'general' (Similarity: 1.00)
# Doc token 'inquiries' is similar to keyword 'inquiries' (Similarity: 1.00)
# Doc token 'Email' is similar to keyword 'contact' (Similarity: 0.64)
# Doc token 'Email' is similar to keyword 'email' (Similarity: 1.00)
# Doc token 'Support' is similar to keyword 'support' (Similarity: 1.00)
# Doc token 'Monitored' is similar to keyword 'monitoring' (Similarity: 0.74)
# Doc token 'Monitored' is similar to keyword 'monitor' (Similarity: 0.61)
# Doc token 'AM' is similar to keyword 'pm' (Similarity: 0.78)
# Doc token 'PM' is similar to keyword 'pm' (Similarity: 1.00)
# Doc token 'M' is similar to keyword 'm' (Similarity: 1.00)
# Doc token 'F' is similar to keyword 'f' (Similarity: 1.00)
# Doc token 'F' is similar to keyword 'b' (Similarity: 0.67)
# Doc token 'Incident' is similar to keyword 'incidents' (Similarity: 0.78)
# Doc token 'Incident' is similar to keyword 'incident' (Similarity: 1.00)
# Doc token 'Prioritization' is similar to keyword 'prioritization' (Similarity: 1.00)
# Doc token 'Critical' is similar to keyword 'critical' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'outage' is similar to keyword 'outage' (Similarity: 1.00)
# Doc token 'severe' is similar to keyword 'conditions' (Similarity: 0.63)
# Doc token 'degradation' is similar to keyword 'degradation' (Similarity: 1.00)
# Doc token 'users' is similar to keyword 'access' (Similarity: 0.60)
# Doc token 'users' is similar to keyword 'user' (Similarity: 0.79)
# Doc token 'users' is similar to keyword 'users' (Similarity: 1.00)
# Doc token 'Target' is similar to keyword 'target' (Similarity: 1.00)
# Doc token 'Resolution' is similar to keyword 'resolution' (Similarity: 1.00)
# Doc token 'Time' is similar to keyword 'day' (Similarity: 0.73)
# Doc token 'Time' is similar to keyword 'days' (Similarity: 0.65)
# Doc token 'Time' is similar to keyword 'time' (Similarity: 1.00)
# Doc token 'Time' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'TRT' is similar to keyword 'trt' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'day' (Similarity: 0.68)
# Doc token 'hours' is similar to keyword 'hours' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'days' (Similarity: 0.77)
# Doc token 'hours' is similar to keyword 'minutes' (Similarity: 0.74)
# Doc token 'High' is similar to keyword 'level' (Similarity: 0.60)
# Doc token 'High' is similar to keyword 'low' (Similarity: 0.76)
# Doc token 'High' is similar to keyword 'high' (Similarity: 1.00)
# Doc token 'Significant' is similar to keyword 'changes' (Similarity: 0.62)
# Doc token 'Significant' is similar to keyword 'critical' (Similarity: 0.67)
# Doc token 'Significant' is similar to keyword 'specific' (Similarity: 0.60)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'degradation' is similar to keyword 'degradation' (Similarity: 1.00)
# Doc token 'subset' is similar to keyword 'subset' (Similarity: 1.00)
# Doc token 'users' is similar to keyword 'access' (Similarity: 0.60)
# Doc token 'users' is similar to keyword 'user' (Similarity: 0.79)
# Doc token 'users' is similar to keyword 'users' (Similarity: 1.00)
# Doc token 'critical' is similar to keyword 'critical' (Similarity: 1.00)
# Doc token 'applications' is similar to keyword 'capabilities' (Similarity: 0.61)
# Doc token 'applications' is similar to keyword 'applications' (Similarity: 1.00)
# Doc token 'TRT' is similar to keyword 'trt' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'day' (Similarity: 0.68)
# Doc token 'hours' is similar to keyword 'hours' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'days' (Similarity: 0.77)
# Doc token 'hours' is similar to keyword 'minutes' (Similarity: 0.74)
# Doc token 'Medium' is similar to keyword 'medium' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'degradation' is similar to keyword 'degradation' (Similarity: 1.00)
# Doc token 'issues' is similar to keyword 'issues' (Similarity: 1.00)
# Doc token 'TRT' is similar to keyword 'trt' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'day' (Similarity: 0.68)
# Doc token 'hours' is similar to keyword 'hours' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'days' (Similarity: 0.77)
# Doc token 'hours' is similar to keyword 'minutes' (Similarity: 0.74)
# Doc token 'Low' is similar to keyword 'low' (Similarity: 1.00)
# Doc token 'Low' is similar to keyword 'rate' (Similarity: 0.60)
# Doc token 'Low' is similar to keyword 'high' (Similarity: 0.76)
# Doc token 'General' is similar to keyword 'terms' (Similarity: 0.62)
# Doc token 'General' is similar to keyword 'general' (Similarity: 1.00)
# Doc token 'inquiries' is similar to keyword 'inquiries' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'issues' is similar to keyword 'issues' (Similarity: 1.00)
# Doc token 'TRT' is similar to keyword 'trt' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'day' (Similarity: 0.68)
# Doc token 'hours' is similar to keyword 'hours' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'days' (Similarity: 0.77)
# Doc token 'hours' is similar to keyword 'minutes' (Similarity: 0.74)
# Doc token 'Reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'Communication' is similar to keyword 'communication' (Similarity: 1.00)
# Doc token 'NexGen' is similar to keyword 'nexgen' (Similarity: 1.00)
# Doc token 'Telecom' is similar to keyword 'broadband' (Similarity: 0.63)
# Doc token 'Telecom' is similar to keyword 'telecom' (Similarity: 1.00)
# Doc token 'provide' is similar to keyword 'services' (Similarity: 0.64)
# Doc token 'provide' is similar to keyword 'information' (Similarity: 0.61)
# Doc token 'provide' is similar to keyword 'specific' (Similarity: 0.60)
# Doc token 'updates' is similar to keyword 'updates' (Similarity: 1.00)
# Doc token 'incident' is similar to keyword 'incidents' (Similarity: 0.78)
# Doc token 'incident' is similar to keyword 'incident' (Similarity: 1.00)
# Doc token 'status' is similar to keyword 'status' (Similarity: 1.00)
# Doc token 'until' is similar to keyword 'time' (Similarity: 0.67)
# Doc token 'until' is similar to keyword 'end' (Similarity: 0.62)
# Doc token 'resolution' is similar to keyword 'resolution' (Similarity: 1.00)
# Doc token 'Dispute' is similar to keyword 'disputes' (Similarity: 0.86)
# Doc token 'Dispute' is similar to keyword 'dispute' (Similarity: 1.00)
# Doc token 'Dispute' is similar to keyword 'agreement' (Similarity: 0.65)
# Doc token 'Resolution' is similar to keyword 'resolution' (Similarity: 1.00)
# Doc token 'Any' is similar to keyword 'notice' (Similarity: 0.64)
# Doc token 'Any' is similar to keyword 'specific' (Similarity: 0.65)
# Doc token 'disputes' is similar to keyword 'disputes' (Similarity: 1.00)
# Doc token 'disputes' is similar to keyword 'mediation' (Similarity: 0.61)
# Doc token 'disputes' is similar to keyword 'dispute' (Similarity: 0.86)
# Doc token 'SLA' is similar to keyword 'sla' (Similarity: 1.00)
# Doc token 'first' is similar to keyword 'time' (Similarity: 0.62)
# Doc token 'first' is similar to keyword 'end' (Similarity: 0.63)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'faith' is similar to keyword 'faith' (Similarity: 1.00)
# Doc token 'negotiation' is similar to keyword 'negotiation' (Similarity: 1.00)
# Doc token 'negotiation' is similar to keyword 'mediation' (Similarity: 0.69)
# Doc token 'negotiation' is similar to keyword 'agreement' (Similarity: 0.60)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'parties' is similar to keyword 'parties' (Similarity: 1.00)
# Doc token 'parties' is similar to keyword 'party' (Similarity: 0.85)
# Doc token 'If' is similar to keyword 'notice' (Similarity: 0.63)
# Doc token 'If' is similar to keyword 'time' (Similarity: 0.64)
# Doc token 'resolution' is similar to keyword 'resolution' (Similarity: 1.00)
# Doc token 'not' is similar to keyword 'notice' (Similarity: 0.60)
# Doc token 'not' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'days' is similar to keyword 'day' (Similarity: 0.78)
# Doc token 'days' is similar to keyword 'hours' (Similarity: 0.77)
# Doc token 'days' is similar to keyword 'days' (Similarity: 1.00)
# Doc token 'days' is similar to keyword 'month' (Similarity: 0.70)
# Doc token 'days' is similar to keyword 'Business Days' (Similarity: 0.65)
# Doc token 'days' is similar to keyword 'time' (Similarity: 0.65)
# Doc token 'party' is similar to keyword 'parties' (Similarity: 0.85)
# Doc token 'party' is similar to keyword 'party' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'dispute' is similar to keyword 'disputes' (Similarity: 0.86)
# Doc token 'dispute' is similar to keyword 'dispute' (Similarity: 1.00)
# Doc token 'dispute' is similar to keyword 'agreement' (Similarity: 0.65)
# Doc token 'mediation' is similar to keyword 'negotiation' (Similarity: 0.69)
# Doc token 'mediation' is similar to keyword 'disputes' (Similarity: 0.61)
# Doc token 'mediation' is similar to keyword 'mediation' (Similarity: 1.00)
# Doc token 'Termination' is similar to keyword 'termination' (Similarity: 1.00)
# Doc token 'SLA' is similar to keyword 'sla' (Similarity: 1.00)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'terminated' is similar to keyword 'termination' (Similarity: 0.76)
# Doc token 'party' is similar to keyword 'parties' (Similarity: 0.85)
# Doc token 'party' is similar to keyword 'party' (Similarity: 1.00)
# Doc token 'days' is similar to keyword 'day' (Similarity: 0.78)
# Doc token 'days' is similar to keyword 'hours' (Similarity: 0.77)
# Doc token 'days' is similar to keyword 'days' (Similarity: 1.00)
# Doc token 'days' is similar to keyword 'month' (Similarity: 0.70)
# Doc token 'days' is similar to keyword 'Business Days' (Similarity: 0.65)
# Doc token 'days' is similar to keyword 'time' (Similarity: 0.65)
# Doc token 'written' is similar to keyword 'writing' (Similarity: 0.73)
# Doc token 'notice' is similar to keyword 'notify' (Similarity: 0.61)
# Doc token 'notice' is similar to keyword 'notice' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'terms' is similar to keyword 'terms' (Similarity: 1.00)
# Doc token 'terms' is similar to keyword 'specific' (Similarity: 0.61)
# Doc token 'terms' is similar to keyword 'general' (Similarity: 0.62)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'master' is similar to keyword 'master' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'agreement' is similar to keyword 'negotiation' (Similarity: 0.60)
# Doc token 'agreement' is similar to keyword 'dispute' (Similarity: 0.65)
# Doc token 'agreement' is similar to keyword 'agreement' (Similarity: 1.00)
# Doc token 'NexGen' is similar to keyword 'nexgen' (Similarity: 1.00)
# Doc token 'Telecom' is similar to keyword 'broadband' (Similarity: 0.63)
# Doc token 'Telecom' is similar to keyword 'telecom' (Similarity: 1.00)
# Doc token 'Enterprise' is similar to keyword 'solutions' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'enterprise' (Similarity: 1.00)
# Doc token 'Enterprise' is similar to keyword 'computing' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'management' (Similarity: 0.63)
# Doc token 'Enterprise' is similar to keyword 'infrastructure' (Similarity: 0.63)
# Doc token 'Solutions' is similar to keyword 'services' (Similarity: 0.61)
# Doc token 'Solutions' is similar to keyword 'solutions' (Similarity: 1.00)
# Doc token 'Solutions' is similar to keyword 'enterprise' (Similarity: 0.60)
# Doc token 'Solutions' is similar to keyword 'management' (Similarity: 0.60)
# Doc token 'Corp.' is similar to keyword 'corp' (Similarity: 0.78)
# Doc token 'Review' is similar to keyword 'review' (Similarity: 1.00)
# Doc token 'Amendment' is similar to keyword 'amendments' (Similarity: 0.85)
# Doc token 'Amendment' is similar to keyword 'amendment' (Similarity: 1.00)
# Doc token 'Amendment' is similar to keyword 'provision' (Similarity: 0.63)
# Doc token 'SLA' is similar to keyword 'sla' (Similarity: 1.00)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'reviewed' is similar to keyword 'review' (Similarity: 0.70)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'anniversary' is similar to keyword 'anniversary' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'Effective' is similar to keyword 'effective' (Similarity: 1.00)
# Doc token 'Date' is similar to keyword 'date' (Similarity: 1.00)
# Doc token 'if' is similar to keyword 'notice' (Similarity: 0.63)
# Doc token 'if' is similar to keyword 'time' (Similarity: 0.64)
# Doc token 'significant' is similar to keyword 'changes' (Similarity: 0.62)
# Doc token 'significant' is similar to keyword 'critical' (Similarity: 0.67)
# Doc token 'significant' is similar to keyword 'specific' (Similarity: 0.60)
# Doc token 'changes' is similar to keyword 'changes' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'services' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'requirements' is similar to keyword 'requirements' (Similarity: 1.00)
# Doc token 'requirements' is similar to keyword 'specific' (Similarity: 0.61)
# Doc token 'network' is similar to keyword 'network' (Similarity: 1.00)
# Doc token 'network' is similar to keyword 'connectivity' (Similarity: 0.62)
# Doc token 'network' is similar to keyword 'networks' (Similarity: 0.88)
# Doc token 'capabilities' is similar to keyword 'capabilities' (Similarity: 1.00)
# Doc token 'capabilities' is similar to keyword 'connectivity' (Similarity: 0.62)
# Doc token 'capabilities' is similar to keyword 'enhanced' (Similarity: 0.63)
# Doc token 'capabilities' is similar to keyword 'applications' (Similarity: 0.61)
# Doc token 'Any' is similar to keyword 'notice' (Similarity: 0.64)
# Doc token 'Any' is similar to keyword 'specific' (Similarity: 0.65)
# Doc token 'amendments' is similar to keyword 'amendments' (Similarity: 1.00)
# Doc token 'amendments' is similar to keyword 'amendment' (Similarity: 0.85)
# Doc token 'amendments' is similar to keyword 'provision' (Similarity: 0.60)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'agreed' is similar to keyword 'agreement' (Similarity: 0.75)
# Doc token 'writing' is similar to keyword 'writing' (Similarity: 1.00)
