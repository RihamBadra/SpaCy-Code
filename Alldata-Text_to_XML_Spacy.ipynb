# %% [markdown]
# # **Text to XML**

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.6.15)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
# Step 1: Import required libraries
import spacy
import xml.etree.ElementTree as ET
from google.colab import files

# Step 2: Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Step 3: Read the SLA text file
with open("AlldataSLA.txt", "r", encoding="utf-8") as file:
    text = file.read()

# Step 4: Process the text using spaCy
doc = nlp(text)

# Step 5: Extract keywords (nouns and proper nouns, not stop words or punctuation)
keywords = {token.text.lower() for token in doc if token.pos_ in ("NOUN", "PROPN") and not token.is_stop and token.is_alpha}

# Step 6: Format the keywords line
keywords_line = 'keywords={ ' + ", ".join(f'"{kw}"' for kw in sorted(keywords)) + ' }'

# Step 7: Write formatted line to TXT file
output_filename = "Extracted_keywords.txt"
with open(output_filename, "w", encoding="utf-8") as f:
    f.write(keywords_line)

# Step 8: Download the TXT file (for Colab users)
files.download(output_filename)

# Step 9: Print extracted keywords
print("Extracted keywords:")
print(keywords_line)
# Out:
# Extracted keywords:
# keywords={ "access", "acme", "activities", "advance", "agreement", "agreementid", "amendment", "amendments", "anniversary", "annual", "appendix", "applications", "ar", "area", "audit", "auto", "availability", "availabilitybreach", "average", "b", "basic", "breach", "broadband", "calendar", "cap", "capabilities", "capacity", "cards", "cell", "changes", "channels", "claim", "client", "cloud", "communication", "computing", "conditions", "confidentiality", "connectivity", "contact", "core", "corp", "coverage", "coveragearea", "cpe", "credit", "credits", "critical", "customer", "customercontact", "customerz", "cycle", "daily", "dashboard", "data", "date", "days", "definition", "degradation", "delay", "delivery", "deliverymethod", "description", "deviation", "device", "devices", "dispute", "disputes", "downlink", "downtime", "edge", "effective", "effectivedate", "effort", "egress", "email", "embb", "end", "enhanced", "enterprise", "equipment", "esim", "event", "exclusions", "expirationdate", "f", "faith", "fault", "faults", "fee", "file", "format", "formula", "frequency", "function", "functioning", "g", "gateway", "gateways", "gbps", "general", "geographic", "gigabits", "governing", "guaranteed", "helpdesk", "high", "hour", "hourly", "hours", "icmp", "id", "ids", "incident", "incidentresolutiontime", "incidentresponsetime", "incidents", "industrial", "information", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "iot", "issues", "jitter", "jurisdiction", "kpi", "latency", "latencybreach", "law", "level", "levels", "locations", "loss", "low", "m", "maintenance", "major", "management", "map", "maps", "master", "max", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "mediation", "medium", "method", "metric", "metrics", "metropolitan", "milliseconds", "min", "minimum", "minor", "minute", "minutes", "mobile", "monitor", "monitoring", "month", "monthly", "months", "ms", "negotiation", "network", "networks", "new", "nexgen", "nextgen", "noc", "notice", "notification", "notify", "nr", "objective", "objectives", "online", "outage", "packet", "parties", "party", "pdf", "peak", "penalties", "penalty", "percentage", "percentile", "performance", "period", "phone", "plane", "planned", "pm", "point", "policy", "portal", "premises", "premium", "prioritization", "priority", "probes", "profiles", "provider", "providersupportemail", "provision", "quarterly", "radio", "rate", "receipt", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "report", "reporting", "reports", "requirements", "resolution", "respond", "response", "responsibilities", "restoration", "review", "rights", "round", "rtt", "scope", "segment", "service", "servicename", "sim", "sla", "slices", "slos", "smartphones", "solutions", "specific", "speed", "status", "streaming", "subset", "support", "supporteddevices", "tablets", "target", "technology", "telco", "telecom", "termination", "terminationnoticeperiod", "terms", "tests", "threshold", "throughput", "tickets", "tiers", "time", "tolerated", "tools", "total", "tracking", "traffic", "transfers", "trip", "trt", "type", "ue", "ues", "updates", "upf", "uplink", "uptime", "usage", "usecases", "user", "users", "video", "vr", "way", "web", "window", "windows", "workdays", "writing", "x", "xml", "xxxx", "xy", "zone", "zones" }

# %%
import re
import xml.etree.ElementTree as ET

# Load the text
with open("AlldataSLA.txt", "r") as file:
    lines = file.readlines()

# Create root element for XML
root = ET.Element("requirements")

# Define basic patterns to match requirements
patterns = [
    (r"latency.*?(less than|under|<)\s*(\d+\.?\d*)\s*ms", "latency"),
    (r"availability.*?(\d+\.?\d*)\s*%", "availability"),
    (r"jitter.*?(up to|less than|<)\s*(\d+\.?\d*)\s*ms", "jitter")
]

# Process each line
for line in lines:
    print(f"Processing line: {line.strip()}")
    for pattern, req_type in patterns:
        match = re.search(pattern, line, re.IGNORECASE)
        if match:
            print(f" Matched {req_type}: {match.groupdict()}")
            req_elem = ET.SubElement(root, "requirement")
            ET.SubElement(req_elem, "type").text = req_type

            # Safely extract named groups
            value = match.groupdict().get("value")
            operator = match.groupdict().get("operator")

            if value:
                ET.SubElement(req_elem, "constraint").text = value
            else:
                print(" No 'value' group found for match:", match.group())

            if operator:
                req_elem.set("operator", operator)

# Save to XML
tree = ET.ElementTree(root)
tree.write("output.xml", encoding="utf-8", xml_declaration=True)

print(" XML generated as 'output.xml'")
# Out:
# Processing line: 5G SERVICE LEVEL AGREEMENT (SLA)
# Processing line: Service Provider: Telco Solutions Inc.
# Processing line: Customer: Enterprise Client Ltd.
# Processing line: Effective Date: 01-Oct-2025
# Processing line: Review Cycle: Quarterly
# Processing line:
# Processing line: 1. SERVICE AVAILABILITY
# Processing line: Target: 99.95% monthly uptime
# Processing line:
# Processing line: Measurement:
# Processing line:
# Processing line: Exclusions: Scheduled maintenance (max 4hrs/month, notified 72hrs in advance)
# Processing line:
# Processing line: Formula: (Total Minutes - Downtime) / Total Minutes
# Processing line:
# Processing line: Penalty: 5% service credit per 0.1% below target
# Processing line:
# Processing line: 2. NETWORK LATENCY
# Processing line: Target: ≤20ms end-to-end (UE to Core)
# Processing line:
# Processing line: Scope: Urban zones (per coverage map in Appendix A)
# Processing line:
# Processing line: Measurement: 95th percentile of hourly probes
# Processing line:
# Processing line: Penalty: 3% service credit per 1ms sustained breach
# Processing line:
# Processing line: 3. DOWNLINK THROUGHPUT
# Processing line: Target: ≥500 Mbps peak / ≥200 Mbps average per device
# Processing line:
# Processing line: Conditions: Non-congested network, <50 concurrently active UEs
# Processing line:
# Processing line: Measurement: Daily speed tests (9 AM–5 PM, workdays)
# Processing line:
# Processing line: Penalty: 2% service credit per 10% deviation
# Processing line:
# Processing line: 4. RELIABILITY
# Processing line: Target: ≤0.001% packet loss
# Processing line:
# Processing line: Measurement: ICMP probes every 5 minutes
# Processing line:
# Processing line: Penalty: 4% service credit per 0.0005% breach
# Processing line:
# Processing line: 5. FAULT RESTORATION
# Processing line: Critical Faults: ≤4 hours
# Processing line:
# Processing line: Non-Critical Faults: ≤24 hours
# Processing line:
# Processing line: Penalty: $500/hour delay beyond target
# Processing line:
# Processing line: 6. REPORTING & SUPPORT
# Processing line: KPI Reports: Monthly (by 5th of next month)
# Processing line:
# Processing line: Support: 24/7 helpdesk (max 15-min response for P1 tickets)
# Processing line:
# Processing line: Audit Rights: Customer may request measurement logs quarterly
# Processing line:
# Processing line: 7. SERVICE CREDITS
# Processing line: Max Annual Credit: 20% of monthly fee
# Processing line:
# Processing line: Claim Window: 30 days from report receipt
# Processing line:
# Processing line: Service Level Agreement (SLA) - 5G Enhanced Mobile Broadband (eMBB) Service
# Processing line:
# Processing line: Agreement ID: SLA-5G-eMBB-001-20250626
# Processing line: Effective Date: 2025-07-01
# Processing line: Service Provider: NexGen Telecom Inc.
# Processing line: Customer: Enterprise Solutions Corp.
# Processing line: Service Type: 5G Enhanced Mobile Broadband (eMBB) - High-Capacity Data Service
# Processing line:
# Processing line: 1. Service Description
# Processing line:
# Processing line: This SLA outlines the terms and conditions for the provision of a dedicated 5G Enhanced Mobile Broadband (eMBB) service to Enterprise Solutions Corp. This service is designed to deliver high-throughput, low-latency connectivity primarily for data-intensive applications, including but not limited to, cloud computing, high-definition video streaming, and large file transfers.
# Processing line:
# Processing line: 2. Service Scope
# Processing line:
# Processing line: Geographic Coverage: Primary service area: Metropolitan Region X, with secondary coverage in Industrial Zone Y. Specific cell IDs and coverage maps are attached as Appendix A.
# Processing line:
# Processing line: User Devices: Support for 5G-compliant devices (smartphones, tablets, IoT gateways) utilizing the designated SIM cards/eSIM profiles provided by NexGen Telecom Inc.
# Processing line:
# Processing line: Traffic Prioritization: eMBB traffic will receive priority over best-effort traffic within the defined service slices.
# Processing line:
# Processing line: 3. Service Level Objectives (SLOs) and Performance Metrics
# Processing line:
# Processing line: The following performance metrics will be measured and monitored to ensure the agreed-upon service levels are met. All measurements are based on aggregated data over 15-minute intervals, unless otherwise specified.
# Processing line:
# Processing line: 3.1. Throughput (Downlink)
# Processing line:
# Processing line: Objective: Average downlink throughput of 1 Gbps (Gigabits per second).
# Processing line:
# Processing line: Minimum Guaranteed: 750 Mbps.
# Processing line:
# Processing line: Measurement Point: User Plane Function (UPF) egress to customer premises equipment (CPE).
# Processing line:
# Processing line: Reporting Frequency: Daily aggregated reports, monthly detailed reports.
# Processing line:
# Processing line: 3.2. Throughput (Uplink)
# Processing line:
# Processing line: Objective: Average uplink throughput of 200 Mbps.
# Processing line:
# Processing line: Minimum Guaranteed: 150 Mbps.
# Processing line:
# Processing line: Measurement Point: CPE ingress to UPF ingress.
# Processing line:
# Processing line: Reporting Frequency: Daily aggregated reports, monthly detailed reports.
# Processing line:
# Processing line: 3.3. Latency (Round Trip Time - RTT)
# Processing line:
# Processing line: Objective: Average end-to-end latency of less than 10 ms (milliseconds).
#  Matched latency: {}
#  No 'value' group found for match: latency of less than 10 ms
# Processing line:
# Processing line: Maximum Tolerated: 15 ms for 99.9% of traffic.
# Processing line:
# Processing line: Measurement Point: From customer device to designated core network gateway.
# Processing line:
# Processing line: Reporting Frequency: Hourly aggregated reports, weekly detailed reports.
# Processing line:
# Processing line: 3.4. Jitter
# Processing line:
# Processing line: Objective: Maximum jitter of 2 ms.
# Processing line:
# Processing line: Measurement Point: From customer device to designated core network gateway.
# Processing line:
# Processing line: Reporting Frequency: Hourly aggregated reports, weekly detailed reports.
# Processing line:
# Processing line: 3.5. Packet Loss Rate
# Processing line:
# Processing line: Objective: Less than 0.01% packet loss.
# Processing line:
# Processing line: Maximum Tolerated: 0.05%.
# Processing line:
# Processing line: Measurement Point: End-to-end across the 5G network segment.
# Processing line:
# Processing line: Reporting Frequency: Daily aggregated reports.
# Processing line:
# Processing line: 3.6. Service Availability
# Processing line:
# Processing line: Objective: 99.99% availability of the 5G eMBB service within the primary service area.
# Processing line:
# Processing line: Definition: Uptime measured as the percentage of time the service is fully operational and accessible to the customer. Planned maintenance windows are excluded.
# Processing line:
# Processing line: Reporting Frequency: Monthly.
# Processing line:
# Processing line: 4. Service Credits and Penalties
# Processing line:
# Processing line: In the event that NexGen Telecom Inc. fails to meet the agreed-upon Service Level Objectives (SLOs) for a given month, the Customer shall be entitled to service credits as follows:
# Processing line:
# Processing line: Availability:
# Processing line:
# Processing line: 99.9% to < 99.99% availability: 5% service credit on monthly fee.
#  Matched availability: {}
#  No 'value' group found for match: availability: 5%
# Processing line:
# Processing line: 99.0% to < 99.9% availability: 10% service credit on monthly fee.
#  Matched availability: {}
#  No 'value' group found for match: availability: 10%
# Processing line:
# Processing line: < 99.0% availability: 20% service credit on monthly fee.
#  Matched availability: {}
#  No 'value' group found for match: availability: 20%
# Processing line:
# Processing line: Throughput (Downlink/Uplink) - if Minimum Guaranteed is not met for more than 5% of the reporting period: 5% service credit on monthly fee per metric.
# Processing line:
# Processing line: Latency/Packet Loss/Jitter - if Maximum Tolerated is exceeded for more than 1% of the reporting period: 5% service credit on monthly fee per metric.
# Processing line:
# Processing line: Service credits will be applied to the subsequent month's invoice. Total service credits in any given month shall not exceed 25% of the total monthly service fee.
# Processing line:
# Processing line: 5. Responsibilities of the Parties
# Processing line:
# Processing line: 5.1. NexGen Telecom Inc. (Service Provider):
# Processing line:
# Processing line: Maintain the 5G network infrastructure to meet the specified SLOs.
# Processing line:
# Processing line: Provide 24/7 technical support.
# Processing line:
# Processing line: Monitor service performance and provide regular reports to the Customer.
# Processing line:
# Processing line: Notify Customer of planned maintenance activities at least 72 hours in advance.
# Processing line:
# Processing line: Respond to and resolve service incidents within the defined support windows.
# Processing line:
# Processing line: 5.2. Enterprise Solutions Corp. (Customer):
# Processing line:
# Processing line: Provide necessary access to customer premises for equipment installation and maintenance.
# Processing line:
# Processing line: Ensure proper functioning of customer-owned equipment (CPE) and devices.
# Processing line:
# Processing line: Notify NexGen Telecom Inc. promptly of any service issues.
# Processing line:
# Processing line: Adhere to the fair usage policy (if applicable, detailed in Appendix B).
# Processing line:
# Processing line: 6. Support and Incident Management
# Processing line:
# Processing line: 6.1. Support Channels:
# Processing line:
# Processing line: Online Portal: Available 24/7 for incident reporting and tracking.
# Processing line:
# Processing line: Phone Support: [+XX XXXX XXXX] (24/7 for critical incidents, 9 AM - 5 PM M-F for general inquiries).
# Processing line:
# Processing line: Email Support: support@nexgentelecom.com (Monitored 9 AM - 5 PM M-F).
# Processing line:
# Processing line: 6.2. Incident Prioritization:
# Processing line:
# Processing line: Critical (P1): Complete service outage or severe degradation impacting all users. Target Resolution Time (TRT): 4 hours.
# Processing line:
# Processing line: High (P2): Significant service degradation impacting a subset of users or critical applications. TRT: 8 hours.
# Processing line:
# Processing line: Medium (P3): Minor service degradation or intermittent issues. TRT: 24 hours.
# Processing line:
# Processing line: Low (P4): General inquiries or non-service impacting issues. TRT: 48 hours.
# Processing line:
# Processing line: 6.3. Reporting and Communication: NexGen Telecom Inc. will provide regular updates on incident status until resolution.
# Processing line:
# Processing line: 7. Dispute Resolution
# Processing line:
# Processing line: Any disputes arising from this SLA shall first be attempted to be resolved through good-faith negotiation between the parties. If an amicable resolution cannot be reached within 30 days, either party may escalate the dispute to formal mediation.
# Processing line:
# Processing line: 8. Termination
# Processing line:
# Processing line: This SLA may be terminated by either party with 60 days' written notice, subject to the terms of the master service agreement between NexGen Telecom Inc. and Enterprise Solutions Corp.
# Processing line:
# Processing line: 9. Review and Amendment
# Processing line:
# Processing line: This SLA will be reviewed annually on the anniversary of the Effective Date or sooner if significant changes in service requirements or network capabilities occur. Any amendments must be mutually agreed upon in writing.
# Processing line:
# Processing line:
# Processing line: 1. Parties Involved
# Processing line:
# Processing line: Service Provider: XY
# Processing line: Customer: CustomerZ
# Processing line: Agreement Date: 2025-06-09
# Processing line: Effective Period: 2025-06-10
# Processing line:
# Processing line: 2. Service Description
# Processing line:
# Processing line: Service Name: 5G Connectivity Service
# Processing line: Service Scope: High-speed, low-latency wireless connectivity using 5G NR (New Radio) technology.
# Processing line: Coverage Area: [Geographic Area or Locations]
# Processing line: Service Tiers: [e.g., Basic, Premium, Enterprise]
# Processing line:
# Processing line: 3. Performance Metrics
# Processing line:
# Processing line: Availability: ≥ 99.99% uptime per calendar month
#  Matched availability: {}
#  No 'value' group found for match: Availability: ≥ 99.99%
# Processing line: Latency: ≤ 10 ms (one-way)
# Processing line: Throughput:
# Processing line: Downlink: ≥ 1 Gbps
# Processing line: Uplink: ≥ 100 Mbps
# Processing line: Jitter: ≤ 5 ms
# Processing line: Packet Loss: ≤ 0.1%
# Processing line:
# Processing line: 4. Monitoring and Reporting
# Processing line:
# Processing line: Monitoring Tools: [Provider Monitoring Dashboard]
# Processing line: Reporting Frequency: Monthly
# Processing line: Report Delivery Method: [Email, Web Portal]
# Processing line:
# Processing line: 5. Support and Maintenance
# Processing line:
# Processing line: Support Hours: 24/7
# Processing line: Incident Response Time:
# Processing line: Critical: ≤ 15 minutes
# Processing line: Major: ≤ 1 hour
# Processing line: Minor: ≤ 4 hours
# Processing line: Planned Maintenance Notification: Minimum 48 hours in advance
# Processing line:
# Processing line: 6. Penalties and Remedies
# Processing line:
# Processing line: Service Credits:
# Processing line: Availability < 99.99%: 5% monthly fee credit
#  Matched availability: {}
#  No 'value' group found for match: Availability < 99.99%
# Processing line: Latency > 10 ms: 3% monthly fee credit
# Processing line: Maximum Credit Cap: 25% of monthly service fee
# Processing line:
# Processing line: 7. Termination Conditions
# Processing line:
# Processing line: Breach of SLA: Termination allowed after 3 consecutive months of non-compliance
# Processing line: Notice Period: 30 days written notice
# Processing line:
# Processing line: 8. Miscellaneous
# Processing line:
# Processing line: Governing Law: [Jurisdiction]
# Processing line: Amendments: Must be in writing and signed by both parties
# Processing line: Confidentiality: Both parties agree to maintain confidentiality of SLA terms
# Processing line:
# Processing line: **5G Service Level Agreement (SLA)**
# Processing line:
# Processing line: **1. General Information**
# Processing line:
# Processing line: * **AgreementID**: SLA-5G-001
# Processing line: * **Provider**: NextGen Mobile Networks
# Processing line: * **Customer**: Acme Corp
# Processing line: * **ServiceName**: 5G Enhanced Mobile Broadband (eMBB)
# Processing line: * **EffectiveDate**: 2025-07-01
# Processing line: * **ExpirationDate**: 2026-06-30
# Processing line:
# Processing line: **2. Service Scope**
# Processing line:
# Processing line: * **CoverageArea**: Urban and suburban zones in Region-X
# Processing line: * **SupportedDevices**: 3GPP Release 16 compliant devices
# Processing line: * **UseCases**: Video streaming, AR/VR, industrial IoT
# Processing line:
# Processing line: **3. Performance Metrics**
# Processing line:
# Processing line: * **Availability**:
# Processing line:
# Processing line: * **Target**: 99.99%
# Processing line: * **MeasurementPeriod**: Monthly
# Processing line:
# Processing line: * **Latency**:
# Processing line:
# Processing line: * **Target**: ≤ 5 ms (edge-to-edge)
# Processing line: * **MeasurementPeriod**: Continuous
# Processing line:
# Processing line: * **Throughput**:
# Processing line:
# Processing line: * **Downlink**: ≥ 1 Gbps
# Processing line: * **Uplink**: ≥ 500 Mbps
# Processing line: * **MeasurementPeriod**: Peak hours (17:00–21:00 local time)
# Processing line:
# Processing line: * **Jitter**:
# Processing line:
# Processing line: * **Target**: ≤ 10ms
# Processing line:
# Processing line: **4. Fault Management**
# Processing line:
# Processing line: * **IncidentResponseTime**: ≤ 15 minutes
# Processing line: * **IncidentResolutionTime**: ≤ 4 hours (Priority 1 incidents)
# Processing line: * **Monitoring**: 24/7 NOC monitoring
# Processing line:
# Processing line: **5. Penalties and Remedies**
# Processing line:
# Processing line: * **AvailabilityBreach**:
# Processing line:
# Processing line: * **Threshold**: < 99.5%
# Processing line: * **Credit**: 10% monthly fee refund
# Processing line: * **LatencyBreach**:
# Processing line:
# Processing line: * **Threshold**: > 10 ms average for over 3hours
# Processing line: * **Credit**: 5% monthly fee refund
# Processing line: * **MaximumTotalCredit**: 30% of monthly fee
# Processing line:
# Processing line: **6. Reporting**
# Processing line:
# Processing line: * **Frequency**: Monthly
# Processing line: * **Format**: PDF, XML
# Processing line: * **DeliveryMethod**: Email to customer-designated recipient
# Processing line:
# Processing line: **7. Contact Information**
# Processing line:
# Processing line: * **ProviderSupportEmail**: [support@nextgen-networks.com](mailto:support@nextgen-networks.com)
# Processing line: * **ProviderSupportPhone**: +1-800-555-5GSL
# Processing line: * **CustomerContact**: [itops@acme-corp.com](mailto:itops@acme-corp.com)
# Processing line:
# Processing line: **8. Terms and Termination**
# Processing line:
# Processing line: * **TerminationNoticePeriod**: 30 days
# Processing line: * **Renewal**: Auto-renewal annually unless terminated
#  XML generated as 'output.xml'

# %%
for token in doc:
    print(f"Token: {token.text}, POS: {token.pos_}, Dependency: {token.dep_}")
for ent in doc.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: compound
# Token: SERVICE, POS: NOUN, Dependency: compound
# Token: LEVEL, POS: NOUN, Dependency: compound
# Token: AGREEMENT, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: SLA, POS: PROPN, Dependency: nmod
# Token: ), POS: PUNCT, Dependency: punct
# Token:
# , POS: SPACE, Dependency: dep
# Token: Service, POS: PROPN, Dependency: compound
# Token: Provider, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Telco, POS: PROPN, Dependency: compound
# Token: Solutions, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Customer, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Enterprise, POS: PROPN, Dependency: compound
# Token: Client, POS: PROPN, Dependency: compound
# Token: Ltd., POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Effective, POS: PROPN, Dependency: compound
# Token: Date, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 01, POS: NUM, Dependency: nummod
# Token: -, POS: PUNCT, Dependency: punct
# Token: Oct-2025, POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Review, POS: PROPN, Dependency: compound
# Token: Cycle, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Quarterly, POS: PROPN, Dependency: appos
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 1, POS: X, Dependency: nummod
# Token: ., POS: X, Dependency: punct
# Token: SERVICE, POS: NOUN, Dependency: compound
# Token: AVAILABILITY, POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Target, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 99.95, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: appos
# Token: monthly, POS: ADJ, Dependency: amod
# Token: uptime, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Exclusions, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Scheduled, POS: VERB, Dependency: amod
# Token: maintenance, POS: NOUN, Dependency: nsubj
# Token: (, POS: PUNCT, Dependency: punct
# Token: max, POS: PROPN, Dependency: nmod
# Token: 4hrs, POS: PROPN, Dependency: nmod
# Token: /, POS: SYM, Dependency: punct
# Token: month, POS: NOUN, Dependency: appos
# Token: ,, POS: PUNCT, Dependency: punct
# Token: notified, POS: VERB, Dependency: acl
# Token: 72hrs, POS: ADJ, Dependency: oprd
# Token: in, POS: ADP, Dependency: prep
# Token: advance, POS: NOUN, Dependency: pobj
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Formula, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: (, POS: PUNCT, Dependency: punct
# Token: Total, POS: PROPN, Dependency: compound
# Token: Minutes, POS: PROPN, Dependency: compound
# Token: -, POS: PUNCT, Dependency: punct
# Token: Downtime, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: /, POS: SYM, Dependency: punct
# Token: Total, POS: PROPN, Dependency: compound
# Token: Minutes, POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Penalty, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: per, POS: ADP, Dependency: prep
# Token: 0.1, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: pobj
# Token: below, POS: ADP, Dependency: prep
# Token: target, POS: NOUN, Dependency: pobj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 2, POS: NUM, Dependency: nummod
# Token: ., POS: PUNCT, Dependency: punct
# Token: NETWORK, POS: PROPN, Dependency: compound
# Token: LATENCY, POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Target, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: ≤20ms, POS: NUM, Dependency: nummod
# Token: end, POS: NOUN, Dependency: nmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: to, POS: ADP, Dependency: prep
# Token: -, POS: PUNCT, Dependency: punct
# Token: end, POS: NOUN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: UE, POS: PROPN, Dependency: nmod
# Token: to, POS: ADP, Dependency: prep
# Token: Core, POS: PROPN, Dependency: pobj
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Scope, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Urban, POS: ADJ, Dependency: amod
# Token: zones, POS: NOUN, Dependency: appos
# Token: (, POS: PUNCT, Dependency: punct
# Token: per, POS: ADP, Dependency: prep
# Token: coverage, POS: NOUN, Dependency: compound
# Token: map, POS: NOUN, Dependency: pobj
# Token: in, POS: ADP, Dependency: prep
# Token: Appendix, POS: PROPN, Dependency: nmod
# Token: A, POS: PROPN, Dependency: nmod
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: 95th, POS: ADJ, Dependency: amod
# Token: percentile, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: hourly, POS: ADJ, Dependency: amod
# Token: probes, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Penalty, POS: PROPN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: 3, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: per, POS: ADP, Dependency: prep
# Token: 1ms, POS: ADJ, Dependency: amod
# Token: sustained, POS: ADJ, Dependency: amod
# Token: breach, POS: NOUN, Dependency: pobj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3, POS: NUM, Dependency: nummod
# Token: ., POS: PUNCT, Dependency: punct
# Token: DOWNLINK, POS: PROPN, Dependency: compound
# Token: THROUGHPUT, POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Target, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: ≥500, POS: ADJ, Dependency: amod
# Token: Mbps, POS: PROPN, Dependency: compound
# Token: peak, POS: NOUN, Dependency: dep
# Token: /, POS: SYM, Dependency: punct
# Token: ≥200, POS: VERB, Dependency: acl
# Token: Mbps, POS: PROPN, Dependency: dobj
# Token: average, POS: ADJ, Dependency: amod
# Token: per, POS: ADP, Dependency: prep
# Token: device, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Conditions, POS: NOUN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Non, POS: ADJ, Dependency: amod
# Token: -, POS: ADJ, Dependency: amod
# Token: congested, POS: ADJ, Dependency: amod
# Token: network, POS: NOUN, Dependency: appos
# Token: ,, POS: PUNCT, Dependency: punct
# Token: <, POS: X, Dependency: punct
# Token: 50, POS: NUM, Dependency: punct
# Token: concurrently, POS: ADV, Dependency: advmod
# Token: active, POS: ADJ, Dependency: amod
# Token: UEs, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Daily, POS: ADJ, Dependency: amod
# Token: speed, POS: NOUN, Dependency: compound
# Token: tests, POS: NOUN, Dependency: appos
# Token: (, POS: PUNCT, Dependency: punct
# Token: 9, POS: NUM, Dependency: nummod
# Token: AM–5, POS: ADJ, Dependency: amod
# Token: PM, POS: NOUN, Dependency: nmod
# Token: ,, POS: PUNCT, Dependency: punct
# Token: workdays, POS: NOUN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Penalty, POS: NOUN, Dependency: npadvmod
# Token: :, POS: PUNCT, Dependency: punct
# Token: 2, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: per, POS: ADP, Dependency: prep
# Token: 10, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: deviation, POS: NOUN, Dependency: pobj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 4, POS: NUM, Dependency: nummod
# Token: ., POS: PUNCT, Dependency: punct
# Token: RELIABILITY, POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Target, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: ≤0.001, POS: PUNCT, Dependency: punct
# Token: %, POS: NOUN, Dependency: compound
# Token: packet, POS: NOUN, Dependency: compound
# Token: loss, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: ICMP, POS: PROPN, Dependency: nsubj
# Token: probes, POS: VERB, Dependency: acl
# Token: every, POS: DET, Dependency: det
# Token: 5, POS: NUM, Dependency: nummod
# Token: minutes, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Penalty, POS: PROPN, Dependency: dobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: 4, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: per, POS: ADP, Dependency: prep
# Token: 0.0005, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: breach, POS: NOUN, Dependency: pobj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 5, POS: NUM, Dependency: nummod
# Token: ., POS: PUNCT, Dependency: punct
# Token: FAULT, POS: PROPN, Dependency: compound
# Token: RESTORATION, POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Critical, POS: PROPN, Dependency: compound
# Token: Faults, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: ≤4, POS: PROPN, Dependency: compound
# Token: hours, POS: NOUN, Dependency: appos
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Non, POS: ADJ, Dependency: amod
# Token: -, POS: ADJ, Dependency: compound
# Token: Critical, POS: ADJ, Dependency: amod
# Token: Faults, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: ≤24, POS: PRON, Dependency: nmod
# Token: hours, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Penalty, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: $, POS: SYM, Dependency: quantmod
# Token: 500, POS: NUM, Dependency: nummod
# Token: /, POS: SYM, Dependency: punct
# Token: hour, POS: NOUN, Dependency: compound
# Token: delay, POS: NOUN, Dependency: appos
# Token: beyond, POS: ADP, Dependency: prep
# Token: target, POS: NOUN, Dependency: pobj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 6, POS: NUM, Dependency: nummod
# Token: ., POS: PUNCT, Dependency: punct
# Token: REPORTING, POS: PROPN, Dependency: appos
# Token: &, POS: CCONJ, Dependency: cc
# Token: SUPPORT, POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: KPI, POS: PROPN, Dependency: compound
# Token: Reports, POS: NOUN, Dependency: conj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Monthly, POS: PROPN, Dependency: appos
# Token: (, POS: PUNCT, Dependency: punct
# Token: by, POS: ADP, Dependency: prep
# Token: 5th, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: next, POS: ADJ, Dependency: amod
# Token: month, POS: NOUN, Dependency: pobj
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Support, POS: NOUN, Dependency: dep
# Token: :, POS: PUNCT, Dependency: punct
# Token: 24/7, POS: NUM, Dependency: nummod
# Token: helpdesk, POS: NOUN, Dependency: appos
# Token: (, POS: PUNCT, Dependency: punct
# Token: max, POS: PROPN, Dependency: nmod
# Token: 15, POS: NUM, Dependency: nummod
# Token: -, POS: PUNCT, Dependency: punct
# Token: min, POS: NOUN, Dependency: compound
# Token: response, POS: NOUN, Dependency: appos
# Token: for, POS: ADP, Dependency: prep
# Token: P1, POS: PROPN, Dependency: compound
# Token: tickets, POS: NOUN, Dependency: pobj
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Audit, POS: PROPN, Dependency: compound
# Token: Rights, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Customer, POS: NOUN, Dependency: nsubj
# Token: may, POS: AUX, Dependency: aux
# Token: request, POS: VERB, Dependency: ROOT
# Token: measurement, POS: NOUN, Dependency: nsubj
# Token: logs, POS: VERB, Dependency: ccomp
# Token: quarterly, POS: ADV, Dependency: advmod
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 7, POS: NUM, Dependency: dobj
# Token: ., POS: X, Dependency: punct
# Token: SERVICE, POS: NOUN, Dependency: compound
# Token: CREDITS, POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Max, POS: PROPN, Dependency: compound
# Token: Annual, POS: PROPN, Dependency: compound
# Token: Credit, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 20, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Claim, POS: PROPN, Dependency: compound
# Token: Window, POS: PROPN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: 30, POS: NUM, Dependency: nummod
# Token: days, POS: NOUN, Dependency: appos
# Token: from, POS: ADP, Dependency: prep
# Token: report, POS: NOUN, Dependency: compound
# Token: receipt, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Service, POS: PROPN, Dependency: compound
# Token: Level, POS: PROPN, Dependency: compound
# Token: Agreement, POS: PROPN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: SLA, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: -, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: nmod
# Token: Enhanced, POS: PROPN, Dependency: amod
# Token: Mobile, POS: PROPN, Dependency: compound
# Token: Broadband, POS: PROPN, Dependency: nmod
# Token: (, POS: PUNCT, Dependency: punct
# Token: eMBB, POS: PROPN, Dependency: nmod
# Token: ), POS: PUNCT, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Agreement, POS: PROPN, Dependency: compound
# Token: ID, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: SLA-5G, POS: PROPN, Dependency: nmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: eMBB-001, POS: NOUN, Dependency: nmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: 20250626, POS: NUM, Dependency: nummod
# Token:
# , POS: SPACE, Dependency: dep
# Token: Effective, POS: PROPN, Dependency: compound
# Token: Date, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 2025, POS: NUM, Dependency: nummod
# Token: -, POS: SYM, Dependency: punct
# Token: 07, POS: NUM, Dependency: nmod
# Token: -, POS: SYM, Dependency: punct
# Token: 01, POS: NUM, Dependency: nummod
# Token:
# , POS: SPACE, Dependency: dep
# Token: Service, POS: PROPN, Dependency: compound
# Token: Provider, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Customer, POS: NOUN, Dependency: nmod
# Token: :, POS: PUNCT, Dependency: punct
# Token: Enterprise, POS: PROPN, Dependency: compound
# Token: Solutions, POS: PROPN, Dependency: compound
# Token: Corp., POS: PROPN, Dependency: compound
# Token:
# , POS: SPACE, Dependency: dep
# Token: Service, POS: PROPN, Dependency: compound
# Token: Type, POS: PROPN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: compound
# Token: Enhanced, POS: PROPN, Dependency: amod
# Token: Mobile, POS: PROPN, Dependency: compound
# Token: Broadband, POS: PROPN, Dependency: appos
# Token: (, POS: PUNCT, Dependency: punct
# Token: eMBB, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: -, POS: PUNCT, Dependency: punct
# Token: High, POS: PROPN, Dependency: compound
# Token: -, POS: PUNCT, Dependency: punct
# Token: Capacity, POS: PROPN, Dependency: compound
# Token: Data, POS: PROPN, Dependency: compound
# Token: Service, POS: PROPN, Dependency: appos
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 1, POS: NUM, Dependency: appos
# Token: ., POS: X, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Description, POS: PROPN, Dependency: nsubj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: This, POS: DET, Dependency: det
# Token: SLA, POS: PROPN, Dependency: appos
# Token: outlines, POS: VERB, Dependency: ROOT
# Token: the, POS: DET, Dependency: det
# Token: terms, POS: NOUN, Dependency: dobj
# Token: and, POS: CCONJ, Dependency: cc
# Token: conditions, POS: NOUN, Dependency: conj
# Token: for, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: provision, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: a, POS: DET, Dependency: det
# Token: dedicated, POS: ADJ, Dependency: amod
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: nmod
# Token: Enhanced, POS: ADJ, Dependency: amod
# Token: Mobile, POS: PROPN, Dependency: nmod
# Token: Broadband, POS: PROPN, Dependency: nmod
# Token: (, POS: PUNCT, Dependency: punct
# Token: eMBB, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: service, POS: NOUN, Dependency: pobj
# Token: to, POS: ADP, Dependency: prep
# Token: Enterprise, POS: PROPN, Dependency: compound
# Token: Solutions, POS: PROPN, Dependency: compound
# Token: Corp., POS: PROPN, Dependency: punct
# Token: This, POS: DET, Dependency: det
# Token: service, POS: NOUN, Dependency: nsubjpass
# Token: is, POS: AUX, Dependency: auxpass
# Token: designed, POS: VERB, Dependency: ROOT
# Token: to, POS: PART, Dependency: aux
# Token: deliver, POS: VERB, Dependency: xcomp
# Token: high, POS: ADJ, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: throughput, POS: NOUN, Dependency: nmod
# Token: ,, POS: PUNCT, Dependency: punct
# Token: low, POS: ADJ, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: latency, POS: NOUN, Dependency: compound
# Token: connectivity, POS: NOUN, Dependency: dobj
# Token: primarily, POS: ADV, Dependency: advmod
# Token: for, POS: ADP, Dependency: prep
# Token: data, POS: NOUN, Dependency: npadvmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: intensive, POS: ADJ, Dependency: amod
# Token: applications, POS: NOUN, Dependency: pobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: including, POS: VERB, Dependency: prep
# Token: but, POS: CCONJ, Dependency: cc
# Token: not, POS: PART, Dependency: neg
# Token: limited, POS: VERB, Dependency: conj
# Token: to, POS: ADP, Dependency: prep
# Token: ,, POS: PUNCT, Dependency: punct
# Token: cloud, POS: PROPN, Dependency: compound
# Token: computing, POS: NOUN, Dependency: appos
# Token: ,, POS: PUNCT, Dependency: punct
# Token: high, POS: ADJ, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: definition, POS: NOUN, Dependency: compound
# Token: video, POS: NOUN, Dependency: compound
# Token: streaming, POS: NOUN, Dependency: conj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: and, POS: CCONJ, Dependency: cc
# Token: large, POS: ADJ, Dependency: amod
# Token: file, POS: NOUN, Dependency: compound
# Token: transfers, POS: NOUN, Dependency: conj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 2, POS: X, Dependency: meta
# Token: ., POS: X, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Scope, POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Geographic, POS: PROPN, Dependency: compound
# Token: Coverage, POS: PROPN, Dependency: nsubjpass
# Token: :, POS: PUNCT, Dependency: punct
# Token: Primary, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: area, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Metropolitan, POS: PROPN, Dependency: compound
# Token: Region, POS: PROPN, Dependency: compound
# Token: X, POS: PROPN, Dependency: appos
# Token: ,, POS: PUNCT, Dependency: punct
# Token: with, POS: ADP, Dependency: prep
# Token: secondary, POS: ADJ, Dependency: amod
# Token: coverage, POS: NOUN, Dependency: pobj
# Token: in, POS: ADP, Dependency: prep
# Token: Industrial, POS: PROPN, Dependency: compound
# Token: Zone, POS: PROPN, Dependency: compound
# Token: Y., POS: PROPN, Dependency: compound
# Token: Specific, POS: PROPN, Dependency: compound
# Token: cell, POS: NOUN, Dependency: compound
# Token: IDs, POS: NOUN, Dependency: pobj
# Token: and, POS: CCONJ, Dependency: cc
# Token: coverage, POS: NOUN, Dependency: compound
# Token: maps, POS: NOUN, Dependency: conj
# Token: are, POS: AUX, Dependency: auxpass
# Token: attached, POS: VERB, Dependency: ROOT
# Token: as, POS: ADP, Dependency: prep
# Token: Appendix, POS: PROPN, Dependency: compound
# Token: A., POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: User, POS: PROPN, Dependency: compound
# Token: Devices, POS: PROPN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Support, POS: NOUN, Dependency: appos
# Token: for, POS: ADP, Dependency: prep
# Token: 5G, POS: NOUN, Dependency: npadvmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: compliant, POS: ADJ, Dependency: amod
# Token: devices, POS: NOUN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: smartphones, POS: NOUN, Dependency: appos
# Token: ,, POS: PUNCT, Dependency: punct
# Token: tablets, POS: NOUN, Dependency: conj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: IoT, POS: ADJ, Dependency: amod
# Token: gateways, POS: NOUN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: utilizing, POS: VERB, Dependency: acl
# Token: the, POS: DET, Dependency: det
# Token: designated, POS: VERB, Dependency: amod
# Token: SIM, POS: PROPN, Dependency: nmod
# Token: cards, POS: NOUN, Dependency: nmod
# Token: /, POS: SYM, Dependency: punct
# Token: eSIM, POS: NOUN, Dependency: compound
# Token: profiles, POS: NOUN, Dependency: dobj
# Token: provided, POS: VERB, Dependency: acl
# Token: by, POS: ADP, Dependency: agent
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: nmod
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Traffic, POS: PROPN, Dependency: compound
# Token: Prioritization, POS: PROPN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: eMBB, POS: NOUN, Dependency: appos
# Token: traffic, POS: NOUN, Dependency: nsubj
# Token: will, POS: AUX, Dependency: aux
# Token: receive, POS: VERB, Dependency: conj
# Token: priority, POS: NOUN, Dependency: dobj
# Token: over, POS: ADP, Dependency: prep
# Token: best, POS: ADJ, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: effort, POS: NOUN, Dependency: compound
# Token: traffic, POS: NOUN, Dependency: pobj
# Token: within, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: defined, POS: VERB, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: slices, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3, POS: X, Dependency: ROOT
# Token: ., POS: X, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Level, POS: PROPN, Dependency: compound
# Token: Objectives, POS: PROPN, Dependency: nsubjpass
# Token: (, POS: PUNCT, Dependency: punct
# Token: SLOs, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: and, POS: CCONJ, Dependency: cc
# Token: Performance, POS: PROPN, Dependency: compound
# Token: Metrics, POS: PROPN, Dependency: conj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: The, POS: DET, Dependency: det
# Token: following, POS: VERB, Dependency: amod
# Token: performance, POS: NOUN, Dependency: compound
# Token: metrics, POS: NOUN, Dependency: appos
# Token: will, POS: AUX, Dependency: aux
# Token: be, POS: AUX, Dependency: auxpass
# Token: measured, POS: VERB, Dependency: ROOT
# Token: and, POS: CCONJ, Dependency: cc
# Token: monitored, POS: VERB, Dependency: conj
# Token: to, POS: PART, Dependency: aux
# Token: ensure, POS: VERB, Dependency: xcomp
# Token: the, POS: DET, Dependency: det
# Token: agreed, POS: VERB, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: upon, POS: ADP, Dependency: prt
# Token: service, POS: NOUN, Dependency: compound
# Token: levels, POS: NOUN, Dependency: nsubjpass
# Token: are, POS: AUX, Dependency: auxpass
# Token: met, POS: VERB, Dependency: ccomp
# Token: ., POS: PUNCT, Dependency: punct
# Token: All, POS: DET, Dependency: det
# Token: measurements, POS: NOUN, Dependency: nsubjpass
# Token: are, POS: AUX, Dependency: auxpass
# Token: based, POS: VERB, Dependency: ROOT
# Token: on, POS: ADP, Dependency: prep
# Token: aggregated, POS: VERB, Dependency: amod
# Token: data, POS: NOUN, Dependency: pobj
# Token: over, POS: ADP, Dependency: prep
# Token: 15, POS: NUM, Dependency: nummod
# Token: -, POS: PUNCT, Dependency: punct
# Token: minute, POS: NOUN, Dependency: compound
# Token: intervals, POS: NOUN, Dependency: pobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: unless, POS: SCONJ, Dependency: mark
# Token: otherwise, POS: ADV, Dependency: advmod
# Token: specified, POS: VERB, Dependency: advcl
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.1, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Throughput, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: Downlink, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Average, POS: ADJ, Dependency: amod
# Token: downlink, POS: NOUN, Dependency: compound
# Token: throughput, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: 1, POS: NUM, Dependency: nummod
# Token: Gbps, POS: PROPN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: Gigabits, POS: NOUN, Dependency: appos
# Token: per, POS: ADP, Dependency: prep
# Token: second, POS: ADJ, Dependency: pobj
# Token: ), POS: PUNCT, Dependency: punct
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Minimum, POS: PROPN, Dependency: compound
# Token: Guaranteed, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 750, POS: NUM, Dependency: nummod
# Token: Mbps, POS: PROPN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: compound
# Token: Point, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: User, POS: PROPN, Dependency: compound
# Token: Plane, POS: PROPN, Dependency: compound
# Token: Function, POS: PROPN, Dependency: nmod
# Token: (, POS: PUNCT, Dependency: punct
# Token: UPF, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: egress, POS: NOUN, Dependency: appos
# Token: to, POS: ADP, Dependency: prep
# Token: customer, POS: NOUN, Dependency: compound
# Token: premises, POS: NOUN, Dependency: compound
# Token: equipment, POS: NOUN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: CPE, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: VERB, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: nsubj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Daily, POS: PROPN, Dependency: nsubj
# Token: aggregated, POS: VERB, Dependency: ROOT
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: monthly, POS: ADJ, Dependency: advmod
# Token: detailed, POS: ADJ, Dependency: amod
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.2, POS: NUM, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token: Throughput, POS: PROPN, Dependency: nmod
# Token: (, POS: PUNCT, Dependency: punct
# Token: Uplink, POS: PROPN, Dependency: nmod
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Average, POS: ADJ, Dependency: amod
# Token: uplink, POS: ADJ, Dependency: amod
# Token: throughput, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: 200, POS: NUM, Dependency: nummod
# Token: Mbps, POS: PROPN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Minimum, POS: PROPN, Dependency: compound
# Token: Guaranteed, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 150, POS: NUM, Dependency: nummod
# Token: Mbps, POS: PROPN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: compound
# Token: Point, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: CPE, POS: PROPN, Dependency: compound
# Token: ingress, POS: NOUN, Dependency: appos
# Token: to, POS: ADP, Dependency: prep
# Token: UPF, POS: PROPN, Dependency: compound
# Token: ingress, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: PROPN, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: nsubj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Daily, POS: PROPN, Dependency: nsubj
# Token: aggregated, POS: VERB, Dependency: ROOT
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: monthly, POS: ADJ, Dependency: advmod
# Token: detailed, POS: ADJ, Dependency: amod
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.3, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Latency, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: Round, POS: PROPN, Dependency: compound
# Token: Trip, POS: PROPN, Dependency: compound
# Token: Time, POS: PROPN, Dependency: compound
# Token: -, POS: PUNCT, Dependency: punct
# Token: RTT, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Average, POS: ADJ, Dependency: amod
# Token: end, POS: NOUN, Dependency: nmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: to, POS: ADP, Dependency: prep
# Token: -, POS: PUNCT, Dependency: punct
# Token: end, POS: NOUN, Dependency: pobj
# Token: latency, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: less, POS: ADJ, Dependency: amod
# Token: than, POS: ADP, Dependency: quantmod
# Token: 10, POS: NUM, Dependency: nummod
# Token: ms, POS: NOUN, Dependency: pobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: milliseconds, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Maximum, POS: PROPN, Dependency: compound
# Token: Tolerated, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 15, POS: NUM, Dependency: nummod
# Token: ms, POS: NOUN, Dependency: appos
# Token: for, POS: ADP, Dependency: prep
# Token: 99.9, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: traffic, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: compound
# Token: Point, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: From, POS: ADP, Dependency: prep
# Token: customer, POS: NOUN, Dependency: compound
# Token: device, POS: NOUN, Dependency: pobj
# Token: to, POS: ADP, Dependency: prep
# Token: designated, POS: VERB, Dependency: amod
# Token: core, POS: NOUN, Dependency: amod
# Token: network, POS: NOUN, Dependency: compound
# Token: gateway, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: PROPN, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Hourly, POS: PROPN, Dependency: nsubj
# Token: aggregated, POS: VERB, Dependency: amod
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: weekly, POS: ADJ, Dependency: amod
# Token: detailed, POS: ADJ, Dependency: amod
# Token: reports, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.4, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Jitter, POS: NOUN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Maximum, POS: ADJ, Dependency: amod
# Token: jitter, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: 2, POS: NUM, Dependency: nummod
# Token: ms, POS: PROPN, Dependency: compound
# Token: ., POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: compound
# Token: Point, POS: PROPN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: From, POS: ADP, Dependency: prep
# Token: customer, POS: NOUN, Dependency: compound
# Token: device, POS: NOUN, Dependency: pobj
# Token: to, POS: ADP, Dependency: prep
# Token: designated, POS: VERB, Dependency: amod
# Token: core, POS: NOUN, Dependency: amod
# Token: network, POS: NOUN, Dependency: compound
# Token: gateway, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: PROPN, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Hourly, POS: PROPN, Dependency: nsubj
# Token: aggregated, POS: VERB, Dependency: amod
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: weekly, POS: ADJ, Dependency: amod
# Token: detailed, POS: ADJ, Dependency: amod
# Token: reports, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.5, POS: NUM, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token: Packet, POS: PROPN, Dependency: compound
# Token: Loss, POS: PROPN, Dependency: compound
# Token: Rate, POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Less, POS: ADJ, Dependency: amod
# Token: than, POS: ADP, Dependency: quantmod
# Token: 0.01, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: nmod
# Token: packet, POS: NOUN, Dependency: compound
# Token: loss, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Maximum, POS: PROPN, Dependency: compound
# Token: Tolerated, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 0.05, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Measurement, POS: PROPN, Dependency: compound
# Token: Point, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: End, POS: NOUN, Dependency: appos
# Token: -, POS: PUNCT, Dependency: punct
# Token: to, POS: ADP, Dependency: prep
# Token: -, POS: PUNCT, Dependency: punct
# Token: end, POS: NOUN, Dependency: pobj
# Token: across, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: compound
# Token: network, POS: NOUN, Dependency: compound
# Token: segment, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: PROPN, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: nsubj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Daily, POS: PROPN, Dependency: nsubj
# Token: aggregated, POS: VERB, Dependency: ROOT
# Token: reports, POS: NOUN, Dependency: dobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 3.6, POS: NUM, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Availability, POS: PROPN, Dependency: compound
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Objective, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 99.99, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: availability, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: compound
# Token: eMBB, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: pobj
# Token: within, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: primary, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: area, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Definition, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Uptime, POS: PROPN, Dependency: nsubj
# Token: measured, POS: VERB, Dependency: acl
# Token: as, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: percentage, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: time, POS: NOUN, Dependency: pobj
# Token: the, POS: DET, Dependency: det
# Token: service, POS: NOUN, Dependency: nsubj
# Token: is, POS: AUX, Dependency: ccomp
# Token: fully, POS: ADV, Dependency: advmod
# Token: operational, POS: ADJ, Dependency: acomp
# Token: and, POS: CCONJ, Dependency: cc
# Token: accessible, POS: ADJ, Dependency: conj
# Token: to, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: customer, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token: Planned, POS: VERB, Dependency: amod
# Token: maintenance, POS: NOUN, Dependency: compound
# Token: windows, POS: NOUN, Dependency: nsubjpass
# Token: are, POS: AUX, Dependency: auxpass
# Token: excluded, POS: VERB, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Reporting, POS: PROPN, Dependency: compound
# Token: Frequency, POS: PROPN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: Monthly, POS: ADV, Dependency: advmod
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 4, POS: X, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Credits, POS: PROPN, Dependency: nsubjpass
# Token: and, POS: CCONJ, Dependency: cc
# Token: Penalties, POS: PROPN, Dependency: conj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: In, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: event, POS: NOUN, Dependency: pobj
# Token: that, POS: SCONJ, Dependency: mark
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: nsubj
# Token: fails, POS: VERB, Dependency: relcl
# Token: to, POS: PART, Dependency: aux
# Token: meet, POS: VERB, Dependency: xcomp
# Token: the, POS: DET, Dependency: det
# Token: agreed, POS: VERB, Dependency: amod
# Token: -, POS: PUNCT, Dependency: punct
# Token: upon, POS: ADP, Dependency: prt
# Token: Service, POS: PROPN, Dependency: compound
# Token: Level, POS: PROPN, Dependency: compound
# Token: Objectives, POS: PROPN, Dependency: dobj
# Token: (, POS: PUNCT, Dependency: punct
# Token: SLOs, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: for, POS: ADP, Dependency: prep
# Token: a, POS: DET, Dependency: det
# Token: given, POS: VERB, Dependency: amod
# Token: month, POS: NOUN, Dependency: pobj
# Token: ,, POS: PUNCT, Dependency: punct
# Token: the, POS: DET, Dependency: det
# Token: Customer, POS: PROPN, Dependency: nsubjpass
# Token: shall, POS: AUX, Dependency: aux
# Token: be, POS: AUX, Dependency: auxpass
# Token: entitled, POS: VERB, Dependency: ROOT
# Token: to, POS: ADP, Dependency: prep
# Token: service, POS: NOUN, Dependency: compound
# Token: credits, POS: NOUN, Dependency: pobj
# Token: as, POS: SCONJ, Dependency: mark
# Token: follows, POS: VERB, Dependency: advcl
# Token: :, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Availability, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 99.9, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: appos
# Token: to, POS: PART, Dependency: aux
# Token: <, POS: X, Dependency: punct
# Token: 99.99, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: availability, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: on, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 99.0, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: nmod
# Token: to, POS: AUX, Dependency: aux
# Token: <, POS: X, Dependency: appos
# Token: 99.9, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: availability, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 10, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: on, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: <, POS: X, Dependency: punct
# Token: 99.0, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: availability, POS: NOUN, Dependency: ROOT
# Token: :, POS: PUNCT, Dependency: punct
# Token: 20, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: on, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Throughput, POS: PROPN, Dependency: ROOT
# Token: (, POS: PUNCT, Dependency: punct
# Token: Downlink, POS: PROPN, Dependency: nmod
# Token: /, POS: SYM, Dependency: punct
# Token: Uplink, POS: PROPN, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token: -, POS: PUNCT, Dependency: punct
# Token: if, POS: SCONJ, Dependency: mark
# Token: Minimum, POS: ADJ, Dependency: compound
# Token: Guaranteed, POS: PROPN, Dependency: nsubjpass
# Token: is, POS: AUX, Dependency: auxpass
# Token: not, POS: PART, Dependency: neg
# Token: met, POS: VERB, Dependency: conj
# Token: for, POS: ADP, Dependency: prep
# Token: more, POS: ADJ, Dependency: amod
# Token: than, POS: ADP, Dependency: quantmod
# Token: 5, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: reporting, POS: NOUN, Dependency: compound
# Token: period, POS: NOUN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: on, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token: per, POS: ADP, Dependency: prep
# Token: metric, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Latency, POS: PROPN, Dependency: nmod
# Token: /, POS: SYM, Dependency: punct
# Token: Packet, POS: PROPN, Dependency: nmod
# Token: Loss, POS: PROPN, Dependency: nmod
# Token: /, POS: SYM, Dependency: punct
# Token: Jitter, POS: PROPN, Dependency: dep
# Token: -, POS: PUNCT, Dependency: punct
# Token: if, POS: SCONJ, Dependency: mark
# Token: Maximum, POS: PROPN, Dependency: compound
# Token: Tolerated, POS: PROPN, Dependency: nsubjpass
# Token: is, POS: AUX, Dependency: auxpass
# Token: exceeded, POS: VERB, Dependency: ROOT
# Token: for, POS: ADP, Dependency: prep
# Token: more, POS: ADJ, Dependency: amod
# Token: than, POS: ADP, Dependency: quantmod
# Token: 1, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: pobj
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: reporting, POS: NOUN, Dependency: compound
# Token: period, POS: NOUN, Dependency: pobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: compound
# Token: service, POS: NOUN, Dependency: compound
# Token: credit, POS: NOUN, Dependency: appos
# Token: on, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token: per, POS: ADP, Dependency: prep
# Token: metric, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Service, POS: NOUN, Dependency: compound
# Token: credits, POS: NOUN, Dependency: nsubjpass
# Token: will, POS: AUX, Dependency: aux
# Token: be, POS: AUX, Dependency: auxpass
# Token: applied, POS: VERB, Dependency: ROOT
# Token: to, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: subsequent, POS: ADJ, Dependency: amod
# Token: month, POS: NOUN, Dependency: poss
# Token: 's, POS: PART, Dependency: case
# Token: invoice, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token: Total, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: credits, POS: NOUN, Dependency: nsubj
# Token: in, POS: ADP, Dependency: prep
# Token: any, POS: DET, Dependency: det
# Token: given, POS: VERB, Dependency: amod
# Token: month, POS: NOUN, Dependency: pobj
# Token: shall, POS: AUX, Dependency: aux
# Token: not, POS: PART, Dependency: neg
# Token: exceed, POS: VERB, Dependency: ROOT
# Token: 25, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: dobj
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: total, POS: ADJ, Dependency: amod
# Token: monthly, POS: ADJ, Dependency: amod
# Token: service, POS: NOUN, Dependency: compound
# Token: fee, POS: NOUN, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 5, POS: X, Dependency: ROOT
# Token: ., POS: PUNCT, Dependency: punct
# Token: Responsibilities, POS: NOUN, Dependency: ROOT
# Token: of, POS: ADP, Dependency: prep
# Token: the, POS: DET, Dependency: det
# Token: Parties, POS: NOUN, Dependency: pobj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: 5.1, POS: NUM, Dependency: nummod
# Token: ., POS: PUNCT, Dependency: punct
# Token: NexGen, POS: PROPN, Dependency: compound
# Token: Telecom, POS: PROPN, Dependency: compound
# Token: Inc., POS: PROPN, Dependency: nsubj
# Token: (, POS: PUNCT, Dependency: punct
# Token: Service, POS: PROPN, Dependency: compound
# Token: Provider, POS: PROPN, Dependency: appos
# Token: ):, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: Maintain, POS: VERB, Dependency: ROOT
# Token: the, POS: DET, Dependency: det
# Token: 5, POS: NUM, Dependency: nummod
# Token: G, POS: NOUN, Dependency: compound
# Token: network, POS: NOUN, Dependency: compound
# Token: infrastructure, POS: NOUN, Dependency: dobj
# Token: to, POS: PART, Dependency: aux
# Token: meet, POS: VERB, Dependency: relcl
# Token: the, POS: DET, Dependency: det
# ...
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 10, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: appos
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: compound
# Token: refund, POS: NOUN, Dependency: appos
# Token:
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: nummod
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: appos
# Token: LatencyBreach, POS: NOUN, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token:
#
#   , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: Threshold, POS: NOUN, Dependency: appos
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: >, POS: X, Dependency: quantmod
# Token: 10, POS: NUM, Dependency: nummod
# Token: ms, POS: NOUN, Dependency: compound
# Token: average, POS: NOUN, Dependency: appos
# Token: for, POS: ADP, Dependency: prep
# Token: over, POS: ADP, Dependency: quantmod
# Token: 3hours, POS: NUM, Dependency: pobj
# Token:
#   , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: pobj
# Token: *, POS: PUNCT, Dependency: pobj
# Token: *, POS: PUNCT, Dependency: pobj
# Token: Credit, POS: NOUN, Dependency: pobj
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 5, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: appos
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: compound
# Token: refund, POS: NOUN, Dependency: appos
# Token:
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: nummod
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: NOUN, Dependency: appos
# Token: MaximumTotalCredit, POS: VERB, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: NOUN, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 30, POS: NUM, Dependency: nummod
# Token: %, POS: NOUN, Dependency: appos
# Token: of, POS: ADP, Dependency: prep
# Token: monthly, POS: ADJ, Dependency: amod
# Token: fee, POS: NOUN, Dependency: pobj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: nummod
# Token: *, POS: NOUN, Dependency: pobj
# Token: 6, POS: NUM, Dependency: pobj
# Token: ., POS: PUNCT, Dependency: punct
# Token: Reporting, POS: VERB, Dependency: ROOT
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: dobj
# Token: *, POS: PUNCT, Dependency: punct
# Token: Frequency, POS: NOUN, Dependency: dobj
# Token: *, POS: NOUN, Dependency: punct
# Token: *, POS: NOUN, Dependency: dobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: Monthly, POS: ADV, Dependency: nummod
# Token:
# , POS: SPACE, Dependency: dep
# Token: *, POS: NUM, Dependency: punct
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: punct
# Token: Format, POS: NOUN, Dependency: dobj
# Token: *, POS: PROPN, Dependency: punct
# Token: *, POS: PROPN, Dependency: dobj
# Token: :, POS: PUNCT, Dependency: punct
# Token: PDF, POS: PROPN, Dependency: npadvmod
# Token: ,, POS: PUNCT, Dependency: punct
# Token: XML, POS: PROPN, Dependency: appos
# Token:
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: nummod
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: appos
# Token: DeliveryMethod, POS: PROPN, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Email, POS: NOUN, Dependency: appos
# Token: to, POS: ADP, Dependency: prep
# Token: customer, POS: NOUN, Dependency: npadvmod
# Token: -, POS: PUNCT, Dependency: punct
# Token: designated, POS: VERB, Dependency: amod
# Token: recipient, POS: NOUN, Dependency: pobj
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: nummod
# Token: *, POS: NOUN, Dependency: appos
# Token: 7, POS: NUM, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token: Contact, POS: NOUN, Dependency: compound
# Token: Information, POS: PROPN, Dependency: ROOT
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: appos
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: ProviderSupportEmail, POS: NOUN, Dependency: appos
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: [, POS: X, Dependency: punct
# Token: support@nextgen-networks.com](mailto:support@nextgen-networks.com, POS: X, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token:
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: punct
# Token: ProviderSupportPhone, POS: X, Dependency: appos
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: +1, POS: PROPN, Dependency: appos
# Token: -, POS: PUNCT, Dependency: punct
# Token: 800, POS: NUM, Dependency: appos
# Token: -, POS: NUM, Dependency: punct
# Token: 555, POS: NUM, Dependency: nummod
# Token: -, POS: PUNCT, Dependency: punct
# Token: 5GSL, POS: NOUN, Dependency: appos
# Token:
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: CustomerContact, POS: NOUN, Dependency: appos
# Token: *, POS: NOUN, Dependency: punct
# Token: *, POS: PUNCT, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: [, POS: X, Dependency: dep
# Token: itops@acme-corp.com](mailto:itops@acme-corp.com, POS: X, Dependency: appos
# Token: ), POS: PUNCT, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: NUM, Dependency: appos
# Token: 8, POS: NUM, Dependency: appos
# Token: ., POS: PUNCT, Dependency: punct
# Token: Terms, POS: NOUN, Dependency: nsubj
# Token: and, POS: CCONJ, Dependency: cc
# Token: Termination, POS: NOUN, Dependency: conj
# Token: *, POS: PUNCT, Dependency: conj
# Token: *, POS: NOUN, Dependency: punct
# Token:
#
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: TerminationNoticePeriod, POS: NOUN, Dependency: appos
# Token: *, POS: PUNCT, Dependency: punct
# Token: *, POS: PUNCT, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: 30, POS: NUM, Dependency: nummod
# Token: days, POS: NOUN, Dependency: appos
# Token:
# , POS: SPACE, Dependency: dep
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: Renewal, POS: NOUN, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: *, POS: PUNCT, Dependency: appos
# Token: :, POS: PUNCT, Dependency: punct
# Token: Auto, POS: NOUN, Dependency: compound
# Token: -, POS: PUNCT, Dependency: punct
# Token: renewal, POS: NOUN, Dependency: appos
# Token: annually, POS: ADV, Dependency: advmod
# Token: unless, POS: SCONJ, Dependency: mark
# Token: terminated, POS: VERB, Dependency: ROOT
# Token:
# , POS: SPACE, Dependency: dep
# Entity: 5, Label: CARDINAL
# Entity: Telco Solutions Inc., Label: ORG
# Entity: Effective Date, Label: ORG
# Entity: 01, Label: CARDINAL
# Entity: 1, Label: CARDINAL
# Entity: AVAILABILITY, Label: ORG
# Entity: 99.95%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 4hrs/month, Label: DATE
# Entity: 72hrs, Label: CARDINAL
# Entity: Formula, Label: PERSON
# Entity: 5%, Label: PERCENT
# Entity: 0.1%, Label: PERCENT
# Entity: 2, Label: CARDINAL
# Entity: NETWORK LATENCY, Label: PERSON
# Entity: Target, Label: ORG
# Entity: 95th, Label: ORDINAL
# Entity: hourly, Label: TIME
# Entity: 3%, Label: PERCENT
# Entity: 1ms, Label: ORDINAL
# Entity: 3, Label: CARDINAL
# Entity: DOWNLINK, Label: ORG
# Entity: Target, Label: ORG
# Entity: Mbps, Label: PERSON
# Entity: Mbps, Label: PERSON
# Entity: 50, Label: CARDINAL
# Entity: 9 AM–5 PM, Label: TIME
# Entity: 2%, Label: PERCENT
# Entity: 10%, Label: PERCENT
# Entity: 4, Label: CARDINAL
# Entity: every 5 minutes, Label: TIME
# Entity: 4%, Label: PERCENT
# Entity: 0.0005%, Label: PERCENT
# Entity: 5, Label: CARDINAL
# Entity: ≤4 hours, Label: TIME
# Entity: Non-Critical Faults, Label: ORG
# Entity: 500, Label: MONEY
# Entity: 6, Label: CARDINAL
# Entity: REPORTING & SUPPORT
# KPI Reports, Label: ORG
# Entity: Monthly, Label: DATE
# Entity: 5th, Label: ORDINAL
# Entity: next month, Label: DATE
# Entity: 24/7, Label: CARDINAL
# Entity: max, Label: PERSON
# Entity: 15, Label: CARDINAL
# Entity: P1, Label: NORP
# Entity: quarterly, Label: DATE
# Entity: 7, Label: CARDINAL
# Entity: Max Annual Credit, Label: PERSON
# Entity: 20%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 30 days, Label: DATE
# Entity: 5, Label: CARDINAL
# Entity: 20250626, Label: DATE
# Entity: Effective Date, Label: ORG
# Entity: 2025-07-01, Label: DATE
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 1, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: cloud computing, Label: PERSON
# Entity: 2, Label: CARDINAL
# Entity: Service Scope
#
# Geographic Coverage: Primary, Label: ORG
# Entity: Appendix A.
#
# User Devices: Support, Label: PERSON
# Entity: 5G, Label: CARDINAL
# Entity: IoT, Label: ORG
# Entity: SIM, Label: ORG
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 3, Label: CARDINAL
# Entity: Performance Metrics, Label: ORG
# Entity: 15-minute, Label: TIME
# Entity: 3.1, Label: CARDINAL
# Entity: Downlink, Label: PERSON
# Entity: 1, Label: CARDINAL
# Entity: second, Label: ORDINAL
# Entity: 750, Label: CARDINAL
# Entity: Mbps, Label: PERSON
# Entity: CPE, Label: ORG
# Entity: monthly, Label: DATE
# Entity: 3.2, Label: CARDINAL
# Entity: 200, Label: CARDINAL
# Entity: 150, Label: CARDINAL
# Entity: Mbps, Label: PERSON
# Entity: monthly, Label: DATE
# Entity: 3.3, Label: CARDINAL
# Entity: less than 10, Label: CARDINAL
# Entity: 15, Label: CARDINAL
# Entity: 99.9%, Label: PERCENT
# Entity: Hourly, Label: TIME
# Entity: weekly, Label: DATE
# Entity: 3.4, Label: CARDINAL
# Entity: 2, Label: CARDINAL
# Entity: Hourly, Label: TIME
# Entity: weekly, Label: DATE
# Entity: 3.5, Label: CARDINAL
# Entity: Packet Loss Rate
#
# , Label: ORG
# Entity: Less than 0.01%, Label: PERCENT
# Entity: 0.05%, Label: PERCENT
# Entity: 5, Label: CARDINAL
# Entity: 3.6, Label: CARDINAL
# Entity: 99.99%, Label: PERCENT
# Entity: 5, Label: CARDINAL
# Entity: Monthly, Label: DATE
# Entity: 4, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: Service Level Objectives, Label: ORG
# Entity: a given month, Label: DATE
# Entity: Customer, Label: ORG
# Entity: 99.9%, Label: PERCENT
# Entity: 99.99%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 99.0%, Label: PERCENT
# Entity: 99.9%, Label: PERCENT
# Entity: 10%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 99.0%, Label: PERCENT
# Entity: 20%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: more than 5%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: Maximum Tolerated, Label: PERSON
# Entity: more than 1%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: month, Label: DATE
# Entity: any given month, Label: DATE
# Entity: 25%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 5, Label: CARDINAL
# Entity: 5.1, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 24/7, Label: CARDINAL
# Entity: Customer, Label: ORG
# Entity: Respond, Label: PERSON
# Entity: 5.2, Label: CARDINAL
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: Customer, Label: ORG
# Entity: CPE, Label: ORG
# Entity: Notify NexGen Telecom Inc., Label: ORG
# Entity: Appendix, Label: NORP
# Entity: 6, Label: CARDINAL
# Entity: 6.1, Label: CARDINAL
# Entity: 9 AM - 5 PM M-F, Label: TIME
# Entity: Email Support, Label: PERSON
# Entity: 9 AM - 5 PM M-F, Label: TIME
# Entity: 6.2, Label: CARDINAL
# Entity: Target Resolution Time, Label: ORG
# Entity: TRT, Label: ORG
# Entity: 4 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 8 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 24 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 48 hours, Label: TIME
# Entity: 6.3, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 7, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: first, Label: ORDINAL
# Entity: 30 days, Label: DATE
# Entity: 8, Label: CARDINAL
# Entity: 60 days', Label: DATE
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: 9, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: annually, Label: DATE
# Entity: the Effective Date, Label: ORG
# Entity: 1, Label: CARDINAL
# Entity: 2025-06-09, Label: DATE
# Entity: 2025-06-10, Label: DATE
# Entity: 2, Label: CARDINAL
# Entity: 5, Label: CARDINAL
# Entity: G Connectivity Service
# Service Scope, Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: New Radio, Label: ORG
# Entity: Basic, Premium, Enterprise]
#
# , Label: WORK_OF_ART
# Entity: 3, Label: CARDINAL
# Entity: Performance Metrics
#
# Availability, Label: ORG
# Entity: ≥, Label: GPE
# Entity: 99.99%, Label: PERCENT
# Entity: ≤, Label: PERSON
# Entity: 10, Label: CARDINAL
# Entity: one, Label: CARDINAL
# Entity: ≥, Label: PERSON
# Entity: 1 Gbps
# Uplink, Label: QUANTITY
# Entity: ≥, Label: PERSON
# Entity: 100, Label: CARDINAL
# Entity: ≤, Label: PERSON
# Entity: 5, Label: CARDINAL
# Entity: 0.1%, Label: PERCENT
# Entity: 4, Label: CARDINAL
# Entity: Monthly, Label: DATE
# Entity: Email, Label: PERSON
# Entity: 5, Label: CARDINAL
# Entity: 24/7, Label: CARDINAL
# Entity: 15 minutes, Label: TIME
# Entity: 1 hour, Label: TIME
# Entity: ≤, Label: PERSON
# Entity: 4 hours, Label: TIME
# Entity: 48 hours, Label: TIME
# Entity: 6, Label: CARDINAL
# Entity: 99.99%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 10, Label: CARDINAL
# Entity: 3%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: Maximum Credit Cap, Label: PERSON
# Entity: 25%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 7, Label: CARDINAL
# Entity: Termination Conditions
#
# Breach, Label: ORG
# Entity: 3 consecutive months, Label: DATE
# Entity: Notice Period, Label: ORG
# Entity: 30 days, Label: DATE
# Entity: 8, Label: CARDINAL
# Entity: 5, Label: CARDINAL
# Entity: 1, Label: CARDINAL
# Entity: Acme Corp, Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 2025-07-01, Label: DATE
# Entity: 2026-06-30, Label: DATE
# Entity: 2, Label: CARDINAL
# Entity: 3GPP Release, Label: ORG
# Entity: 16, Label: CARDINAL
# Entity: AR/VR, Label: ORG
# Entity: IoT, Label: ORG
# Entity: 3, Label: CARDINAL
# Entity: 99.99%, Label: PERCENT
# Entity: Monthly, Label: DATE
# Entity: ≤, Label: PERSON
# Entity: Continuous, Label: PERSON
# Entity: ≥, Label: PERSON
# Entity: 1 Gbps
#   *, Label: QUANTITY
# Entity: ≥, Label: PERSON
# Entity: Mbps
#   *, Label: PERSON
# Entity: Peak hours, Label: TIME
# Entity: 17:00–21:00, Label: CARDINAL
# Entity: 4, Label: CARDINAL
# Entity: Fault Management**, Label: ORG
# Entity: ≤, Label: PERSON
# Entity: 15 minutes, Label: TIME
# Entity: ≤, Label: PERSON
# Entity: 4 hours, Label: TIME
# Entity: 1, Label: CARDINAL
# Entity: 24/7, Label: CARDINAL
# Entity: NOC, Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 99.5%, Label: PERCENT
# Entity: 10%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 10, Label: CARDINAL
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 30%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 6, Label: CARDINAL
# Entity: Monthly, Label: DATE
# Entity: PDF, Label: ORG
# Entity: XML, Label: ORG
# Entity: 7, Label: CARDINAL
# Entity: Contact Information*, Label: ORG
# Entity: support@nextgen-networks.com](mailto:support@nextgen-networks.com, Label: ORG
# Entity: itops@acme-corp.com](mailto:itops@acme-corp.com, Label: ORG
# Entity: 8, Label: CARDINAL
# Entity: 30 days, Label: DATE

# %%
# # First keyword set
# keywords1 = {
#    "availability", "db", "downlink", "environments", "hours", "jitter",
#     "latency", "loss", "mbps", "milliseconds", "minutes", "mission", "network", "noise",
#     "session", "setup", "signal", "streaming", "throughput", "time", "urllc", "reliability", "packet", "qos",
#     "acceptance", "notifies", "Business Days", "requirements", "obligations", "agreement", "acme",
#     "agreementid",  "coveragearea", "customer", "days", "deliverymethod", "edge",
#     "effectivedate", "elements", "format", "frequency", "gbps", "general",
#     "measurementperiod", "metrics", "mobile", "monitoring", "ms", "networks",
#    "penalties", "performance", "priority", "provider",
#    "recipient", "refund", "region", "release", "remedies", "renewal", "target", "termination",
#    "terms", "threshold", "uplink", "usecases",
# }

# # Second keyword set
# keywords2={ "access", "activities", "advance", "agreement",  "appendix", "applications", "area", "availability", "broadband", "capabilities", "capacity", "cards", "cell", "changes", "channels", "cloud", "communication", "computing", "conditions", "connectivity", "core", "coverage", "cpe", "credit", "credits", "critical", "customer", "daily", "data", "date", "days", "definition", "degradation", "description", "device", "devices", "dispute", "disputes", "downlink", "effective", "effort", "egress", "email", "embb", "end", "enhanced", "enterprise", "equipment", "esim", "event", "fee", "file", "frequency", "function", "functioning", "gateway", "gateways", "gbps", "general", "gigabits", "guaranteed", "high", "hourly", "hours", "id", "ids", "incident", "incidents", "industrial", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "latency", "level", "levels", "loss", "low", "maintenance", "management", "maximum", "mbps", "measurement", "measurements", "medium", "metric", "metrics", "metropolitan", "milliseconds", "minimum", "minute", "mobile", "monitor", "month", "ms", "negotiation", "network", "nexgen", "notice", "notify", "objective", "objectives", "online", "outage", "packet", "parties", "party", "penalties", "percentage", "performance", "period", "phone", "plane", "pm", "point", "policy", "portal", "premises", "prioritization", "priority", "profiles", "provider", "provision", "rate", "region", "reporting", "reports", "requirements", "resolution", "respond", "responsibilities", "review", "scope", "segment", "service", "sim", "sla", "slices", "slos", "solutions", "specific", "status", "streaming", "subset", "support", "target", "telecom", "termination", "terms", "throughput", "time", "traffic", "transfers", "type", "updates", "uplink", "uptime", "usage", "user", "users", "video" }

# # Merge sets without duplicates
# merged_keywords = keywords1.union(keywords2)

# # Create a sorted list of quoted keywords
# keywords = sorted(f'"{kw}"' for kw in merged_keywords)

# # Format the final string
# output_string = "keywords={ " + ", ".join(keywords) + " }"

# # Print in desired format
# print("keywords={ " + ", ".join(keywords) + " }")

# # Save to a .txt file
# with open("merged_keywords.txt", "w", encoding="utf-8") as file:
#     file.write(output_string)

# print("Keywords saved to merged_keywords.txt")
# Out:
# keywords={ "Business Days", "acceptance", "access", "acme", "activities", "advance", "agreement", "agreementid", "appendix", "applications", "area", "availability", "broadband", "capabilities", "capacity", "cards", "cell", "changes", "channels", "cloud", "communication", "computing", "conditions", "connectivity", "core", "coverage", "coveragearea", "cpe", "credit", "credits", "critical", "customer", "daily", "data", "date", "days", "db", "definition", "degradation", "deliverymethod", "description", "device", "devices", "dispute", "disputes", "downlink", "edge", "effective", "effectivedate", "effort", "egress", "elements", "email", "embb", "end", "enhanced", "enterprise", "environments", "equipment", "esim", "event", "fee", "file", "format", "frequency", "function", "functioning", "gateway", "gateways", "gbps", "general", "gigabits", "guaranteed", "high", "hourly", "hours", "id", "ids", "incident", "incidents", "industrial", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "latency", "level", "levels", "loss", "low", "maintenance", "management", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "medium", "metric", "metrics", "metropolitan", "milliseconds", "minimum", "minute", "minutes", "mission", "mobile", "monitor", "monitoring", "month", "ms", "negotiation", "network", "networks", "nexgen", "noise", "notice", "notifies", "notify", "objective", "objectives", "obligations", "online", "outage", "packet", "parties", "party", "penalties", "percentage", "performance", "period", "phone", "plane", "pm", "point", "policy", "portal", "premises", "prioritization", "priority", "profiles", "provider", "provision", "qos", "rate", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "reporting", "reports", "requirements", "resolution", "respond", "responsibilities", "review", "scope", "segment", "service", "session", "setup", "signal", "sim", "sla", "slices", "slos", "solutions", "specific", "status", "streaming", "subset", "support", "target", "telecom", "termination", "terms", "threshold", "throughput", "time", "traffic", "transfers", "type", "updates", "uplink", "uptime", "urllc", "usage", "usecases", "user", "users", "video" }
# Keywords saved to merged_keywords.txt

# %%
keywords={ "access", "acme", "activities", "advance", "agreement", "agreementid", "amendment", "amendments", "anniversary", "annual", "appendix", "applications", "ar", "area", "audit", "auto", "availability", "availabilitybreach", "average", "basic", "breach", "broadband", "calendar", "capabilities", "capacity", "cards", "cell", "changes", "channels", "claim", "client", "cloud", "communication", "computing", "conditions", "confidentiality", "connectivity", "contact", "core", "corp", "coverage", "coveragearea", "cpe", "credit", "credits", "critical", "customer", "customercontact", "customerz", "cycle", "daily", "dashboard", "data", "date", "days", "definition", "degradation", "delay", "delivery", "deliverymethod", "description", "deviation", "device", "devices", "dispute", "disputes", "downlink", "downtime", "edge", "effective", "effectivedate", "effort", "egress", "email", "embb", "end", "enhanced", "enterprise", "equipment", "esim", "event", "exclusions", "expirationdate", "fault", "faults", "fee", "file", "format", "formula", "frequency", "function", "functioning", "g", "gateway", "gateways", "gbps", "general", "geographic", "gigabits", "governing", "guaranteed", "helpdesk", "high", "hour", "hourly", "hours", "id", "ids", "incident", "incidentresolutiontime", "incidentresponsetime", "incidents", "industrial", "information", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "jurisdiction", "kpi", "latency", "latencybreach", "law", "level", "levels", "locations", "loss", "low", "maintenance", "major", "management", "map", "maps", "master", "max", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "mediation", "medium", "method", "metric", "metrics", "metropolitan", "milliseconds", "min", "minimum", "minor", "minute", "minutes", "mobile", "monitor", "monitoring", "month", "monthly", "months", "ms", "negotiation", "network", "networks", "new", "nexgen", "nextgen", "notice", "notification", "notify", "objective", "objectives", "online", "outage", "packet", "parties", "party", "pdf", "peak", "penalties", "penalty", "percentage", "percentile", "performance", "period", "phone", "plane", "planned", "pm", "point", "policy", "portal", "premises", "premium", "prioritization", "priority", "probes", "profiles", "provider", "providersupportemail", "provision", "quarterly", "radio", "rate", "receipt", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "report", "reporting", "reports", "requirements", "resolution", "respond", "response", "responsibilities", "restoration", "review", "rights", "round","scope", "segment", "service", "servicename", "sim", "sla", "slices", "slos", "smartphones", "solutions", "specific", "speed", "status", "streaming", "subset", "support", "supporteddevices", "tablets", "target", "technology", "telco", "telecom", "termination", "terminationnoticeperiod", "terms", "tests", "threshold", "throughput", "tickets", "tiers", "time", "tolerated", "tools", "total", "tracking", "traffic", "transfers", "trip", "trt", "type", "ue", "ues", "updates", "upf", "uplink", "uptime", "usage", "usecases", "user", "users", "workdays", "writing", "zone", "zones" }

for token in doc:
    if token.text.lower() in keywords:
        print(f"\nKeyword: {token.text}")
        for child in token.children:
            print(f"  -> Child: {child.text} ({child.dep_}, {child.pos_})")
        for ancestor in token.ancestors:
            print(f"  <- Ancestor: {ancestor.text} ({ancestor.dep_}, {ancestor.pos_})")
# Out:
# Keyword: G
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: SERVICE
#   <- Ancestor: LEVEL (compound, NOUN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: LEVEL
#   -> Child: SERVICE (compound, NOUN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: AGREEMENT
#   -> Child: 5 (nummod, NUM)
#   -> Child: G (compound, NOUN)
#   -> Child: LEVEL (compound, NOUN)
#   -> Child: Provider (appos, PROPN)
#   -> Child: Customer (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Quarterly (appos, PROPN)
#   -> Child: . (punct, X)
#
# Keyword: SLA
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Service
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Provider
#   -> Child: ( (punct, PUNCT)
#   -> Child: SLA (nmod, PROPN)
#   -> Child: Service (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Telco
#   <- Ancestor: Inc. (compound, PROPN)
#   <- Ancestor: Customer (appos, NOUN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Solutions
#   <- Ancestor: Inc. (compound, PROPN)
#   <- Ancestor: Customer (appos, NOUN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Customer
#   -> Child: Inc. (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Date (appos, PROPN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Enterprise
#   <- Ancestor: Ltd. (compound, PROPN)
#   <- Ancestor: Date (appos, PROPN)
#   <- Ancestor: Customer (appos, NOUN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Client
#   <- Ancestor: Ltd. (compound, PROPN)
#   <- Ancestor: Date (appos, PROPN)
#   <- Ancestor: Customer (appos, NOUN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Effective
#   <- Ancestor: Date (appos, PROPN)
#   <- Ancestor: Customer (appos, NOUN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Date
#   -> Child: Ltd. (compound, PROPN)
#   -> Child: Effective (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Cycle (appos, NOUN)
#   <- Ancestor: Customer (appos, NOUN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Review
#   -> Child: Oct-2025 (compound, PROPN)
#   <- Ancestor: Cycle (appos, NOUN)
#   <- Ancestor: Date (appos, PROPN)
#   <- Ancestor: Customer (appos, NOUN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Cycle
#   -> Child: Review (compound, PROPN)
#   <- Ancestor: Date (appos, PROPN)
#   <- Ancestor: Customer (appos, NOUN)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: Quarterly
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: 1 (nummod, X)
#   <- Ancestor: AGREEMENT (ROOT, PROPN)
#
# Keyword: SERVICE
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: AVAILABILITY
#   -> Child:
#  (dep, SPACE)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Target
#   -> Child: SERVICE (compound, NOUN)
#   -> Child: AVAILABILITY (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: % (appos, NOUN)
#   -> Child: Exclusions (appos, NOUN)
#
# Keyword: monthly
#   <- Ancestor: Measurement (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: uptime
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Measurement (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Measurement
#   -> Child: monthly (amod, ADJ)
#   -> Child: uptime (compound, NOUN)
#   -> Child: : (punct, PUNCT)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Exclusions
#   -> Child: : (punct, PUNCT)
#   -> Child: notified (acl, VERB)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: maintenance
#   -> Child: Scheduled (amod, VERB)
#   -> Child: ( (punct, PUNCT)
#   -> Child: month (appos, NOUN)
#   -> Child: , (punct, PUNCT)
#   <- Ancestor: notified (acl, VERB)
#   <- Ancestor: Exclusions (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: max
#   <- Ancestor: month (appos, NOUN)
#   <- Ancestor: maintenance (nsubj, NOUN)
#   <- Ancestor: notified (acl, VERB)
#   <- Ancestor: Exclusions (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: month
#   -> Child: max (nmod, PROPN)
#   -> Child: 4hrs (nmod, PROPN)
#   -> Child: / (punct, SYM)
#   <- Ancestor: maintenance (nsubj, NOUN)
#   <- Ancestor: notified (acl, VERB)
#   <- Ancestor: Exclusions (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: advance
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: notified (acl, VERB)
#   <- Ancestor: Exclusions (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Formula
#   -> Child: : (punct, PUNCT)
#   -> Child: ( (punct, PUNCT)
#   -> Child: Downtime (appos, PROPN)
#   -> Child: / (punct, SYM)
#   -> Child: Penalty (appos, PROPN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Total
#   <- Ancestor: Downtime (appos, PROPN)
#   <- Ancestor: Formula (ROOT, NOUN)
#
# Keyword: Minutes
#   <- Ancestor: Downtime (appos, PROPN)
#   <- Ancestor: Formula (ROOT, NOUN)
#
# Keyword: Downtime
#   -> Child: Total (compound, PROPN)
#   -> Child: Minutes (compound, PROPN)
#   -> Child: - (punct, PUNCT)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: Formula (ROOT, NOUN)
#
# Keyword: Total
#   <- Ancestor: Penalty (appos, PROPN)
#   <- Ancestor: Formula (ROOT, NOUN)
#
# Keyword: Minutes
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Penalty (appos, PROPN)
#   <- Ancestor: Formula (ROOT, NOUN)
#
# Keyword: Penalty
#   -> Child: Total (compound, PROPN)
#   -> Child: Minutes (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: credit (appos, NOUN)
#   <- Ancestor: Formula (ROOT, NOUN)
#
# Keyword: service
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: Penalty (appos, PROPN)
#   <- Ancestor: Formula (ROOT, NOUN)
#
# Keyword: credit
#   -> Child: % (compound, NOUN)
#   -> Child: service (compound, NOUN)
#   -> Child: per (prep, ADP)
#   <- Ancestor: Penalty (appos, PROPN)
#   <- Ancestor: Formula (ROOT, NOUN)
#
# Keyword: target
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: 2 (nummod, NUM)
#   <- Ancestor: below (prep, ADP)
#   <- Ancestor: % (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: Penalty (appos, PROPN)
#   <- Ancestor: Formula (ROOT, NOUN)
#
# Keyword: NETWORK
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: LATENCY
#   -> Child:
#  (dep, SPACE)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Target
#   -> Child: NETWORK (compound, PROPN)
#   -> Child: LATENCY (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Scope (appos, NOUN)
#
# Keyword: end
#   -> Child: - (punct, PUNCT)
#   -> Child: to (prep, ADP)
#   <- Ancestor: UE (nmod, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: end
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: end (nmod, NOUN)
#   <- Ancestor: UE (nmod, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: UE
#   -> Child: end (nmod, NOUN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: to (prep, ADP)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Core
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: UE (nmod, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Scope
#   -> Child: ≤20ms (nummod, NUM)
#   -> Child: UE (nmod, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: zones (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#   -> Child: Target (appos, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: ≥200 (acl, VERB)
#   -> Child: : (punct, PUNCT)
#   -> Child: network (appos, NOUN)
#   -> Child: < (punct, X)
#   -> Child: 50 (punct, NUM)
#   -> Child: Measurement (appos, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: tests (appos, NOUN)
#   -> Child: Penalty (npadvmod, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: credit (appos, NOUN)
#   -> Child: per (prep, ADP)
#   -> Child: . (punct, PUNCT)
#   -> Child: Target (appos, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: probes (acl, VERB)
#   -> Child: . (punct, PUNCT)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: zones
#   -> Child: Urban (amod, ADJ)
#   -> Child: ( (punct, PUNCT)
#   -> Child: per (prep, ADP)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: coverage
#   <- Ancestor: map (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: map
#   -> Child: coverage (compound, NOUN)
#   -> Child: in (prep, ADP)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Appendix
#   <- Ancestor: A (nmod, PROPN)
#   <- Ancestor: Measurement (pobj, PROPN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: map (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Measurement
#   -> Child: A (nmod, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: percentile (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: credit (appos, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: map (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: percentile
#   -> Child: 95th (amod, ADJ)
#   -> Child: of (prep, ADP)
#   <- Ancestor: Measurement (pobj, PROPN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: map (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: hourly
#   <- Ancestor: probes (compound, NOUN)
#   <- Ancestor: Penalty (pobj, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: percentile (appos, NOUN)
#   <- Ancestor: Measurement (pobj, PROPN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: map (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: probes
#   -> Child: hourly (amod, ADJ)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Penalty (pobj, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: percentile (appos, NOUN)
#   <- Ancestor: Measurement (pobj, PROPN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: map (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Penalty
#   -> Child: probes (compound, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: percentile (appos, NOUN)
#   <- Ancestor: Measurement (pobj, PROPN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: map (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: service
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: Measurement (pobj, PROPN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: map (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: credit
#   -> Child: % (compound, NOUN)
#   -> Child: service (compound, NOUN)
#   -> Child: per (prep, ADP)
#   <- Ancestor: Measurement (pobj, PROPN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: map (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: breach
#   -> Child: 1ms (amod, ADJ)
#   -> Child: sustained (amod, ADJ)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: 3 (nummod, NUM)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: Measurement (pobj, PROPN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: map (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: DOWNLINK
#   <- Ancestor: Target (appos, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: THROUGHPUT
#   -> Child:
#  (dep, SPACE)
#   <- Ancestor: Target (appos, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Target
#   -> Child: DOWNLINK (compound, PROPN)
#   -> Child: THROUGHPUT (compound, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Mbps
#   <- Ancestor: ≥200 (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: peak
#   <- Ancestor: ≥200 (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Mbps
#   -> Child: average (amod, ADJ)
#   <- Ancestor: ≥200 (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: average
#   -> Child: per (prep, ADP)
#   <- Ancestor: Mbps (dobj, PROPN)
#   <- Ancestor: ≥200 (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: device
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Conditions (pobj, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: average (amod, ADJ)
#   <- Ancestor: Mbps (dobj, PROPN)
#   <- Ancestor: ≥200 (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Conditions
#   -> Child: device (compound, NOUN)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: average (amod, ADJ)
#   <- Ancestor: Mbps (dobj, PROPN)
#   <- Ancestor: ≥200 (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: network
#   -> Child: Non (amod, ADJ)
#   -> Child: - (amod, ADJ)
#   -> Child: congested (amod, ADJ)
#   -> Child: , (punct, PUNCT)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: UEs
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Measurement (appos, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Measurement
#   -> Child: active (amod, ADJ)
#   -> Child: UEs (compound, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Daily
#   <- Ancestor: tests (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: speed
#   <- Ancestor: tests (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: tests
#   -> Child: Daily (amod, ADJ)
#   -> Child: speed (compound, NOUN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: workdays (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: PM
#   -> Child: 9 (nummod, NUM)
#   -> Child: AM–5 (amod, ADJ)
#   -> Child: , (punct, PUNCT)
#   <- Ancestor: workdays (appos, NOUN)
#   <- Ancestor: tests (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: workdays
#   -> Child: PM (nmod, NOUN)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: tests (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Penalty
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: service
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: credit
#   -> Child: % (compound, NOUN)
#   -> Child: service (compound, NOUN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: deviation
#   -> Child: % (compound, NOUN)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: 4 (nummod, NUM)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: RELIABILITY
#   -> Child:
#  (dep, SPACE)
#   <- Ancestor: Target (appos, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Target
#   -> Child: RELIABILITY (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: ≤0.001 (punct, PUNCT)
#   -> Child: Measurement (appos, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: packet
#   <- Ancestor: loss (compound, NOUN)
#   <- Ancestor: Measurement (appos, PROPN)
#   <- Ancestor: Target (appos, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: loss
#   -> Child: packet (compound, NOUN)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Measurement (appos, PROPN)
#   <- Ancestor: Target (appos, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Measurement
#   -> Child: % (compound, NOUN)
#   -> Child: loss (compound, NOUN)
#   <- Ancestor: Target (appos, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: probes
#   -> Child: ICMP (nsubj, PROPN)
#   -> Child: Penalty (dobj, PROPN)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: minutes
#   -> Child: 5 (nummod, NUM)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Penalty (dobj, PROPN)
#   <- Ancestor: probes (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: Penalty
#   -> Child: every (det, DET)
#   -> Child: minutes (compound, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: credit (appos, NOUN)
#   <- Ancestor: probes (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: service
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: Penalty (dobj, PROPN)
#   <- Ancestor: probes (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: credit
#   -> Child: % (compound, NOUN)
#   -> Child: service (compound, NOUN)
#   -> Child: per (prep, ADP)
#   <- Ancestor: Penalty (dobj, PROPN)
#   <- Ancestor: probes (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: breach
#   -> Child: % (compound, NOUN)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: 5 (nummod, NUM)
#   <- Ancestor: per (prep, ADP)
#   <- Ancestor: credit (appos, NOUN)
#   <- Ancestor: Penalty (dobj, PROPN)
#   <- Ancestor: probes (acl, VERB)
#   <- Ancestor: Scope (appos, NOUN)
#   <- Ancestor: Target (ROOT, PROPN)
#
# Keyword: FAULT
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: RESTORATION
#   -> Child:
#  (dep, SPACE)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: Critical
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: Faults
#   -> Child: FAULT (compound, PROPN)
#   -> Child: RESTORATION (compound, PROPN)
#   -> Child: Critical (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: hours (appos, NOUN)
#   -> Child: REPORTING (appos, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Monthly (appos, PROPN)
#
# Keyword: hours
#   -> Child: ≤4 (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: Faults (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Penalty (appos, PROPN)
#   -> Child: . (punct, PUNCT)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: Critical
#   <- Ancestor: Faults (appos, NOUN)
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: Faults
#   -> Child: Non (amod, ADJ)
#   -> Child: - (compound, ADJ)
#   -> Child: Critical (amod, ADJ)
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: hours
#   -> Child: ≤24 (nmod, PRON)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Penalty (appos, PROPN)
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: Penalty
#   -> Child: hours (compound, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: delay (appos, NOUN)
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: hour
#   -> Child: $ (quantmod, SYM)
#   -> Child: 500 (nummod, NUM)
#   -> Child: / (punct, SYM)
#   <- Ancestor: delay (appos, NOUN)
#   <- Ancestor: Penalty (appos, PROPN)
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: delay
#   -> Child: hour (compound, NOUN)
#   -> Child: beyond (prep, ADP)
#   <- Ancestor: Penalty (appos, PROPN)
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: target
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: 6 (nummod, NUM)
#   <- Ancestor: beyond (prep, ADP)
#   <- Ancestor: delay (appos, NOUN)
#   <- Ancestor: Penalty (appos, PROPN)
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: REPORTING
#   -> Child: & (cc, CCONJ)
#   -> Child: Reports (conj, NOUN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: SUPPORT
#   -> Child:
#  (dep, SPACE)
#   <- Ancestor: KPI (compound, PROPN)
#   <- Ancestor: Reports (conj, NOUN)
#   <- Ancestor: REPORTING (appos, PROPN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: KPI
#   -> Child: SUPPORT (compound, PROPN)
#   <- Ancestor: Reports (conj, NOUN)
#   <- Ancestor: REPORTING (appos, PROPN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: Reports
#   -> Child: KPI (compound, PROPN)
#   <- Ancestor: REPORTING (appos, PROPN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: Monthly
#   -> Child: ( (punct, PUNCT)
#   -> Child: by (prep, ADP)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: month
#   -> Child: next (amod, ADJ)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: 5th (pobj, NOUN)
#   <- Ancestor: by (prep, ADP)
#   <- Ancestor: Monthly (appos, PROPN)
#   <- Ancestor: Faults (ROOT, NOUN)
#
# Keyword: Support
#   -> Child: : (punct, PUNCT)
#   -> Child: helpdesk (appos, NOUN)
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: helpdesk
#   -> Child: 24/7 (nummod, NUM)
#   -> Child: ( (punct, PUNCT)
#   -> Child: response (appos, NOUN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: Rights (appos, PROPN)
#   -> Child: : (punct, PUNCT)
#   <- Ancestor: Support (dep, NOUN)
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: max
#   <- Ancestor: response (appos, NOUN)
#   <- Ancestor: helpdesk (appos, NOUN)
#   <- Ancestor: Support (dep, NOUN)
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: min
#   -> Child: 15 (nummod, NUM)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: response (appos, NOUN)
#   <- Ancestor: helpdesk (appos, NOUN)
#   <- Ancestor: Support (dep, NOUN)
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: response
#   -> Child: max (nmod, PROPN)
#   -> Child: min (compound, NOUN)
#   -> Child: for (prep, ADP)
#   <- Ancestor: helpdesk (appos, NOUN)
#   <- Ancestor: Support (dep, NOUN)
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: tickets
#   -> Child: P1 (compound, PROPN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: response (appos, NOUN)
#   <- Ancestor: helpdesk (appos, NOUN)
#   <- Ancestor: Support (dep, NOUN)
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: Audit
#   <- Ancestor: Rights (appos, PROPN)
#   <- Ancestor: helpdesk (appos, NOUN)
#   <- Ancestor: Support (dep, NOUN)
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: Rights
#   -> Child: Audit (compound, PROPN)
#   <- Ancestor: helpdesk (appos, NOUN)
#   <- Ancestor: Support (dep, NOUN)
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: Customer
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: measurement
#   <- Ancestor: logs (ccomp, VERB)
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: quarterly
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: logs (ccomp, VERB)
#   <- Ancestor: request (ROOT, VERB)
#
# Keyword: SERVICE
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: CREDITS
#   -> Child:
#  (dep, SPACE)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Max
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Annual
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Credit
#   -> Child: SERVICE (compound, NOUN)
#   -> Child: CREDITS (compound, PROPN)
#   -> Child: Max (compound, PROPN)
#   -> Child: Annual (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: % (appos, NOUN)
#   -> Child: 1 (appos, NUM)
#   -> Child: . (punct, X)
#
# Keyword: monthly
#   <- Ancestor: fee (compound, NOUN)
#   <- Ancestor: Window (pobj, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: fee
#   -> Child: monthly (amod, ADJ)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Window (pobj, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Claim
#   <- Ancestor: Window (pobj, PROPN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: days
#   -> Child: 30 (nummod, NUM)
#   -> Child: from (prep, ADP)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: report
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: receipt
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Service
#   <- Ancestor: Level (compound, PROPN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Level
#   -> Child: Service (compound, PROPN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Agreement
#   -> Child: report (compound, NOUN)
#   -> Child: receipt (compound, NOUN)
#   -> Child: Level (compound, PROPN)
#   -> Child: SLA (appos, PROPN)
#   -> Child: - (punct, PUNCT)
#   -> Child: ID (appos, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Date (appos, NOUN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: SLA
#   -> Child: ( (punct, PUNCT)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: G
#   -> Child: 5 (nummod, NUM)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Enhanced
#   <- Ancestor: Broadband (nmod, PROPN)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Mobile
#   <- Ancestor: Broadband (nmod, PROPN)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Broadband
#   -> Child: Enhanced (amod, PROPN)
#   -> Child: Mobile (compound, PROPN)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: eMBB
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Service
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Agreement (compound, PROPN)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Agreement
#   -> Child: Service (compound, PROPN)
#   <- Ancestor: ID (appos, PROPN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: ID
#   -> Child: G (nmod, NOUN)
#   -> Child: Broadband (nmod, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: eMBB (nmod, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: Agreement (compound, PROPN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Effective
#   <- Ancestor: Date (appos, NOUN)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Date
#   -> Child: SLA-5G (nmod, PROPN)
#   -> Child: eMBB-001 (nmod, NOUN)
#   -> Child: Effective (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   <- Ancestor: Agreement (pobj, PROPN)
#   <- Ancestor: from (prep, ADP)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Service
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Provider
#   -> Child: 2025 (nummod, NUM)
#   -> Child: - (punct, SYM)
#   -> Child: 01 (nummod, NUM)
#   -> Child: Service (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Type (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: NexGen
#   <- Ancestor: Inc. (compound, PROPN)
#   <- Ancestor: Customer (nmod, NOUN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Telecom
#   <- Ancestor: Inc. (compound, PROPN)
#   <- Ancestor: Customer (nmod, NOUN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Customer
#   -> Child: Inc. (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Enterprise
#   <- Ancestor: Corp. (compound, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Solutions
#   <- Ancestor: Corp. (compound, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Service
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Type
#   -> Child: Customer (nmod, NOUN)
#   -> Child: Corp. (compound, PROPN)
#   -> Child: Service (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Broadband (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: G
#   -> Child: 5 (nummod, NUM)
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Enhanced
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Mobile
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Broadband
#   -> Child: G (compound, NOUN)
#   -> Child: Enhanced (amod, PROPN)
#   -> Child: Mobile (compound, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: eMBB (appos, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: - (punct, PUNCT)
#   -> Child: Service (appos, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: eMBB
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: High
#   <- Ancestor: Capacity (compound, PROPN)
#   <- Ancestor: Service (appos, PROPN)
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Capacity
#   -> Child: High (compound, PROPN)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: Service (appos, PROPN)
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Data
#   <- Ancestor: Service (appos, PROPN)
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Service
#   -> Child: Capacity (compound, PROPN)
#   -> Child: Data (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Broadband (appos, PROPN)
#   <- Ancestor: Type (appos, PROPN)
#   <- Ancestor: Provider (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Credit (ROOT, PROPN)
#
# Keyword: Service
#   <- Ancestor: Description (nsubj, PROPN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Description
#   -> Child: Service (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: SLA (appos, PROPN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: SLA
#   -> Child: This (det, DET)
#   <- Ancestor: Description (nsubj, PROPN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: terms
#   -> Child: the (det, DET)
#   -> Child: and (cc, CCONJ)
#   -> Child: conditions (conj, NOUN)
#   -> Child: for (prep, ADP)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: conditions
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: provision
#   -> Child: the (det, DET)
#   -> Child: of (prep, ADP)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: G
#   -> Child: 5 (nummod, NUM)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Enhanced
#   <- Ancestor: Broadband (nmod, PROPN)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Mobile
#   <- Ancestor: Broadband (nmod, PROPN)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Broadband
#   -> Child: Enhanced (amod, ADJ)
#   -> Child: Mobile (nmod, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: eMBB (appos, PROPN)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: eMBB
#   <- Ancestor: Broadband (nmod, PROPN)
#   <- Ancestor: service (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: service
#   -> Child: a (det, DET)
#   -> Child: dedicated (amod, ADJ)
#   -> Child: G (nmod, NOUN)
#   -> Child: Broadband (nmod, PROPN)
#   -> Child: ) (punct, PUNCT)
#   -> Child: to (prep, ADP)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: provision (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: terms (dobj, NOUN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Enterprise
#   <- Ancestor: Corp. (punct, PROPN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: Solutions
#   <- Ancestor: Corp. (punct, PROPN)
#   <- Ancestor: outlines (ROOT, VERB)
#
# Keyword: service
#   -> Child: This (det, DET)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: high
#   <- Ancestor: throughput (nmod, NOUN)
#   <- Ancestor: connectivity (dobj, NOUN)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: throughput
#   -> Child: high (amod, ADJ)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: connectivity (dobj, NOUN)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: low
#   <- Ancestor: latency (compound, NOUN)
#   <- Ancestor: connectivity (dobj, NOUN)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: latency
#   -> Child: low (amod, ADJ)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: connectivity (dobj, NOUN)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: connectivity
#   -> Child: throughput (nmod, NOUN)
#   -> Child: , (punct, PUNCT)
#   -> Child: latency (compound, NOUN)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: data
#   <- Ancestor: intensive (amod, ADJ)
#   <- Ancestor: applications (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: applications
#   -> Child: intensive (amod, ADJ)
#   -> Child: , (punct, PUNCT)
#   -> Child: including (prep, VERB)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: cloud
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: computing
#   -> Child: cloud (compound, PROPN)
#   -> Child: , (punct, PUNCT)
#   -> Child: streaming (conj, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: high
#   <- Ancestor: definition (compound, NOUN)
#   <- Ancestor: streaming (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: definition
#   -> Child: high (amod, ADJ)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: streaming (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: streaming
#   -> Child: definition (compound, NOUN)
#   -> Child: video (compound, NOUN)
#   -> Child: , (punct, PUNCT)
#   -> Child: and (cc, CCONJ)
#   -> Child: transfers (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: file
#   <- Ancestor: transfers (conj, NOUN)
#   <- Ancestor: streaming (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: transfers
#   -> Child: large (amod, ADJ)
#   -> Child: file (compound, NOUN)
#   <- Ancestor: streaming (conj, NOUN)
#   <- Ancestor: computing (appos, NOUN)
#   <- Ancestor: limited (conj, VERB)
#   <- Ancestor: deliver (xcomp, VERB)
#   <- Ancestor: designed (ROOT, VERB)
#
# Keyword: Service
#   <- Ancestor: Scope (compound, PROPN)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Scope
#   -> Child: Service (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Geographic
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Coverage
#   -> Child: 2 (meta, X)
#   -> Child: . (punct, X)
#   -> Child: Scope (compound, PROPN)
#   -> Child: Geographic (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: area (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: X (appos, PROPN)
#   -> Child: , (punct, PUNCT)
#   -> Child: with (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: area (appos, NOUN)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: area
#   -> Child: Primary (amod, ADJ)
#   -> Child: service (compound, NOUN)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Metropolitan
#   <- Ancestor: Region (compound, PROPN)
#   <- Ancestor: X (appos, PROPN)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Region
#   -> Child: Metropolitan (compound, PROPN)
#   <- Ancestor: X (appos, PROPN)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: coverage
#   -> Child: secondary (amod, ADJ)
#   -> Child: in (prep, ADP)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Industrial
#   <- Ancestor: Zone (compound, PROPN)
#   <- Ancestor: IDs (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Zone
#   -> Child: Industrial (compound, PROPN)
#   <- Ancestor: IDs (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Specific
#   -> Child: Y. (compound, PROPN)
#   <- Ancestor: IDs (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: cell
#   <- Ancestor: IDs (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: IDs
#   -> Child: Zone (compound, PROPN)
#   -> Child: Specific (compound, PROPN)
#   -> Child: cell (compound, NOUN)
#   -> Child: and (cc, CCONJ)
#   -> Child: maps (conj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: coverage
#   <- Ancestor: maps (conj, NOUN)
#   <- Ancestor: IDs (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: maps
#   -> Child: coverage (compound, NOUN)
#   <- Ancestor: IDs (pobj, NOUN)
#   <- Ancestor: in (prep, ADP)
#   <- Ancestor: coverage (pobj, NOUN)
#   <- Ancestor: with (prep, ADP)
#   <- Ancestor: Coverage (nsubjpass, PROPN)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Appendix
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: User
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Devices
#   -> Child: Appendix (compound, PROPN)
#   -> Child: A. (compound, NOUN)
#   -> Child: User (compound, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: Support (appos, NOUN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Support
#   -> Child: for (prep, ADP)
#   -> Child: utilizing (acl, VERB)
#   -> Child: : (punct, PUNCT)
#   -> Child: eMBB (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: devices
#   -> Child: compliant (amod, ADJ)
#   -> Child: ( (punct, PUNCT)
#   -> Child: smartphones (appos, NOUN)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: smartphones
#   -> Child: , (punct, PUNCT)
#   -> Child: tablets (conj, NOUN)
#   <- Ancestor: devices (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: tablets
#   -> Child: , (punct, PUNCT)
#   -> Child: gateways (appos, NOUN)
#   <- Ancestor: smartphones (appos, NOUN)
#   <- Ancestor: devices (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: gateways
#   -> Child: IoT (amod, ADJ)
#   <- Ancestor: tablets (conj, NOUN)
#   <- Ancestor: smartphones (appos, NOUN)
#   <- Ancestor: devices (pobj, NOUN)
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: SIM
#   <- Ancestor: cards (nmod, NOUN)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: cards
#   -> Child: SIM (nmod, PROPN)
#   -> Child: / (punct, SYM)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: eSIM
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: profiles
#   -> Child: the (det, DET)
#   -> Child: designated (amod, VERB)
#   -> Child: cards (nmod, NOUN)
#   -> Child: eSIM (compound, NOUN)
#   -> Child: provided (acl, VERB)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: NexGen
#   <- Ancestor: Inc. (nmod, PROPN)
#   <- Ancestor: Prioritization (pobj, PROPN)
#   <- Ancestor: by (agent, ADP)
#   <- Ancestor: provided (acl, VERB)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Telecom
#   <- Ancestor: Inc. (nmod, PROPN)
#   <- Ancestor: Prioritization (pobj, PROPN)
#   <- Ancestor: by (agent, ADP)
#   <- Ancestor: provided (acl, VERB)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Traffic
#   <- Ancestor: Prioritization (pobj, PROPN)
#   <- Ancestor: by (agent, ADP)
#   <- Ancestor: provided (acl, VERB)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Prioritization
#   -> Child: Inc. (nmod, PROPN)
#   -> Child: Traffic (compound, PROPN)
#   <- Ancestor: by (agent, ADP)
#   <- Ancestor: provided (acl, VERB)
#   <- Ancestor: profiles (dobj, NOUN)
#   <- Ancestor: utilizing (acl, VERB)
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: eMBB
#   <- Ancestor: Support (appos, NOUN)
#   <- Ancestor: Devices (pobj, PROPN)
#   <- Ancestor: as (prep, ADP)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: traffic
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: priority
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: effort
#   -> Child: best (amod, ADJ)
#   -> Child: - (punct, PUNCT)
#   <- Ancestor: traffic (pobj, NOUN)
#   <- Ancestor: over (prep, ADP)
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: traffic
#   -> Child: effort (compound, NOUN)
#   <- Ancestor: over (prep, ADP)
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: service
#   <- Ancestor: slices (pobj, NOUN)
#   <- Ancestor: within (prep, ADP)
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: slices
#   -> Child: the (det, DET)
#   -> Child: defined (amod, VERB)
#   -> Child: service (compound, NOUN)
#   <- Ancestor: within (prep, ADP)
#   <- Ancestor: receive (conj, VERB)
#   <- Ancestor: attached (ROOT, VERB)
#
# Keyword: Service
#   <- Ancestor: Level (compound, PROPN)
#   <- Ancestor: Objectives (nsubjpass, PROPN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: Level
#   -> Child: Service (compound, PROPN)
#   <- Ancestor: Objectives (nsubjpass, PROPN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: Objectives
#   -> Child: Level (compound, PROPN)
#   -> Child: ( (punct, PUNCT)
#   -> Child: SLOs (appos, PROPN)
#   -> Child: metrics (appos, NOUN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: SLOs
#   -> Child: ) (punct, PUNCT)
#   -> Child: and (cc, CCONJ)
#   -> Child: Metrics (conj, PROPN)
#   <- Ancestor: Objectives (nsubjpass, PROPN)
#   <- Ancestor: measured (ROOT, VERB)
#
# Keyword: Performance
#   <- Ancestor: Metrics (conj, PROPN)
#   <- Ancestor: SLOs (appos, PROPN)
# ...
#   <- Ancestor: streaming (appos, NOUN)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (ROOT, PROPN)
#
# Keyword: industrial
#   <- Ancestor: IoT (conj, NOUN)
#   <- Ancestor: VR (appos, PROPN)
#   <- Ancestor: streaming (appos, NOUN)
#   <- Ancestor: zones (appos, NOUN)
#   <- Ancestor: Scope (ROOT, PROPN)
#
# Keyword: Performance
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Metrics
#   -> Child: Performance (compound, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: Availability (appos, NOUN)
#   -> Child: * (punct, NOUN)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: Target (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: % (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: MeasurementPeriod (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: Throughput (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: Downlink (appos, NOUN)
#   -> Child: * (punct, NOUN)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: ≥ (appos, PROPN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: Uplink (appos, NOUN)
#   -> Child: * (punct, NOUN)
#   -> Child: * (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: ≥ (appos, PROPN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: MeasurementPeriod (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: hours (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: Jitter (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: Target (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: 10ms (appos, ADJ)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, NOUN)
#   -> Child: 4 (appos, NUM)
#   -> Child: . (punct, X)
#
# Keyword: Availability
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Target
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: MeasurementPeriod
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Monthly
#   -> Child:
#
#  (dep, SPACE)
#   <- Ancestor: * (appos, PUNCT)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Latency
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Target
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: ms
#   -> Child: 5 (nummod, NUM)
#   -> Child: ( (punct, PUNCT)
#   -> Child: edge (appos, NOUN)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: ≤ (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: edge
#   -> Child: - (punct, PUNCT)
#   -> Child: to (prep, ADP)
#   <- Ancestor: ms (appos, NOUN)
#   <- Ancestor: ≤ (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: edge
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: edge (appos, NOUN)
#   <- Ancestor: ms (appos, NOUN)
#   <- Ancestor: ≤ (appos, PROPN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: MeasurementPeriod
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Throughput
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Downlink
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Gbps
#   -> Child: 1 (nummod, NUM)
#   -> Child:
#    (dep, SPACE)
#   -> Child: * (nummod, PUNCT)
#   <- Ancestor: ≥ (appos, PROPN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Uplink
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Mbps
#   -> Child: 500 (nummod, NUM)
#   -> Child:
#    (dep, SPACE)
#   -> Child: * (nummod, PUNCT)
#   <- Ancestor: ≥ (appos, PROPN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: MeasurementPeriod
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Peak
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: hours
#   -> Child: Peak (compound, ADJ)
#   -> Child: ( (punct, PUNCT)
#   -> Child: time (appos, NOUN)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: time
#   -> Child: 17:00–21:00 (nummod, NUM)
#   -> Child: local (amod, ADJ)
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Jitter
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Target
#   <- Ancestor: Metrics (ROOT, NOUN)
#
# Keyword: Fault
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: Management
#   -> Child: Fault (compound, PROPN)
#   -> Child: * (punct, PROPN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: IncidentResponseTime (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: ≤ (appos, ADJ)
#   -> Child: minutes (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: Monitoring (appos, VERB)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: monitoring (appos, NOUN)
#
# Keyword: IncidentResponseTime
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: minutes
#   -> Child: 15 (nummod, NUM)
#   -> Child:
#  (dep, SPACE)
#   -> Child: * (nummod, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: IncidentResolutionTime (appos, NOUN)
#   -> Child: * (appos, NOUN)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: ≤ (appos, ADJ)
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: IncidentResolutionTime
#   <- Ancestor: minutes (appos, NOUN)
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: hours
#   -> Child: 4 (nummod, NUM)
#   -> Child: incidents (appos, NOUN)
#   -> Child: ) (punct, PUNCT)
#   <- Ancestor: ≤ (appos, ADJ)
#   <- Ancestor: minutes (appos, NOUN)
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: Priority
#   -> Child: 1 (nummod, NUM)
#   <- Ancestor: incidents (appos, NOUN)
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: ≤ (appos, ADJ)
#   <- Ancestor: minutes (appos, NOUN)
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: incidents
#   -> Child: ( (punct, PUNCT)
#   -> Child: Priority (nmod, PROPN)
#   <- Ancestor: hours (appos, NOUN)
#   <- Ancestor: ≤ (appos, ADJ)
#   <- Ancestor: minutes (appos, NOUN)
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: Monitoring
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: monitoring
#   -> Child: NOC (compound, PROPN)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: * (dobj, PUNCT)
#   -> Child: * (dobj, NOUN)
#   -> Child: 5 (dobj, NUM)
#   -> Child: . (punct, PUNCT)
#   <- Ancestor: Management (ROOT, PROPN)
#
# Keyword: Penalties
#   -> Child: and (cc, CCONJ)
#   -> Child: Remedies (conj, PROPN)
#   -> Child: * (conj, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: AvailabilityBreach (appos, PROPN)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: Threshold (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, NOUN)
#   -> Child: < (appos, X)
#   -> Child: % (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: LatencyBreach (appos, NOUN)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: Threshold (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: average (appos, NOUN)
#   -> Child: . (punct, PUNCT)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: Remedies
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: AvailabilityBreach
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: Threshold
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: Credit
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: monthly
#   <- Ancestor: refund (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: fee
#   <- Ancestor: refund (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: refund
#   -> Child: monthly (amod, ADJ)
#   -> Child: fee (compound, NOUN)
#   -> Child:
#  (dep, SPACE)
#   -> Child: * (nummod, PUNCT)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: LatencyBreach
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: Threshold
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: ms
#   <- Ancestor: average (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: average
#   -> Child: 10 (nummod, NUM)
#   -> Child: ms (compound, NOUN)
#   -> Child: for (prep, ADP)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: % (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: Credit
#   <- Ancestor: for (prep, ADP)
#   <- Ancestor: average (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: monthly
#   <- Ancestor: refund (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: average (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: fee
#   <- Ancestor: refund (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: average (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: refund
#   -> Child: monthly (amod, ADJ)
#   -> Child: fee (compound, NOUN)
#   -> Child:
#  (dep, SPACE)
#   -> Child: * (nummod, PUNCT)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: average (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: monthly
#   <- Ancestor: fee (pobj, NOUN)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: average (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: fee
#   -> Child: monthly (amod, ADJ)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: * (nummod, PUNCT)
#   <- Ancestor: of (prep, ADP)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: % (appos, NOUN)
#   <- Ancestor: average (appos, NOUN)
#   <- Ancestor: Penalties (nsubj, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: Reporting
#   -> Child: Penalties (nsubj, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (dobj, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: Frequency (dobj, NOUN)
#   -> Child: * (punct, NOUN)
#   -> Child: * (dobj, NOUN)
#   -> Child: : (punct, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: Format (dobj, NOUN)
#   -> Child: * (punct, PROPN)
#   -> Child: * (dobj, PROPN)
#   -> Child: : (punct, PUNCT)
#   -> Child: PDF (npadvmod, PROPN)
#   -> Child: . (punct, PUNCT)
#
# Keyword: Frequency
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: Monthly
#   -> Child:
#  (dep, SPACE)
#   -> Child: * (punct, NUM)
#   <- Ancestor: * (punct, PUNCT)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: Format
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: PDF
#   -> Child: , (punct, PUNCT)
#   -> Child: XML (appos, PROPN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: DeliveryMethod (appos, PROPN)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: Email (appos, NOUN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: DeliveryMethod
#   <- Ancestor: PDF (npadvmod, PROPN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: Email
#   -> Child: to (prep, ADP)
#   <- Ancestor: PDF (npadvmod, PROPN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: customer
#   <- Ancestor: designated (amod, VERB)
#   <- Ancestor: recipient (pobj, NOUN)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: Email (appos, NOUN)
#   <- Ancestor: PDF (npadvmod, PROPN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: recipient
#   -> Child: designated (amod, VERB)
#   -> Child:
#
#  (dep, SPACE)
#   -> Child: * (nummod, PUNCT)
#   -> Child: * (appos, NOUN)
#   -> Child: 7 (appos, NUM)
#   <- Ancestor: to (prep, ADP)
#   <- Ancestor: Email (appos, NOUN)
#   <- Ancestor: PDF (npadvmod, PROPN)
#   <- Ancestor: Reporting (ROOT, VERB)
#
# Keyword: Contact
#   <- Ancestor: Information (ROOT, PROPN)
#
# Keyword: Information
#   -> Child: Contact (compound, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: ProviderSupportEmail (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: support@nextgen-networks.com](mailto:support@nextgen-networks.com (appos, X)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (punct, PUNCT)
#   -> Child: ProviderSupportPhone (appos, X)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: +1 (appos, PROPN)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: CustomerContact (appos, NOUN)
#   -> Child: * (punct, NOUN)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: itops@acme-corp.com](mailto:itops@acme-corp.com (appos, X)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, NUM)
#   -> Child: 8 (appos, NUM)
#   -> Child: . (punct, PUNCT)
#
# Keyword: ProviderSupportEmail
#   <- Ancestor: Information (ROOT, PROPN)
#
# Keyword: CustomerContact
#   <- Ancestor: Information (ROOT, PROPN)
#
# Keyword: Terms
#   -> Child: and (cc, CCONJ)
#   -> Child: Termination (conj, NOUN)
#   -> Child: * (conj, PUNCT)
#   -> Child: * (punct, NOUN)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: TerminationNoticePeriod (appos, NOUN)
#   -> Child: * (punct, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: days (appos, NOUN)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: Termination
#   <- Ancestor: Terms (nsubj, NOUN)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: TerminationNoticePeriod
#   <- Ancestor: Terms (nsubj, NOUN)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: days
#   -> Child: 30 (nummod, NUM)
#   -> Child:
#  (dep, SPACE)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: Renewal (appos, NOUN)
#   -> Child: * (appos, PUNCT)
#   -> Child: * (appos, PUNCT)
#   -> Child: : (punct, PUNCT)
#   -> Child: renewal (appos, NOUN)
#   <- Ancestor: Terms (nsubj, NOUN)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: Renewal
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: Terms (nsubj, NOUN)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: Auto
#   <- Ancestor: renewal (appos, NOUN)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: Terms (nsubj, NOUN)
#   <- Ancestor: terminated (ROOT, VERB)
#
# Keyword: renewal
#   -> Child: Auto (compound, NOUN)
#   -> Child: - (punct, PUNCT)
#   -> Child: annually (advmod, ADV)
#   <- Ancestor: days (appos, NOUN)
#   <- Ancestor: Terms (nsubj, NOUN)
#   <- Ancestor: terminated (ROOT, VERB)

# %%
for ent in doc.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Entity: 5, Label: CARDINAL
# Entity: Telco Solutions Inc., Label: ORG
# Entity: Effective Date, Label: ORG
# Entity: 01, Label: CARDINAL
# Entity: 1, Label: CARDINAL
# Entity: AVAILABILITY, Label: ORG
# Entity: 99.95%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 4hrs/month, Label: DATE
# Entity: 72hrs, Label: CARDINAL
# Entity: Formula, Label: PERSON
# Entity: 5%, Label: PERCENT
# Entity: 0.1%, Label: PERCENT
# Entity: 2, Label: CARDINAL
# Entity: NETWORK LATENCY, Label: PERSON
# Entity: Target, Label: ORG
# Entity: 95th, Label: ORDINAL
# Entity: hourly, Label: TIME
# Entity: 3%, Label: PERCENT
# Entity: 1ms, Label: ORDINAL
# Entity: 3, Label: CARDINAL
# Entity: DOWNLINK, Label: ORG
# Entity: Target, Label: ORG
# Entity: Mbps, Label: PERSON
# Entity: Mbps, Label: PERSON
# Entity: 50, Label: CARDINAL
# Entity: 9 AM–5 PM, Label: TIME
# Entity: 2%, Label: PERCENT
# Entity: 10%, Label: PERCENT
# Entity: 4, Label: CARDINAL
# Entity: every 5 minutes, Label: TIME
# Entity: 4%, Label: PERCENT
# Entity: 0.0005%, Label: PERCENT
# Entity: 5, Label: CARDINAL
# Entity: ≤4 hours, Label: TIME
# Entity: Non-Critical Faults, Label: ORG
# Entity: 500, Label: MONEY
# Entity: 6, Label: CARDINAL
# Entity: REPORTING & SUPPORT
# KPI Reports, Label: ORG
# Entity: Monthly, Label: DATE
# Entity: 5th, Label: ORDINAL
# Entity: next month, Label: DATE
# Entity: 24/7, Label: CARDINAL
# Entity: max, Label: PERSON
# Entity: 15, Label: CARDINAL
# Entity: P1, Label: NORP
# Entity: quarterly, Label: DATE
# Entity: 7, Label: CARDINAL
# Entity: Max Annual Credit, Label: PERSON
# Entity: 20%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 30 days, Label: DATE
# Entity: 5, Label: CARDINAL
# Entity: 20250626, Label: DATE
# Entity: Effective Date, Label: ORG
# Entity: 2025-07-01, Label: DATE
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 1, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: cloud computing, Label: PERSON
# Entity: 2, Label: CARDINAL
# Entity: Service Scope
#
# Geographic Coverage: Primary, Label: ORG
# Entity: Appendix A.
#
# User Devices: Support, Label: PERSON
# Entity: 5G, Label: CARDINAL
# Entity: IoT, Label: ORG
# Entity: SIM, Label: ORG
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 3, Label: CARDINAL
# Entity: Performance Metrics, Label: ORG
# Entity: 15-minute, Label: TIME
# Entity: 3.1, Label: CARDINAL
# Entity: Downlink, Label: PERSON
# Entity: 1, Label: CARDINAL
# Entity: second, Label: ORDINAL
# Entity: 750, Label: CARDINAL
# Entity: Mbps, Label: PERSON
# Entity: CPE, Label: ORG
# Entity: monthly, Label: DATE
# Entity: 3.2, Label: CARDINAL
# Entity: 200, Label: CARDINAL
# Entity: 150, Label: CARDINAL
# Entity: Mbps, Label: PERSON
# Entity: monthly, Label: DATE
# Entity: 3.3, Label: CARDINAL
# Entity: less than 10, Label: CARDINAL
# Entity: 15, Label: CARDINAL
# Entity: 99.9%, Label: PERCENT
# Entity: Hourly, Label: TIME
# Entity: weekly, Label: DATE
# Entity: 3.4, Label: CARDINAL
# Entity: 2, Label: CARDINAL
# Entity: Hourly, Label: TIME
# Entity: weekly, Label: DATE
# Entity: 3.5, Label: CARDINAL
# Entity: Packet Loss Rate
#
# , Label: ORG
# Entity: Less than 0.01%, Label: PERCENT
# Entity: 0.05%, Label: PERCENT
# Entity: 5, Label: CARDINAL
# Entity: 3.6, Label: CARDINAL
# Entity: 99.99%, Label: PERCENT
# Entity: 5, Label: CARDINAL
# Entity: Monthly, Label: DATE
# Entity: 4, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: Service Level Objectives, Label: ORG
# Entity: a given month, Label: DATE
# Entity: Customer, Label: ORG
# Entity: 99.9%, Label: PERCENT
# Entity: 99.99%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 99.0%, Label: PERCENT
# Entity: 99.9%, Label: PERCENT
# Entity: 10%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 99.0%, Label: PERCENT
# Entity: 20%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: more than 5%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: Maximum Tolerated, Label: PERSON
# Entity: more than 1%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: month, Label: DATE
# Entity: any given month, Label: DATE
# Entity: 25%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 5, Label: CARDINAL
# Entity: 5.1, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 24/7, Label: CARDINAL
# Entity: Customer, Label: ORG
# Entity: Respond, Label: PERSON
# Entity: 5.2, Label: CARDINAL
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: Customer, Label: ORG
# Entity: CPE, Label: ORG
# Entity: Notify NexGen Telecom Inc., Label: ORG
# Entity: Appendix, Label: NORP
# Entity: 6, Label: CARDINAL
# Entity: 6.1, Label: CARDINAL
# Entity: 9 AM - 5 PM M-F, Label: TIME
# Entity: Email Support, Label: PERSON
# Entity: 9 AM - 5 PM M-F, Label: TIME
# Entity: 6.2, Label: CARDINAL
# Entity: Target Resolution Time, Label: ORG
# Entity: TRT, Label: ORG
# Entity: 4 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 8 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 24 hours, Label: TIME
# Entity: TRT, Label: ORG
# Entity: 48 hours, Label: TIME
# Entity: 6.3, Label: CARDINAL
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: 7, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: first, Label: ORDINAL
# Entity: 30 days, Label: DATE
# Entity: 8, Label: CARDINAL
# Entity: 60 days', Label: DATE
# Entity: NexGen Telecom Inc., Label: ORG
# Entity: Enterprise Solutions Corp., Label: ORG
# Entity: 9, Label: CARDINAL
# Entity: SLA, Label: ORG
# Entity: annually, Label: DATE
# Entity: the Effective Date, Label: ORG
# Entity: 1, Label: CARDINAL
# Entity: 2025-06-09, Label: DATE
# Entity: 2025-06-10, Label: DATE
# Entity: 2, Label: CARDINAL
# Entity: 5, Label: CARDINAL
# Entity: G Connectivity Service
# Service Scope, Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: New Radio, Label: ORG
# Entity: Basic, Premium, Enterprise]
#
# , Label: WORK_OF_ART
# Entity: 3, Label: CARDINAL
# Entity: Performance Metrics
#
# Availability, Label: ORG
# Entity: ≥, Label: GPE
# Entity: 99.99%, Label: PERCENT
# Entity: ≤, Label: PERSON
# Entity: 10, Label: CARDINAL
# Entity: one, Label: CARDINAL
# Entity: ≥, Label: PERSON
# Entity: 1 Gbps
# Uplink, Label: QUANTITY
# Entity: ≥, Label: PERSON
# Entity: 100, Label: CARDINAL
# Entity: ≤, Label: PERSON
# Entity: 5, Label: CARDINAL
# Entity: 0.1%, Label: PERCENT
# Entity: 4, Label: CARDINAL
# Entity: Monthly, Label: DATE
# Entity: Email, Label: PERSON
# Entity: 5, Label: CARDINAL
# Entity: 24/7, Label: CARDINAL
# Entity: 15 minutes, Label: TIME
# Entity: 1 hour, Label: TIME
# Entity: ≤, Label: PERSON
# Entity: 4 hours, Label: TIME
# Entity: 48 hours, Label: TIME
# Entity: 6, Label: CARDINAL
# Entity: 99.99%, Label: PERCENT
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 10, Label: CARDINAL
# Entity: 3%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: Maximum Credit Cap, Label: PERSON
# Entity: 25%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 7, Label: CARDINAL
# Entity: Termination Conditions
#
# Breach, Label: ORG
# Entity: 3 consecutive months, Label: DATE
# Entity: Notice Period, Label: ORG
# Entity: 30 days, Label: DATE
# Entity: 8, Label: CARDINAL
# Entity: 5, Label: CARDINAL
# Entity: 1, Label: CARDINAL
# Entity: Acme Corp, Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 2025-07-01, Label: DATE
# Entity: 2026-06-30, Label: DATE
# Entity: 2, Label: CARDINAL
# Entity: 3GPP Release, Label: ORG
# Entity: 16, Label: CARDINAL
# Entity: AR/VR, Label: ORG
# Entity: IoT, Label: ORG
# Entity: 3, Label: CARDINAL
# Entity: 99.99%, Label: PERCENT
# Entity: Monthly, Label: DATE
# Entity: ≤, Label: PERSON
# Entity: Continuous, Label: PERSON
# Entity: ≥, Label: PERSON
# Entity: 1 Gbps
#   *, Label: QUANTITY
# Entity: ≥, Label: PERSON
# Entity: Mbps
#   *, Label: PERSON
# Entity: Peak hours, Label: TIME
# Entity: 17:00–21:00, Label: CARDINAL
# Entity: 4, Label: CARDINAL
# Entity: Fault Management**, Label: ORG
# Entity: ≤, Label: PERSON
# Entity: 15 minutes, Label: TIME
# Entity: ≤, Label: PERSON
# Entity: 4 hours, Label: TIME
# Entity: 1, Label: CARDINAL
# Entity: 24/7, Label: CARDINAL
# Entity: NOC, Label: ORG
# Entity: 5, Label: CARDINAL
# Entity: 99.5%, Label: PERCENT
# Entity: 10%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 10, Label: CARDINAL
# Entity: 5%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 30%, Label: PERCENT
# Entity: monthly, Label: DATE
# Entity: 6, Label: CARDINAL
# Entity: Monthly, Label: DATE
# Entity: PDF, Label: ORG
# Entity: XML, Label: ORG
# Entity: 7, Label: CARDINAL
# Entity: Contact Information*, Label: ORG
# Entity: support@nextgen-networks.com](mailto:support@nextgen-networks.com, Label: ORG
# Entity: itops@acme-corp.com](mailto:itops@acme-corp.com, Label: ORG
# Entity: 8, Label: CARDINAL
# Entity: 30 days, Label: DATE

# %%
from spacy.matcher import Matcher
from collections import defaultdict

# Assume: `doc = nlp(text)` is already run
matcher = Matcher(nlp.vocab)

# --- Define static patterns ---
availability_pattern = [
    {'LIKE_NUM': True}, {'TEXT': '%'}, {'LOWER': 'uptime'}
]
response_time_pattern = [
    {'LOWER': 'response'}, {'LOWER': 'time'}, {'LOWER': 'should'},
    {'LOWER': 'not'}, {'LOWER': 'exceed'}, {'LIKE_NUM': True}, {'LOWER': 'hours'}
]

matcher.add('AVAILABILITY', [availability_pattern])
matcher.add('RESPONSE_TIME', [response_time_pattern])

keywords={ "access", "acme", "activities", "advance", "agreement", "agreementid", "amendment", "amendments", "anniversary", "annual", "appendix", "applications", "ar", "area", "audit", "auto", "availability", "availabilitybreach", "average", "basic", "breach", "broadband", "calendar", "capabilities", "capacity", "cards", "cell", "changes", "channels", "claim", "client", "cloud", "communication", "computing", "conditions", "confidentiality", "connectivity", "contact", "core", "corp", "coverage", "coveragearea", "cpe", "credit", "credits", "critical", "customer", "customercontact", "customerz", "cycle", "daily", "dashboard", "data", "date", "days", "definition", "degradation", "delay", "delivery", "deliverymethod", "description", "deviation", "device", "devices", "dispute", "disputes", "downlink", "downtime", "edge", "effective", "effectivedate", "effort", "egress", "email", "embb", "end", "enhanced", "enterprise", "equipment", "esim", "event", "exclusions", "expirationdate", "fault", "faults", "fee", "file", "format", "formula", "frequency", "function", "functioning", "g", "gateway", "gateways", "gbps", "general", "geographic", "gigabits", "governing", "guaranteed", "helpdesk", "high", "hour", "hourly", "hours", "id", "ids", "incident", "incidentresolutiontime", "incidentresponsetime", "incidents", "industrial", "information", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "jurisdiction", "kpi", "latency", "latencybreach", "law", "level", "levels", "locations", "loss", "low", "maintenance", "major", "management", "map", "maps", "master", "max", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "mediation", "medium", "method", "metric", "metrics", "metropolitan", "milliseconds", "min", "minimum", "minor", "minute", "minutes", "mobile", "monitor", "monitoring", "month", "monthly", "months", "ms", "negotiation", "network", "networks", "new", "nexgen", "nextgen", "notice", "notification", "notify", "objective", "objectives", "online", "outage", "packet", "parties", "party", "pdf", "peak", "penalties", "penalty", "percentage", "percentile", "performance", "period", "phone", "plane", "planned", "pm", "point", "policy", "portal", "premises", "premium", "prioritization", "priority", "probes", "profiles", "provider", "providersupportemail", "provision", "quarterly", "radio", "rate", "receipt", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "report", "reporting", "reports", "requirements", "resolution", "respond", "response", "responsibilities", "restoration", "review", "rights", "round","scope", "segment", "service", "servicename", "sim", "sla", "slices", "slos", "smartphones", "solutions", "specific", "speed", "status", "streaming", "subset", "support", "supporteddevices", "tablets", "target", "technology", "telco", "telecom", "termination", "terminationnoticeperiod", "terms", "tests", "threshold", "throughput", "tickets", "tiers", "time", "tolerated", "tools", "total", "tracking", "traffic", "transfers", "trip", "trt", "type", "ue", "ues", "updates", "upf", "uplink", "uptime", "usage", "usecases", "user", "users", "workdays", "writing", "zone", "zones" }

for kw in keywords:
    matcher.add(f"KEYWORD_{kw.lower()}", [[{"LOWER": kw.lower()}]])

# --- Apply matcher ---
matches = matcher(doc)

# --- Initialize storage ---
availability = None
response_time = None
matched_keywords = defaultdict(list)

# --- Process matches ---
for match_id, start, end in matches:
    span = doc[start:end]
    match_label = nlp.vocab.strings[match_id]

    if match_label == 'AVAILABILITY':
        availability = span.text
    elif match_label == 'RESPONSE_TIME':
        response_time = span.text
    elif match_label.startswith("KEYWORD_"):
        keyword = span.text.lower()

        # Look for number or units around the keyword
        window_start = max(0, start - 3)
        window_end = min(len(doc), end + 4)
        context = doc[window_start:window_end]

        # Look for nearby values: numbers, %, ms, etc.
        values = [
            token.text for token in context
            if token.like_num or token.text.lower() in {'%', 'ms', 'mbps', 'milliseconds', 'minutes', 'hours', 'ratio'}
        ]

        if values:
            matched_keywords[keyword].extend(values)

# --- Print results ---
print(f"Availability Match: {availability}")
print(f"Response Time Match: {response_time}\n")

print("Keyword-Value Pairs Found in Text:")
for kw, vals in sorted(matched_keywords.items()):
    vals_clean = ", ".join(set(vals))  # Remove duplicates
    print(f"- {kw}: {vals_clean}")
# Out:
# Availability Match: 99.99% uptime
# Response Time Match: None
#
# Keyword-Value Pairs Found in Text:
# - activities: 72, hours
# - advance: 72, 6, hours, 48
# - agreement: 2025
# - annual: 20, %
# - applications: 8
# - availability: 1, 99.95, 10, %, 20, 99.99, 3.6, 5, 99.0, 99.9
# - average: 1, 200, Mbps, 10, ms
# - breach: 5, 3, 0.0005, %
# - calendar: %
# - capacity: 1
# - channels: 6.1
# - claim: 30
# - conditions: 7
# - connectivity: 5
# - contact: 7
# - credit: 25, 3, 2, 0.0005, 10, %, 4, 20, 5, 0.1
# - credits: 7, 4
# - critical: 24/7, minutes, 9, 15, hours
# - cycle: 1
# - daily: 9
# - data: 1, 15
# - date: 06, 2025, 07, 20250626, 01
# - days: 30, 8, 60
# - delay: 500, 6
# - description: 1, 2
# - deviation: 4, 10, %
# - device: Mbps
# - devices: 16
# - dispute: 7
# - downlink: 1, 3
# - downtime: Minutes
# - edge: ms, 5
# - effective: 09, 20250626, 01, 2025
# - effectivedate: 2025
# - embb: 5
# - end: 5
# - enhanced: 5
# - enterprise: 9, 5.2, 3
# - expirationdate: 2026
# - fault: 5, 4
# - faults: hours
# - fee: 3, 10, %, 7, 5, 6, 99.0
# - file: 2
# - formula: Minutes
# - g: 5
# - gbps: 1, second
# - general: 1
# - gigabits: 1, second
# - guaranteed: 750, Mbps, 150
# - helpdesk: 24/7, 15
# - high: hours
# - hour: 1, 500
# - hourly: 95th
# - hours: 1, 24/7, 4, 8, 6.3, 6, 48, 72, 24, hours, Hours
# - incident: 24/7, 6.2, 6.1
# - incidents: 1, 24/7, 9
# - information: 1, 7
# - infrastructure: 5
# - intervals: 15
# - issues: 48, 24
# - jitter: 3.4, 2, Mbps, 100, ms, 5
# - latency: 3.3, 2, 10, ms, 5
# - level: 5, 3
# - loss: 0.01, %, ms, 0.1, 3.5
# - low: hours
# - maintenance: 72, hours, 48, Hours
# - major: minutes, 1, 15
# - management: 6.1, 4
# - max: 24/7, 15, 20
# - maximum: 2, %, 15, 0.05, ms, 25
# - mbps: 200, 500, Mbps, 150, 100, 750
# - measurement: Mbps, %, ms, 95th, 7
# - mediation: 8
# - medium: hours
# - metrics: 3
# - milliseconds: ms, milliseconds, 10
# - min: 15
# - minimum: Mbps, 150, 48, 750, hours
# - minor: 1, hours, 4
# - minute: 15
# - minutes: minutes, 4, Minutes, 15, 5
# - mobile: 5
# - monitoring: 5, 24/7, 4
# - month: 5th, 25
# - monthly: 25, 3, 30, 4, %, 10, 5th, 20, 7, 99.95, 5, 99.0
# - months: 3
# - ms: 3, 2, milliseconds, 10, %, 15, ms, 5, one, 99.9
# - network: 5, 50, 2
# - nexgen: 5.1
# - notice: 30, 8
# - notification: 48, hours
# - objective: 0.01, 99.99, %
# - online: 24/7
# - packet: 0.01, %, ms, 5, 0.1, 3.5
# - parties: 1, 5.1
# - party: 60
# - peak: hours, Mbps
# - penalties: 5, 6
# - penalty: 500, 3, 2, minutes, 4, %, Minutes, 5, hours
# - percentile: 95th
# - performance: 3
# - period: 06, 2025, 30, %, 09, 5
# - planned: hours, 4
# - pm: 5, 9
# - portal: 5, 24/7
# - prioritization: 6.2
# - priority: 1, hours, 4
# - probes: minutes, 5, 3
# - provider: 01
# - provision: 5
# - quarterly: 1, 7
# - recipient: 7
# - refund: %
# - release: 16
# - reliability: 4
# - report: 30
# - reporting: 24/7, 6.3, %, 5, 6
# - reports: 3.3, 3.4, 3.2, 3.6, 3.5
# - resolution: 7
# - response: 24/7, 15
# - responsibilities: 5
# - restoration: 5
# - review: 9
# - scope: 2
# - segment: 5
# - service: 1, 3, 2, 0.0005, 10, %, 4, 20, 7, 3.6, 5, 01, 0.1
# - servicename: 5
# - sla: 5, first
# - slices: 3
# - slos: 24/7
# - solutions: 9, 5.2
# - speed: 9
# - support: 24/7, 5.2, 6.1, 5, 6, Hours
# - target: Mbps, 2, %, 99.99, 99.95, 6, 0.1
# - telecom: 5.1
# - termination: 3, 7, 8
# - terminationnoticeperiod: 30
# - terms: 5, 8
# - tests: 9
# - throughput: 1, 200, 3, Mbps, 3.1, 3.2
# - time: 4
# - tolerated: ms, 15, 0.05, %
# - total: Minutes, %
# - traffic: 99.9, %
# - transfers: 2
# - trt: 8, 4, 48, 24, hours
# - type: 5
# - ues: 50
# - uplink: 200, 1, Mbps, 100
# - uptime: %, 99.99, 99.95
# - writing: 1

# %%
for keyword in keywords:
    words = keyword.lower().split()
    pattern = [{'LOWER': word.strip(",")} for word in words]
    matcher.add(keyword.upper().replace(" ", "_"), [pattern])

# Apply the matcher
matches = matcher(doc)

# Print matches
for match_id, start, end in matches:
    span = doc[start:end]
    print(f"Matched '{span.text}' with label '{nlp.vocab.strings[match_id]}' at position {start}-{end}")
# Out:
# Matched 'G' with label 'KEYWORD_g' at position 1-2
# Matched 'G' with label 'G' at position 1-2
# Matched 'SERVICE' with label 'KEYWORD_service' at position 2-3
# Matched 'SERVICE' with label 'SERVICE' at position 2-3
# Matched 'LEVEL' with label 'KEYWORD_level' at position 3-4
# Matched 'LEVEL' with label 'LEVEL' at position 3-4
# Matched 'AGREEMENT' with label 'KEYWORD_agreement' at position 4-5
# Matched 'AGREEMENT' with label 'AGREEMENT' at position 4-5
# Matched 'SLA' with label 'KEYWORD_sla' at position 6-7
# Matched 'SLA' with label 'SLA' at position 6-7
# Matched 'Service' with label 'KEYWORD_service' at position 9-10
# Matched 'Service' with label 'SERVICE' at position 9-10
# Matched 'Provider' with label 'KEYWORD_provider' at position 10-11
# Matched 'Provider' with label 'PROVIDER' at position 10-11
# Matched 'Telco' with label 'KEYWORD_telco' at position 12-13
# Matched 'Telco' with label 'TELCO' at position 12-13
# Matched 'Solutions' with label 'KEYWORD_solutions' at position 13-14
# Matched 'Solutions' with label 'SOLUTIONS' at position 13-14
# Matched 'Customer' with label 'KEYWORD_customer' at position 16-17
# Matched 'Customer' with label 'CUSTOMER' at position 16-17
# Matched 'Enterprise' with label 'KEYWORD_enterprise' at position 18-19
# Matched 'Enterprise' with label 'ENTERPRISE' at position 18-19
# Matched 'Client' with label 'KEYWORD_client' at position 19-20
# Matched 'Client' with label 'CLIENT' at position 19-20
# Matched 'Effective' with label 'KEYWORD_effective' at position 22-23
# Matched 'Effective' with label 'EFFECTIVE' at position 22-23
# Matched 'Date' with label 'KEYWORD_date' at position 23-24
# Matched 'Date' with label 'DATE' at position 23-24
# Matched 'Review' with label 'KEYWORD_review' at position 29-30
# Matched 'Review' with label 'REVIEW' at position 29-30
# Matched 'Cycle' with label 'KEYWORD_cycle' at position 30-31
# Matched 'Cycle' with label 'CYCLE' at position 30-31
# Matched 'Quarterly' with label 'KEYWORD_quarterly' at position 32-33
# Matched 'Quarterly' with label 'QUARTERLY' at position 32-33
# Matched 'SERVICE' with label 'KEYWORD_service' at position 36-37
# Matched 'SERVICE' with label 'SERVICE' at position 36-37
# Matched 'AVAILABILITY' with label 'KEYWORD_availability' at position 37-38
# Matched 'AVAILABILITY' with label 'AVAILABILITY' at position 37-38
# Matched 'Target' with label 'KEYWORD_target' at position 39-40
# Matched 'Target' with label 'TARGET' at position 39-40
# Matched 'monthly' with label 'KEYWORD_monthly' at position 43-44
# Matched 'monthly' with label 'MONTHLY' at position 43-44
# Matched 'uptime' with label 'KEYWORD_uptime' at position 44-45
# Matched 'uptime' with label 'UPTIME' at position 44-45
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 46-47
# Matched 'Measurement' with label 'MEASUREMENT' at position 46-47
# Matched 'Exclusions' with label 'KEYWORD_exclusions' at position 49-50
# Matched 'Exclusions' with label 'EXCLUSIONS' at position 49-50
# Matched 'maintenance' with label 'KEYWORD_maintenance' at position 52-53
# Matched 'maintenance' with label 'MAINTENANCE' at position 52-53
# Matched 'max' with label 'KEYWORD_max' at position 54-55
# Matched 'max' with label 'MAX' at position 54-55
# Matched 'month' with label 'KEYWORD_month' at position 57-58
# Matched 'month' with label 'MONTH' at position 57-58
# Matched 'advance' with label 'KEYWORD_advance' at position 62-63
# Matched 'advance' with label 'ADVANCE' at position 62-63
# Matched 'Formula' with label 'KEYWORD_formula' at position 65-66
# Matched 'Formula' with label 'FORMULA' at position 65-66
# Matched 'Total' with label 'KEYWORD_total' at position 68-69
# Matched 'Total' with label 'TOTAL' at position 68-69
# Matched 'Minutes' with label 'KEYWORD_minutes' at position 69-70
# Matched 'Minutes' with label 'MINUTES' at position 69-70
# Matched 'Downtime' with label 'KEYWORD_downtime' at position 71-72
# Matched 'Downtime' with label 'DOWNTIME' at position 71-72
# Matched 'Total' with label 'KEYWORD_total' at position 74-75
# Matched 'Total' with label 'TOTAL' at position 74-75
# Matched 'Minutes' with label 'KEYWORD_minutes' at position 75-76
# Matched 'Minutes' with label 'MINUTES' at position 75-76
# Matched 'Penalty' with label 'KEYWORD_penalty' at position 77-78
# Matched 'Penalty' with label 'PENALTY' at position 77-78
# Matched 'service' with label 'KEYWORD_service' at position 81-82
# Matched 'service' with label 'SERVICE' at position 81-82
# Matched 'credit' with label 'KEYWORD_credit' at position 82-83
# Matched 'credit' with label 'CREDIT' at position 82-83
# Matched 'target' with label 'KEYWORD_target' at position 87-88
# Matched 'target' with label 'TARGET' at position 87-88
# Matched 'NETWORK' with label 'KEYWORD_network' at position 91-92
# Matched 'NETWORK' with label 'NETWORK' at position 91-92
# Matched 'LATENCY' with label 'KEYWORD_latency' at position 92-93
# Matched 'LATENCY' with label 'LATENCY' at position 92-93
# Matched 'Target' with label 'KEYWORD_target' at position 94-95
# Matched 'Target' with label 'TARGET' at position 94-95
# Matched 'end' with label 'KEYWORD_end' at position 97-98
# Matched 'end' with label 'END' at position 97-98
# Matched 'end' with label 'KEYWORD_end' at position 101-102
# Matched 'end' with label 'END' at position 101-102
# Matched 'UE' with label 'KEYWORD_ue' at position 103-104
# Matched 'UE' with label 'UE' at position 103-104
# Matched 'Core' with label 'KEYWORD_core' at position 105-106
# Matched 'Core' with label 'CORE' at position 105-106
# Matched 'Scope' with label 'KEYWORD_scope' at position 108-109
# Matched 'Scope' with label 'SCOPE' at position 108-109
# Matched 'zones' with label 'KEYWORD_zones' at position 111-112
# Matched 'zones' with label 'ZONES' at position 111-112
# Matched 'coverage' with label 'KEYWORD_coverage' at position 114-115
# Matched 'coverage' with label 'COVERAGE' at position 114-115
# Matched 'map' with label 'KEYWORD_map' at position 115-116
# Matched 'map' with label 'MAP' at position 115-116
# Matched 'Appendix' with label 'KEYWORD_appendix' at position 117-118
# Matched 'Appendix' with label 'APPENDIX' at position 117-118
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 121-122
# Matched 'Measurement' with label 'MEASUREMENT' at position 121-122
# Matched 'percentile' with label 'KEYWORD_percentile' at position 124-125
# Matched 'percentile' with label 'PERCENTILE' at position 124-125
# Matched 'hourly' with label 'KEYWORD_hourly' at position 126-127
# Matched 'hourly' with label 'HOURLY' at position 126-127
# Matched 'probes' with label 'KEYWORD_probes' at position 127-128
# Matched 'probes' with label 'PROBES' at position 127-128
# Matched 'Penalty' with label 'KEYWORD_penalty' at position 129-130
# Matched 'Penalty' with label 'PENALTY' at position 129-130
# Matched 'service' with label 'KEYWORD_service' at position 133-134
# Matched 'service' with label 'SERVICE' at position 133-134
# Matched 'credit' with label 'KEYWORD_credit' at position 134-135
# Matched 'credit' with label 'CREDIT' at position 134-135
# Matched 'breach' with label 'KEYWORD_breach' at position 138-139
# Matched 'breach' with label 'BREACH' at position 138-139
# Matched 'DOWNLINK' with label 'KEYWORD_downlink' at position 142-143
# Matched 'DOWNLINK' with label 'DOWNLINK' at position 142-143
# Matched 'THROUGHPUT' with label 'KEYWORD_throughput' at position 143-144
# Matched 'THROUGHPUT' with label 'THROUGHPUT' at position 143-144
# Matched 'Target' with label 'KEYWORD_target' at position 145-146
# Matched 'Target' with label 'TARGET' at position 145-146
# Matched 'Mbps' with label 'KEYWORD_mbps' at position 148-149
# Matched 'Mbps' with label 'MBPS' at position 148-149
# Matched 'peak' with label 'KEYWORD_peak' at position 149-150
# Matched 'peak' with label 'PEAK' at position 149-150
# Matched 'Mbps' with label 'KEYWORD_mbps' at position 152-153
# Matched 'Mbps' with label 'MBPS' at position 152-153
# Matched 'average' with label 'KEYWORD_average' at position 153-154
# Matched 'average' with label 'AVERAGE' at position 153-154
# Matched 'device' with label 'KEYWORD_device' at position 155-156
# Matched 'device' with label 'DEVICE' at position 155-156
# Matched 'Conditions' with label 'KEYWORD_conditions' at position 157-158
# Matched 'Conditions' with label 'CONDITIONS' at position 157-158
# Matched 'network' with label 'KEYWORD_network' at position 162-163
# Matched 'network' with label 'NETWORK' at position 162-163
# Matched 'UEs' with label 'KEYWORD_ues' at position 168-169
# Matched 'UEs' with label 'UES' at position 168-169
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 170-171
# Matched 'Measurement' with label 'MEASUREMENT' at position 170-171
# Matched 'Daily' with label 'KEYWORD_daily' at position 172-173
# Matched 'Daily' with label 'DAILY' at position 172-173
# Matched 'speed' with label 'KEYWORD_speed' at position 173-174
# Matched 'speed' with label 'SPEED' at position 173-174
# Matched 'tests' with label 'KEYWORD_tests' at position 174-175
# Matched 'tests' with label 'TESTS' at position 174-175
# Matched 'PM' with label 'KEYWORD_pm' at position 178-179
# Matched 'PM' with label 'PM' at position 178-179
# Matched 'workdays' with label 'KEYWORD_workdays' at position 180-181
# Matched 'workdays' with label 'WORKDAYS' at position 180-181
# Matched 'Penalty' with label 'KEYWORD_penalty' at position 183-184
# Matched 'Penalty' with label 'PENALTY' at position 183-184
# Matched 'service' with label 'KEYWORD_service' at position 187-188
# Matched 'service' with label 'SERVICE' at position 187-188
# Matched 'credit' with label 'KEYWORD_credit' at position 188-189
# Matched 'credit' with label 'CREDIT' at position 188-189
# Matched 'deviation' with label 'KEYWORD_deviation' at position 192-193
# Matched 'deviation' with label 'DEVIATION' at position 192-193
# Matched 'RELIABILITY' with label 'KEYWORD_reliability' at position 196-197
# Matched 'RELIABILITY' with label 'RELIABILITY' at position 196-197
# Matched 'Target' with label 'KEYWORD_target' at position 198-199
# Matched 'Target' with label 'TARGET' at position 198-199
# Matched 'packet' with label 'KEYWORD_packet' at position 202-203
# Matched 'packet' with label 'PACKET' at position 202-203
# Matched 'loss' with label 'KEYWORD_loss' at position 203-204
# Matched 'loss' with label 'LOSS' at position 203-204
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 205-206
# Matched 'Measurement' with label 'MEASUREMENT' at position 205-206
# Matched 'probes' with label 'KEYWORD_probes' at position 208-209
# Matched 'probes' with label 'PROBES' at position 208-209
# Matched 'minutes' with label 'KEYWORD_minutes' at position 211-212
# Matched 'minutes' with label 'MINUTES' at position 211-212
# Matched 'Penalty' with label 'KEYWORD_penalty' at position 213-214
# Matched 'Penalty' with label 'PENALTY' at position 213-214
# Matched 'service' with label 'KEYWORD_service' at position 217-218
# Matched 'service' with label 'SERVICE' at position 217-218
# Matched 'credit' with label 'KEYWORD_credit' at position 218-219
# Matched 'credit' with label 'CREDIT' at position 218-219
# Matched 'breach' with label 'KEYWORD_breach' at position 222-223
# Matched 'breach' with label 'BREACH' at position 222-223
# Matched 'FAULT' with label 'KEYWORD_fault' at position 226-227
# Matched 'FAULT' with label 'FAULT' at position 226-227
# Matched 'RESTORATION' with label 'KEYWORD_restoration' at position 227-228
# Matched 'RESTORATION' with label 'RESTORATION' at position 227-228
# Matched 'Critical' with label 'KEYWORD_critical' at position 229-230
# Matched 'Critical' with label 'CRITICAL' at position 229-230
# Matched 'Faults' with label 'KEYWORD_faults' at position 230-231
# Matched 'Faults' with label 'FAULTS' at position 230-231
# Matched 'hours' with label 'KEYWORD_hours' at position 233-234
# Matched 'hours' with label 'HOURS' at position 233-234
# Matched 'Critical' with label 'KEYWORD_critical' at position 237-238
# Matched 'Critical' with label 'CRITICAL' at position 237-238
# Matched 'Faults' with label 'KEYWORD_faults' at position 238-239
# Matched 'Faults' with label 'FAULTS' at position 238-239
# Matched 'hours' with label 'KEYWORD_hours' at position 241-242
# Matched 'hours' with label 'HOURS' at position 241-242
# Matched 'Penalty' with label 'KEYWORD_penalty' at position 243-244
# Matched 'Penalty' with label 'PENALTY' at position 243-244
# Matched 'hour' with label 'KEYWORD_hour' at position 248-249
# Matched 'hour' with label 'HOUR' at position 248-249
# Matched 'delay' with label 'KEYWORD_delay' at position 249-250
# Matched 'delay' with label 'DELAY' at position 249-250
# Matched 'target' with label 'KEYWORD_target' at position 251-252
# Matched 'target' with label 'TARGET' at position 251-252
# Matched 'REPORTING' with label 'KEYWORD_reporting' at position 255-256
# Matched 'REPORTING' with label 'REPORTING' at position 255-256
# Matched 'SUPPORT' with label 'KEYWORD_support' at position 257-258
# Matched 'SUPPORT' with label 'SUPPORT' at position 257-258
# Matched 'KPI' with label 'KEYWORD_kpi' at position 259-260
# Matched 'KPI' with label 'KPI' at position 259-260
# Matched 'Reports' with label 'KEYWORD_reports' at position 260-261
# Matched 'Reports' with label 'REPORTS' at position 260-261
# Matched 'Monthly' with label 'KEYWORD_monthly' at position 262-263
# Matched 'Monthly' with label 'MONTHLY' at position 262-263
# Matched 'month' with label 'KEYWORD_month' at position 268-269
# Matched 'month' with label 'MONTH' at position 268-269
# Matched 'Support' with label 'KEYWORD_support' at position 271-272
# Matched 'Support' with label 'SUPPORT' at position 271-272
# Matched 'helpdesk' with label 'KEYWORD_helpdesk' at position 274-275
# Matched 'helpdesk' with label 'HELPDESK' at position 274-275
# Matched 'max' with label 'KEYWORD_max' at position 276-277
# Matched 'max' with label 'MAX' at position 276-277
# Matched 'min' with label 'KEYWORD_min' at position 279-280
# Matched 'min' with label 'MIN' at position 279-280
# Matched 'response' with label 'KEYWORD_response' at position 280-281
# Matched 'response' with label 'RESPONSE' at position 280-281
# Matched 'tickets' with label 'KEYWORD_tickets' at position 283-284
# Matched 'tickets' with label 'TICKETS' at position 283-284
# Matched 'Audit' with label 'KEYWORD_audit' at position 286-287
# Matched 'Audit' with label 'AUDIT' at position 286-287
# Matched 'Rights' with label 'KEYWORD_rights' at position 287-288
# Matched 'Rights' with label 'RIGHTS' at position 287-288
# Matched 'Customer' with label 'KEYWORD_customer' at position 289-290
# Matched 'Customer' with label 'CUSTOMER' at position 289-290
# Matched 'measurement' with label 'KEYWORD_measurement' at position 292-293
# Matched 'measurement' with label 'MEASUREMENT' at position 292-293
# Matched 'quarterly' with label 'KEYWORD_quarterly' at position 294-295
# Matched 'quarterly' with label 'QUARTERLY' at position 294-295
# Matched 'SERVICE' with label 'KEYWORD_service' at position 298-299
# Matched 'SERVICE' with label 'SERVICE' at position 298-299
# Matched 'CREDITS' with label 'KEYWORD_credits' at position 299-300
# Matched 'CREDITS' with label 'CREDITS' at position 299-300
# Matched 'Max' with label 'KEYWORD_max' at position 301-302
# Matched 'Max' with label 'MAX' at position 301-302
# Matched 'Annual' with label 'KEYWORD_annual' at position 302-303
# Matched 'Annual' with label 'ANNUAL' at position 302-303
# Matched 'Credit' with label 'KEYWORD_credit' at position 303-304
# Matched 'Credit' with label 'CREDIT' at position 303-304
# Matched 'monthly' with label 'KEYWORD_monthly' at position 308-309
# Matched 'monthly' with label 'MONTHLY' at position 308-309
# Matched 'fee' with label 'KEYWORD_fee' at position 309-310
# Matched 'fee' with label 'FEE' at position 309-310
# Matched 'Claim' with label 'KEYWORD_claim' at position 311-312
# Matched 'Claim' with label 'CLAIM' at position 311-312
# Matched 'days' with label 'KEYWORD_days' at position 315-316
# Matched 'days' with label 'DAYS' at position 315-316
# Matched 'report' with label 'KEYWORD_report' at position 317-318
# Matched 'report' with label 'REPORT' at position 317-318
# Matched 'receipt' with label 'KEYWORD_receipt' at position 318-319
# Matched 'receipt' with label 'RECEIPT' at position 318-319
# Matched 'Service' with label 'KEYWORD_service' at position 320-321
# Matched 'Service' with label 'SERVICE' at position 320-321
# Matched 'Level' with label 'KEYWORD_level' at position 321-322
# Matched 'Level' with label 'LEVEL' at position 321-322
# Matched 'Agreement' with label 'KEYWORD_agreement' at position 322-323
# Matched 'Agreement' with label 'AGREEMENT' at position 322-323
# Matched 'SLA' with label 'KEYWORD_sla' at position 324-325
# Matched 'SLA' with label 'SLA' at position 324-325
# Matched 'G' with label 'KEYWORD_g' at position 328-329
# Matched 'G' with label 'G' at position 328-329
# Matched 'Enhanced' with label 'KEYWORD_enhanced' at position 329-330
# Matched 'Enhanced' with label 'ENHANCED' at position 329-330
# Matched 'Mobile' with label 'KEYWORD_mobile' at position 330-331
# Matched 'Mobile' with label 'MOBILE' at position 330-331
# Matched 'Broadband' with label 'KEYWORD_broadband' at position 331-332
# Matched 'Broadband' with label 'BROADBAND' at position 331-332
# Matched 'eMBB' with label 'KEYWORD_embb' at position 333-334
# Matched 'eMBB' with label 'EMBB' at position 333-334
# Matched 'Service' with label 'KEYWORD_service' at position 335-336
# Matched 'Service' with label 'SERVICE' at position 335-336
# Matched 'Agreement' with label 'KEYWORD_agreement' at position 337-338
# Matched 'Agreement' with label 'AGREEMENT' at position 337-338
# Matched 'ID' with label 'KEYWORD_id' at position 338-339
# Matched 'ID' with label 'ID' at position 338-339
# Matched 'Effective' with label 'KEYWORD_effective' at position 346-347
# Matched 'Effective' with label 'EFFECTIVE' at position 346-347
# Matched 'Date' with label 'KEYWORD_date' at position 347-348
# Matched 'Date' with label 'DATE' at position 347-348
# Matched 'Service' with label 'KEYWORD_service' at position 355-356
# Matched 'Service' with label 'SERVICE' at position 355-356
# Matched 'Provider' with label 'KEYWORD_provider' at position 356-357
# Matched 'Provider' with label 'PROVIDER' at position 356-357
# Matched 'NexGen' with label 'KEYWORD_nexgen' at position 358-359
# Matched 'NexGen' with label 'NEXGEN' at position 358-359
# Matched 'Telecom' with label 'KEYWORD_telecom' at position 359-360
# Matched 'Telecom' with label 'TELECOM' at position 359-360
# Matched 'Customer' with label 'KEYWORD_customer' at position 362-363
# Matched 'Customer' with label 'CUSTOMER' at position 362-363
# Matched 'Enterprise' with label 'KEYWORD_enterprise' at position 364-365
# Matched 'Enterprise' with label 'ENTERPRISE' at position 364-365
# Matched 'Solutions' with label 'KEYWORD_solutions' at position 365-366
# Matched 'Solutions' with label 'SOLUTIONS' at position 365-366
# Matched 'Service' with label 'KEYWORD_service' at position 368-369
# Matched 'Service' with label 'SERVICE' at position 368-369
# Matched 'Type' with label 'KEYWORD_type' at position 369-370
# Matched 'Type' with label 'TYPE' at position 369-370
# Matched 'G' with label 'KEYWORD_g' at position 372-373
# Matched 'G' with label 'G' at position 372-373
# Matched 'Enhanced' with label 'KEYWORD_enhanced' at position 373-374
# Matched 'Enhanced' with label 'ENHANCED' at position 373-374
# Matched 'Mobile' with label 'KEYWORD_mobile' at position 374-375
# Matched 'Mobile' with label 'MOBILE' at position 374-375
# Matched 'Broadband' with label 'KEYWORD_broadband' at position 375-376
# Matched 'Broadband' with label 'BROADBAND' at position 375-376
# Matched 'eMBB' with label 'KEYWORD_embb' at position 377-378
# Matched 'eMBB' with label 'EMBB' at position 377-378
# Matched 'High' with label 'KEYWORD_high' at position 380-381
# Matched 'High' with label 'HIGH' at position 380-381
# Matched 'Capacity' with label 'KEYWORD_capacity' at position 382-383
# Matched 'Capacity' with label 'CAPACITY' at position 382-383
# Matched 'Data' with label 'KEYWORD_data' at position 383-384
# Matched 'Data' with label 'DATA' at position 383-384
# Matched 'Service' with label 'KEYWORD_service' at position 384-385
# Matched 'Service' with label 'SERVICE' at position 384-385
# Matched 'Service' with label 'KEYWORD_service' at position 388-389
# Matched 'Service' with label 'SERVICE' at position 388-389
# Matched 'Description' with label 'KEYWORD_description' at position 389-390
# Matched 'Description' with label 'DESCRIPTION' at position 389-390
# Matched 'SLA' with label 'KEYWORD_sla' at position 392-393
# Matched 'SLA' with label 'SLA' at position 392-393
# Matched 'terms' with label 'KEYWORD_terms' at position 395-396
# Matched 'terms' with label 'TERMS' at position 395-396
# Matched 'conditions' with label 'KEYWORD_conditions' at position 397-398
# Matched 'conditions' with label 'CONDITIONS' at position 397-398
# Matched 'provision' with label 'KEYWORD_provision' at position 400-401
# Matched 'provision' with label 'PROVISION' at position 400-401
# Matched 'G' with label 'KEYWORD_g' at position 405-406
# Matched 'G' with label 'G' at position 405-406
# Matched 'Enhanced' with label 'KEYWORD_enhanced' at position 406-407
# Matched 'Enhanced' with label 'ENHANCED' at position 406-407
# Matched 'Mobile' with label 'KEYWORD_mobile' at position 407-408
# Matched 'Mobile' with label 'MOBILE' at position 407-408
# Matched 'Broadband' with label 'KEYWORD_broadband' at position 408-409
# Matched 'Broadband' with label 'BROADBAND' at position 408-409
# Matched 'eMBB' with label 'KEYWORD_embb' at position 410-411
# Matched 'eMBB' with label 'EMBB' at position 410-411
# Matched 'service' with label 'KEYWORD_service' at position 412-413
# Matched 'service' with label 'SERVICE' at position 412-413
# Matched 'Enterprise' with label 'KEYWORD_enterprise' at position 414-415
# Matched 'Enterprise' with label 'ENTERPRISE' at position 414-415
# Matched 'Solutions' with label 'KEYWORD_solutions' at position 415-416
# Matched 'Solutions' with label 'SOLUTIONS' at position 415-416
# Matched 'service' with label 'KEYWORD_service' at position 418-419
# Matched 'service' with label 'SERVICE' at position 418-419
# Matched 'high' with label 'KEYWORD_high' at position 423-424
# Matched 'high' with label 'HIGH' at position 423-424
# Matched 'throughput' with label 'KEYWORD_throughput' at position 425-426
# Matched 'throughput' with label 'THROUGHPUT' at position 425-426
# Matched 'low' with label 'KEYWORD_low' at position 427-428
# Matched 'low' with label 'LOW' at position 427-428
# Matched 'latency' with label 'KEYWORD_latency' at position 429-430
# Matched 'latency' with label 'LATENCY' at position 429-430
# Matched 'connectivity' with label 'KEYWORD_connectivity' at position 430-431
# Matched 'connectivity' with label 'CONNECTIVITY' at position 430-431
# Matched 'data' with label 'KEYWORD_data' at position 433-434
# Matched 'data' with label 'DATA' at position 433-434
# Matched 'applications' with label 'KEYWORD_applications' at position 436-437
# Matched 'applications' with label 'APPLICATIONS' at position 436-437
# Matched 'cloud' with label 'KEYWORD_cloud' at position 444-445
# Matched 'cloud' with label 'CLOUD' at position 444-445
# Matched 'computing' with label 'KEYWORD_computing' at position 445-446
# Matched 'computing' with label 'COMPUTING' at position 445-446
# Matched 'high' with label 'KEYWORD_high' at position 447-448
# Matched 'high' with label 'HIGH' at position 447-448
# Matched 'definition' with label 'KEYWORD_definition' at position 449-450
# Matched 'definition' with label 'DEFINITION' at position 449-450
# Matched 'streaming' with label 'KEYWORD_streaming' at position 451-452
# Matched 'streaming' with label 'STREAMING' at position 451-452
# Matched 'file' with label 'KEYWORD_file' at position 455-456
# Matched 'file' with label 'FILE' at position 455-456
# Matched 'transfers' with label 'KEYWORD_transfers' at position 456-457
# Matched 'transfers' with label 'TRANSFERS' at position 456-457
# Matched 'Service' with label 'KEYWORD_service' at position 461-462
# Matched 'Service' with label 'SERVICE' at position 461-462
# Matched 'Scope' with label 'KEYWORD_scope' at position 462-463
# Matched 'Scope' with label 'SCOPE' at position 462-463
# Matched 'Geographic' with label 'KEYWORD_geographic' at position 464-465
# Matched 'Geographic' with label 'GEOGRAPHIC' at position 464-465
# Matched 'Coverage' with label 'KEYWORD_coverage' at position 465-466
# Matched 'Coverage' with label 'COVERAGE' at position 465-466
# Matched 'service' with label 'KEYWORD_service' at position 468-469
# Matched 'service' with label 'SERVICE' at position 468-469
# Matched 'area' with label 'KEYWORD_area' at position 469-470
# Matched 'area' with label 'AREA' at position 469-470
# Matched 'Metropolitan' with label 'KEYWORD_metropolitan' at position 471-472
# Matched 'Metropolitan' with label 'METROPOLITAN' at position 471-472
# Matched 'Region' with label 'KEYWORD_region' at position 472-473
# Matched 'Region' with label 'REGION' at position 472-473
# Matched 'coverage' with label 'KEYWORD_coverage' at position 477-478
# Matched 'coverage' with label 'COVERAGE' at position 477-478
# Matched 'Industrial' with label 'KEYWORD_industrial' at position 479-480
# Matched 'Industrial' with label 'INDUSTRIAL' at position 479-480
# Matched 'Zone' with label 'KEYWORD_zone' at position 480-481
# Matched 'Zone' with label 'ZONE' at position 480-481
# Matched 'Specific' with label 'KEYWORD_specific' at position 482-483
# Matched 'Specific' with label 'SPECIFIC' at position 482-483
# Matched 'cell' with label 'KEYWORD_cell' at position 483-484
# Matched 'cell' with label 'CELL' at position 483-484
# Matched 'IDs' with label 'KEYWORD_ids' at position 484-485
# Matched 'IDs' with label 'IDS' at position 484-485
# Matched 'coverage' with label 'KEYWORD_coverage' at position 486-487
# Matched 'coverage' with label 'COVERAGE' at position 486-487
# Matched 'maps' with label 'KEYWORD_maps' at position 487-488
# Matched 'maps' with label 'MAPS' at position 487-488
# Matched 'Appendix' with label 'KEYWORD_appendix' at position 491-492
# Matched 'Appendix' with label 'APPENDIX' at position 491-492
# Matched 'User' with label 'KEYWORD_user' at position 494-495
# Matched 'User' with label 'USER' at position 494-495
# Matched 'Devices' with label 'KEYWORD_devices' at position 495-496
# Matched 'Devices' with label 'DEVICES' at position 495-496
# Matched 'Support' with label 'KEYWORD_support' at position 497-498
# Matched 'Support' with label 'SUPPORT' at position 497-498
# Matched 'devices' with label 'KEYWORD_devices' at position 502-503
# Matched 'devices' with label 'DEVICES' at position 502-503
# Matched 'smartphones' with label 'KEYWORD_smartphones' at position 504-505
# Matched 'smartphones' with label 'SMARTPHONES' at position 504-505
# Matched 'tablets' with label 'KEYWORD_tablets' at position 506-507
# Matched 'tablets' with label 'TABLETS' at position 506-507
# Matched 'gateways' with label 'KEYWORD_gateways' at position 509-510
# Matched 'gateways' with label 'GATEWAYS' at position 509-510
# Matched 'SIM' with label 'KEYWORD_sim' at position 514-515
# Matched 'SIM' with label 'SIM' at position 514-515
# Matched 'cards' with label 'KEYWORD_cards' at position 515-516
# Matched 'cards' with label 'CARDS' at position 515-516
# Matched 'eSIM' with label 'KEYWORD_esim' at position 517-518
# Matched 'eSIM' with label 'ESIM' at position 517-518
# Matched 'profiles' with label 'KEYWORD_profiles' at position 518-519
# Matched 'profiles' with label 'PROFILES' at position 518-519
# Matched 'NexGen' with label 'KEYWORD_nexgen' at position 521-522
# Matched 'NexGen' with label 'NEXGEN' at position 521-522
# Matched 'Telecom' with label 'KEYWORD_telecom' at position 522-523
# Matched 'Telecom' with label 'TELECOM' at position 522-523
# Matched 'Traffic' with label 'KEYWORD_traffic' at position 525-526
# Matched 'Traffic' with label 'TRAFFIC' at position 525-526
# Matched 'Prioritization' with label 'KEYWORD_prioritization' at position 526-527
# Matched 'Prioritization' with label 'PRIORITIZATION' at position 526-527
# Matched 'eMBB' with label 'KEYWORD_embb' at position 528-529
# Matched 'eMBB' with label 'EMBB' at position 528-529
# Matched 'traffic' with label 'KEYWORD_traffic' at position 529-530
# Matched 'traffic' with label 'TRAFFIC' at position 529-530
# Matched 'priority' with label 'KEYWORD_priority' at position 532-533
# Matched 'priority' with label 'PRIORITY' at position 532-533
# Matched 'effort' with label 'KEYWORD_effort' at position 536-537
# Matched 'effort' with label 'EFFORT' at position 536-537
# Matched 'traffic' with label 'KEYWORD_traffic' at position 537-538
# Matched 'traffic' with label 'TRAFFIC' at position 537-538
# Matched 'service' with label 'KEYWORD_service' at position 541-542
# Matched 'service' with label 'SERVICE' at position 541-542
# Matched 'slices' with label 'KEYWORD_slices' at position 542-543
# Matched 'slices' with label 'SLICES' at position 542-543
# Matched 'Service' with label 'KEYWORD_service' at position 547-548
# Matched 'Service' with label 'SERVICE' at position 547-548
# Matched 'Level' with label 'KEYWORD_level' at position 548-549
# Matched 'Level' with label 'LEVEL' at position 548-549
# Matched 'Objectives' with label 'KEYWORD_objectives' at position 549-550
# Matched 'Objectives' with label 'OBJECTIVES' at position 549-550
# Matched 'SLOs' with label 'KEYWORD_slos' at position 551-552
# Matched 'SLOs' with label 'SLOS' at position 551-552
# Matched 'Performance' with label 'KEYWORD_performance' at position 554-555
# Matched 'Performance' with label 'PERFORMANCE' at position 554-555
# Matched 'Metrics' with label 'KEYWORD_metrics' at position 555-556
# Matched 'Metrics' with label 'METRICS' at position 555-556
# Matched 'performance' with label 'KEYWORD_performance' at position 559-560
# Matched 'performance' with label 'PERFORMANCE' at position 559-560
# Matched 'metrics' with label 'KEYWORD_metrics' at position 560-561
# Matched 'metrics' with label 'METRICS' at position 560-561
# Matched 'service' with label 'KEYWORD_service' at position 572-573
# Matched 'service' with label 'SERVICE' at position 572-573
# Matched 'levels' with label 'KEYWORD_levels' at position 573-574
# Matched 'levels' with label 'LEVELS' at position 573-574
# Matched 'measurements' with label 'KEYWORD_measurements' at position 578-579
# Matched 'measurements' with label 'MEASUREMENTS' at position 578-579
# Matched 'data' with label 'KEYWORD_data' at position 583-584
# Matched 'data' with label 'DATA' at position 583-584
# Matched 'minute' with label 'KEYWORD_minute' at position 587-588
# Matched 'minute' with label 'MINUTE' at position 587-588
# Matched 'intervals' with label 'KEYWORD_intervals' at position 588-589
# Matched 'intervals' with label 'INTERVALS' at position 588-589
# Matched 'Throughput' with label 'KEYWORD_throughput' at position 597-598
# Matched 'Throughput' with label 'THROUGHPUT' at position 597-598
# Matched 'Downlink' with label 'KEYWORD_downlink' at position 599-600
# Matched 'Downlink' with label 'DOWNLINK' at position 599-600
# Matched 'Objective' with label 'KEYWORD_objective' at position 602-603
# Matched 'Objective' with label 'OBJECTIVE' at position 602-603
# Matched 'Average' with label 'KEYWORD_average' at position 604-605
# Matched 'Average' with label 'AVERAGE' at position 604-605
# Matched 'downlink' with label 'KEYWORD_downlink' at position 605-606
# Matched 'downlink' with label 'DOWNLINK' at position 605-606
# Matched 'throughput' with label 'KEYWORD_throughput' at position 606-607
# Matched 'throughput' with label 'THROUGHPUT' at position 606-607
# Matched 'Gbps' with label 'KEYWORD_gbps' at position 609-610
# Matched 'Gbps' with label 'GBPS' at position 609-610
# Matched 'Gigabits' with label 'KEYWORD_gigabits' at position 611-612
# Matched 'Gigabits' with label 'GIGABITS' at position 611-612
# Matched 'Minimum' with label 'KEYWORD_minimum' at position 617-618
# Matched 'Minimum' with label 'MINIMUM' at position 617-618
# Matched 'Guaranteed' with label 'KEYWORD_guaranteed' at position 618-619
# Matched 'Guaranteed' with label 'GUARANTEED' at position 618-619
# Matched 'Mbps' with label 'KEYWORD_mbps' at position 621-622
# Matched 'Mbps' with label 'MBPS' at position 621-622
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 624-625
# Matched 'Measurement' with label 'MEASUREMENT' at position 624-625
# Matched 'Point' with label 'KEYWORD_point' at position 625-626
# Matched 'Point' with label 'POINT' at position 625-626
# Matched 'User' with label 'KEYWORD_user' at position 627-628
# Matched 'User' with label 'USER' at position 627-628
# Matched 'Plane' with label 'KEYWORD_plane' at position 628-629
# Matched 'Plane' with label 'PLANE' at position 628-629
# Matched 'Function' with label 'KEYWORD_function' at position 629-630
# Matched 'Function' with label 'FUNCTION' at position 629-630
# Matched 'UPF' with label 'KEYWORD_upf' at position 631-632
# Matched 'UPF' with label 'UPF' at position 631-632
# Matched 'egress' with label 'KEYWORD_egress' at position 633-634
# Matched 'egress' with label 'EGRESS' at position 633-634
# Matched 'customer' with label 'KEYWORD_customer' at position 635-636
# Matched 'customer' with label 'CUSTOMER' at position 635-636
# Matched 'premises' with label 'KEYWORD_premises' at position 636-637
# Matched 'premises' with label 'PREMISES' at position 636-637
# Matched 'equipment' with label 'KEYWORD_equipment' at position 637-638
# Matched 'equipment' with label 'EQUIPMENT' at position 637-638
# Matched 'CPE' with label 'KEYWORD_cpe' at position 639-640
# Matched 'CPE' with label 'CPE' at position 639-640
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 643-644
# Matched 'Reporting' with label 'REPORTING' at position 643-644
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 644-645
# Matched 'Frequency' with label 'FREQUENCY' at position 644-645
# Matched 'Daily' with label 'KEYWORD_daily' at position 646-647
# Matched 'Daily' with label 'DAILY' at position 646-647
# Matched 'reports' with label 'KEYWORD_reports' at position 648-649
# Matched 'reports' with label 'REPORTS' at position 648-649
# Matched 'monthly' with label 'KEYWORD_monthly' at position 650-651
# Matched 'monthly' with label 'MONTHLY' at position 650-651
# Matched 'reports' with label 'KEYWORD_reports' at position 652-653
# Matched 'reports' with label 'REPORTS' at position 652-653
# Matched 'Throughput' with label 'KEYWORD_throughput' at position 657-658
# Matched 'Throughput' with label 'THROUGHPUT' at position 657-658
# Matched 'Uplink' with label 'KEYWORD_uplink' at position 659-660
# Matched 'Uplink' with label 'UPLINK' at position 659-660
# Matched 'Objective' with label 'KEYWORD_objective' at position 662-663
# Matched 'Objective' with label 'OBJECTIVE' at position 662-663
# Matched 'Average' with label 'KEYWORD_average' at position 664-665
# Matched 'Average' with label 'AVERAGE' at position 664-665
# Matched 'uplink' with label 'KEYWORD_uplink' at position 665-666
# Matched 'uplink' with label 'UPLINK' at position 665-666
# Matched 'throughput' with label 'KEYWORD_throughput' at position 666-667
# Matched 'throughput' with label 'THROUGHPUT' at position 666-667
# Matched 'Mbps' with label 'KEYWORD_mbps' at position 669-670
# Matched 'Mbps' with label 'MBPS' at position 669-670
# Matched 'Minimum' with label 'KEYWORD_minimum' at position 672-673
# Matched 'Minimum' with label 'MINIMUM' at position 672-673
# Matched 'Guaranteed' with label 'KEYWORD_guaranteed' at position 673-674
# Matched 'Guaranteed' with label 'GUARANTEED' at position 673-674
# Matched 'Mbps' with label 'KEYWORD_mbps' at position 676-677
# Matched 'Mbps' with label 'MBPS' at position 676-677
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 679-680
# Matched 'Measurement' with label 'MEASUREMENT' at position 679-680
# Matched 'Point' with label 'KEYWORD_point' at position 680-681
# Matched 'Point' with label 'POINT' at position 680-681
# Matched 'CPE' with label 'KEYWORD_cpe' at position 682-683
# Matched 'CPE' with label 'CPE' at position 682-683
# Matched 'ingress' with label 'KEYWORD_ingress' at position 683-684
# Matched 'ingress' with label 'INGRESS' at position 683-684
# Matched 'UPF' with label 'KEYWORD_upf' at position 685-686
# Matched 'UPF' with label 'UPF' at position 685-686
# Matched 'ingress' with label 'KEYWORD_ingress' at position 686-687
# Matched 'ingress' with label 'INGRESS' at position 686-687
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 689-690
# Matched 'Reporting' with label 'REPORTING' at position 689-690
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 690-691
# Matched 'Frequency' with label 'FREQUENCY' at position 690-691
# Matched 'Daily' with label 'KEYWORD_daily' at position 692-693
# Matched 'Daily' with label 'DAILY' at position 692-693
# Matched 'reports' with label 'KEYWORD_reports' at position 694-695
# Matched 'reports' with label 'REPORTS' at position 694-695
# Matched 'monthly' with label 'KEYWORD_monthly' at position 696-697
# Matched 'monthly' with label 'MONTHLY' at position 696-697
# Matched 'reports' with label 'KEYWORD_reports' at position 698-699
# Matched 'reports' with label 'REPORTS' at position 698-699
# Matched 'Latency' with label 'KEYWORD_latency' at position 703-704
# Matched 'Latency' with label 'LATENCY' at position 703-704
# Matched 'Round' with label 'KEYWORD_round' at position 705-706
# Matched 'Round' with label 'ROUND' at position 705-706
# Matched 'Trip' with label 'KEYWORD_trip' at position 706-707
# Matched 'Trip' with label 'TRIP' at position 706-707
# Matched 'Time' with label 'KEYWORD_time' at position 707-708
# Matched 'Time' with label 'TIME' at position 707-708
# Matched 'Objective' with label 'KEYWORD_objective' at position 712-713
# Matched 'Objective' with label 'OBJECTIVE' at position 712-713
# Matched 'Average' with label 'KEYWORD_average' at position 714-715
# Matched 'Average' with label 'AVERAGE' at position 714-715
# Matched 'end' with label 'KEYWORD_end' at position 715-716
# Matched 'end' with label 'END' at position 715-716
# Matched 'end' with label 'KEYWORD_end' at position 719-720
# Matched 'end' with label 'END' at position 719-720
# Matched 'latency' with label 'KEYWORD_latency' at position 720-721
# Matched 'latency' with label 'LATENCY' at position 720-721
# Matched 'ms' with label 'KEYWORD_ms' at position 725-726
# Matched 'ms' with label 'MS' at position 725-726
# Matched 'milliseconds' with label 'KEYWORD_milliseconds' at position 727-728
# Matched 'milliseconds' with label 'MILLISECONDS' at position 727-728
# Matched 'Maximum' with label 'KEYWORD_maximum' at position 731-732
# Matched 'Maximum' with label 'MAXIMUM' at position 731-732
# Matched 'Tolerated' with label 'KEYWORD_tolerated' at position 732-733
# Matched 'Tolerated' with label 'TOLERATED' at position 732-733
# Matched 'ms' with label 'KEYWORD_ms' at position 735-736
# Matched 'ms' with label 'MS' at position 735-736
# Matched 'traffic' with label 'KEYWORD_traffic' at position 740-741
# Matched 'traffic' with label 'TRAFFIC' at position 740-741
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 743-744
# Matched 'Measurement' with label 'MEASUREMENT' at position 743-744
# Matched 'Point' with label 'KEYWORD_point' at position 744-745
# Matched 'Point' with label 'POINT' at position 744-745
# Matched 'customer' with label 'KEYWORD_customer' at position 747-748
# Matched 'customer' with label 'CUSTOMER' at position 747-748
# Matched 'device' with label 'KEYWORD_device' at position 748-749
# Matched 'device' with label 'DEVICE' at position 748-749
# Matched 'core' with label 'KEYWORD_core' at position 751-752
# Matched 'core' with label 'CORE' at position 751-752
# Matched 'network' with label 'KEYWORD_network' at position 752-753
# Matched 'network' with label 'NETWORK' at position 752-753
# Matched 'gateway' with label 'KEYWORD_gateway' at position 753-754
# Matched 'gateway' with label 'GATEWAY' at position 753-754
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 756-757
# Matched 'Reporting' with label 'REPORTING' at position 756-757
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 757-758
# Matched 'Frequency' with label 'FREQUENCY' at position 757-758
# Matched 'Hourly' with label 'KEYWORD_hourly' at position 759-760
# Matched 'Hourly' with label 'HOURLY' at position 759-760
# Matched 'reports' with label 'KEYWORD_reports' at position 761-762
# Matched 'reports' with label 'REPORTS' at position 761-762
# Matched 'reports' with label 'KEYWORD_reports' at position 765-766
# Matched 'reports' with label 'REPORTS' at position 765-766
# Matched 'Jitter' with label 'KEYWORD_jitter' at position 770-771
# Matched 'Jitter' with label 'JITTER' at position 770-771
# Matched 'Objective' with label 'KEYWORD_objective' at position 772-773
# Matched 'Objective' with label 'OBJECTIVE' at position 772-773
# Matched 'Maximum' with label 'KEYWORD_maximum' at position 774-775
# Matched 'Maximum' with label 'MAXIMUM' at position 774-775
# Matched 'jitter' with label 'KEYWORD_jitter' at position 775-776
# Matched 'jitter' with label 'JITTER' at position 775-776
# Matched 'ms' with label 'KEYWORD_ms' at position 778-779
# Matched 'ms' with label 'MS' at position 778-779
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 781-782
# Matched 'Measurement' with label 'MEASUREMENT' at position 781-782
# Matched 'Point' with label 'KEYWORD_point' at position 782-783
# Matched 'Point' with label 'POINT' at position 782-783
# Matched 'customer' with label 'KEYWORD_customer' at position 785-786
# Matched 'customer' with label 'CUSTOMER' at position 785-786
# Matched 'device' with label 'KEYWORD_device' at position 786-787
# Matched 'device' with label 'DEVICE' at position 786-787
# Matched 'core' with label 'KEYWORD_core' at position 789-790
# Matched 'core' with label 'CORE' at position 789-790
# Matched 'network' with label 'KEYWORD_network' at position 790-791
# Matched 'network' with label 'NETWORK' at position 790-791
# Matched 'gateway' with label 'KEYWORD_gateway' at position 791-792
# Matched 'gateway' with label 'GATEWAY' at position 791-792
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 794-795
# Matched 'Reporting' with label 'REPORTING' at position 794-795
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 795-796
# Matched 'Frequency' with label 'FREQUENCY' at position 795-796
# Matched 'Hourly' with label 'KEYWORD_hourly' at position 797-798
# Matched 'Hourly' with label 'HOURLY' at position 797-798
# Matched 'reports' with label 'KEYWORD_reports' at position 799-800
# Matched 'reports' with label 'REPORTS' at position 799-800
# Matched 'reports' with label 'KEYWORD_reports' at position 803-804
# Matched 'reports' with label 'REPORTS' at position 803-804
# Matched 'Packet' with label 'KEYWORD_packet' at position 808-809
# Matched 'Packet' with label 'PACKET' at position 808-809
# Matched 'Loss' with label 'KEYWORD_loss' at position 809-810
# Matched 'Loss' with label 'LOSS' at position 809-810
# Matched 'Rate' with label 'KEYWORD_rate' at position 810-811
# Matched 'Rate' with label 'RATE' at position 810-811
# Matched 'Objective' with label 'KEYWORD_objective' at position 812-813
# Matched 'Objective' with label 'OBJECTIVE' at position 812-813
# Matched 'packet' with label 'KEYWORD_packet' at position 818-819
# Matched 'packet' with label 'PACKET' at position 818-819
# Matched 'loss' with label 'KEYWORD_loss' at position 819-820
# Matched 'loss' with label 'LOSS' at position 819-820
# Matched 'Maximum' with label 'KEYWORD_maximum' at position 822-823
# Matched 'Maximum' with label 'MAXIMUM' at position 822-823
# Matched 'Tolerated' with label 'KEYWORD_tolerated' at position 823-824
# Matched 'Tolerated' with label 'TOLERATED' at position 823-824
# Matched 'Measurement' with label 'KEYWORD_measurement' at position 829-830
# Matched 'Measurement' with label 'MEASUREMENT' at position 829-830
# Matched 'Point' with label 'KEYWORD_point' at position 830-831
# Matched 'Point' with label 'POINT' at position 830-831
# Matched 'End' with label 'KEYWORD_end' at position 832-833
# Matched 'End' with label 'END' at position 832-833
# Matched 'end' with label 'KEYWORD_end' at position 836-837
# Matched 'end' with label 'END' at position 836-837
# Matched 'G' with label 'KEYWORD_g' at position 840-841
# Matched 'G' with label 'G' at position 840-841
# Matched 'network' with label 'KEYWORD_network' at position 841-842
# Matched 'network' with label 'NETWORK' at position 841-842
# Matched 'segment' with label 'KEYWORD_segment' at position 842-843
# Matched 'segment' with label 'SEGMENT' at position 842-843
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 845-846
# Matched 'Reporting' with label 'REPORTING' at position 845-846
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 846-847
# Matched 'Frequency' with label 'FREQUENCY' at position 846-847
# Matched 'Daily' with label 'KEYWORD_daily' at position 848-849
# Matched 'Daily' with label 'DAILY' at position 848-849
# Matched 'reports' with label 'KEYWORD_reports' at position 850-851
# Matched 'reports' with label 'REPORTS' at position 850-851
# Matched 'Service' with label 'KEYWORD_service' at position 855-856
# Matched 'Service' with label 'SERVICE' at position 855-856
# Matched 'Availability' with label 'KEYWORD_availability' at position 856-857
# Matched 'Availability' with label 'AVAILABILITY' at position 856-857
# Matched 'Objective' with label 'KEYWORD_objective' at position 858-859
# Matched 'Objective' with label 'OBJECTIVE' at position 858-859
# Matched 'availability' with label 'KEYWORD_availability' at position 862-863
# Matched 'availability' with label 'AVAILABILITY' at position 862-863
# Matched 'G' with label 'KEYWORD_g' at position 866-867
# Matched 'G' with label 'G' at position 866-867
# Matched 'eMBB' with label 'KEYWORD_embb' at position 867-868
# Matched 'eMBB' with label 'EMBB' at position 867-868
# Matched 'service' with label 'KEYWORD_service' at position 868-869
# Matched 'service' with label 'SERVICE' at position 868-869
# Matched 'service' with label 'KEYWORD_service' at position 872-873
# Matched 'service' with label 'SERVICE' at position 872-873
# Matched 'area' with label 'KEYWORD_area' at position 873-874
# Matched 'area' with label 'AREA' at position 873-874
# Matched 'Definition' with label 'KEYWORD_definition' at position 876-877
# Matched 'Definition' with label 'DEFINITION' at position 876-877
# Matched 'Uptime' with label 'KEYWORD_uptime' at position 878-879
# Matched 'Uptime' with label 'UPTIME' at position 878-879
# Matched 'percentage' with label 'KEYWORD_percentage' at position 882-883
# Matched 'percentage' with label 'PERCENTAGE' at position 882-883
# Matched 'time' with label 'KEYWORD_time' at position 884-885
# Matched 'time' with label 'TIME' at position 884-885
# Matched 'service' with label 'KEYWORD_service' at position 886-887
# Matched 'service' with label 'SERVICE' at position 886-887
# Matched 'customer' with label 'KEYWORD_customer' at position 894-895
# Matched 'customer' with label 'CUSTOMER' at position 894-895
# Matched 'Planned' with label 'KEYWORD_planned' at position 896-897
# Matched 'Planned' with label 'PLANNED' at position 896-897
# Matched 'maintenance' with label 'KEYWORD_maintenance' at position 897-898
# Matched 'maintenance' with label 'MAINTENANCE' at position 897-898
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 903-904
# Matched 'Reporting' with label 'REPORTING' at position 903-904
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 904-905
# Matched 'Frequency' with label 'FREQUENCY' at position 904-905
# Matched 'Monthly' with label 'KEYWORD_monthly' at position 906-907
# Matched 'Monthly' with label 'MONTHLY' at position 906-907
# Matched 'Service' with label 'KEYWORD_service' at position 911-912
# Matched 'Service' with label 'SERVICE' at position 911-912
# Matched 'Credits' with label 'KEYWORD_credits' at position 912-913
# Matched 'Credits' with label 'CREDITS' at position 912-913
# Matched 'Penalties' with label 'KEYWORD_penalties' at position 914-915
# Matched 'Penalties' with label 'PENALTIES' at position 914-915
# Matched 'event' with label 'KEYWORD_event' at position 918-919
# Matched 'event' with label 'EVENT' at position 918-919
# Matched 'NexGen' with label 'KEYWORD_nexgen' at position 920-921
# Matched 'NexGen' with label 'NEXGEN' at position 920-921
# Matched 'Telecom' with label 'KEYWORD_telecom' at position 921-922
# Matched 'Telecom' with label 'TELECOM' at position 921-922
# Matched 'Service' with label 'KEYWORD_service' at position 930-931
# Matched 'Service' with label 'SERVICE' at position 930-931
# Matched 'Level' with label 'KEYWORD_level' at position 931-932
# Matched 'Level' with label 'LEVEL' at position 931-932
# Matched 'Objectives' with label 'KEYWORD_objectives' at position 932-933
# ...
# Matched 'days' with label 'KEYWORD_days' at position 1839-1840
# Matched 'days' with label 'DAYS' at position 1839-1840
# Matched 'notice' with label 'KEYWORD_notice' at position 1841-1842
# Matched 'notice' with label 'NOTICE' at position 1841-1842
# Matched 'Governing' with label 'KEYWORD_governing' at position 1847-1848
# Matched 'Governing' with label 'GOVERNING' at position 1847-1848
# Matched 'Law' with label 'KEYWORD_law' at position 1848-1849
# Matched 'Law' with label 'LAW' at position 1848-1849
# Matched 'Jurisdiction' with label 'KEYWORD_jurisdiction' at position 1851-1852
# Matched 'Jurisdiction' with label 'JURISDICTION' at position 1851-1852
# Matched 'Amendments' with label 'KEYWORD_amendments' at position 1854-1855
# Matched 'Amendments' with label 'AMENDMENTS' at position 1854-1855
# Matched 'writing' with label 'KEYWORD_writing' at position 1859-1860
# Matched 'writing' with label 'WRITING' at position 1859-1860
# Matched 'parties' with label 'KEYWORD_parties' at position 1864-1865
# Matched 'parties' with label 'PARTIES' at position 1864-1865
# Matched 'Confidentiality' with label 'KEYWORD_confidentiality' at position 1866-1867
# Matched 'Confidentiality' with label 'CONFIDENTIALITY' at position 1866-1867
# Matched 'parties' with label 'KEYWORD_parties' at position 1869-1870
# Matched 'parties' with label 'PARTIES' at position 1869-1870
# Matched 'confidentiality' with label 'KEYWORD_confidentiality' at position 1873-1874
# Matched 'confidentiality' with label 'CONFIDENTIALITY' at position 1873-1874
# Matched 'SLA' with label 'KEYWORD_sla' at position 1875-1876
# Matched 'SLA' with label 'SLA' at position 1875-1876
# Matched 'terms' with label 'KEYWORD_terms' at position 1876-1877
# Matched 'terms' with label 'TERMS' at position 1876-1877
# Matched 'G' with label 'KEYWORD_g' at position 1881-1882
# Matched 'G' with label 'G' at position 1881-1882
# Matched 'Service' with label 'KEYWORD_service' at position 1882-1883
# Matched 'Service' with label 'SERVICE' at position 1882-1883
# Matched 'Level' with label 'KEYWORD_level' at position 1883-1884
# Matched 'Level' with label 'LEVEL' at position 1883-1884
# Matched 'Agreement' with label 'KEYWORD_agreement' at position 1884-1885
# Matched 'Agreement' with label 'AGREEMENT' at position 1884-1885
# Matched 'SLA' with label 'KEYWORD_sla' at position 1886-1887
# Matched 'SLA' with label 'SLA' at position 1886-1887
# Matched 'General' with label 'KEYWORD_general' at position 1895-1896
# Matched 'General' with label 'GENERAL' at position 1895-1896
# Matched 'Information' with label 'KEYWORD_information' at position 1896-1897
# Matched 'Information' with label 'INFORMATION' at position 1896-1897
# Matched 'AgreementID' with label 'KEYWORD_agreementid' at position 1903-1904
# Matched 'AgreementID' with label 'AGREEMENTID' at position 1903-1904
# Matched 'Provider' with label 'KEYWORD_provider' at position 1912-1913
# Matched 'Provider' with label 'PROVIDER' at position 1912-1913
# Matched 'NextGen' with label 'KEYWORD_nextgen' at position 1916-1917
# Matched 'NextGen' with label 'NEXTGEN' at position 1916-1917
# Matched 'Mobile' with label 'KEYWORD_mobile' at position 1917-1918
# Matched 'Mobile' with label 'MOBILE' at position 1917-1918
# Matched 'Networks' with label 'KEYWORD_networks' at position 1918-1919
# Matched 'Networks' with label 'NETWORKS' at position 1918-1919
# Matched 'Customer' with label 'KEYWORD_customer' at position 1923-1924
# Matched 'Customer' with label 'CUSTOMER' at position 1923-1924
# Matched 'Acme' with label 'KEYWORD_acme' at position 1927-1928
# Matched 'Acme' with label 'ACME' at position 1927-1928
# Matched 'Corp' with label 'KEYWORD_corp' at position 1928-1929
# Matched 'Corp' with label 'CORP' at position 1928-1929
# Matched 'ServiceName' with label 'KEYWORD_servicename' at position 1933-1934
# Matched 'ServiceName' with label 'SERVICENAME' at position 1933-1934
# Matched 'G' with label 'KEYWORD_g' at position 1938-1939
# Matched 'G' with label 'G' at position 1938-1939
# Matched 'Enhanced' with label 'KEYWORD_enhanced' at position 1939-1940
# Matched 'Enhanced' with label 'ENHANCED' at position 1939-1940
# Matched 'Mobile' with label 'KEYWORD_mobile' at position 1940-1941
# Matched 'Mobile' with label 'MOBILE' at position 1940-1941
# Matched 'Broadband' with label 'KEYWORD_broadband' at position 1941-1942
# Matched 'Broadband' with label 'BROADBAND' at position 1941-1942
# Matched 'eMBB' with label 'KEYWORD_embb' at position 1943-1944
# Matched 'eMBB' with label 'EMBB' at position 1943-1944
# Matched 'EffectiveDate' with label 'KEYWORD_effectivedate' at position 1949-1950
# Matched 'EffectiveDate' with label 'EFFECTIVEDATE' at position 1949-1950
# Matched 'ExpirationDate' with label 'KEYWORD_expirationdate' at position 1962-1963
# Matched 'ExpirationDate' with label 'EXPIRATIONDATE' at position 1962-1963
# Matched 'Service' with label 'KEYWORD_service' at position 1976-1977
# Matched 'Service' with label 'SERVICE' at position 1976-1977
# Matched 'Scope' with label 'KEYWORD_scope' at position 1977-1978
# Matched 'Scope' with label 'SCOPE' at position 1977-1978
# Matched 'CoverageArea' with label 'KEYWORD_coveragearea' at position 1984-1985
# Matched 'CoverageArea' with label 'COVERAGEAREA' at position 1984-1985
# Matched 'zones' with label 'KEYWORD_zones' at position 1991-1992
# Matched 'zones' with label 'ZONES' at position 1991-1992
# Matched 'Region' with label 'KEYWORD_region' at position 1993-1994
# Matched 'Region' with label 'REGION' at position 1993-1994
# Matched 'SupportedDevices' with label 'KEYWORD_supporteddevices' at position 2000-2001
# Matched 'SupportedDevices' with label 'SUPPORTEDDEVICES' at position 2000-2001
# Matched 'Release' with label 'KEYWORD_release' at position 2005-2006
# Matched 'Release' with label 'RELEASE' at position 2005-2006
# Matched 'devices' with label 'KEYWORD_devices' at position 2008-2009
# Matched 'devices' with label 'DEVICES' at position 2008-2009
# Matched 'UseCases' with label 'KEYWORD_usecases' at position 2013-2014
# Matched 'UseCases' with label 'USECASES' at position 2013-2014
# Matched 'streaming' with label 'KEYWORD_streaming' at position 2018-2019
# Matched 'streaming' with label 'STREAMING' at position 2018-2019
# Matched 'AR' with label 'KEYWORD_ar' at position 2020-2021
# Matched 'AR' with label 'AR' at position 2020-2021
# Matched 'industrial' with label 'KEYWORD_industrial' at position 2024-2025
# Matched 'industrial' with label 'INDUSTRIAL' at position 2024-2025
# Matched 'Performance' with label 'KEYWORD_performance' at position 2031-2032
# Matched 'Performance' with label 'PERFORMANCE' at position 2031-2032
# Matched 'Metrics' with label 'KEYWORD_metrics' at position 2032-2033
# Matched 'Metrics' with label 'METRICS' at position 2032-2033
# Matched 'Availability' with label 'KEYWORD_availability' at position 2039-2040
# Matched 'Availability' with label 'AVAILABILITY' at position 2039-2040
# Matched 'Target' with label 'KEYWORD_target' at position 2047-2048
# Matched 'Target' with label 'TARGET' at position 2047-2048
# Matched 'MeasurementPeriod' with label 'KEYWORD_measurementperiod' at position 2057-2058
# Matched 'MeasurementPeriod' with label 'MEASUREMENTPERIOD' at position 2057-2058
# Matched 'Monthly' with label 'KEYWORD_monthly' at position 2061-2062
# Matched 'Monthly' with label 'MONTHLY' at position 2061-2062
# Matched 'Latency' with label 'KEYWORD_latency' at position 2066-2067
# Matched 'Latency' with label 'LATENCY' at position 2066-2067
# Matched 'Target' with label 'KEYWORD_target' at position 2074-2075
# Matched 'Target' with label 'TARGET' at position 2074-2075
# Matched 'ms' with label 'KEYWORD_ms' at position 2080-2081
# Matched 'ms' with label 'MS' at position 2080-2081
# Matched 'edge' with label 'KEYWORD_edge' at position 2082-2083
# Matched 'edge' with label 'EDGE' at position 2082-2083
# Matched 'edge' with label 'KEYWORD_edge' at position 2086-2087
# Matched 'edge' with label 'EDGE' at position 2086-2087
# Matched 'MeasurementPeriod' with label 'KEYWORD_measurementperiod' at position 2092-2093
# Matched 'MeasurementPeriod' with label 'MEASUREMENTPERIOD' at position 2092-2093
# Matched 'Throughput' with label 'KEYWORD_throughput' at position 2101-2102
# Matched 'Throughput' with label 'THROUGHPUT' at position 2101-2102
# Matched 'Downlink' with label 'KEYWORD_downlink' at position 2109-2110
# Matched 'Downlink' with label 'DOWNLINK' at position 2109-2110
# Matched 'Gbps' with label 'KEYWORD_gbps' at position 2115-2116
# Matched 'Gbps' with label 'GBPS' at position 2115-2116
# Matched 'Uplink' with label 'KEYWORD_uplink' at position 2120-2121
# Matched 'Uplink' with label 'UPLINK' at position 2120-2121
# Matched 'Mbps' with label 'KEYWORD_mbps' at position 2126-2127
# Matched 'Mbps' with label 'MBPS' at position 2126-2127
# Matched 'MeasurementPeriod' with label 'KEYWORD_measurementperiod' at position 2131-2132
# Matched 'MeasurementPeriod' with label 'MEASUREMENTPERIOD' at position 2131-2132
# Matched 'Peak' with label 'KEYWORD_peak' at position 2135-2136
# Matched 'Peak' with label 'PEAK' at position 2135-2136
# Matched 'hours' with label 'KEYWORD_hours' at position 2136-2137
# Matched 'hours' with label 'HOURS' at position 2136-2137
# Matched 'time' with label 'KEYWORD_time' at position 2140-2141
# Matched 'time' with label 'TIME' at position 2140-2141
# Matched 'Jitter' with label 'KEYWORD_jitter' at position 2146-2147
# Matched 'Jitter' with label 'JITTER' at position 2146-2147
# Matched 'Target' with label 'KEYWORD_target' at position 2154-2155
# Matched 'Target' with label 'TARGET' at position 2154-2155
# Matched 'Fault' with label 'KEYWORD_fault' at position 2165-2166
# Matched 'Fault' with label 'FAULT' at position 2165-2166
# Matched 'Management' with label 'KEYWORD_management' at position 2166-2167
# Matched 'Management' with label 'MANAGEMENT' at position 2166-2167
# Matched 'IncidentResponseTime' with label 'KEYWORD_incidentresponsetime' at position 2173-2174
# Matched 'IncidentResponseTime' with label 'INCIDENTRESPONSETIME' at position 2173-2174
# Matched 'minutes' with label 'KEYWORD_minutes' at position 2179-2180
# Matched 'minutes' with label 'MINUTES' at position 2179-2180
# Matched 'IncidentResolutionTime' with label 'KEYWORD_incidentresolutiontime' at position 2184-2185
# Matched 'IncidentResolutionTime' with label 'INCIDENTRESOLUTIONTIME' at position 2184-2185
# Matched 'hours' with label 'KEYWORD_hours' at position 2190-2191
# Matched 'hours' with label 'HOURS' at position 2190-2191
# Matched 'Priority' with label 'KEYWORD_priority' at position 2192-2193
# Matched 'Priority' with label 'PRIORITY' at position 2192-2193
# Matched 'incidents' with label 'KEYWORD_incidents' at position 2194-2195
# Matched 'incidents' with label 'INCIDENTS' at position 2194-2195
# Matched 'Monitoring' with label 'KEYWORD_monitoring' at position 2200-2201
# Matched 'Monitoring' with label 'MONITORING' at position 2200-2201
# Matched 'monitoring' with label 'KEYWORD_monitoring' at position 2206-2207
# Matched 'monitoring' with label 'MONITORING' at position 2206-2207
# Matched 'Penalties' with label 'KEYWORD_penalties' at position 2212-2213
# Matched 'Penalties' with label 'PENALTIES' at position 2212-2213
# Matched 'Remedies' with label 'KEYWORD_remedies' at position 2214-2215
# Matched 'Remedies' with label 'REMEDIES' at position 2214-2215
# Matched 'AvailabilityBreach' with label 'KEYWORD_availabilitybreach' at position 2221-2222
# Matched 'AvailabilityBreach' with label 'AVAILABILITYBREACH' at position 2221-2222
# Matched 'Threshold' with label 'KEYWORD_threshold' at position 2229-2230
# Matched 'Threshold' with label 'THRESHOLD' at position 2229-2230
# Matched 'Credit' with label 'KEYWORD_credit' at position 2240-2241
# Matched 'Credit' with label 'CREDIT' at position 2240-2241
# Matched 'monthly' with label 'KEYWORD_monthly' at position 2246-2247
# Matched 'monthly' with label 'MONTHLY' at position 2246-2247
# Matched 'fee' with label 'KEYWORD_fee' at position 2247-2248
# Matched 'fee' with label 'FEE' at position 2247-2248
# Matched 'refund' with label 'KEYWORD_refund' at position 2248-2249
# Matched 'refund' with label 'REFUND' at position 2248-2249
# Matched 'LatencyBreach' with label 'KEYWORD_latencybreach' at position 2253-2254
# Matched 'LatencyBreach' with label 'LATENCYBREACH' at position 2253-2254
# Matched 'Threshold' with label 'KEYWORD_threshold' at position 2261-2262
# Matched 'Threshold' with label 'THRESHOLD' at position 2261-2262
# Matched 'ms' with label 'KEYWORD_ms' at position 2267-2268
# Matched 'ms' with label 'MS' at position 2267-2268
# Matched 'average' with label 'KEYWORD_average' at position 2268-2269
# Matched 'average' with label 'AVERAGE' at position 2268-2269
# Matched 'Credit' with label 'KEYWORD_credit' at position 2276-2277
# Matched 'Credit' with label 'CREDIT' at position 2276-2277
# Matched 'monthly' with label 'KEYWORD_monthly' at position 2282-2283
# Matched 'monthly' with label 'MONTHLY' at position 2282-2283
# Matched 'fee' with label 'KEYWORD_fee' at position 2283-2284
# Matched 'fee' with label 'FEE' at position 2283-2284
# Matched 'refund' with label 'KEYWORD_refund' at position 2284-2285
# Matched 'refund' with label 'REFUND' at position 2284-2285
# Matched 'monthly' with label 'KEYWORD_monthly' at position 2296-2297
# Matched 'monthly' with label 'MONTHLY' at position 2296-2297
# Matched 'fee' with label 'KEYWORD_fee' at position 2297-2298
# Matched 'fee' with label 'FEE' at position 2297-2298
# Matched 'Reporting' with label 'KEYWORD_reporting' at position 2303-2304
# Matched 'Reporting' with label 'REPORTING' at position 2303-2304
# Matched 'Frequency' with label 'KEYWORD_frequency' at position 2310-2311
# Matched 'Frequency' with label 'FREQUENCY' at position 2310-2311
# Matched 'Monthly' with label 'KEYWORD_monthly' at position 2314-2315
# Matched 'Monthly' with label 'MONTHLY' at position 2314-2315
# Matched 'Format' with label 'KEYWORD_format' at position 2319-2320
# Matched 'Format' with label 'FORMAT' at position 2319-2320
# Matched 'PDF' with label 'KEYWORD_pdf' at position 2323-2324
# Matched 'PDF' with label 'PDF' at position 2323-2324
# Matched 'DeliveryMethod' with label 'KEYWORD_deliverymethod' at position 2330-2331
# Matched 'DeliveryMethod' with label 'DELIVERYMETHOD' at position 2330-2331
# Matched 'Email' with label 'KEYWORD_email' at position 2334-2335
# Matched 'Email' with label 'EMAIL' at position 2334-2335
# Matched 'customer' with label 'KEYWORD_customer' at position 2336-2337
# Matched 'customer' with label 'CUSTOMER' at position 2336-2337
# Matched 'recipient' with label 'KEYWORD_recipient' at position 2339-2340
# Matched 'recipient' with label 'RECIPIENT' at position 2339-2340
# Matched 'Contact' with label 'KEYWORD_contact' at position 2345-2346
# Matched 'Contact' with label 'CONTACT' at position 2345-2346
# Matched 'Information' with label 'KEYWORD_information' at position 2346-2347
# Matched 'Information' with label 'INFORMATION' at position 2346-2347
# Matched 'ProviderSupportEmail' with label 'KEYWORD_providersupportemail' at position 2353-2354
# Matched 'ProviderSupportEmail' with label 'PROVIDERSUPPORTEMAIL' at position 2353-2354
# Matched 'CustomerContact' with label 'KEYWORD_customercontact' at position 2379-2380
# Matched 'CustomerContact' with label 'CUSTOMERCONTACT' at position 2379-2380
# Matched 'Terms' with label 'KEYWORD_terms' at position 2391-2392
# Matched 'Terms' with label 'TERMS' at position 2391-2392
# Matched 'Termination' with label 'KEYWORD_termination' at position 2393-2394
# Matched 'Termination' with label 'TERMINATION' at position 2393-2394
# Matched 'TerminationNoticePeriod' with label 'KEYWORD_terminationnoticeperiod' at position 2400-2401
# Matched 'TerminationNoticePeriod' with label 'TERMINATIONNOTICEPERIOD' at position 2400-2401
# Matched 'days' with label 'KEYWORD_days' at position 2405-2406
# Matched 'days' with label 'DAYS' at position 2405-2406
# Matched 'Renewal' with label 'KEYWORD_renewal' at position 2410-2411
# Matched 'Renewal' with label 'RENEWAL' at position 2410-2411
# Matched 'Auto' with label 'KEYWORD_auto' at position 2414-2415
# Matched 'Auto' with label 'AUTO' at position 2414-2415
# Matched 'renewal' with label 'KEYWORD_renewal' at position 2416-2417
# Matched 'renewal' with label 'RENEWAL' at position 2416-2417

# %%
# Optional: define custom overrides for certain proper nouns
custom_lemma_map = {
    "Licensor": "license",
    "Licensee": "license"
}

# Print tokens and their lemmas
for token in doc:
    if token.text in custom_lemma_map:
        lemma = custom_lemma_map[token.text]
    else:
        lemma = token.lemma_
    print(f"Token: {token.text} -> Lemma: {lemma}")
# Out:
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: SERVICE -> Lemma: service
# Token: LEVEL -> Lemma: level
# Token: AGREEMENT -> Lemma: AGREEMENT
# Token: ( -> Lemma: (
# Token: SLA -> Lemma: SLA
# Token: ) -> Lemma: )
# Token:
#  -> Lemma:
#
# Token: Service -> Lemma: Service
# Token: Provider -> Lemma: Provider
# Token: : -> Lemma: :
# Token: Telco -> Lemma: Telco
# Token: Solutions -> Lemma: Solutions
# Token: Inc. -> Lemma: Inc.
# Token:
#  -> Lemma:
#
# Token: Customer -> Lemma: customer
# Token: : -> Lemma: :
# Token: Enterprise -> Lemma: Enterprise
# Token: Client -> Lemma: Client
# Token: Ltd. -> Lemma: Ltd.
# Token:
#  -> Lemma:
#
# Token: Effective -> Lemma: Effective
# Token: Date -> Lemma: Date
# Token: : -> Lemma: :
# Token: 01 -> Lemma: 01
# Token: - -> Lemma: -
# Token: Oct-2025 -> Lemma: Oct-2025
# Token:
#  -> Lemma:
#
# Token: Review -> Lemma: Review
# Token: Cycle -> Lemma: cycle
# Token: : -> Lemma: :
# Token: Quarterly -> Lemma: Quarterly
# Token:
#
#  -> Lemma:
#
#
# Token: 1 -> Lemma: 1
# Token: . -> Lemma: .
# Token: SERVICE -> Lemma: service
# Token: AVAILABILITY -> Lemma: AVAILABILITY
# Token:
#  -> Lemma:
#
# Token: Target -> Lemma: Target
# Token: : -> Lemma: :
# Token: 99.95 -> Lemma: 99.95
# Token: % -> Lemma: %
# Token: monthly -> Lemma: monthly
# Token: uptime -> Lemma: uptime
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: : -> Lemma: :
# Token:
#
#  -> Lemma:
#
#
# Token: Exclusions -> Lemma: exclusion
# Token: : -> Lemma: :
# Token: Scheduled -> Lemma: schedule
# Token: maintenance -> Lemma: maintenance
# Token: ( -> Lemma: (
# Token: max -> Lemma: max
# Token: 4hrs -> Lemma: 4hrs
# Token: / -> Lemma: /
# Token: month -> Lemma: month
# Token: , -> Lemma: ,
# Token: notified -> Lemma: notify
# Token: 72hrs -> Lemma: 72hrs
# Token: in -> Lemma: in
# Token: advance -> Lemma: advance
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Formula -> Lemma: formula
# Token: : -> Lemma: :
# Token: ( -> Lemma: (
# Token: Total -> Lemma: Total
# Token: Minutes -> Lemma: Minutes
# Token: - -> Lemma: -
# Token: Downtime -> Lemma: Downtime
# Token: ) -> Lemma: )
# Token: / -> Lemma: /
# Token: Total -> Lemma: Total
# Token: Minutes -> Lemma: Minutes
# Token:
#
#  -> Lemma:
#
#
# Token: Penalty -> Lemma: Penalty
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: per -> Lemma: per
# Token: 0.1 -> Lemma: 0.1
# Token: % -> Lemma: %
# Token: below -> Lemma: below
# Token: target -> Lemma: target
# Token:
#
#  -> Lemma:
#
#
# Token: 2 -> Lemma: 2
# Token: . -> Lemma: .
# Token: NETWORK -> Lemma: NETWORK
# Token: LATENCY -> Lemma: LATENCY
# Token:
#  -> Lemma:
#
# Token: Target -> Lemma: Target
# Token: : -> Lemma: :
# Token: ≤20ms -> Lemma: ≤20ms
# Token: end -> Lemma: end
# Token: - -> Lemma: -
# Token: to -> Lemma: to
# Token: - -> Lemma: -
# Token: end -> Lemma: end
# Token: ( -> Lemma: (
# Token: UE -> Lemma: UE
# Token: to -> Lemma: to
# Token: Core -> Lemma: Core
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Scope -> Lemma: scope
# Token: : -> Lemma: :
# Token: Urban -> Lemma: urban
# Token: zones -> Lemma: zone
# Token: ( -> Lemma: (
# Token: per -> Lemma: per
# Token: coverage -> Lemma: coverage
# Token: map -> Lemma: map
# Token: in -> Lemma: in
# Token: Appendix -> Lemma: Appendix
# Token: A -> Lemma: A
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: : -> Lemma: :
# Token: 95th -> Lemma: 95th
# Token: percentile -> Lemma: percentile
# Token: of -> Lemma: of
# Token: hourly -> Lemma: hourly
# Token: probes -> Lemma: probe
# Token:
#
#  -> Lemma:
#
#
# Token: Penalty -> Lemma: Penalty
# Token: : -> Lemma: :
# Token: 3 -> Lemma: 3
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: per -> Lemma: per
# Token: 1ms -> Lemma: 1ms
# Token: sustained -> Lemma: sustained
# Token: breach -> Lemma: breach
# Token:
#
#  -> Lemma:
#
#
# Token: 3 -> Lemma: 3
# Token: . -> Lemma: .
# Token: DOWNLINK -> Lemma: DOWNLINK
# Token: THROUGHPUT -> Lemma: THROUGHPUT
# Token:
#  -> Lemma:
#
# Token: Target -> Lemma: Target
# Token: : -> Lemma: :
# Token: ≥500 -> Lemma: ≥500
# Token: Mbps -> Lemma: Mbps
# Token: peak -> Lemma: peak
# Token: / -> Lemma: /
# Token: ≥200 -> Lemma: ≥200
# Token: Mbps -> Lemma: Mbps
# Token: average -> Lemma: average
# Token: per -> Lemma: per
# Token: device -> Lemma: device
# Token:
#
#  -> Lemma:
#
#
# Token: Conditions -> Lemma: condition
# Token: : -> Lemma: :
# Token: Non -> Lemma: non
# Token: - -> Lemma: -
# Token: congested -> Lemma: congested
# Token: network -> Lemma: network
# Token: , -> Lemma: ,
# Token: < -> Lemma: <
# Token: 50 -> Lemma: 50
# Token: concurrently -> Lemma: concurrently
# Token: active -> Lemma: active
# Token: UEs -> Lemma: ue
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: : -> Lemma: :
# Token: Daily -> Lemma: daily
# Token: speed -> Lemma: speed
# Token: tests -> Lemma: test
# Token: ( -> Lemma: (
# Token: 9 -> Lemma: 9
# Token: AM–5 -> Lemma: am–5
# Token: PM -> Lemma: pm
# Token: , -> Lemma: ,
# Token: workdays -> Lemma: workday
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Penalty -> Lemma: penalty
# Token: : -> Lemma: :
# Token: 2 -> Lemma: 2
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: per -> Lemma: per
# Token: 10 -> Lemma: 10
# Token: % -> Lemma: %
# Token: deviation -> Lemma: deviation
# Token:
#
#  -> Lemma:
#
#
# Token: 4 -> Lemma: 4
# Token: . -> Lemma: .
# Token: RELIABILITY -> Lemma: RELIABILITY
# Token:
#  -> Lemma:
#
# Token: Target -> Lemma: Target
# Token: : -> Lemma: :
# Token: ≤0.001 -> Lemma: ≤0.001
# Token: % -> Lemma: %
# Token: packet -> Lemma: packet
# Token: loss -> Lemma: loss
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: : -> Lemma: :
# Token: ICMP -> Lemma: ICMP
# Token: probes -> Lemma: probe
# Token: every -> Lemma: every
# Token: 5 -> Lemma: 5
# Token: minutes -> Lemma: minute
# Token:
#
#  -> Lemma:
#
#
# Token: Penalty -> Lemma: Penalty
# Token: : -> Lemma: :
# Token: 4 -> Lemma: 4
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: per -> Lemma: per
# Token: 0.0005 -> Lemma: 0.0005
# Token: % -> Lemma: %
# Token: breach -> Lemma: breach
# Token:
#
#  -> Lemma:
#
#
# Token: 5 -> Lemma: 5
# Token: . -> Lemma: .
# Token: FAULT -> Lemma: FAULT
# Token: RESTORATION -> Lemma: RESTORATION
# Token:
#  -> Lemma:
#
# Token: Critical -> Lemma: Critical
# Token: Faults -> Lemma: fault
# Token: : -> Lemma: :
# Token: ≤4 -> Lemma: ≤4
# Token: hours -> Lemma: hour
# Token:
#
#  -> Lemma:
#
#
# Token: Non -> Lemma: non
# Token: - -> Lemma: -
# Token: Critical -> Lemma: critical
# Token: Faults -> Lemma: fault
# Token: : -> Lemma: :
# Token: ≤24 -> Lemma: ≤24
# Token: hours -> Lemma: hour
# Token:
#
#  -> Lemma:
#
#
# Token: Penalty -> Lemma: Penalty
# Token: : -> Lemma: :
# Token: $ -> Lemma: $
# Token: 500 -> Lemma: 500
# Token: / -> Lemma: /
# Token: hour -> Lemma: hour
# Token: delay -> Lemma: delay
# Token: beyond -> Lemma: beyond
# Token: target -> Lemma: target
# Token:
#
#  -> Lemma:
#
#
# Token: 6 -> Lemma: 6
# Token: . -> Lemma: .
# Token: REPORTING -> Lemma: REPORTING
# Token: & -> Lemma: &
# Token: SUPPORT -> Lemma: SUPPORT
# Token:
#  -> Lemma:
#
# Token: KPI -> Lemma: KPI
# Token: Reports -> Lemma: report
# Token: : -> Lemma: :
# Token: Monthly -> Lemma: Monthly
# Token: ( -> Lemma: (
# Token: by -> Lemma: by
# Token: 5th -> Lemma: 5th
# Token: of -> Lemma: of
# Token: next -> Lemma: next
# Token: month -> Lemma: month
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Support -> Lemma: support
# Token: : -> Lemma: :
# Token: 24/7 -> Lemma: 24/7
# Token: helpdesk -> Lemma: helpdesk
# Token: ( -> Lemma: (
# Token: max -> Lemma: max
# Token: 15 -> Lemma: 15
# Token: - -> Lemma: -
# Token: min -> Lemma: min
# Token: response -> Lemma: response
# Token: for -> Lemma: for
# Token: P1 -> Lemma: P1
# Token: tickets -> Lemma: ticket
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Audit -> Lemma: Audit
# Token: Rights -> Lemma: Rights
# Token: : -> Lemma: :
# Token: Customer -> Lemma: customer
# Token: may -> Lemma: may
# Token: request -> Lemma: request
# Token: measurement -> Lemma: measurement
# Token: logs -> Lemma: log
# Token: quarterly -> Lemma: quarterly
# Token:
#
#  -> Lemma:
#
#
# Token: 7 -> Lemma: 7
# Token: . -> Lemma: .
# Token: SERVICE -> Lemma: service
# Token: CREDITS -> Lemma: CREDITS
# Token:
#  -> Lemma:
#
# Token: Max -> Lemma: Max
# Token: Annual -> Lemma: Annual
# Token: Credit -> Lemma: Credit
# Token: : -> Lemma: :
# Token: 20 -> Lemma: 20
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token:
#
#  -> Lemma:
#
#
# Token: Claim -> Lemma: Claim
# Token: Window -> Lemma: Window
# Token: : -> Lemma: :
# Token: 30 -> Lemma: 30
# Token: days -> Lemma: day
# Token: from -> Lemma: from
# Token: report -> Lemma: report
# Token: receipt -> Lemma: receipt
# Token:
#
#  -> Lemma:
#
#
# Token: Service -> Lemma: Service
# Token: Level -> Lemma: Level
# Token: Agreement -> Lemma: Agreement
# Token: ( -> Lemma: (
# Token: SLA -> Lemma: SLA
# Token: ) -> Lemma: )
# Token: - -> Lemma: -
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: Enhanced -> Lemma: Enhanced
# Token: Mobile -> Lemma: Mobile
# Token: Broadband -> Lemma: Broadband
# Token: ( -> Lemma: (
# Token: eMBB -> Lemma: eMBB
# Token: ) -> Lemma: )
# Token: Service -> Lemma: Service
# Token:
#
#  -> Lemma:
#
#
# Token: Agreement -> Lemma: Agreement
# Token: ID -> Lemma: ID
# Token: : -> Lemma: :
# Token: SLA-5G -> Lemma: SLA-5G
# Token: - -> Lemma: -
# Token: eMBB-001 -> Lemma: embb-001
# Token: - -> Lemma: -
# Token: 20250626 -> Lemma: 20250626
# Token:
#  -> Lemma:
#
# Token: Effective -> Lemma: Effective
# Token: Date -> Lemma: date
# Token: : -> Lemma: :
# Token: 2025 -> Lemma: 2025
# Token: - -> Lemma: -
# Token: 07 -> Lemma: 07
# Token: - -> Lemma: -
# Token: 01 -> Lemma: 01
# Token:
#  -> Lemma:
#
# Token: Service -> Lemma: Service
# Token: Provider -> Lemma: Provider
# Token: : -> Lemma: :
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token:
#  -> Lemma:
#
# Token: Customer -> Lemma: customer
# Token: : -> Lemma: :
# Token: Enterprise -> Lemma: Enterprise
# Token: Solutions -> Lemma: Solutions
# Token: Corp. -> Lemma: Corp.
# Token:
#  -> Lemma:
#
# Token: Service -> Lemma: Service
# Token: Type -> Lemma: Type
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: Enhanced -> Lemma: Enhanced
# Token: Mobile -> Lemma: Mobile
# Token: Broadband -> Lemma: Broadband
# Token: ( -> Lemma: (
# Token: eMBB -> Lemma: eMBB
# Token: ) -> Lemma: )
# Token: - -> Lemma: -
# Token: High -> Lemma: High
# Token: - -> Lemma: -
# Token: Capacity -> Lemma: Capacity
# Token: Data -> Lemma: Data
# Token: Service -> Lemma: Service
# Token:
#
#  -> Lemma:
#
#
# Token: 1 -> Lemma: 1
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Description -> Lemma: Description
# Token:
#
#  -> Lemma:
#
#
# Token: This -> Lemma: this
# Token: SLA -> Lemma: SLA
# Token: outlines -> Lemma: outline
# Token: the -> Lemma: the
# Token: terms -> Lemma: term
# Token: and -> Lemma: and
# Token: conditions -> Lemma: condition
# Token: for -> Lemma: for
# Token: the -> Lemma: the
# Token: provision -> Lemma: provision
# Token: of -> Lemma: of
# Token: a -> Lemma: a
# Token: dedicated -> Lemma: dedicated
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: Enhanced -> Lemma: enhanced
# Token: Mobile -> Lemma: Mobile
# Token: Broadband -> Lemma: Broadband
# Token: ( -> Lemma: (
# Token: eMBB -> Lemma: eMBB
# Token: ) -> Lemma: )
# Token: service -> Lemma: service
# Token: to -> Lemma: to
# Token: Enterprise -> Lemma: Enterprise
# Token: Solutions -> Lemma: Solutions
# Token: Corp. -> Lemma: Corp.
# Token: This -> Lemma: this
# Token: service -> Lemma: service
# Token: is -> Lemma: be
# Token: designed -> Lemma: design
# Token: to -> Lemma: to
# Token: deliver -> Lemma: deliver
# Token: high -> Lemma: high
# Token: - -> Lemma: -
# Token: throughput -> Lemma: throughput
# Token: , -> Lemma: ,
# Token: low -> Lemma: low
# Token: - -> Lemma: -
# Token: latency -> Lemma: latency
# Token: connectivity -> Lemma: connectivity
# Token: primarily -> Lemma: primarily
# Token: for -> Lemma: for
# Token: data -> Lemma: data
# Token: - -> Lemma: -
# Token: intensive -> Lemma: intensive
# Token: applications -> Lemma: application
# Token: , -> Lemma: ,
# Token: including -> Lemma: include
# Token: but -> Lemma: but
# Token: not -> Lemma: not
# Token: limited -> Lemma: limit
# Token: to -> Lemma: to
# Token: , -> Lemma: ,
# Token: cloud -> Lemma: cloud
# Token: computing -> Lemma: computing
# Token: , -> Lemma: ,
# Token: high -> Lemma: high
# Token: - -> Lemma: -
# Token: definition -> Lemma: definition
# Token: video -> Lemma: video
# Token: streaming -> Lemma: streaming
# Token: , -> Lemma: ,
# Token: and -> Lemma: and
# Token: large -> Lemma: large
# Token: file -> Lemma: file
# Token: transfers -> Lemma: transfer
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 2 -> Lemma: 2
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Scope -> Lemma: Scope
# Token:
#
#  -> Lemma:
#
#
# Token: Geographic -> Lemma: Geographic
# Token: Coverage -> Lemma: Coverage
# Token: : -> Lemma: :
# Token: Primary -> Lemma: primary
# Token: service -> Lemma: service
# Token: area -> Lemma: area
# Token: : -> Lemma: :
# Token: Metropolitan -> Lemma: Metropolitan
# Token: Region -> Lemma: Region
# Token: X -> Lemma: X
# Token: , -> Lemma: ,
# Token: with -> Lemma: with
# Token: secondary -> Lemma: secondary
# Token: coverage -> Lemma: coverage
# Token: in -> Lemma: in
# Token: Industrial -> Lemma: Industrial
# Token: Zone -> Lemma: Zone
# Token: Y. -> Lemma: Y.
# Token: Specific -> Lemma: Specific
# Token: cell -> Lemma: cell
# Token: IDs -> Lemma: id
# Token: and -> Lemma: and
# Token: coverage -> Lemma: coverage
# Token: maps -> Lemma: map
# Token: are -> Lemma: be
# Token: attached -> Lemma: attach
# Token: as -> Lemma: as
# Token: Appendix -> Lemma: Appendix
# Token: A. -> Lemma: a.
# Token:
#
#  -> Lemma:
#
#
# Token: User -> Lemma: User
# Token: Devices -> Lemma: Devices
# Token: : -> Lemma: :
# Token: Support -> Lemma: support
# Token: for -> Lemma: for
# Token: 5G -> Lemma: 5g
# Token: - -> Lemma: -
# Token: compliant -> Lemma: compliant
# Token: devices -> Lemma: device
# Token: ( -> Lemma: (
# Token: smartphones -> Lemma: smartphone
# Token: , -> Lemma: ,
# Token: tablets -> Lemma: tablet
# Token: , -> Lemma: ,
# Token: IoT -> Lemma: iot
# Token: gateways -> Lemma: gateway
# Token: ) -> Lemma: )
# Token: utilizing -> Lemma: utilize
# Token: the -> Lemma: the
# Token: designated -> Lemma: designate
# Token: SIM -> Lemma: SIM
# Token: cards -> Lemma: card
# Token: / -> Lemma: /
# Token: eSIM -> Lemma: esim
# Token: profiles -> Lemma: profile
# Token: provided -> Lemma: provide
# Token: by -> Lemma: by
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token:
#
#  -> Lemma:
#
#
# Token: Traffic -> Lemma: Traffic
# Token: Prioritization -> Lemma: Prioritization
# Token: : -> Lemma: :
# Token: eMBB -> Lemma: embb
# Token: traffic -> Lemma: traffic
# Token: will -> Lemma: will
# Token: receive -> Lemma: receive
# Token: priority -> Lemma: priority
# Token: over -> Lemma: over
# Token: best -> Lemma: good
# Token: - -> Lemma: -
# Token: effort -> Lemma: effort
# Token: traffic -> Lemma: traffic
# Token: within -> Lemma: within
# Token: the -> Lemma: the
# Token: defined -> Lemma: define
# Token: service -> Lemma: service
# Token: slices -> Lemma: slice
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3 -> Lemma: 3
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Level -> Lemma: Level
# Token: Objectives -> Lemma: Objectives
# Token: ( -> Lemma: (
# Token: SLOs -> Lemma: SLOs
# Token: ) -> Lemma: )
# Token: and -> Lemma: and
# Token: Performance -> Lemma: Performance
# Token: Metrics -> Lemma: Metrics
# Token:
#
#  -> Lemma:
#
#
# Token: The -> Lemma: the
# Token: following -> Lemma: follow
# Token: performance -> Lemma: performance
# Token: metrics -> Lemma: metric
# Token: will -> Lemma: will
# Token: be -> Lemma: be
# Token: measured -> Lemma: measure
# Token: and -> Lemma: and
# Token: monitored -> Lemma: monitor
# Token: to -> Lemma: to
# Token: ensure -> Lemma: ensure
# Token: the -> Lemma: the
# Token: agreed -> Lemma: agree
# Token: - -> Lemma: -
# Token: upon -> Lemma: upon
# Token: service -> Lemma: service
# Token: levels -> Lemma: level
# Token: are -> Lemma: be
# Token: met -> Lemma: meet
# Token: . -> Lemma: .
# Token: All -> Lemma: all
# Token: measurements -> Lemma: measurement
# Token: are -> Lemma: be
# Token: based -> Lemma: base
# Token: on -> Lemma: on
# Token: aggregated -> Lemma: aggregate
# Token: data -> Lemma: datum
# Token: over -> Lemma: over
# Token: 15 -> Lemma: 15
# Token: - -> Lemma: -
# Token: minute -> Lemma: minute
# Token: intervals -> Lemma: interval
# Token: , -> Lemma: ,
# Token: unless -> Lemma: unless
# Token: otherwise -> Lemma: otherwise
# Token: specified -> Lemma: specify
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.1 -> Lemma: 3.1
# Token: . -> Lemma: .
# Token: Throughput -> Lemma: Throughput
# Token: ( -> Lemma: (
# Token: Downlink -> Lemma: Downlink
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: Average -> Lemma: average
# Token: downlink -> Lemma: downlink
# Token: throughput -> Lemma: throughput
# Token: of -> Lemma: of
# Token: 1 -> Lemma: 1
# Token: Gbps -> Lemma: Gbps
# Token: ( -> Lemma: (
# Token: Gigabits -> Lemma: gigabit
# Token: per -> Lemma: per
# Token: second -> Lemma: second
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Minimum -> Lemma: Minimum
# Token: Guaranteed -> Lemma: Guaranteed
# Token: : -> Lemma: :
# Token: 750 -> Lemma: 750
# Token: Mbps -> Lemma: Mbps
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: Point -> Lemma: Point
# Token: : -> Lemma: :
# Token: User -> Lemma: User
# Token: Plane -> Lemma: Plane
# Token: Function -> Lemma: Function
# Token: ( -> Lemma: (
# Token: UPF -> Lemma: UPF
# Token: ) -> Lemma: )
# Token: egress -> Lemma: egress
# Token: to -> Lemma: to
# Token: customer -> Lemma: customer
# Token: premises -> Lemma: premise
# Token: equipment -> Lemma: equipment
# Token: ( -> Lemma: (
# Token: CPE -> Lemma: CPE
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: report
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Daily -> Lemma: Daily
# Token: aggregated -> Lemma: aggregate
# Token: reports -> Lemma: report
# Token: , -> Lemma: ,
# Token: monthly -> Lemma: monthly
# Token: detailed -> Lemma: detailed
# Token: reports -> Lemma: report
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.2 -> Lemma: 3.2
# Token: . -> Lemma: .
# Token: Throughput -> Lemma: Throughput
# Token: ( -> Lemma: (
# Token: Uplink -> Lemma: Uplink
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: Average -> Lemma: average
# Token: uplink -> Lemma: uplink
# Token: throughput -> Lemma: throughput
# Token: of -> Lemma: of
# Token: 200 -> Lemma: 200
# Token: Mbps -> Lemma: Mbps
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Minimum -> Lemma: Minimum
# Token: Guaranteed -> Lemma: Guaranteed
# Token: : -> Lemma: :
# Token: 150 -> Lemma: 150
# Token: Mbps -> Lemma: Mbps
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: Point -> Lemma: Point
# Token: : -> Lemma: :
# Token: CPE -> Lemma: CPE
# Token: ingress -> Lemma: ingress
# Token: to -> Lemma: to
# Token: UPF -> Lemma: UPF
# Token: ingress -> Lemma: ingress
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Daily -> Lemma: Daily
# Token: aggregated -> Lemma: aggregate
# Token: reports -> Lemma: report
# Token: , -> Lemma: ,
# Token: monthly -> Lemma: monthly
# Token: detailed -> Lemma: detailed
# Token: reports -> Lemma: report
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.3 -> Lemma: 3.3
# Token: . -> Lemma: .
# Token: Latency -> Lemma: Latency
# Token: ( -> Lemma: (
# Token: Round -> Lemma: Round
# Token: Trip -> Lemma: Trip
# Token: Time -> Lemma: Time
# Token: - -> Lemma: -
# Token: RTT -> Lemma: RTT
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: Average -> Lemma: average
# Token: end -> Lemma: end
# Token: - -> Lemma: -
# Token: to -> Lemma: to
# Token: - -> Lemma: -
# Token: end -> Lemma: end
# Token: latency -> Lemma: latency
# Token: of -> Lemma: of
# Token: less -> Lemma: less
# Token: than -> Lemma: than
# Token: 10 -> Lemma: 10
# Token: ms -> Lemma: ms
# Token: ( -> Lemma: (
# Token: milliseconds -> Lemma: milliseconds
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Maximum -> Lemma: Maximum
# Token: Tolerated -> Lemma: Tolerated
# Token: : -> Lemma: :
# Token: 15 -> Lemma: 15
# Token: ms -> Lemma: ms
# Token: for -> Lemma: for
# Token: 99.9 -> Lemma: 99.9
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: traffic -> Lemma: traffic
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: Point -> Lemma: Point
# Token: : -> Lemma: :
# Token: From -> Lemma: from
# Token: customer -> Lemma: customer
# Token: device -> Lemma: device
# Token: to -> Lemma: to
# Token: designated -> Lemma: designate
# Token: core -> Lemma: core
# Token: network -> Lemma: network
# Token: gateway -> Lemma: gateway
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Hourly -> Lemma: Hourly
# Token: aggregated -> Lemma: aggregate
# Token: reports -> Lemma: report
# Token: , -> Lemma: ,
# Token: weekly -> Lemma: weekly
# Token: detailed -> Lemma: detailed
# Token: reports -> Lemma: report
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.4 -> Lemma: 3.4
# Token: . -> Lemma: .
# Token: Jitter -> Lemma: jitter
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: Maximum -> Lemma: maximum
# Token: jitter -> Lemma: jitter
# Token: of -> Lemma: of
# Token: 2 -> Lemma: 2
# Token: ms -> Lemma: ms
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: Point -> Lemma: Point
# Token: : -> Lemma: :
# Token: From -> Lemma: from
# Token: customer -> Lemma: customer
# Token: device -> Lemma: device
# Token: to -> Lemma: to
# Token: designated -> Lemma: designate
# Token: core -> Lemma: core
# Token: network -> Lemma: network
# Token: gateway -> Lemma: gateway
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Hourly -> Lemma: Hourly
# Token: aggregated -> Lemma: aggregate
# Token: reports -> Lemma: report
# Token: , -> Lemma: ,
# Token: weekly -> Lemma: weekly
# Token: detailed -> Lemma: detailed
# Token: reports -> Lemma: report
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.5 -> Lemma: 3.5
# Token: . -> Lemma: .
# Token: Packet -> Lemma: Packet
# Token: Loss -> Lemma: Loss
# Token: Rate -> Lemma: Rate
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: Less -> Lemma: Less
# Token: than -> Lemma: than
# Token: 0.01 -> Lemma: 0.01
# Token: % -> Lemma: %
# Token: packet -> Lemma: packet
# Token: loss -> Lemma: loss
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Maximum -> Lemma: Maximum
# Token: Tolerated -> Lemma: Tolerated
# Token: : -> Lemma: :
# Token: 0.05 -> Lemma: 0.05
# Token: % -> Lemma: %
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Measurement -> Lemma: Measurement
# Token: Point -> Lemma: Point
# Token: : -> Lemma: :
# Token: End -> Lemma: end
# Token: - -> Lemma: -
# Token: to -> Lemma: to
# Token: - -> Lemma: -
# Token: end -> Lemma: end
# Token: across -> Lemma: across
# Token: the -> Lemma: the
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: network -> Lemma: network
# Token: segment -> Lemma: segment
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Daily -> Lemma: Daily
# Token: aggregated -> Lemma: aggregate
# Token: reports -> Lemma: report
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 3.6 -> Lemma: 3.6
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Availability -> Lemma: Availability
# Token:
#
#  -> Lemma:
#
#
# Token: Objective -> Lemma: objective
# Token: : -> Lemma: :
# Token: 99.99 -> Lemma: 99.99
# Token: % -> Lemma: %
# Token: availability -> Lemma: availability
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: eMBB -> Lemma: embb
# Token: service -> Lemma: service
# Token: within -> Lemma: within
# Token: the -> Lemma: the
# Token: primary -> Lemma: primary
# Token: service -> Lemma: service
# Token: area -> Lemma: area
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Definition -> Lemma: definition
# Token: : -> Lemma: :
# Token: Uptime -> Lemma: Uptime
# Token: measured -> Lemma: measure
# Token: as -> Lemma: as
# Token: the -> Lemma: the
# Token: percentage -> Lemma: percentage
# Token: of -> Lemma: of
# Token: time -> Lemma: time
# Token: the -> Lemma: the
# Token: service -> Lemma: service
# Token: is -> Lemma: be
# Token: fully -> Lemma: fully
# Token: operational -> Lemma: operational
# Token: and -> Lemma: and
# Token: accessible -> Lemma: accessible
# Token: to -> Lemma: to
# Token: the -> Lemma: the
# Token: customer -> Lemma: customer
# Token: . -> Lemma: .
# Token: Planned -> Lemma: plan
# Token: maintenance -> Lemma: maintenance
# Token: windows -> Lemma: window
# Token: are -> Lemma: be
# Token: excluded -> Lemma: exclude
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Monthly -> Lemma: monthly
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 4 -> Lemma: 4
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Credits -> Lemma: Credits
# Token: and -> Lemma: and
# Token: Penalties -> Lemma: Penalties
# Token:
#
#  -> Lemma:
#
#
# Token: In -> Lemma: in
# Token: the -> Lemma: the
# Token: event -> Lemma: event
# Token: that -> Lemma: that
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token: fails -> Lemma: fail
# Token: to -> Lemma: to
# Token: meet -> Lemma: meet
# Token: the -> Lemma: the
# Token: agreed -> Lemma: agree
# Token: - -> Lemma: -
# Token: upon -> Lemma: upon
# Token: Service -> Lemma: Service
# Token: Level -> Lemma: Level
# Token: Objectives -> Lemma: Objectives
# Token: ( -> Lemma: (
# Token: SLOs -> Lemma: SLOs
# Token: ) -> Lemma: )
# Token: for -> Lemma: for
# Token: a -> Lemma: a
# Token: given -> Lemma: give
# Token: month -> Lemma: month
# Token: , -> Lemma: ,
# Token: the -> Lemma: the
# Token: Customer -> Lemma: Customer
# Token: shall -> Lemma: shall
# Token: be -> Lemma: be
# Token: entitled -> Lemma: entitle
# Token: to -> Lemma: to
# Token: service -> Lemma: service
# Token: credits -> Lemma: credit
# Token: as -> Lemma: as
# Token: follows -> Lemma: follow
# Token: : -> Lemma: :
# Token:
#
#  -> Lemma:
#
#
# Token: Availability -> Lemma: availability
# Token: : -> Lemma: :
# Token:
#
#  -> Lemma:
#
#
# Token: 99.9 -> Lemma: 99.9
# Token: % -> Lemma: %
# Token: to -> Lemma: to
# Token: < -> Lemma: <
# Token: 99.99 -> Lemma: 99.99
# Token: % -> Lemma: %
# Token: availability -> Lemma: availability
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: on -> Lemma: on
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 99.0 -> Lemma: 99.0
# Token: % -> Lemma: %
# Token: to -> Lemma: to
# Token: < -> Lemma: <
# Token: 99.9 -> Lemma: 99.9
# Token: % -> Lemma: %
# Token: availability -> Lemma: availability
# Token: : -> Lemma: :
# Token: 10 -> Lemma: 10
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: on -> Lemma: on
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: < -> Lemma: <
# Token: 99.0 -> Lemma: 99.0
# Token: % -> Lemma: %
# Token: availability -> Lemma: availability
# Token: : -> Lemma: :
# Token: 20 -> Lemma: 20
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: on -> Lemma: on
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Throughput -> Lemma: Throughput
# Token: ( -> Lemma: (
# Token: Downlink -> Lemma: Downlink
# Token: / -> Lemma: /
# Token: Uplink -> Lemma: Uplink
# Token: ) -> Lemma: )
# Token: - -> Lemma: -
# Token: if -> Lemma: if
# Token: Minimum -> Lemma: minimum
# Token: Guaranteed -> Lemma: Guaranteed
# Token: is -> Lemma: be
# Token: not -> Lemma: not
# Token: met -> Lemma: meet
# Token: for -> Lemma: for
# Token: more -> Lemma: more
# Token: than -> Lemma: than
# Token: 5 -> Lemma: 5
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: reporting -> Lemma: reporting
# Token: period -> Lemma: period
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: on -> Lemma: on
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: per -> Lemma: per
# Token: metric -> Lemma: metric
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Latency -> Lemma: Latency
# Token: / -> Lemma: /
# Token: Packet -> Lemma: Packet
# Token: Loss -> Lemma: Loss
# Token: / -> Lemma: /
# Token: Jitter -> Lemma: Jitter
# Token: - -> Lemma: -
# Token: if -> Lemma: if
# Token: Maximum -> Lemma: Maximum
# Token: Tolerated -> Lemma: Tolerated
# Token: is -> Lemma: be
# Token: exceeded -> Lemma: exceed
# Token: for -> Lemma: for
# Token: more -> Lemma: more
# Token: than -> Lemma: than
# Token: 1 -> Lemma: 1
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: reporting -> Lemma: reporting
# Token: period -> Lemma: period
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: % -> Lemma: %
# Token: service -> Lemma: service
# Token: credit -> Lemma: credit
# Token: on -> Lemma: on
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: per -> Lemma: per
# Token: metric -> Lemma: metric
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Service -> Lemma: service
# Token: credits -> Lemma: credit
# Token: will -> Lemma: will
# Token: be -> Lemma: be
# Token: applied -> Lemma: apply
# Token: to -> Lemma: to
# Token: the -> Lemma: the
# Token: subsequent -> Lemma: subsequent
# Token: month -> Lemma: month
# Token: 's -> Lemma: 's
# Token: invoice -> Lemma: invoice
# Token: . -> Lemma: .
# Token: Total -> Lemma: total
# Token: service -> Lemma: service
# Token: credits -> Lemma: credit
# Token: in -> Lemma: in
# Token: any -> Lemma: any
# Token: given -> Lemma: give
# Token: month -> Lemma: month
# Token: shall -> Lemma: shall
# Token: not -> Lemma: not
# Token: exceed -> Lemma: exceed
# Token: 25 -> Lemma: 25
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: total -> Lemma: total
# Token: monthly -> Lemma: monthly
# Token: service -> Lemma: service
# Token: fee -> Lemma: fee
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 5 -> Lemma: 5
# Token: . -> Lemma: .
# Token: Responsibilities -> Lemma: responsibility
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: Parties -> Lemma: party
# Token:
#
#  -> Lemma:
#
#
# Token: 5.1 -> Lemma: 5.1
# Token: . -> Lemma: .
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token: ( -> Lemma: (
# Token: Service -> Lemma: Service
# Token: Provider -> Lemma: Provider
# Token: ): -> Lemma: ):
# Token:
#
#  -> Lemma:
#
#
# Token: Maintain -> Lemma: maintain
# Token: the -> Lemma: the
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: network -> Lemma: network
# Token: infrastructure -> Lemma: infrastructure
# Token: to -> Lemma: to
# Token: meet -> Lemma: meet
# Token: the -> Lemma: the
# Token: specified -> Lemma: specify
# Token: SLOs -> Lemma: slo
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Provide -> Lemma: provide
# Token: 24/7 -> Lemma: 24/7
# Token: technical -> Lemma: technical
# Token: support -> Lemma: support
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Monitor -> Lemma: Monitor
# Token: service -> Lemma: service
# Token: performance -> Lemma: performance
# Token: and -> Lemma: and
# Token: provide -> Lemma: provide
# Token: regular -> Lemma: regular
# Token: reports -> Lemma: report
# Token: to -> Lemma: to
# Token: the -> Lemma: the
# Token: Customer -> Lemma: Customer
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Notify -> Lemma: Notify
# Token: Customer -> Lemma: Customer
# Token: of -> Lemma: of
# Token: planned -> Lemma: plan
# Token: maintenance -> Lemma: maintenance
# Token: activities -> Lemma: activity
# Token: at -> Lemma: at
# Token: least -> Lemma: least
# Token: 72 -> Lemma: 72
# Token: hours -> Lemma: hour
# Token: in -> Lemma: in
# Token: advance -> Lemma: advance
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Respond -> Lemma: Respond
# Token: to -> Lemma: to
# Token: and -> Lemma: and
# Token: resolve -> Lemma: resolve
# Token: service -> Lemma: service
# Token: incidents -> Lemma: incident
# Token: within -> Lemma: within
# Token: the -> Lemma: the
# Token: defined -> Lemma: define
# Token: support -> Lemma: support
# Token: windows -> Lemma: window
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 5.2 -> Lemma: 5.2
# Token: . -> Lemma: .
# Token: Enterprise -> Lemma: Enterprise
# Token: Solutions -> Lemma: Solutions
# Token: Corp. -> Lemma: Corp.
# Token: ( -> Lemma: (
# Token: Customer -> Lemma: Customer
# Token: ): -> Lemma: ):
# Token:
#
#  -> Lemma:
#
#
# Token: Provide -> Lemma: provide
# Token: necessary -> Lemma: necessary
# Token: access -> Lemma: access
# Token: to -> Lemma: to
# Token: customer -> Lemma: customer
# Token: premises -> Lemma: premise
# Token: for -> Lemma: for
# Token: equipment -> Lemma: equipment
# Token: installation -> Lemma: installation
# Token: and -> Lemma: and
# Token: maintenance -> Lemma: maintenance
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Ensure -> Lemma: ensure
# Token: proper -> Lemma: proper
# Token: functioning -> Lemma: functioning
# Token: of -> Lemma: of
# Token: customer -> Lemma: customer
# Token: - -> Lemma: -
# Token: owned -> Lemma: own
# Token: equipment -> Lemma: equipment
# Token: ( -> Lemma: (
# Token: CPE -> Lemma: CPE
# Token: ) -> Lemma: )
# Token: and -> Lemma: and
# Token: devices -> Lemma: device
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Notify -> Lemma: notify
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token: promptly -> Lemma: promptly
# Token: of -> Lemma: of
# Token: any -> Lemma: any
# Token: service -> Lemma: service
# Token: issues -> Lemma: issue
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Adhere -> Lemma: adhere
# Token: to -> Lemma: to
# Token: the -> Lemma: the
# Token: fair -> Lemma: fair
# Token: usage -> Lemma: usage
# Token: policy -> Lemma: policy
# Token: ( -> Lemma: (
# Token: if -> Lemma: if
# Token: applicable -> Lemma: applicable
# Token: , -> Lemma: ,
# Token: detailed -> Lemma: detail
# Token: in -> Lemma: in
# Token: Appendix -> Lemma: Appendix
# Token: B -> Lemma: B
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 6 -> Lemma: 6
# Token: . -> Lemma: .
# Token: Support -> Lemma: Support
# Token: and -> Lemma: and
# Token: Incident -> Lemma: Incident
# Token: Management -> Lemma: Management
# Token:
#
#  -> Lemma:
#
#
# Token: 6.1 -> Lemma: 6.1
# Token: . -> Lemma: .
# Token: Support -> Lemma: Support
# Token: Channels -> Lemma: Channels
# Token: : -> Lemma: :
# Token:
#
#  -> Lemma:
#
#
# Token: Online -> Lemma: Online
# Token: Portal -> Lemma: Portal
# Token: : -> Lemma: :
# Token: Available -> Lemma: available
# Token: 24/7 -> Lemma: 24/7
# Token: for -> Lemma: for
# Token: incident -> Lemma: incident
# Token: reporting -> Lemma: reporting
# Token: and -> Lemma: and
# Token: tracking -> Lemma: tracking
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Phone -> Lemma: Phone
# Token: Support -> Lemma: support
# Token: : -> Lemma: :
# Token: [ -> Lemma: [
# Token: + -> Lemma: +
# Token: XX -> Lemma: xx
# Token: XXXX -> Lemma: xxxx
# Token: XXXX -> Lemma: xxxx
# Token: ] -> Lemma: ]
# Token: ( -> Lemma: (
# Token: 24/7 -> Lemma: 24/7
# Token: for -> Lemma: for
# Token: critical -> Lemma: critical
# Token: incidents -> Lemma: incident
# Token: , -> Lemma: ,
# Token: 9 -> Lemma: 9
# Token: AM -> Lemma: am
# Token: - -> Lemma: -
# Token: 5 -> Lemma: 5
# Token: PM -> Lemma: PM
# Token: M -> Lemma: M
# Token: - -> Lemma: -
# Token: F -> Lemma: F
# Token: for -> Lemma: for
# Token: general -> Lemma: general
# Token: inquiries -> Lemma: inquiry
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Email -> Lemma: Email
# Token: Support -> Lemma: Support
# Token: : -> Lemma: :
# Token: support@nexgentelecom.com -> Lemma: support@nexgentelecom.com
# Token: ( -> Lemma: (
# Token: Monitored -> Lemma: monitor
# Token: 9 -> Lemma: 9
# Token: AM -> Lemma: AM
# Token: - -> Lemma: -
# Token: 5 -> Lemma: 5
# Token: PM -> Lemma: PM
# Token: M -> Lemma: M
# Token: - -> Lemma: -
# Token: F -> Lemma: F
# Token: ) -> Lemma: )
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 6.2 -> Lemma: 6.2
# Token: . -> Lemma: .
# Token: Incident -> Lemma: Incident
# Token: Prioritization -> Lemma: Prioritization
# Token: : -> Lemma: :
# Token:
#
#  -> Lemma:
#
#
# Token: Critical -> Lemma: Critical
# Token: ( -> Lemma: (
# Token: P1 -> Lemma: P1
# Token: ): -> Lemma: ):
# Token: Complete -> Lemma: complete
# Token: service -> Lemma: service
# Token: outage -> Lemma: outage
# Token: or -> Lemma: or
# Token: severe -> Lemma: severe
# Token: degradation -> Lemma: degradation
# Token: impacting -> Lemma: impact
# Token: all -> Lemma: all
# Token: users -> Lemma: user
# Token: . -> Lemma: .
# Token: Target -> Lemma: Target
# Token: Resolution -> Lemma: Resolution
# Token: Time -> Lemma: Time
# Token: ( -> Lemma: (
# Token: TRT -> Lemma: TRT
# Token: ): -> Lemma: ):
# Token: 4 -> Lemma: 4
# Token: hours -> Lemma: hour
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: High -> Lemma: High
# Token: ( -> Lemma: (
# Token: P2 -> Lemma: p2
# Token: ): -> Lemma: ):
# Token: Significant -> Lemma: significant
# Token: service -> Lemma: service
# Token: degradation -> Lemma: degradation
# Token: impacting -> Lemma: impact
# Token: a -> Lemma: a
# Token: subset -> Lemma: subset
# Token: of -> Lemma: of
# Token: users -> Lemma: user
# Token: or -> Lemma: or
# Token: critical -> Lemma: critical
# Token: applications -> Lemma: application
# Token: . -> Lemma: .
# Token: TRT -> Lemma: TRT
# Token: : -> Lemma: :
# Token: 8 -> Lemma: 8
# Token: hours -> Lemma: hour
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Medium -> Lemma: Medium
# Token: ( -> Lemma: (
# Token: P3 -> Lemma: P3
# Token: ): -> Lemma: ):
# Token: Minor -> Lemma: minor
# Token: service -> Lemma: service
# Token: degradation -> Lemma: degradation
# Token: or -> Lemma: or
# Token: intermittent -> Lemma: intermittent
# Token: issues -> Lemma: issue
# Token: . -> Lemma: .
# Token: TRT -> Lemma: TRT
# Token: : -> Lemma: :
# Token: 24 -> Lemma: 24
# Token: hours -> Lemma: hour
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: Low -> Lemma: Low
# Token: ( -> Lemma: (
# Token: P4 -> Lemma: p4
# Token: ): -> Lemma: ):
# Token: General -> Lemma: General
# Token: inquiries -> Lemma: inquiry
# Token: or -> Lemma: or
# Token: non -> Lemma: non
# Token: - -> Lemma: -
# Token: service -> Lemma: service
# Token: impacting -> Lemma: impact
# Token: issues -> Lemma: issue
# Token: . -> Lemma: .
# Token: TRT -> Lemma: TRT
# Token: : -> Lemma: :
# Token: 48 -> Lemma: 48
# Token: hours -> Lemma: hour
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 6.3 -> Lemma: 6.3
# Token: . -> Lemma: .
# Token: Reporting -> Lemma: reporting
# Token: and -> Lemma: and
# Token: Communication -> Lemma: Communication
# Token: : -> Lemma: :
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token: will -> Lemma: will
# Token: provide -> Lemma: provide
# Token: regular -> Lemma: regular
# Token: updates -> Lemma: update
# Token: on -> Lemma: on
# Token: incident -> Lemma: incident
# Token: status -> Lemma: status
# Token: until -> Lemma: until
# Token: resolution -> Lemma: resolution
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 7 -> Lemma: 7
# Token: . -> Lemma: .
# Token: Dispute -> Lemma: Dispute
# Token: Resolution -> Lemma: Resolution
# Token:
#
#  -> Lemma:
#
#
# Token: Any -> Lemma: any
# Token: disputes -> Lemma: dispute
# Token: arising -> Lemma: arise
# Token: from -> Lemma: from
# Token: this -> Lemma: this
# Token: SLA -> Lemma: SLA
# Token: shall -> Lemma: shall
# Token: first -> Lemma: first
# Token: be -> Lemma: be
# Token: attempted -> Lemma: attempt
# Token: to -> Lemma: to
# Token: be -> Lemma: be
# Token: resolved -> Lemma: resolve
# Token: through -> Lemma: through
# Token: good -> Lemma: good
# Token: - -> Lemma: -
# Token: faith -> Lemma: faith
# Token: negotiation -> Lemma: negotiation
# Token: between -> Lemma: between
# Token: the -> Lemma: the
# Token: parties -> Lemma: party
# Token: . -> Lemma: .
# Token: If -> Lemma: if
# Token: an -> Lemma: an
# Token: amicable -> Lemma: amicable
# Token: resolution -> Lemma: resolution
# Token: can -> Lemma: can
# Token: not -> Lemma: not
# Token: be -> Lemma: be
# Token: reached -> Lemma: reach
# Token: within -> Lemma: within
# Token: 30 -> Lemma: 30
# Token: days -> Lemma: day
# Token: , -> Lemma: ,
# Token: either -> Lemma: either
# Token: party -> Lemma: party
# Token: may -> Lemma: may
# Token: escalate -> Lemma: escalate
# Token: the -> Lemma: the
# Token: dispute -> Lemma: dispute
# Token: to -> Lemma: to
# Token: formal -> Lemma: formal
# Token: mediation -> Lemma: mediation
# Token: . -> Lemma: .
# Token:
#
#  -> Lemma:
#
#
# Token: 8 -> Lemma: 8
# Token: . -> Lemma: .
# Token: Termination -> Lemma: termination
# Token:
#
#  -> Lemma:
#
#
# Token: This -> Lemma: this
# Token: SLA -> Lemma: SLA
# Token: may -> Lemma: may
# Token: be -> Lemma: be
# Token: terminated -> Lemma: terminate
# Token: by -> Lemma: by
# Token: either -> Lemma: either
# Token: party -> Lemma: party
# Token: with -> Lemma: with
# Token: 60 -> Lemma: 60
# Token: days -> Lemma: day
# Token: ' -> Lemma: '
# Token: written -> Lemma: write
# Token: notice -> Lemma: notice
# Token: , -> Lemma: ,
# Token: subject -> Lemma: subject
# Token: to -> Lemma: to
# Token: the -> Lemma: the
# Token: terms -> Lemma: term
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: master -> Lemma: master
# Token: service -> Lemma: service
# Token: agreement -> Lemma: agreement
# Token: between -> Lemma: between
# Token: NexGen -> Lemma: NexGen
# Token: Telecom -> Lemma: Telecom
# Token: Inc. -> Lemma: Inc.
# Token: and -> Lemma: and
# Token: Enterprise -> Lemma: Enterprise
# Token: Solutions -> Lemma: Solutions
# Token: Corp. -> Lemma: Corp.
# Token:
#
#  -> Lemma:
#
#
# Token: 9 -> Lemma: 9
# Token: . -> Lemma: .
# Token: Review -> Lemma: Review
# Token: and -> Lemma: and
# Token: Amendment -> Lemma: Amendment
# Token:
#
#  -> Lemma:
#
#
# Token: This -> Lemma: this
# Token: SLA -> Lemma: SLA
# Token: will -> Lemma: will
# Token: be -> Lemma: be
# Token: reviewed -> Lemma: review
# Token: annually -> Lemma: annually
# Token: on -> Lemma: on
# Token: the -> Lemma: the
# Token: anniversary -> Lemma: anniversary
# Token: of -> Lemma: of
# Token: the -> Lemma: the
# Token: Effective -> Lemma: Effective
# Token: Date -> Lemma: Date
# Token: or -> Lemma: or
# Token: sooner -> Lemma: soon
# Token: if -> Lemma: if
# Token: significant -> Lemma: significant
# Token: changes -> Lemma: change
# Token: in -> Lemma: in
# Token: service -> Lemma: service
# Token: requirements -> Lemma: requirement
# Token: or -> Lemma: or
# Token: network -> Lemma: network
# Token: capabilities -> Lemma: capability
# Token: occur -> Lemma: occur
# Token: . -> Lemma: .
# Token: Any -> Lemma: any
# Token: amendments -> Lemma: amendment
# Token: must -> Lemma: must
# Token: be -> Lemma: be
# Token: mutually -> Lemma: mutually
# Token: agreed -> Lemma: agree
# Token: upon -> Lemma: upon
# Token: in -> Lemma: in
# Token: writing -> Lemma: writing
# Token: . -> Lemma: .
# Token:
#
#
#  -> Lemma:
#
#
#
# Token: 1 -> Lemma: 1
# Token: . -> Lemma: .
# Token: Parties -> Lemma: party
# Token: Involved -> Lemma: involve
# Token:
#
#  -> Lemma:
#
#
# Token: Service -> Lemma: Service
# Token: Provider -> Lemma: Provider
# Token: : -> Lemma: :
# Token: XY -> Lemma: XY
# Token:
#  -> Lemma:
#
# Token: Customer -> Lemma: Customer
# Token: : -> Lemma: :
# Token: CustomerZ -> Lemma: customerz
# Token:
#  -> Lemma:
#
# Token: Agreement -> Lemma: Agreement
# Token: Date -> Lemma: Date
# Token: : -> Lemma: :
# Token: 2025 -> Lemma: 2025
# Token: - -> Lemma: -
# Token: 06 -> Lemma: 06
# Token: - -> Lemma: -
# Token: 09 -> Lemma: 09
# Token:
#  -> Lemma:
#
# Token: Effective -> Lemma: effective
# Token: Period -> Lemma: period
# Token: : -> Lemma: :
# Token: 2025 -> Lemma: 2025
# Token: - -> Lemma: -
# Token: 06 -> Lemma: 06
# Token: - -> Lemma: -
# Token: 10 -> Lemma: 10
# Token:
#
#  -> Lemma:
#
#
# Token: 2 -> Lemma: 2
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Description -> Lemma: Description
# Token:
#
#  -> Lemma:
#
#
# Token: Service -> Lemma: Service
# Token: Name -> Lemma: name
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: G
# Token: Connectivity -> Lemma: Connectivity
# Token: Service -> Lemma: Service
# Token:
#  -> Lemma:
#
# Token: Service -> Lemma: Service
# Token: Scope -> Lemma: scope
# Token: : -> Lemma: :
# Token: High -> Lemma: high
# Token: - -> Lemma: -
# Token: speed -> Lemma: speed
# Token: , -> Lemma: ,
# Token: low -> Lemma: low
# Token: - -> Lemma: -
# Token: latency -> Lemma: latency
# Token: wireless -> Lemma: wireless
# Token: connectivity -> Lemma: connectivity
# Token: using -> Lemma: use
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: NR -> Lemma: NR
# Token: ( -> Lemma: (
# Token: New -> Lemma: New
# Token: Radio -> Lemma: Radio
# Token: ) -> Lemma: )
# Token: technology -> Lemma: technology
# Token: . -> Lemma: .
# Token:
#  -> Lemma:
#
# Token: Coverage -> Lemma: Coverage
# Token: Area -> Lemma: Area
# Token: : -> Lemma: :
# Token: [ -> Lemma: [
# Token: Geographic -> Lemma: Geographic
# Token: Area -> Lemma: Area
# Token: or -> Lemma: or
# Token: Locations -> Lemma: Locations
# Token: ] -> Lemma: ]
# Token:
#  -> Lemma:
#
# Token: Service -> Lemma: Service
# Token: Tiers -> Lemma: tier
# Token: : -> Lemma: :
# Token: [ -> Lemma: [
# Token: e.g. -> Lemma: e.g.
# Token: , -> Lemma: ,
# Token: Basic -> Lemma: Basic
# Token: , -> Lemma: ,
# Token: Premium -> Lemma: Premium
# Token: , -> Lemma: ,
# Token: Enterprise -> Lemma: enterprise
# Token: ] -> Lemma: ]
# Token:
#
#  -> Lemma:
#
#
# Token: 3 -> Lemma: 3
# Token: . -> Lemma: .
# Token: Performance -> Lemma: Performance
# Token: Metrics -> Lemma: metric
# Token:
#
#  -> Lemma:
#
#
# Token: Availability -> Lemma: Availability
# Token: : -> Lemma: :
# Token: ≥ -> Lemma: ≥
# Token: 99.99 -> Lemma: 99.99
# Token: % -> Lemma: %
# Token: uptime -> Lemma: uptime
# Token: per -> Lemma: per
# Token: calendar -> Lemma: calendar
# Token: month -> Lemma: month
# Token:
#  -> Lemma:
#
# Token: Latency -> Lemma: Latency
# Token: : -> Lemma: :
# Token: ≤ -> Lemma: ≤
# Token: 10 -> Lemma: 10
# Token: ms -> Lemma: ms
# Token: ( -> Lemma: (
# Token: one -> Lemma: one
# Token: - -> Lemma: -
# Token: way -> Lemma: way
# Token: ) -> Lemma: )
# Token:
#  -> Lemma:
#
# Token: Throughput -> Lemma: Throughput
# Token: : -> Lemma: :
# Token:
#  -> Lemma:
#
# Token: Downlink -> Lemma: Downlink
# Token: : -> Lemma: :
# Token: ≥ -> Lemma: ≥
# Token: 1 -> Lemma: 1
# Token: Gbps -> Lemma: Gbps
# Token:
#  -> Lemma:
#
# Token: Uplink -> Lemma: Uplink
# Token: : -> Lemma: :
# Token: ≥ -> Lemma: ≥
# Token: 100 -> Lemma: 100
# Token: Mbps -> Lemma: Mbps
# Token:
#  -> Lemma:
#
# Token: Jitter -> Lemma: Jitter
# Token: : -> Lemma: :
# Token: ≤ -> Lemma: ≤
# Token: 5 -> Lemma: 5
# Token: ms -> Lemma: ms
# Token:
#  -> Lemma:
#
# Token: Packet -> Lemma: Packet
# Token: Loss -> Lemma: Loss
# Token: : -> Lemma: :
# Token: ≤ -> Lemma: ≤
# Token: 0.1 -> Lemma: 0.1
# Token: % -> Lemma: %
# Token:
#
#  -> Lemma:
#
#
# Token: 4 -> Lemma: 4
# Token: . -> Lemma: .
# Token: Monitoring -> Lemma: monitoring
# Token: and -> Lemma: and
# Token: Reporting -> Lemma: reporting
# Token:
#
#  -> Lemma:
#
#
# Token: Monitoring -> Lemma: Monitoring
# Token: Tools -> Lemma: Tools
# Token: : -> Lemma: :
# Token: [ -> Lemma: [
# Token: Provider -> Lemma: Provider
# Token: Monitoring -> Lemma: Monitoring
# Token: Dashboard -> Lemma: Dashboard
# Token: ] -> Lemma: ]
# Token:
#  -> Lemma:
#
# Token: Reporting -> Lemma: Reporting
# Token: Frequency -> Lemma: Frequency
# Token: : -> Lemma: :
# Token: Monthly -> Lemma: Monthly
# Token:
#  -> Lemma:
#
# Token: Report -> Lemma: Report
# Token: Delivery -> Lemma: Delivery
# Token: Method -> Lemma: Method
# Token: : -> Lemma: :
# Token: [ -> Lemma: [
# Token: Email -> Lemma: email
# Token: , -> Lemma: ,
# Token: Web -> Lemma: web
# Token: Portal -> Lemma: Portal
# Token: ] -> Lemma: ]
# Token:
#
#  -> Lemma:
#
#
# Token: 5 -> Lemma: 5
# Token: . -> Lemma: .
# Token: Support -> Lemma: Support
# Token: and -> Lemma: and
# Token: Maintenance -> Lemma: Maintenance
# Token:
#
#  -> Lemma:
#
#
# Token: Support -> Lemma: Support
# Token: Hours -> Lemma: hour
# Token: : -> Lemma: :
# Token: 24/7 -> Lemma: 24/7
# Token:
#  -> Lemma:
#
# Token: Incident -> Lemma: Incident
# Token: Response -> Lemma: Response
# Token: Time -> Lemma: Time
# Token: : -> Lemma: :
# Token:
#  -> Lemma:
#
# Token: Critical -> Lemma: Critical
# Token: : -> Lemma: :
# Token: ≤ -> Lemma: ≤
# Token: 15 -> Lemma: 15
# Token: minutes -> Lemma: minute
# Token:
#  -> Lemma:
#
# Token: Major -> Lemma: Major
# Token: : -> Lemma: :
# Token: ≤ -> Lemma: ≤
# Token: 1 -> Lemma: 1
# Token: hour -> Lemma: hour
# Token:
#  -> Lemma:
#
# ...
# Token: fee -> Lemma: fee
# Token: credit -> Lemma: credit
# Token:
#  -> Lemma:
#
# Token: Latency -> Lemma: Latency
# Token: > -> Lemma: >
# Token: 10 -> Lemma: 10
# Token: ms -> Lemma: ms
# Token: : -> Lemma: :
# Token: 3 -> Lemma: 3
# Token: % -> Lemma: %
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: credit -> Lemma: credit
# Token:
#  -> Lemma:
#
# Token: Maximum -> Lemma: Maximum
# Token: Credit -> Lemma: Credit
# Token: Cap -> Lemma: Cap
# Token: : -> Lemma: :
# Token: 25 -> Lemma: 25
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: monthly -> Lemma: monthly
# Token: service -> Lemma: service
# Token: fee -> Lemma: fee
# Token:
#
#  -> Lemma:
#
#
# Token: 7 -> Lemma: 7
# Token: . -> Lemma: .
# Token: Termination -> Lemma: termination
# Token: Conditions -> Lemma: Conditions
# Token:
#
#  -> Lemma:
#
#
# Token: Breach -> Lemma: Breach
# Token: of -> Lemma: of
# Token: SLA -> Lemma: SLA
# Token: : -> Lemma: :
# Token: Termination -> Lemma: termination
# Token: allowed -> Lemma: allow
# Token: after -> Lemma: after
# Token: 3 -> Lemma: 3
# Token: consecutive -> Lemma: consecutive
# Token: months -> Lemma: month
# Token: of -> Lemma: of
# Token: non -> Lemma: non
# Token: - -> Lemma: -
# Token: compliance -> Lemma: compliance
# Token:
#  -> Lemma:
#
# Token: Notice -> Lemma: Notice
# Token: Period -> Lemma: Period
# Token: : -> Lemma: :
# Token: 30 -> Lemma: 30
# Token: days -> Lemma: day
# Token: written -> Lemma: write
# Token: notice -> Lemma: notice
# Token:
#
#  -> Lemma:
#
#
# Token: 8 -> Lemma: 8
# Token: . -> Lemma: .
# Token: Miscellaneous -> Lemma: miscellaneous
# Token:
#
#  -> Lemma:
#
#
# Token: Governing -> Lemma: Governing
# Token: Law -> Lemma: Law
# Token: : -> Lemma: :
# Token: [ -> Lemma: [
# Token: Jurisdiction -> Lemma: Jurisdiction
# Token: ] -> Lemma: ]
# Token:
#  -> Lemma:
#
# Token: Amendments -> Lemma: amendment
# Token: : -> Lemma: :
# Token: Must -> Lemma: must
# Token: be -> Lemma: be
# Token: in -> Lemma: in
# Token: writing -> Lemma: writing
# Token: and -> Lemma: and
# Token: signed -> Lemma: sign
# Token: by -> Lemma: by
# Token: both -> Lemma: both
# Token: parties -> Lemma: party
# Token:
#  -> Lemma:
#
# Token: Confidentiality -> Lemma: confidentiality
# Token: : -> Lemma: :
# Token: Both -> Lemma: both
# Token: parties -> Lemma: party
# Token: agree -> Lemma: agree
# Token: to -> Lemma: to
# Token: maintain -> Lemma: maintain
# Token: confidentiality -> Lemma: confidentiality
# Token: of -> Lemma: of
# Token: SLA -> Lemma: SLA
# Token: terms -> Lemma: term
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: G
# Token: Service -> Lemma: Service
# Token: Level -> Lemma: Level
# Token: Agreement -> Lemma: Agreement
# Token: ( -> Lemma: (
# Token: SLA -> Lemma: SLA
# Token: ) -> Lemma: )
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: 1 -> Lemma: 1
# Token: . -> Lemma: .
# Token: General -> Lemma: General
# Token: Information -> Lemma: Information
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: AgreementID -> Lemma: agreementid
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: SLA-5G-001 -> Lemma: SLA-5G-001
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Provider -> Lemma: provider
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: NextGen -> Lemma: NextGen
# Token: Mobile -> Lemma: Mobile
# Token: Networks -> Lemma: Networks
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Customer -> Lemma: customer
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: Acme -> Lemma: Acme
# Token: Corp -> Lemma: Corp
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: ServiceName -> Lemma: servicename
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: G -> Lemma: g
# Token: Enhanced -> Lemma: Enhanced
# Token: Mobile -> Lemma: Mobile
# Token: Broadband -> Lemma: Broadband
# Token: ( -> Lemma: (
# Token: eMBB -> Lemma: eMBB
# Token: ) -> Lemma: )
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: EffectiveDate -> Lemma: EffectiveDate
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: 2025 -> Lemma: 2025
# Token: - -> Lemma: -
# Token: 07 -> Lemma: 07
# Token: - -> Lemma: -
# Token: 01 -> Lemma: 01
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: ExpirationDate -> Lemma: expirationdate
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: 2026 -> Lemma: 2026
# Token: - -> Lemma: -
# Token: 06 -> Lemma: 06
# Token: - -> Lemma: -
# Token: 30 -> Lemma: 30
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: 2 -> Lemma: 2
# Token: . -> Lemma: .
# Token: Service -> Lemma: Service
# Token: Scope -> Lemma: Scope
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: CoverageArea -> Lemma: CoverageArea
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: Urban -> Lemma: urban
# Token: and -> Lemma: and
# Token: suburban -> Lemma: suburban
# Token: zones -> Lemma: zone
# Token: in -> Lemma: in
# Token: Region -> Lemma: Region
# Token: - -> Lemma: -
# Token: X -> Lemma: x
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: SupportedDevices -> Lemma: supporteddevice
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: 3GPP -> Lemma: 3gpp
# Token: Release -> Lemma: Release
# Token: 16 -> Lemma: 16
# Token: compliant -> Lemma: compliant
# Token: devices -> Lemma: device
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: UseCases -> Lemma: usecase
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: Video -> Lemma: video
# Token: streaming -> Lemma: streaming
# Token: , -> Lemma: ,
# Token: AR -> Lemma: AR
# Token: / -> Lemma: /
# Token: VR -> Lemma: VR
# Token: , -> Lemma: ,
# Token: industrial -> Lemma: industrial
# Token: IoT -> Lemma: iot
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: 3 -> Lemma: 3
# Token: . -> Lemma: .
# Token: Performance -> Lemma: performance
# Token: Metrics -> Lemma: metric
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Availability -> Lemma: availability
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token:
#
#    -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Target -> Lemma: target
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: 99.99 -> Lemma: 99.99
# Token: % -> Lemma: %
# Token:
#    -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: MeasurementPeriod -> Lemma: MeasurementPeriod
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: Monthly -> Lemma: monthly
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Latency -> Lemma: latency
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token:
#
#    -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Target -> Lemma: target
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: ≤ -> Lemma: ≤
# Token: 5 -> Lemma: 5
# Token: ms -> Lemma: ms
# Token: ( -> Lemma: (
# Token: edge -> Lemma: edge
# Token: - -> Lemma: -
# Token: to -> Lemma: to
# Token: - -> Lemma: -
# Token: edge -> Lemma: edge
# Token: ) -> Lemma: )
# Token:
#    -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: MeasurementPeriod -> Lemma: MeasurementPeriod
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: Continuous -> Lemma: continuous
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Throughput -> Lemma: throughput
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token:
#
#    -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Downlink -> Lemma: downlink
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: ≥ -> Lemma: ≥
# Token: 1 -> Lemma: 1
# Token: Gbps -> Lemma: Gbps
# Token:
#    -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Uplink -> Lemma: uplink
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: ≥ -> Lemma: ≥
# Token: 500 -> Lemma: 500
# Token: Mbps -> Lemma: Mbps
# Token:
#    -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: MeasurementPeriod -> Lemma: MeasurementPeriod
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: Peak -> Lemma: peak
# Token: hours -> Lemma: hour
# Token: ( -> Lemma: (
# Token: 17:00–21:00 -> Lemma: 17:00–21:00
# Token: local -> Lemma: local
# Token: time -> Lemma: time
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Jitter -> Lemma: jitter
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token:
#
#    -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Target -> Lemma: target
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: ≤ -> Lemma: ≤
# Token: 10ms -> Lemma: 10ms
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: 4 -> Lemma: 4
# Token: . -> Lemma: .
# Token: Fault -> Lemma: Fault
# Token: Management -> Lemma: Management
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: IncidentResponseTime -> Lemma: incidentresponsetime
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: ≤ -> Lemma: ≤
# Token: 15 -> Lemma: 15
# Token: minutes -> Lemma: minute
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: IncidentResolutionTime -> Lemma: incidentresolutiontime
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: ≤ -> Lemma: ≤
# Token: 4 -> Lemma: 4
# Token: hours -> Lemma: hour
# Token: ( -> Lemma: (
# Token: Priority -> Lemma: Priority
# Token: 1 -> Lemma: 1
# Token: incidents -> Lemma: incident
# Token: ) -> Lemma: )
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Monitoring -> Lemma: monitor
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: 24/7 -> Lemma: 24/7
# Token: NOC -> Lemma: NOC
# Token: monitoring -> Lemma: monitoring
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: 5 -> Lemma: 5
# Token: . -> Lemma: .
# Token: Penalties -> Lemma: penalty
# Token: and -> Lemma: and
# Token: Remedies -> Lemma: Remedies
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: AvailabilityBreach -> Lemma: AvailabilityBreach
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token:
#
#    -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Threshold -> Lemma: threshold
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: < -> Lemma: <
# Token: 99.5 -> Lemma: 99.5
# Token: % -> Lemma: %
# Token:
#    -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Credit -> Lemma: credit
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: 10 -> Lemma: 10
# Token: % -> Lemma: %
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: refund -> Lemma: refund
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: LatencyBreach -> Lemma: LatencyBreach
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token:
#
#    -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Threshold -> Lemma: threshold
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: > -> Lemma: >
# Token: 10 -> Lemma: 10
# Token: ms -> Lemma: ms
# Token: average -> Lemma: average
# Token: for -> Lemma: for
# Token: over -> Lemma: over
# Token: 3hours -> Lemma: 3hours
# Token:
#    -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Credit -> Lemma: credit
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: 5 -> Lemma: 5
# Token: % -> Lemma: %
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token: refund -> Lemma: refund
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: MaximumTotalCredit -> Lemma: maximumtotalcredit
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: 30 -> Lemma: 30
# Token: % -> Lemma: %
# Token: of -> Lemma: of
# Token: monthly -> Lemma: monthly
# Token: fee -> Lemma: fee
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: 6 -> Lemma: 6
# Token: . -> Lemma: .
# Token: Reporting -> Lemma: report
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Frequency -> Lemma: frequency
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: Monthly -> Lemma: monthly
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Format -> Lemma: format
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: PDF -> Lemma: PDF
# Token: , -> Lemma: ,
# Token: XML -> Lemma: XML
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: DeliveryMethod -> Lemma: DeliveryMethod
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: Email -> Lemma: email
# Token: to -> Lemma: to
# Token: customer -> Lemma: customer
# Token: - -> Lemma: -
# Token: designated -> Lemma: designate
# Token: recipient -> Lemma: recipient
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: 7 -> Lemma: 7
# Token: . -> Lemma: .
# Token: Contact -> Lemma: contact
# Token: Information -> Lemma: Information
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: ProviderSupportEmail -> Lemma: providersupportemail
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: [ -> Lemma: [
# Token: support@nextgen-networks.com](mailto:support@nextgen-networks.com -> Lemma: support@nextgen-networks.com](mailto:support@nextgen-networks.com
# Token: ) -> Lemma: )
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: ProviderSupportPhone -> Lemma: providersupportphone
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: +1 -> Lemma: +1
# Token: - -> Lemma: -
# Token: 800 -> Lemma: 800
# Token: - -> Lemma: -
# Token: 555 -> Lemma: 555
# Token: - -> Lemma: -
# Token: 5GSL -> Lemma: 5gsl
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: CustomerContact -> Lemma: customercontact
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: [ -> Lemma: [
# Token: itops@acme-corp.com](mailto:itops@acme-corp.com -> Lemma: itops@acme-corp.com](mailto:itops@acme-corp.com
# Token: ) -> Lemma: )
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: 8 -> Lemma: 8
# Token: . -> Lemma: .
# Token: Terms -> Lemma: term
# Token: and -> Lemma: and
# Token: Termination -> Lemma: termination
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token:
#
#  -> Lemma:
#
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: TerminationNoticePeriod -> Lemma: terminationnoticeperiod
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: 30 -> Lemma: 30
# Token: days -> Lemma: day
# Token:
#  -> Lemma:
#
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: Renewal -> Lemma: renewal
# Token: * -> Lemma: *
# Token: * -> Lemma: *
# Token: : -> Lemma: :
# Token: Auto -> Lemma: auto
# Token: - -> Lemma: -
# Token: renewal -> Lemma: renewal
# Token: annually -> Lemma: annually
# Token: unless -> Lemma: unless
# Token: terminated -> Lemma: terminate
# Token:
#  -> Lemma:

# %%
import xml.etree.ElementTree as ET

# Create root XML element
root = ET.Element("keywords")

# Populate XML with keywords and values
for kw, values in matched_keywords.items():
    keyword_elem = ET.SubElement(root, "keyword", name=kw)
    for val in set(values):  # Use set() to avoid duplicates
        ET.SubElement(keyword_elem, "value").text = val

# Save to file
tree = ET.ElementTree(root)
output_filename = "geminiSLA_keyword_values.xml"
tree.write(output_filename, encoding="utf-8", xml_declaration=True)

# Optional: Pretty print to console
xml_str = ET.tostring(root, encoding="unicode")
print("\nGenerated XML:\n")
print(xml_str)
# Out:
# Generated XML:
#
# <keywords><keyword name="g"><value>5</value></keyword><keyword name="service"><value>1</value><value>3</value><value>2</value><value>0.0005</value><value>10</value><value>%</value><value>4</value><value>20</value><value>7</value><value>3.6</value><value>5</value><value>01</value><value>0.1</value></keyword><keyword name="level"><value>5</value><value>3</value></keyword><keyword name="effective"><value>09</value><value>20250626</value><value>01</value><value>2025</value></keyword><keyword name="date"><value>06</value><value>2025</value><value>07</value><value>20250626</value><value>01</value></keyword><keyword name="cycle"><value>1</value></keyword><keyword name="quarterly"><value>1</value><value>7</value></keyword><keyword name="availability"><value>1</value><value>99.95</value><value>10</value><value>%</value><value>20</value><value>99.99</value><value>3.6</value><value>5</value><value>99.0</value><value>99.9</value></keyword><keyword name="target"><value>Mbps</value><value>2</value><value>%</value><value>99.99</value><value>99.95</value><value>6</value><value>0.1</value></keyword><keyword name="monthly"><value>25</value><value>3</value><value>30</value><value>4</value><value>%</value><value>10</value><value>5th</value><value>20</value><value>7</value><value>99.95</value><value>5</value><value>99.0</value></keyword><keyword name="uptime"><value>%</value><value>99.99</value><value>99.95</value></keyword><keyword name="formula"><value>Minutes</value></keyword><keyword name="total"><value>Minutes</value><value>%</value></keyword><keyword name="minutes"><value>minutes</value><value>4</value><value>Minutes</value><value>15</value><value>5</value></keyword><keyword name="downtime"><value>Minutes</value></keyword><keyword name="penalty"><value>500</value><value>3</value><value>2</value><value>minutes</value><value>4</value><value>%</value><value>Minutes</value><value>5</value><value>hours</value></keyword><keyword name="credit"><value>25</value><value>3</value><value>2</value><value>0.0005</value><value>10</value><value>%</value><value>4</value><value>20</value><value>5</value><value>0.1</value></keyword><keyword name="network"><value>5</value><value>50</value><value>2</value></keyword><keyword name="latency"><value>3.3</value><value>2</value><value>10</value><value>ms</value><value>5</value></keyword><keyword name="measurement"><value>Mbps</value><value>%</value><value>ms</value><value>95th</value><value>7</value></keyword><keyword name="percentile"><value>95th</value></keyword><keyword name="hourly"><value>95th</value></keyword><keyword name="probes"><value>minutes</value><value>5</value><value>3</value></keyword><keyword name="breach"><value>5</value><value>3</value><value>0.0005</value><value>%</value></keyword><keyword name="downlink"><value>1</value><value>3</value></keyword><keyword name="throughput"><value>1</value><value>200</value><value>3</value><value>Mbps</value><value>3.1</value><value>3.2</value></keyword><keyword name="mbps"><value>200</value><value>500</value><value>Mbps</value><value>150</value><value>100</value><value>750</value></keyword><keyword name="peak"><value>hours</value><value>Mbps</value></keyword><keyword name="average"><value>1</value><value>200</value><value>Mbps</value><value>10</value><value>ms</value></keyword><keyword name="device"><value>Mbps</value></keyword><keyword name="ues"><value>50</value></keyword><keyword name="daily"><value>9</value></keyword><keyword name="speed"><value>9</value></keyword><keyword name="tests"><value>9</value></keyword><keyword name="pm"><value>5</value><value>9</value></keyword><keyword name="deviation"><value>4</value><value>10</value><value>%</value></keyword><keyword name="reliability"><value>4</value></keyword><keyword name="packet"><value>0.01</value><value>%</value><value>ms</value><value>5</value><value>0.1</value><value>3.5</value></keyword><keyword name="loss"><value>0.01</value><value>%</value><value>ms</value><value>0.1</value><value>3.5</value></keyword><k ...

# %%
import time
import matplotlib.pyplot as plt

# Create a temporary matcher to test individual keyword timing
timings = []

for kw in sorted(keywords):
    temp_matcher = Matcher(nlp.vocab)
    temp_matcher.add("KEYWORD_TEMP", [[{"LOWER": kw.lower()}]])

    start_time = time.perf_counter()
    temp_matcher(doc)
    elapsed_time = time.perf_counter() - start_time

    timings.append((kw, elapsed_time))

# %%
# Sort by time
timings.sort(key=lambda x: x[1], reverse=True)

# Prepare data
keywords_sorted, times_sorted = zip(*timings)

# Plot
plt.figure(figsize=(15, 15))
plt.barh(keywords_sorted, times_sorted, color="skyblue")
plt.xlabel("Time (seconds)")
plt.ylabel("Keyword")
plt.title("Matching Time per Keyword")
plt.gca().invert_yaxis()  # Show slowest at the top
plt.tight_layout()
plt.show()

# %%
docs = text.split("\n\n")  # Assuming paragraphs are separated by double newlines

total_docs = len(docs)
docs_with_matches = 0

for para in docs:
    doc = nlp(para)
    matches = matcher(doc)
    if matches:
        docs_with_matches += 1

match_rate = (docs_with_matches / total_docs) * 100
print(f"Match Rate: {match_rate:.2f}%")
# Out:
# Match Rate: 99.30%

# %%
import time

total_time = 0.0
# time per match (not per doc), if per doc , set to 0 : match_counts=0
match_counts = len(matches)

for para in docs:
    doc = nlp(para)

    start = time.perf_counter()
    matches = matcher(doc)
    end = time.perf_counter()

    total_time += (end - start)
    match_counts += 1  # or only count if matches found: if matches: match_counts += 1

avg_time_per_match = total_time / match_counts if match_counts > 0 else 0
print(f"Average Time per Match: {avg_time_per_match:.6f} seconds")
# Out:
# Average Time per Match: 0.000288 seconds

# %%
# Create PhraseMatcher
from spacy.matcher import PhraseMatcher
timings = []
for kw in sorted(keywords):
    matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
    keyword_doc = nlp.make_doc(kw)
    matcher.add("KEYWORD", [keyword_doc])

    start_time = time.perf_counter()
    matches = matcher(doc)
    elapsed_time = time.perf_counter() - start_time

    timings.append((kw, elapsed_time))

# (Optional) Sort by elapsed time
timings.sort(key=lambda x: x[1], reverse=True)

# (Optional) Plot top 20 slowest
top_k = 20
top_timings = timings[:top_k]
keywords_top = [x[0] for x in top_timings]
times_top = [x[1] for x in top_timings]

plt.figure(figsize=(10, 6))
plt.barh(keywords_top[::-1], times_top[::-1])
plt.xlabel("Time (seconds)")
plt.title(f"Top {top_k} Slowest Keyword Match Times")
plt.tight_layout()
plt.show()

# %%
# Sort timings by elapsed time (ascending = fastest first)
timings.sort(key=lambda x: x[1])  # No reverse

# Get the 20 fastest matches
top_k = 20
fastest_timings = timings[:top_k]
keywords_top = [x[0] for x in fastest_timings]
times_top = [x[1] for x in fastest_timings]

# Plot
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(keywords_top[::-1], times_top[::-1])  # Reverse for top-down plot
plt.xlabel("Time (seconds)")
plt.title(f"Top {top_k} Fastest Keyword Match Times")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import pandas as pd

# Count matches per keyword
keyword_counts = Counter(keywords)

# Make sure the matcher has been defined and doc exists
if 'matcher' in locals() and 'doc' in locals():
    for match_id, start, end in matcher(doc):
        label = nlp.vocab.strings[match_id]
        if label.startswith("KEYWORD_"):
            keyword = label.replace("KEYWORD_", "")
            keyword_counts[keyword] += 1

# Convert to DataFrame
if keyword_counts:
    df = pd.DataFrame.from_dict(keyword_counts, orient='index', columns=['frequency']).sort_values(by='frequency', ascending=False)

    plt.figure(figsize=(10, len(df) * 0.5))
    sns.heatmap(df, annot=True, fmt='d', cmap="YlGnBu", cbar=False)
    plt.title("Keyword Match Frequency Heatmap")
    plt.xlabel("Frequency")
    plt.ylabel("Keyword")
    plt.tight_layout()
    plt.show()
else:
    print("No keyword matches found. Heatmap not generated.")

# %%
import time

timings = []

for para in text.split("\n\n"):  # or other sections
    doc = nlp(para)
    start = time.perf_counter()
    matcher(doc)
    end = time.perf_counter()
    timings.append(end - start)

# Plot histogram
plt.figure(figsize=(8, 4))
plt.hist(timings, bins=20, color="skyblue", edgecolor="black")
plt.title("Time Distribution of Matches per Paragraph")
plt.xlabel("Time (seconds)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# Span Overlap Visualization (with displacy)
# spaCy's built-in displacy visualizer to highlight matched spans

from spacy import displacy

# Get matches and convert to "entities" for displacy
ents = []

for match_id, start, end in matcher(doc):
    label = nlp.vocab.strings[match_id]
    span = doc[start:end]
    ents.append({
        "start": span.start_char,
        "end": span.end_char,
        "label": label.replace("KEYWORD_", "")
    })

# Render visualization
doc_user_data = {"text": doc.text, "ents": ents, "title": None}
displacy.render(doc_user_data, style="ent", manual=True, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">* **TerminationNoticePeriod**: 30 days<br>* **Renewal**: Auto-renewal annually unless terminated<br></div></span>

# %%
# NOT HELPFULLL

from sklearn.metrics import precision_score, recall_score, f1_score

# Define your sets
# ground_truth = {"latency", "availability", "jitter", "throughput", "reliability", "uptime", "accessibility", "activation time", "scalability", "encryption", "authentication", "protection"
                # "certification", "qos", "service", "support", "data", "management", "rights", "obligation", "review", "penalty", "cost", "stakeholders"}  # proposed sla schema

ground_truth={ "access", "agreement", "agreementid", "annual", "appendix", "applications","area", "audit", "auto", "availability", "availabilitybreach", "average", "basic", "breach", "broadband", "calendar", "capabilities",  "channels", "claim", "client",  "communication", "computing", "conditions", "confidentiality", "connectivity", "contact",  "coverage", "credit",  "critical", "customer", "customercontact", "cycle", "daily", "dashboard", "data", "date", "days", "definition", "degradation", "delay", "delivery", "deliverymethod", "description", "deviation", "device", "devices", "dispute", "disputes", "downlink", "downtime", "edge", "effective", "effectivedate", "effort", "egress", "email", "embb", "end", "enhanced", "enterprise", "equipment", "esim", "event", "exclusions", "expirationdate", "fault", "faults", "fee", "file", "format", "formula", "frequency", "function", "functioning", "g", "gateway", "gateways", "gbps", "general", "geographic", "gigabits", "governing", "guaranteed", "helpdesk", "high", "hour", "hourly", "hours", "id", "ids", "incident", "incidentresolutiontime", "incidentresponsetime", "incidents", "industrial", "information", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "jurisdiction", "kpi", "latency", "latencybreach", "law", "level", "levels", "locations", "loss", "low", "maintenance", "major", "management", "map", "maps", "master", "max", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "mediation", "medium", "method", "metric", "metrics", "metropolitan", "milliseconds", "min", "minimum", "minor", "minute", "minutes", "mobile", "monitor", "monitoring", "month", "monthly", "months", "ms", "negotiation", "network", "networks", "new", "nexgen", "nextgen", "notice", "notification", "notify", "objective", "objectives", "online", "outage", "packet", "parties", "party", "pdf", "peak", "penalties", "penalty", "percentage", "percentile", "performance", "period", "phone", "plane", "planned", "pm", "point", "policy", "portal", "premises", "premium", "prioritization", "priority", "probes", "profiles", "provider", "providersupportemail", "provision", "quarterly", "radio", "rate", "receipt", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "report", "reporting", "reports", "requirements", "resolution", "respond", "response", "responsibilities", "restoration", "review", "rights", "round","scope", "segment", "service", "servicename", "sim", "sla", "slices", "slos", "smartphones", "solutions", "specific", "speed", "status", "streaming", "subset", "support", "supporteddevices", "tablets", "target", "technology", "telco", "telecom", "termination", "terminationnoticeperiod", "terms", "tests", "threshold", "throughput", "tickets", "tiers", "time", "tolerated", "tools", "total", "tracking", "traffic", "transfers", "trip", "trt", "type", "ue", "ues", "updates", "upf", "uplink", "uptime", "usage", "usecases", "user", "users", "workdays", "writing", "zone", "zones" }



# ground_truth = {"latency", "availability", "jitter", "throughput", "reliability", "uptime", "accessibility", "scalability", "encryption",
#                 "qos", "support", "data", "management", "rights", "obligation", "review", "penalty"}  # proposed sla schema

predicted_keywords = keywords       # from your matcher

# Build the union set of all unique keywords seen
all_keywords = sorted(ground_truth.union(predicted_keywords))

# Create binary vectors
y_true = [1 if kw in ground_truth else 0 for kw in all_keywords]
y_pred = [1 if kw in predicted_keywords else 0 for kw in all_keywords]

# Now compute scores
precision = precision_score(y_true, y_pred, zero_division=0)
recall = recall_score(y_true, y_pred, zero_division=0)
f1 = f1_score(y_true, y_pred, zero_division=0)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.9357142857142857
# Recall: 1.0
# F1 Score: 0.966789667896679

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Predicted', 'Predicted'],
            yticklabels=['Not Ground Truth', 'Ground Truth'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **large English NLP model provided by spaCy**

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 4.2 MB/s eta 0:00:00
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from google.colab import files

# Load the large English model with word vectors
nlp = spacy.load("en_core_web_lg")


# Step 3: Read the SLA text file
with open("AlldataSLA.txt", "r", encoding="utf-8") as file:
    text = file.read()

# Step 4: Process the text using spaCy
doc = nlp(text)


# SLA-related keywords to compare against
keywords={ "access", "acme", "activities", "advance", "agreement", "agreementid", "amendment", "amendments", "anniversary", "annual", "appendix", "applications", "ar", "area", "audit", "auto", "availability", "availabilitybreach", "average", "basic", "breach", "broadband", "calendar", "capabilities", "capacity", "cards", "cell", "changes", "channels", "claim", "client", "cloud", "communication", "computing", "conditions", "confidentiality", "connectivity", "contact", "core", "corp", "coverage", "coveragearea", "cpe", "credit", "credits", "critical", "customer", "customercontact", "customerz", "cycle", "daily", "dashboard", "data", "date", "days", "definition", "degradation", "delay", "delivery", "deliverymethod", "description", "deviation", "device", "devices", "dispute", "disputes", "downlink", "downtime", "edge", "effective", "effectivedate", "effort", "egress", "email", "embb", "end", "enhanced", "enterprise", "equipment", "esim", "event", "exclusions", "expirationdate", "fault", "faults", "fee", "file", "format", "formula", "frequency", "function", "functioning", "g", "gateway", "gateways", "gbps", "general", "geographic", "gigabits", "governing", "guaranteed", "helpdesk", "high", "hour", "hourly", "hours", "id", "ids", "incident", "incidentresolutiontime", "incidentresponsetime", "incidents", "industrial", "information", "infrastructure", "ingress", "inquiries", "installation", "intervals", "invoice", "issues", "jitter", "jurisdiction", "kpi", "latency", "latencybreach", "law", "level", "levels", "locations", "loss", "low", "maintenance", "major", "management", "map", "maps", "master", "max", "maximum", "mbps", "measurement", "measurementperiod", "measurements", "mediation", "medium", "method", "metric", "metrics", "metropolitan", "milliseconds", "min", "minimum", "minor", "minute", "minutes", "mobile", "monitor", "monitoring", "month", "monthly", "months", "ms", "negotiation", "network", "networks", "new", "nexgen", "nextgen", "notice", "notification", "notify", "objective", "objectives", "online", "outage", "packet", "parties", "party", "pdf", "peak", "penalties", "penalty", "percentage", "percentile", "performance", "period", "phone", "plane", "planned", "pm", "point", "policy", "portal", "premises", "premium", "prioritization", "priority", "probes", "profiles", "provider", "providersupportemail", "provision", "quarterly", "radio", "rate", "receipt", "recipient", "refund", "region", "release", "reliability", "remedies", "renewal", "report", "reporting", "reports", "requirements", "resolution", "respond", "response", "responsibilities", "restoration", "review", "rights", "round","scope", "segment", "service", "servicename", "sim", "sla", "slices", "slos", "smartphones", "solutions", "specific", "speed", "status", "streaming", "subset", "support", "supporteddevices", "tablets", "target", "technology", "telco", "telecom", "termination", "terminationnoticeperiod", "terms", "tests", "threshold", "throughput", "tickets", "tiers", "time", "tolerated", "tools", "total", "tracking", "traffic", "transfers", "trip", "trt", "type", "ue", "ues", "updates", "upf", "uplink", "uptime", "usage", "usecases", "user", "users", "workdays", "writing", "zone", "zones" }

# Convert keywords to spaCy tokens (handle phrases properly)
keyword_tokens = {kw: nlp(kw)[0] if len(nlp(kw)) == 1 else nlp(kw) for kw in keywords}


# Compare each token in the doc to each keyword
for token in doc:
    if token.has_vector:
        for kw, kw_token in keyword_tokens.items():
            if isinstance(kw_token, spacy.tokens.Token):
                # Single-word keyword
                similarity = token.similarity(kw_token)
            else:
                # Multi-word keyword (e.g., "Business Days") — average similarity
                similarity = sum(token.similarity(t) for t in kw_token) / len(kw_token)

            if similarity > 0.6:
                print(f"Doc token '{token.text}' is similar to keyword '{kw}' (Similarity: {similarity:.2f})")
# Out:
# /tmp/ipython-input-25-2691917800.py:28: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   similarity = token.similarity(kw_token)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'SERVICE' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'SERVICE' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'SERVICE' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'LEVEL' is similar to keyword 'levels' (Similarity: 0.85)
# Doc token 'LEVEL' is similar to keyword 'high' (Similarity: 0.60)
# Doc token 'LEVEL' is similar to keyword 'level' (Similarity: 1.00)
# Doc token 'AGREEMENT' is similar to keyword 'dispute' (Similarity: 0.65)
# Doc token 'AGREEMENT' is similar to keyword 'negotiation' (Similarity: 0.60)
# Doc token 'AGREEMENT' is similar to keyword 'agreement' (Similarity: 1.00)
# Doc token 'SLA' is similar to keyword 'sla' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Provider' is similar to keyword 'service' (Similarity: 0.66)
# Doc token 'Provider' is similar to keyword 'provider' (Similarity: 1.00)
# Doc token 'Telco' is similar to keyword 'telco' (Similarity: 1.00)
# Doc token 'Telco' is similar to keyword 'telecom' (Similarity: 0.79)
# Doc token 'Solutions' is similar to keyword 'solutions' (Similarity: 1.00)
# Doc token 'Solutions' is similar to keyword 'technology' (Similarity: 0.62)
# Doc token 'Solutions' is similar to keyword 'management' (Similarity: 0.60)
# Doc token 'Solutions' is similar to keyword 'enterprise' (Similarity: 0.60)
# Doc token 'Customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'Customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'Customer' is similar to keyword 'client' (Similarity: 0.62)
# Doc token 'Enterprise' is similar to keyword 'solutions' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'management' (Similarity: 0.63)
# Doc token 'Enterprise' is similar to keyword 'computing' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'infrastructure' (Similarity: 0.63)
# Doc token 'Enterprise' is similar to keyword 'enterprise' (Similarity: 1.00)
# Doc token 'Client' is similar to keyword 'customer' (Similarity: 0.62)
# Doc token 'Client' is similar to keyword 'client' (Similarity: 1.00)
# Doc token 'Effective' is similar to keyword 'effective' (Similarity: 1.00)
# Doc token 'Date' is similar to keyword 'date' (Similarity: 1.00)
# Doc token 'Review' is similar to keyword 'review' (Similarity: 1.00)
# Doc token 'Cycle' is similar to keyword 'cycle' (Similarity: 1.00)
# Doc token 'Quarterly' is similar to keyword 'monthly' (Similarity: 0.73)
# Doc token 'Quarterly' is similar to keyword 'quarterly' (Similarity: 1.00)
# Doc token 'Quarterly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'SERVICE' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'SERVICE' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'SERVICE' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'AVAILABILITY' is similar to keyword 'availability' (Similarity: 1.00)
# Doc token 'Target' is similar to keyword 'target' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'monthly' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'quarterly' (Similarity: 0.73)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'monthly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'uptime' is similar to keyword 'uptime' (Similarity: 1.00)
# Doc token 'uptime' is similar to keyword 'downtime' (Similarity: 0.61)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'Exclusions' is similar to keyword 'exclusions' (Similarity: 1.00)
# Doc token 'Scheduled' is similar to keyword 'planned' (Similarity: 0.69)
# Doc token 'maintenance' is similar to keyword 'maintenance' (Similarity: 1.00)
# Doc token 'maintenance' is similar to keyword 'installation' (Similarity: 0.61)
# Doc token 'max' is similar to keyword 'maximum' (Similarity: 0.65)
# Doc token 'max' is similar to keyword 'max' (Similarity: 1.00)
# Doc token 'month' is similar to keyword 'monthly' (Similarity: 0.64)
# Doc token 'month' is similar to keyword 'months' (Similarity: 0.76)
# Doc token 'month' is similar to keyword 'month' (Similarity: 1.00)
# Doc token 'month' is similar to keyword 'days' (Similarity: 0.70)
# Doc token 'notified' is similar to keyword 'notify' (Similarity: 0.81)
# Doc token 'notified' is similar to keyword 'notification' (Similarity: 0.69)
# Doc token 'advance' is similar to keyword 'advance' (Similarity: 1.00)
# Doc token 'Formula' is similar to keyword 'formula' (Similarity: 1.00)
# Doc token 'Total' is similar to keyword 'average' (Similarity: 0.63)
# Doc token 'Total' is similar to keyword 'total' (Similarity: 1.00)
# Doc token 'Minutes' is similar to keyword 'hours' (Similarity: 0.74)
# Doc token 'Minutes' is similar to keyword 'hour' (Similarity: 0.77)
# Doc token 'Minutes' is similar to keyword 'min' (Similarity: 0.69)
# Doc token 'Minutes' is similar to keyword 'minutes' (Similarity: 1.00)
# Doc token 'Minutes' is similar to keyword 'minute' (Similarity: 0.80)
# Doc token 'Downtime' is similar to keyword 'uptime' (Similarity: 0.61)
# Doc token 'Downtime' is similar to keyword 'downtime' (Similarity: 1.00)
# Doc token 'Total' is similar to keyword 'average' (Similarity: 0.63)
# Doc token 'Total' is similar to keyword 'total' (Similarity: 1.00)
# Doc token 'Minutes' is similar to keyword 'hours' (Similarity: 0.74)
# Doc token 'Minutes' is similar to keyword 'hour' (Similarity: 0.77)
# Doc token 'Minutes' is similar to keyword 'min' (Similarity: 0.69)
# Doc token 'Minutes' is similar to keyword 'minutes' (Similarity: 1.00)
# Doc token 'Minutes' is similar to keyword 'minute' (Similarity: 0.80)
# Doc token 'Penalty' is similar to keyword 'penalty' (Similarity: 1.00)
# Doc token 'Penalty' is similar to keyword 'penalties' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'target' is similar to keyword 'target' (Similarity: 1.00)
# Doc token 'NETWORK' is similar to keyword 'connectivity' (Similarity: 0.62)
# Doc token 'NETWORK' is similar to keyword 'networks' (Similarity: 0.88)
# Doc token 'NETWORK' is similar to keyword 'network' (Similarity: 1.00)
# Doc token 'LATENCY' is similar to keyword 'throughput' (Similarity: 0.63)
# Doc token 'LATENCY' is similar to keyword 'jitter' (Similarity: 0.65)
# Doc token 'LATENCY' is similar to keyword 'latency' (Similarity: 1.00)
# Doc token 'Target' is similar to keyword 'target' (Similarity: 1.00)
# Doc token 'end' is similar to keyword 'point' (Similarity: 0.62)
# Doc token 'end' is similar to keyword 'end' (Similarity: 1.00)
# Doc token 'end' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'end' is similar to keyword 'point' (Similarity: 0.62)
# Doc token 'end' is similar to keyword 'end' (Similarity: 1.00)
# Doc token 'end' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'UE' is similar to keyword 'ue' (Similarity: 1.00)
# Doc token 'Core' is similar to keyword 'core' (Similarity: 1.00)
# Doc token 'Scope' is similar to keyword 'scope' (Similarity: 1.00)
# Doc token 'Urban' is similar to keyword 'metropolitan' (Similarity: 0.65)
# Doc token 'zones' is similar to keyword 'zone' (Similarity: 0.75)
# Doc token 'zones' is similar to keyword 'zones' (Similarity: 1.00)
# Doc token 'coverage' is similar to keyword 'coverage' (Similarity: 1.00)
# Doc token 'map' is similar to keyword 'maps' (Similarity: 0.86)
# Doc token 'map' is similar to keyword 'map' (Similarity: 1.00)
# Doc token 'Appendix' is similar to keyword 'appendix' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'percentile' is similar to keyword 'percentile' (Similarity: 1.00)
# Doc token 'hourly' is similar to keyword 'hourly' (Similarity: 1.00)
# Doc token 'probes' is similar to keyword 'probes' (Similarity: 1.00)
# Doc token 'Penalty' is similar to keyword 'penalty' (Similarity: 1.00)
# Doc token 'Penalty' is similar to keyword 'penalties' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'breach' is similar to keyword 'breach' (Similarity: 1.00)
# Doc token 'DOWNLINK' is similar to keyword 'uplink' (Similarity: 0.89)
# Doc token 'DOWNLINK' is similar to keyword 'downlink' (Similarity: 1.00)
# Doc token 'THROUGHPUT' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'THROUGHPUT' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Target' is similar to keyword 'target' (Similarity: 1.00)
# Doc token 'Mbps' is similar to keyword 'mbps' (Similarity: 1.00)
# Doc token 'peak' is similar to keyword 'peak' (Similarity: 1.00)
# Doc token 'Mbps' is similar to keyword 'mbps' (Similarity: 1.00)
# Doc token 'average' is similar to keyword 'average' (Similarity: 1.00)
# Doc token 'average' is similar to keyword 'total' (Similarity: 0.63)
# Doc token 'average' is similar to keyword 'rate' (Similarity: 0.61)
# Doc token 'average' is similar to keyword 'percentage' (Similarity: 0.73)
# Doc token 'device' is similar to keyword 'device' (Similarity: 1.00)
# Doc token 'device' is similar to keyword 'devices' (Similarity: 0.86)
# Doc token 'Conditions' is similar to keyword 'conditions' (Similarity: 1.00)
# Doc token 'network' is similar to keyword 'connectivity' (Similarity: 0.62)
# Doc token 'network' is similar to keyword 'networks' (Similarity: 0.88)
# Doc token 'network' is similar to keyword 'network' (Similarity: 1.00)
# Doc token 'UEs' is similar to keyword 'ues' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'Daily' is similar to keyword 'daily' (Similarity: 1.00)
# Doc token 'speed' is similar to keyword 'speed' (Similarity: 1.00)
# Doc token 'tests' is similar to keyword 'tests' (Similarity: 1.00)
# Doc token 'PM' is similar to keyword 'pm' (Similarity: 1.00)
# Doc token 'workdays' is similar to keyword 'workdays' (Similarity: 1.00)
# Doc token 'Penalty' is similar to keyword 'penalty' (Similarity: 1.00)
# Doc token 'Penalty' is similar to keyword 'penalties' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'deviation' is similar to keyword 'deviation' (Similarity: 1.00)
# Doc token 'RELIABILITY' is similar to keyword 'reliability' (Similarity: 1.00)
# Doc token 'Target' is similar to keyword 'target' (Similarity: 1.00)
# Doc token 'packet' is similar to keyword 'packet' (Similarity: 1.00)
# Doc token 'loss' is similar to keyword 'loss' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'probes' is similar to keyword 'probes' (Similarity: 1.00)
# Doc token 'every' is similar to keyword 'time' (Similarity: 0.69)
# Doc token 'minutes' is similar to keyword 'hours' (Similarity: 0.74)
# Doc token 'minutes' is similar to keyword 'hour' (Similarity: 0.77)
# Doc token 'minutes' is similar to keyword 'min' (Similarity: 0.69)
# Doc token 'minutes' is similar to keyword 'minutes' (Similarity: 1.00)
# Doc token 'minutes' is similar to keyword 'minute' (Similarity: 0.80)
# Doc token 'Penalty' is similar to keyword 'penalty' (Similarity: 1.00)
# Doc token 'Penalty' is similar to keyword 'penalties' (Similarity: 0.85)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'breach' is similar to keyword 'breach' (Similarity: 1.00)
# Doc token 'FAULT' is similar to keyword 'faults' (Similarity: 0.74)
# Doc token 'FAULT' is similar to keyword 'fault' (Similarity: 1.00)
# Doc token 'RESTORATION' is similar to keyword 'restoration' (Similarity: 1.00)
# Doc token 'Critical' is similar to keyword 'critical' (Similarity: 1.00)
# Doc token 'Faults' is similar to keyword 'faults' (Similarity: 1.00)
# Doc token 'Faults' is similar to keyword 'fault' (Similarity: 0.74)
# Doc token 'hours' is similar to keyword 'months' (Similarity: 0.63)
# Doc token 'hours' is similar to keyword 'hours' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'hour' (Similarity: 0.86)
# Doc token 'hours' is similar to keyword 'minutes' (Similarity: 0.74)
# Doc token 'hours' is similar to keyword 'days' (Similarity: 0.77)
# Doc token 'Critical' is similar to keyword 'critical' (Similarity: 1.00)
# Doc token 'Faults' is similar to keyword 'faults' (Similarity: 1.00)
# Doc token 'Faults' is similar to keyword 'fault' (Similarity: 0.74)
# Doc token 'hours' is similar to keyword 'months' (Similarity: 0.63)
# Doc token 'hours' is similar to keyword 'hours' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'hour' (Similarity: 0.86)
# Doc token 'hours' is similar to keyword 'minutes' (Similarity: 0.74)
# Doc token 'hours' is similar to keyword 'days' (Similarity: 0.77)
# Doc token 'Penalty' is similar to keyword 'penalty' (Similarity: 1.00)
# Doc token 'Penalty' is similar to keyword 'penalties' (Similarity: 0.85)
# Doc token 'hour' is similar to keyword 'hours' (Similarity: 0.86)
# Doc token 'hour' is similar to keyword 'hour' (Similarity: 1.00)
# Doc token 'hour' is similar to keyword 'min' (Similarity: 0.64)
# Doc token 'hour' is similar to keyword 'minutes' (Similarity: 0.77)
# Doc token 'hour' is similar to keyword 'days' (Similarity: 0.64)
# Doc token 'hour' is similar to keyword 'minute' (Similarity: 0.74)
# Doc token 'delay' is similar to keyword 'delay' (Similarity: 1.00)
# Doc token 'target' is similar to keyword 'target' (Similarity: 1.00)
# Doc token 'REPORTING' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'REPORTING' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'REPORTING' is similar to keyword 'report' (Similarity: 0.70)
# Doc token 'SUPPORT' is similar to keyword 'support' (Similarity: 1.00)
# Doc token 'KPI' is similar to keyword 'kpi' (Similarity: 1.00)
# Doc token 'Reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'Reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'Reports' is similar to keyword 'report' (Similarity: 0.84)
# Doc token 'Monthly' is similar to keyword 'monthly' (Similarity: 1.00)
# Doc token 'Monthly' is similar to keyword 'quarterly' (Similarity: 0.73)
# Doc token 'Monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'Monthly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'next' is similar to keyword 'month' (Similarity: 0.60)
# Doc token 'next' is similar to keyword 'end' (Similarity: 0.67)
# Doc token 'next' is similar to keyword 'time' (Similarity: 0.63)
# Doc token 'month' is similar to keyword 'monthly' (Similarity: 0.64)
# Doc token 'month' is similar to keyword 'months' (Similarity: 0.76)
# Doc token 'month' is similar to keyword 'month' (Similarity: 1.00)
# Doc token 'month' is similar to keyword 'days' (Similarity: 0.70)
# Doc token 'Support' is similar to keyword 'support' (Similarity: 1.00)
# Doc token 'helpdesk' is similar to keyword 'helpdesk' (Similarity: 1.00)
# Doc token 'max' is similar to keyword 'maximum' (Similarity: 0.65)
# Doc token 'max' is similar to keyword 'max' (Similarity: 1.00)
# Doc token 'min' is similar to keyword 'hour' (Similarity: 0.64)
# Doc token 'min' is similar to keyword 'min' (Similarity: 1.00)
# Doc token 'min' is similar to keyword 'minutes' (Similarity: 0.69)
# Doc token 'response' is similar to keyword 'response' (Similarity: 1.00)
# Doc token 'response' is similar to keyword 'respond' (Similarity: 0.71)
# Doc token 'tickets' is similar to keyword 'tickets' (Similarity: 1.00)
# Doc token 'Audit' is similar to keyword 'audit' (Similarity: 1.00)
# Doc token 'Rights' is similar to keyword 'rights' (Similarity: 1.00)
# Doc token 'Customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'Customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'Customer' is similar to keyword 'client' (Similarity: 0.62)
# Doc token 'request' is similar to keyword 'notify' (Similarity: 0.63)
# Doc token 'measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'quarterly' is similar to keyword 'monthly' (Similarity: 0.73)
# Doc token 'quarterly' is similar to keyword 'quarterly' (Similarity: 1.00)
# Doc token 'quarterly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'SERVICE' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'SERVICE' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'SERVICE' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'CREDITS' is similar to keyword 'credit' (Similarity: 0.62)
# Doc token 'CREDITS' is similar to keyword 'credits' (Similarity: 1.00)
# Doc token 'Max' is similar to keyword 'maximum' (Similarity: 0.65)
# Doc token 'Max' is similar to keyword 'max' (Similarity: 1.00)
# Doc token 'Annual' is similar to keyword 'monthly' (Similarity: 0.64)
# Doc token 'Annual' is similar to keyword 'quarterly' (Similarity: 0.64)
# Doc token 'Annual' is similar to keyword 'annual' (Similarity: 1.00)
# Doc token 'Credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'Credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'monthly' is similar to keyword 'monthly' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'quarterly' (Similarity: 0.73)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'monthly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'fee' is similar to keyword 'fee' (Similarity: 1.00)
# Doc token 'fee' is similar to keyword 'refund' (Similarity: 0.68)
# Doc token 'Claim' is similar to keyword 'claim' (Similarity: 1.00)
# Doc token 'days' is similar to keyword 'months' (Similarity: 0.80)
# Doc token 'days' is similar to keyword 'month' (Similarity: 0.70)
# Doc token 'days' is similar to keyword 'hours' (Similarity: 0.77)
# Doc token 'days' is similar to keyword 'hour' (Similarity: 0.64)
# Doc token 'days' is similar to keyword 'days' (Similarity: 1.00)
# Doc token 'days' is similar to keyword 'time' (Similarity: 0.65)
# Doc token 'report' is similar to keyword 'reporting' (Similarity: 0.70)
# Doc token 'report' is similar to keyword 'reports' (Similarity: 0.84)
# Doc token 'report' is similar to keyword 'report' (Similarity: 1.00)
# Doc token 'receipt' is similar to keyword 'receipt' (Similarity: 1.00)
# Doc token 'receipt' is similar to keyword 'notification' (Similarity: 0.61)
# Doc token 'receipt' is similar to keyword 'invoice' (Similarity: 0.67)
# Doc token 'receipt' is similar to keyword 'refund' (Similarity: 0.66)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Level' is similar to keyword 'levels' (Similarity: 0.85)
# Doc token 'Level' is similar to keyword 'high' (Similarity: 0.60)
# Doc token 'Level' is similar to keyword 'level' (Similarity: 1.00)
# Doc token 'Agreement' is similar to keyword 'dispute' (Similarity: 0.65)
# Doc token 'Agreement' is similar to keyword 'negotiation' (Similarity: 0.60)
# Doc token 'Agreement' is similar to keyword 'agreement' (Similarity: 1.00)
# Doc token 'SLA' is similar to keyword 'sla' (Similarity: 1.00)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'Enhanced' is similar to keyword 'capabilities' (Similarity: 0.63)
# Doc token 'Enhanced' is similar to keyword 'enhanced' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'phone' (Similarity: 0.70)
# Doc token 'Mobile' is similar to keyword 'mobile' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'smartphones' (Similarity: 0.69)
# Doc token 'Broadband' is similar to keyword 'connectivity' (Similarity: 0.60)
# Doc token 'Broadband' is similar to keyword 'broadband' (Similarity: 1.00)
# Doc token 'Broadband' is similar to keyword 'telecom' (Similarity: 0.63)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Agreement' is similar to keyword 'dispute' (Similarity: 0.65)
# Doc token 'Agreement' is similar to keyword 'negotiation' (Similarity: 0.60)
# Doc token 'Agreement' is similar to keyword 'agreement' (Similarity: 1.00)
# Doc token 'Effective' is similar to keyword 'effective' (Similarity: 1.00)
# Doc token 'Date' is similar to keyword 'date' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Provider' is similar to keyword 'service' (Similarity: 0.66)
# Doc token 'Provider' is similar to keyword 'provider' (Similarity: 1.00)
# Doc token 'NexGen' is similar to keyword 'nexgen' (Similarity: 1.00)
# Doc token 'Telecom' is similar to keyword 'telco' (Similarity: 0.79)
# Doc token 'Telecom' is similar to keyword 'broadband' (Similarity: 0.63)
# Doc token 'Telecom' is similar to keyword 'telecom' (Similarity: 1.00)
# Doc token 'Customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'Customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'Customer' is similar to keyword 'client' (Similarity: 0.62)
# Doc token 'Enterprise' is similar to keyword 'solutions' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'management' (Similarity: 0.63)
# Doc token 'Enterprise' is similar to keyword 'computing' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'infrastructure' (Similarity: 0.63)
# Doc token 'Enterprise' is similar to keyword 'enterprise' (Similarity: 1.00)
# Doc token 'Solutions' is similar to keyword 'solutions' (Similarity: 1.00)
# Doc token 'Solutions' is similar to keyword 'technology' (Similarity: 0.62)
# Doc token 'Solutions' is similar to keyword 'management' (Similarity: 0.60)
# Doc token 'Solutions' is similar to keyword 'enterprise' (Similarity: 0.60)
# Doc token 'Corp.' is similar to keyword 'corp' (Similarity: 0.78)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Type' is similar to keyword 'type' (Similarity: 1.00)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'Enhanced' is similar to keyword 'capabilities' (Similarity: 0.63)
# Doc token 'Enhanced' is similar to keyword 'enhanced' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'phone' (Similarity: 0.70)
# Doc token 'Mobile' is similar to keyword 'mobile' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'smartphones' (Similarity: 0.69)
# Doc token 'Broadband' is similar to keyword 'connectivity' (Similarity: 0.60)
# Doc token 'Broadband' is similar to keyword 'broadband' (Similarity: 1.00)
# Doc token 'Broadband' is similar to keyword 'telecom' (Similarity: 0.63)
# Doc token 'High' is similar to keyword 'high' (Similarity: 1.00)
# Doc token 'High' is similar to keyword 'level' (Similarity: 0.60)
# Doc token 'High' is similar to keyword 'low' (Similarity: 0.76)
# Doc token 'Capacity' is similar to keyword 'capacity' (Similarity: 1.00)
# Doc token 'Data' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'Data' is similar to keyword 'data' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Description' is similar to keyword 'description' (Similarity: 1.00)
# Doc token 'SLA' is similar to keyword 'sla' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'terms' is similar to keyword 'terms' (Similarity: 1.00)
# Doc token 'terms' is similar to keyword 'general' (Similarity: 0.62)
# Doc token 'terms' is similar to keyword 'specific' (Similarity: 0.61)
# Doc token 'conditions' is similar to keyword 'conditions' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'provision' is similar to keyword 'amendment' (Similarity: 0.63)
# Doc token 'provision' is similar to keyword 'amendments' (Similarity: 0.60)
# Doc token 'provision' is similar to keyword 'provision' (Similarity: 1.00)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'Enhanced' is similar to keyword 'capabilities' (Similarity: 0.63)
# Doc token 'Enhanced' is similar to keyword 'enhanced' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'phone' (Similarity: 0.70)
# Doc token 'Mobile' is similar to keyword 'mobile' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'smartphones' (Similarity: 0.69)
# Doc token 'Broadband' is similar to keyword 'connectivity' (Similarity: 0.60)
# Doc token 'Broadband' is similar to keyword 'broadband' (Similarity: 1.00)
# Doc token 'Broadband' is similar to keyword 'telecom' (Similarity: 0.63)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Enterprise' is similar to keyword 'solutions' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'management' (Similarity: 0.63)
# Doc token 'Enterprise' is similar to keyword 'computing' (Similarity: 0.60)
# Doc token 'Enterprise' is similar to keyword 'infrastructure' (Similarity: 0.63)
# Doc token 'Enterprise' is similar to keyword 'enterprise' (Similarity: 1.00)
# Doc token 'Solutions' is similar to keyword 'solutions' (Similarity: 1.00)
# Doc token 'Solutions' is similar to keyword 'technology' (Similarity: 0.62)
# Doc token 'Solutions' is similar to keyword 'management' (Similarity: 0.60)
# Doc token 'Solutions' is similar to keyword 'enterprise' (Similarity: 0.60)
# Doc token 'Corp.' is similar to keyword 'corp' (Similarity: 0.78)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'deliver' is similar to keyword 'delivery' (Similarity: 0.62)
# Doc token 'high' is similar to keyword 'high' (Similarity: 1.00)
# Doc token 'high' is similar to keyword 'level' (Similarity: 0.60)
# Doc token 'high' is similar to keyword 'low' (Similarity: 0.76)
# Doc token 'throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'low' is similar to keyword 'high' (Similarity: 0.76)
# Doc token 'low' is similar to keyword 'rate' (Similarity: 0.60)
# Doc token 'low' is similar to keyword 'low' (Similarity: 1.00)
# Doc token 'latency' is similar to keyword 'throughput' (Similarity: 0.63)
# Doc token 'latency' is similar to keyword 'jitter' (Similarity: 0.65)
# Doc token 'latency' is similar to keyword 'latency' (Similarity: 1.00)
# Doc token 'connectivity' is similar to keyword 'connectivity' (Similarity: 1.00)
# Doc token 'connectivity' is similar to keyword 'networks' (Similarity: 0.61)
# Doc token 'connectivity' is similar to keyword 'network' (Similarity: 0.62)
# Doc token 'connectivity' is similar to keyword 'capabilities' (Similarity: 0.62)
# Doc token 'connectivity' is similar to keyword 'broadband' (Similarity: 0.60)
# Doc token 'data' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'data' is similar to keyword 'data' (Similarity: 1.00)
# Doc token 'applications' is similar to keyword 'applications' (Similarity: 1.00)
# Doc token 'applications' is similar to keyword 'capabilities' (Similarity: 0.61)
# Doc token 'but' is similar to keyword 'point' (Similarity: 0.62)
# Doc token 'but' is similar to keyword 'end' (Similarity: 0.61)
# Doc token 'but' is similar to keyword 'time' (Similarity: 0.62)
# Doc token 'not' is similar to keyword 'notice' (Similarity: 0.60)
# Doc token 'not' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'cloud' is similar to keyword 'cloud' (Similarity: 1.00)
# Doc token 'computing' is similar to keyword 'technology' (Similarity: 0.62)
# Doc token 'computing' is similar to keyword 'computing' (Similarity: 1.00)
# Doc token 'computing' is similar to keyword 'enterprise' (Similarity: 0.60)
# Doc token 'high' is similar to keyword 'high' (Similarity: 1.00)
# Doc token 'high' is similar to keyword 'level' (Similarity: 0.60)
# Doc token 'high' is similar to keyword 'low' (Similarity: 0.76)
# Doc token 'definition' is similar to keyword 'definition' (Similarity: 1.00)
# Doc token 'streaming' is similar to keyword 'streaming' (Similarity: 1.00)
# Doc token 'file' is similar to keyword 'file' (Similarity: 1.00)
# Doc token 'file' is similar to keyword 'format' (Similarity: 0.66)
# Doc token 'transfers' is similar to keyword 'transfers' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Scope' is similar to keyword 'scope' (Similarity: 1.00)
# Doc token 'Geographic' is similar to keyword 'geographic' (Similarity: 1.00)
# Doc token 'Coverage' is similar to keyword 'coverage' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'area' is similar to keyword 'area' (Similarity: 1.00)
# Doc token 'area' is similar to keyword 'region' (Similarity: 0.66)
# Doc token 'Metropolitan' is similar to keyword 'metropolitan' (Similarity: 1.00)
# Doc token 'Region' is similar to keyword 'area' (Similarity: 0.66)
# Doc token 'Region' is similar to keyword 'region' (Similarity: 1.00)
# Doc token 'coverage' is similar to keyword 'coverage' (Similarity: 1.00)
# Doc token 'Industrial' is similar to keyword 'industrial' (Similarity: 1.00)
# Doc token 'Zone' is similar to keyword 'zone' (Similarity: 1.00)
# Doc token 'Zone' is similar to keyword 'zones' (Similarity: 0.75)
# Doc token 'Specific' is similar to keyword 'terms' (Similarity: 0.61)
# Doc token 'Specific' is similar to keyword 'specific' (Similarity: 1.00)
# Doc token 'Specific' is similar to keyword 'information' (Similarity: 0.64)
# Doc token 'Specific' is similar to keyword 'requirements' (Similarity: 0.61)
# Doc token 'cell' is similar to keyword 'cell' (Similarity: 1.00)
# Doc token 'cell' is similar to keyword 'phone' (Similarity: 0.62)
# Doc token 'IDs' is similar to keyword 'ids' (Similarity: 1.00)
# Doc token 'coverage' is similar to keyword 'coverage' (Similarity: 1.00)
# Doc token 'maps' is similar to keyword 'maps' (Similarity: 1.00)
# Doc token 'maps' is similar to keyword 'map' (Similarity: 0.86)
# Doc token 'Appendix' is similar to keyword 'appendix' (Similarity: 1.00)
# Doc token 'User' is similar to keyword 'users' (Similarity: 0.79)
# Doc token 'User' is similar to keyword 'user' (Similarity: 1.00)
# Doc token 'Devices' is similar to keyword 'device' (Similarity: 0.86)
# Doc token 'Devices' is similar to keyword 'devices' (Similarity: 1.00)
# Doc token 'Devices' is similar to keyword 'smartphones' (Similarity: 0.63)
# Doc token 'Support' is similar to keyword 'support' (Similarity: 1.00)
# Doc token 'devices' is similar to keyword 'device' (Similarity: 0.86)
# Doc token 'devices' is similar to keyword 'devices' (Similarity: 1.00)
# Doc token 'devices' is similar to keyword 'smartphones' (Similarity: 0.63)
# Doc token 'smartphones' is similar to keyword 'devices' (Similarity: 0.63)
# Doc token 'smartphones' is similar to keyword 'mobile' (Similarity: 0.69)
# Doc token 'smartphones' is similar to keyword 'smartphones' (Similarity: 1.00)
# Doc token 'tablets' is similar to keyword 'tablets' (Similarity: 1.00)
# Doc token 'gateways' is similar to keyword 'gateways' (Similarity: 1.00)
# Doc token 'gateways' is similar to keyword 'gateway' (Similarity: 0.77)
# Doc token 'utilizing' is similar to keyword 'method' (Similarity: 0.60)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'SIM' is similar to keyword 'sim' (Similarity: 1.00)
# Doc token 'cards' is similar to keyword 'cards' (Similarity: 1.00)
# Doc token 'profiles' is similar to keyword 'profiles' (Similarity: 1.00)
# Doc token 'provided' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'NexGen' is similar to keyword 'nexgen' (Similarity: 1.00)
# Doc token 'Telecom' is similar to keyword 'telco' (Similarity: 0.79)
# Doc token 'Telecom' is similar to keyword 'broadband' (Similarity: 0.63)
# Doc token 'Telecom' is similar to keyword 'telecom' (Similarity: 1.00)
# Doc token 'Traffic' is similar to keyword 'traffic' (Similarity: 1.00)
# Doc token 'Prioritization' is similar to keyword 'prioritization' (Similarity: 1.00)
# Doc token 'traffic' is similar to keyword 'traffic' (Similarity: 1.00)
# Doc token 'receive' is similar to keyword 'recipient' (Similarity: 0.62)
# Doc token 'priority' is similar to keyword 'priority' (Similarity: 1.00)
# Doc token 'effort' is similar to keyword 'effort' (Similarity: 1.00)
# Doc token 'traffic' is similar to keyword 'traffic' (Similarity: 1.00)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'defined' is similar to keyword 'definition' (Similarity: 0.63)
# Doc token 'defined' is similar to keyword 'subset' (Similarity: 0.60)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'slices' is similar to keyword 'slices' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Level' is similar to keyword 'levels' (Similarity: 0.85)
# Doc token 'Level' is similar to keyword 'high' (Similarity: 0.60)
# Doc token 'Level' is similar to keyword 'level' (Similarity: 1.00)
# Doc token 'Objectives' is similar to keyword 'objectives' (Similarity: 1.00)
# Doc token 'Objectives' is similar to keyword 'objective' (Similarity: 0.78)
# Doc token 'Objectives' is similar to keyword 'responsibilities' (Similarity: 0.61)
# Doc token 'Performance' is similar to keyword 'performance' (Similarity: 1.00)
# Doc token 'Metrics' is similar to keyword 'metrics' (Similarity: 1.00)
# Doc token 'The' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'following' is similar to keyword 'specific' (Similarity: 0.60)
# Doc token 'performance' is similar to keyword 'performance' (Similarity: 1.00)
# Doc token 'metrics' is similar to keyword 'metrics' (Similarity: 1.00)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'measured' is similar to keyword 'measurements' (Similarity: 0.76)
# Doc token 'measured' is similar to keyword 'measurement' (Similarity: 0.75)
# Doc token 'monitored' is similar to keyword 'monitor' (Similarity: 0.61)
# Doc token 'monitored' is similar to keyword 'monitoring' (Similarity: 0.74)
# Doc token 'ensure' is similar to keyword 'requirements' (Similarity: 0.63)
# Doc token 'the' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'agreed' is similar to keyword 'agreement' (Similarity: 0.75)
# Doc token 'service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'levels' is similar to keyword 'levels' (Similarity: 1.00)
# Doc token 'levels' is similar to keyword 'level' (Similarity: 0.85)
# Doc token 'measurements' is similar to keyword 'measurements' (Similarity: 1.00)
# Doc token 'measurements' is similar to keyword 'measurement' (Similarity: 0.86)
# Doc token 'data' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'data' is similar to keyword 'data' (Similarity: 1.00)
# Doc token 'minute' is similar to keyword 'hour' (Similarity: 0.74)
# Doc token 'minute' is similar to keyword 'minutes' (Similarity: 0.80)
# Doc token 'minute' is similar to keyword 'minute' (Similarity: 1.00)
# Doc token 'intervals' is similar to keyword 'intervals' (Similarity: 1.00)
# Doc token 'unless' is similar to keyword 'notice' (Similarity: 0.66)
# Doc token 'otherwise' is similar to keyword 'notice' (Similarity: 0.61)
# Doc token 'specified' is similar to keyword 'specific' (Similarity: 0.63)
# Doc token 'Throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'Throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Downlink' is similar to keyword 'uplink' (Similarity: 0.89)
# Doc token 'Downlink' is similar to keyword 'downlink' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objectives' (Similarity: 0.78)
# Doc token 'Objective' is similar to keyword 'objective' (Similarity: 1.00)
# Doc token 'Average' is similar to keyword 'average' (Similarity: 1.00)
# Doc token 'Average' is similar to keyword 'total' (Similarity: 0.63)
# Doc token 'Average' is similar to keyword 'rate' (Similarity: 0.61)
# Doc token 'Average' is similar to keyword 'percentage' (Similarity: 0.73)
# Doc token 'downlink' is similar to keyword 'uplink' (Similarity: 0.89)
# Doc token 'downlink' is similar to keyword 'downlink' (Similarity: 1.00)
# Doc token 'throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Gbps' is similar to keyword 'gbps' (Similarity: 1.00)
# Doc token 'Gigabits' is similar to keyword 'gigabits' (Similarity: 1.00)
# Doc token 'second' is similar to keyword 'end' (Similarity: 0.63)
# Doc token 'Minimum' is similar to keyword 'maximum' (Similarity: 0.78)
# Doc token 'Minimum' is similar to keyword 'minimum' (Similarity: 1.00)
# Doc token 'Guaranteed' is similar to keyword 'guaranteed' (Similarity: 1.00)
# Doc token 'Mbps' is similar to keyword 'mbps' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'point' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'end' (Similarity: 0.62)
# Doc token 'User' is similar to keyword 'users' (Similarity: 0.79)
# Doc token 'User' is similar to keyword 'user' (Similarity: 1.00)
# Doc token 'Plane' is similar to keyword 'plane' (Similarity: 1.00)
# Doc token 'Function' is similar to keyword 'function' (Similarity: 1.00)
# Doc token 'Function' is similar to keyword 'functioning' (Similarity: 0.60)
# Doc token 'UPF' is similar to keyword 'upf' (Similarity: 1.00)
# Doc token 'egress' is similar to keyword 'ingress' (Similarity: 0.79)
# Doc token 'egress' is similar to keyword 'egress' (Similarity: 1.00)
# Doc token 'customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'customer' is similar to keyword 'client' (Similarity: 0.62)
# Doc token 'premises' is similar to keyword 'premises' (Similarity: 1.00)
# Doc token 'equipment' is similar to keyword 'equipment' (Similarity: 1.00)
# Doc token 'CPE' is similar to keyword 'cpe' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'Reporting' is similar to keyword 'report' (Similarity: 0.70)
# Doc token 'Frequency' is similar to keyword 'frequency' (Similarity: 1.00)
# Doc token 'Daily' is similar to keyword 'daily' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'report' (Similarity: 0.84)
# Doc token 'monthly' is similar to keyword 'monthly' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'quarterly' (Similarity: 0.73)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'monthly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'detailed' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'report' (Similarity: 0.84)
# Doc token 'Throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'Throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Uplink' is similar to keyword 'uplink' (Similarity: 1.00)
# Doc token 'Uplink' is similar to keyword 'downlink' (Similarity: 0.89)
# Doc token 'Objective' is similar to keyword 'objectives' (Similarity: 0.78)
# Doc token 'Objective' is similar to keyword 'objective' (Similarity: 1.00)
# Doc token 'Average' is similar to keyword 'average' (Similarity: 1.00)
# Doc token 'Average' is similar to keyword 'total' (Similarity: 0.63)
# Doc token 'Average' is similar to keyword 'rate' (Similarity: 0.61)
# Doc token 'Average' is similar to keyword 'percentage' (Similarity: 0.73)
# Doc token 'uplink' is similar to keyword 'uplink' (Similarity: 1.00)
# Doc token 'uplink' is similar to keyword 'downlink' (Similarity: 0.89)
# Doc token 'throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Mbps' is similar to keyword 'mbps' (Similarity: 1.00)
# Doc token 'Minimum' is similar to keyword 'maximum' (Similarity: 0.78)
# Doc token 'Minimum' is similar to keyword 'minimum' (Similarity: 1.00)
# Doc token 'Guaranteed' is similar to keyword 'guaranteed' (Similarity: 1.00)
# Doc token 'Mbps' is similar to keyword 'mbps' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'point' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'end' (Similarity: 0.62)
# Doc token 'CPE' is similar to keyword 'cpe' (Similarity: 1.00)
# Doc token 'ingress' is similar to keyword 'ingress' (Similarity: 1.00)
# Doc token 'ingress' is similar to keyword 'egress' (Similarity: 0.79)
# Doc token 'UPF' is similar to keyword 'upf' (Similarity: 1.00)
# Doc token 'ingress' is similar to keyword 'ingress' (Similarity: 1.00)
# Doc token 'ingress' is similar to keyword 'egress' (Similarity: 0.79)
# Doc token 'Reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'Reporting' is similar to keyword 'report' (Similarity: 0.70)
# Doc token 'Frequency' is similar to keyword 'frequency' (Similarity: 1.00)
# Doc token 'Daily' is similar to keyword 'daily' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'report' (Similarity: 0.84)
# Doc token 'monthly' is similar to keyword 'monthly' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'quarterly' (Similarity: 0.73)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'monthly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'detailed' is similar to keyword 'information' (Similarity: 0.62)
# Doc token 'reports' is similar to keyword 'reporting' (Similarity: 0.80)
# Doc token 'reports' is similar to keyword 'reports' (Similarity: 1.00)
# Doc token 'reports' is similar to keyword 'report' (Similarity: 0.84)
# Doc token 'Latency' is similar to keyword 'throughput' (Similarity: 0.63)
# Doc token 'Latency' is similar to keyword 'jitter' (Similarity: 0.65)
# Doc token 'Latency' is similar to keyword 'latency' (Similarity: 1.00)
# Doc token 'Round' is similar to keyword 'round' (Similarity: 1.00)
# Doc token 'Trip' is similar to keyword 'trip' (Similarity: 1.00)
# Doc token 'Time' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'Time' is similar to keyword 'days' (Similarity: 0.65)
# Doc token 'Time' is similar to keyword 'time' (Similarity: 1.00)
# Doc token 'Objective' is similar to keyword 'objectives' (Similarity: 0.78)
# Doc token 'Objective' is similar to keyword 'objective' (Similarity: 1.00)
# Doc token 'Average' is similar to keyword 'average' (Similarity: 1.00)
# Doc token 'Average' is similar to keyword 'total' (Similarity: 0.63)
# Doc token 'Average' is similar to keyword 'rate' (Similarity: 0.61)
# Doc token 'Average' is similar to keyword 'percentage' (Similarity: 0.73)
# Doc token 'end' is similar to keyword 'point' (Similarity: 0.62)
# Doc token 'end' is similar to keyword 'end' (Similarity: 1.00)
# Doc token 'end' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'end' is similar to keyword 'point' (Similarity: 0.62)
# Doc token 'end' is similar to keyword 'end' (Similarity: 1.00)
# Doc token 'end' is similar to keyword 'time' (Similarity: 0.60)
# Doc token 'latency' is similar to keyword 'throughput' (Similarity: 0.63)
# Doc token 'latency' is similar to keyword 'jitter' (Similarity: 0.65)
# Doc token 'latency' is similar to keyword 'latency' (Similarity: 1.00)
# Doc token 'ms' is similar to keyword 'ms' (Similarity: 1.00)
# Doc token 'milliseconds' is similar to keyword 'milliseconds' (Similarity: 1.00)
# Doc token 'Maximum' is similar to keyword 'maximum' (Similarity: 1.00)
# Doc token 'Maximum' is similar to keyword 'minimum' (Similarity: 0.78)
# Doc token 'Maximum' is similar to keyword 'max' (Similarity: 0.65)
# Doc token 'Tolerated' is similar to keyword 'tolerated' (Similarity: 1.00)
# Doc token 'ms' is similar to keyword 'ms' (Similarity: 1.00)
# Doc token 'traffic' is similar to keyword 'traffic' (Similarity: 1.00)
# Doc token 'Measurement' is similar to keyword 'measurements' (Similarity: 0.86)
# Doc token 'Measurement' is similar to keyword 'measurement' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'point' (Similarity: 1.00)
# Doc token 'Point' is similar to keyword 'end' (Similarity: 0.62)
# Doc token 'customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'customer' is similar to keyword 'client' (Similarity: 0.62)
# ...
# Doc token 'days' is similar to keyword 'hour' (Similarity: 0.64)
# Doc token 'days' is similar to keyword 'days' (Similarity: 1.00)
# Doc token 'days' is similar to keyword 'time' (Similarity: 0.65)
# Doc token 'written' is similar to keyword 'writing' (Similarity: 0.73)
# Doc token 'notice' is similar to keyword 'notify' (Similarity: 0.61)
# Doc token 'notice' is similar to keyword 'notification' (Similarity: 0.60)
# Doc token 'notice' is similar to keyword 'notice' (Similarity: 1.00)
# Doc token 'Governing' is similar to keyword 'governing' (Similarity: 1.00)
# Doc token 'Governing' is similar to keyword 'jurisdiction' (Similarity: 0.62)
# Doc token 'Law' is similar to keyword 'jurisdiction' (Similarity: 0.61)
# Doc token 'Law' is similar to keyword 'law' (Similarity: 1.00)
# Doc token 'Jurisdiction' is similar to keyword 'governing' (Similarity: 0.62)
# Doc token 'Jurisdiction' is similar to keyword 'jurisdiction' (Similarity: 1.00)
# Doc token 'Jurisdiction' is similar to keyword 'law' (Similarity: 0.61)
# Doc token 'Amendments' is similar to keyword 'amendment' (Similarity: 0.85)
# Doc token 'Amendments' is similar to keyword 'amendments' (Similarity: 1.00)
# Doc token 'Amendments' is similar to keyword 'provision' (Similarity: 0.60)
# Doc token 'be' is similar to keyword 'time' (Similarity: 0.61)
# Doc token 'writing' is similar to keyword 'writing' (Similarity: 1.00)
# Doc token 'parties' is similar to keyword 'party' (Similarity: 0.85)
# Doc token 'parties' is similar to keyword 'parties' (Similarity: 1.00)
# Doc token 'Confidentiality' is similar to keyword 'confidentiality' (Similarity: 1.00)
# Doc token 'parties' is similar to keyword 'party' (Similarity: 0.85)
# Doc token 'parties' is similar to keyword 'parties' (Similarity: 1.00)
# Doc token 'maintain' is similar to keyword 'maintenance' (Similarity: 0.60)
# Doc token 'confidentiality' is similar to keyword 'confidentiality' (Similarity: 1.00)
# Doc token 'SLA' is similar to keyword 'sla' (Similarity: 1.00)
# Doc token 'terms' is similar to keyword 'terms' (Similarity: 1.00)
# Doc token 'terms' is similar to keyword 'general' (Similarity: 0.62)
# Doc token 'terms' is similar to keyword 'specific' (Similarity: 0.61)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Level' is similar to keyword 'levels' (Similarity: 0.85)
# Doc token 'Level' is similar to keyword 'high' (Similarity: 0.60)
# Doc token 'Level' is similar to keyword 'level' (Similarity: 1.00)
# Doc token 'Agreement' is similar to keyword 'dispute' (Similarity: 0.65)
# Doc token 'Agreement' is similar to keyword 'negotiation' (Similarity: 0.60)
# Doc token 'Agreement' is similar to keyword 'agreement' (Similarity: 1.00)
# Doc token 'SLA' is similar to keyword 'sla' (Similarity: 1.00)
# Doc token 'General' is similar to keyword 'terms' (Similarity: 0.62)
# Doc token 'General' is similar to keyword 'general' (Similarity: 1.00)
# Doc token 'Information' is similar to keyword 'specific' (Similarity: 0.64)
# Doc token 'Information' is similar to keyword 'information' (Similarity: 1.00)
# Doc token 'Information' is similar to keyword 'data' (Similarity: 0.62)
# Doc token 'Information' is similar to keyword 'contact' (Similarity: 0.65)
# Doc token 'Provider' is similar to keyword 'service' (Similarity: 0.66)
# Doc token 'Provider' is similar to keyword 'provider' (Similarity: 1.00)
# Doc token 'NextGen' is similar to keyword 'nextgen' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'phone' (Similarity: 0.70)
# Doc token 'Mobile' is similar to keyword 'mobile' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'smartphones' (Similarity: 0.69)
# Doc token 'Networks' is similar to keyword 'connectivity' (Similarity: 0.61)
# Doc token 'Networks' is similar to keyword 'networks' (Similarity: 1.00)
# Doc token 'Networks' is similar to keyword 'network' (Similarity: 0.88)
# Doc token 'Customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'Customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'Customer' is similar to keyword 'client' (Similarity: 0.62)
# Doc token 'Acme' is similar to keyword 'acme' (Similarity: 1.00)
# Doc token 'Corp' is similar to keyword 'corp' (Similarity: 1.00)
# Doc token 'G' is similar to keyword 'g' (Similarity: 1.00)
# Doc token 'Enhanced' is similar to keyword 'capabilities' (Similarity: 0.63)
# Doc token 'Enhanced' is similar to keyword 'enhanced' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'phone' (Similarity: 0.70)
# Doc token 'Mobile' is similar to keyword 'mobile' (Similarity: 1.00)
# Doc token 'Mobile' is similar to keyword 'smartphones' (Similarity: 0.69)
# Doc token 'Broadband' is similar to keyword 'connectivity' (Similarity: 0.60)
# Doc token 'Broadband' is similar to keyword 'broadband' (Similarity: 1.00)
# Doc token 'Broadband' is similar to keyword 'telecom' (Similarity: 0.63)
# Doc token 'Service' is similar to keyword 'service' (Similarity: 1.00)
# Doc token 'Service' is similar to keyword 'customer' (Similarity: 0.67)
# Doc token 'Service' is similar to keyword 'provider' (Similarity: 0.66)
# Doc token 'Scope' is similar to keyword 'scope' (Similarity: 1.00)
# Doc token 'Urban' is similar to keyword 'metropolitan' (Similarity: 0.65)
# Doc token 'suburban' is similar to keyword 'metropolitan' (Similarity: 0.61)
# Doc token 'zones' is similar to keyword 'zone' (Similarity: 0.75)
# Doc token 'zones' is similar to keyword 'zones' (Similarity: 1.00)
# Doc token 'Region' is similar to keyword 'area' (Similarity: 0.66)
# Doc token 'Region' is similar to keyword 'region' (Similarity: 1.00)
# Doc token 'Release' is similar to keyword 'release' (Similarity: 1.00)
# Doc token 'devices' is similar to keyword 'device' (Similarity: 0.86)
# Doc token 'devices' is similar to keyword 'devices' (Similarity: 1.00)
# Doc token 'devices' is similar to keyword 'smartphones' (Similarity: 0.63)
# Doc token 'streaming' is similar to keyword 'streaming' (Similarity: 1.00)
# Doc token 'AR' is similar to keyword 'ar' (Similarity: 1.00)
# Doc token 'industrial' is similar to keyword 'industrial' (Similarity: 1.00)
# Doc token 'Performance' is similar to keyword 'performance' (Similarity: 1.00)
# Doc token 'Metrics' is similar to keyword 'metrics' (Similarity: 1.00)
# Doc token 'Availability' is similar to keyword 'availability' (Similarity: 1.00)
# Doc token 'Target' is similar to keyword 'target' (Similarity: 1.00)
# Doc token 'Monthly' is similar to keyword 'monthly' (Similarity: 1.00)
# Doc token 'Monthly' is similar to keyword 'quarterly' (Similarity: 0.73)
# Doc token 'Monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'Monthly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'Latency' is similar to keyword 'throughput' (Similarity: 0.63)
# Doc token 'Latency' is similar to keyword 'jitter' (Similarity: 0.65)
# Doc token 'Latency' is similar to keyword 'latency' (Similarity: 1.00)
# Doc token 'Target' is similar to keyword 'target' (Similarity: 1.00)
# Doc token 'ms' is similar to keyword 'ms' (Similarity: 1.00)
# Doc token 'edge' is similar to keyword 'edge' (Similarity: 1.00)
# Doc token 'edge' is similar to keyword 'edge' (Similarity: 1.00)
# Doc token 'Throughput' is similar to keyword 'throughput' (Similarity: 1.00)
# Doc token 'Throughput' is similar to keyword 'latency' (Similarity: 0.63)
# Doc token 'Downlink' is similar to keyword 'uplink' (Similarity: 0.89)
# Doc token 'Downlink' is similar to keyword 'downlink' (Similarity: 1.00)
# Doc token 'Gbps' is similar to keyword 'gbps' (Similarity: 1.00)
# Doc token 'Uplink' is similar to keyword 'uplink' (Similarity: 1.00)
# Doc token 'Uplink' is similar to keyword 'downlink' (Similarity: 0.89)
# Doc token 'Mbps' is similar to keyword 'mbps' (Similarity: 1.00)
# Doc token 'Peak' is similar to keyword 'peak' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'months' (Similarity: 0.63)
# Doc token 'hours' is similar to keyword 'hours' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'hour' (Similarity: 0.86)
# Doc token 'hours' is similar to keyword 'minutes' (Similarity: 0.74)
# Doc token 'hours' is similar to keyword 'days' (Similarity: 0.77)
# Doc token 'time' is similar to keyword 'end' (Similarity: 0.60)
# Doc token 'time' is similar to keyword 'days' (Similarity: 0.65)
# Doc token 'time' is similar to keyword 'time' (Similarity: 1.00)
# Doc token 'Jitter' is similar to keyword 'jitter' (Similarity: 1.00)
# Doc token 'Jitter' is similar to keyword 'latency' (Similarity: 0.65)
# Doc token 'Target' is similar to keyword 'target' (Similarity: 1.00)
# Doc token 'Fault' is similar to keyword 'faults' (Similarity: 0.74)
# Doc token 'Fault' is similar to keyword 'fault' (Similarity: 1.00)
# Doc token 'Management' is similar to keyword 'solutions' (Similarity: 0.60)
# Doc token 'Management' is similar to keyword 'management' (Similarity: 1.00)
# Doc token 'Management' is similar to keyword 'enterprise' (Similarity: 0.63)
# Doc token 'minutes' is similar to keyword 'hours' (Similarity: 0.74)
# Doc token 'minutes' is similar to keyword 'hour' (Similarity: 0.77)
# Doc token 'minutes' is similar to keyword 'min' (Similarity: 0.69)
# Doc token 'minutes' is similar to keyword 'minutes' (Similarity: 1.00)
# Doc token 'minutes' is similar to keyword 'minute' (Similarity: 0.80)
# Doc token 'hours' is similar to keyword 'months' (Similarity: 0.63)
# Doc token 'hours' is similar to keyword 'hours' (Similarity: 1.00)
# Doc token 'hours' is similar to keyword 'hour' (Similarity: 0.86)
# Doc token 'hours' is similar to keyword 'minutes' (Similarity: 0.74)
# Doc token 'hours' is similar to keyword 'days' (Similarity: 0.77)
# Doc token 'Priority' is similar to keyword 'priority' (Similarity: 1.00)
# Doc token 'incidents' is similar to keyword 'incident' (Similarity: 0.78)
# Doc token 'incidents' is similar to keyword 'incidents' (Similarity: 1.00)
# Doc token 'Monitoring' is similar to keyword 'monitor' (Similarity: 0.76)
# Doc token 'Monitoring' is similar to keyword 'monitoring' (Similarity: 1.00)
# Doc token 'Monitoring' is similar to keyword 'tracking' (Similarity: 0.63)
# Doc token 'monitoring' is similar to keyword 'monitor' (Similarity: 0.76)
# Doc token 'monitoring' is similar to keyword 'monitoring' (Similarity: 1.00)
# Doc token 'monitoring' is similar to keyword 'tracking' (Similarity: 0.63)
# Doc token 'Penalties' is similar to keyword 'penalty' (Similarity: 0.85)
# Doc token 'Penalties' is similar to keyword 'penalties' (Similarity: 1.00)
# Doc token 'Remedies' is similar to keyword 'remedies' (Similarity: 1.00)
# Doc token 'Threshold' is similar to keyword 'threshold' (Similarity: 1.00)
# Doc token 'Credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'Credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'monthly' is similar to keyword 'monthly' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'quarterly' (Similarity: 0.73)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'monthly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'fee' is similar to keyword 'fee' (Similarity: 1.00)
# Doc token 'fee' is similar to keyword 'refund' (Similarity: 0.68)
# Doc token 'refund' is similar to keyword 'receipt' (Similarity: 0.66)
# Doc token 'refund' is similar to keyword 'fee' (Similarity: 0.68)
# Doc token 'refund' is similar to keyword 'invoice' (Similarity: 0.61)
# Doc token 'refund' is similar to keyword 'refund' (Similarity: 1.00)
# Doc token 'Threshold' is similar to keyword 'threshold' (Similarity: 1.00)
# Doc token 'ms' is similar to keyword 'ms' (Similarity: 1.00)
# Doc token 'average' is similar to keyword 'average' (Similarity: 1.00)
# Doc token 'average' is similar to keyword 'total' (Similarity: 0.63)
# Doc token 'average' is similar to keyword 'rate' (Similarity: 0.61)
# Doc token 'average' is similar to keyword 'percentage' (Similarity: 0.73)
# Doc token 'Credit' is similar to keyword 'credit' (Similarity: 1.00)
# Doc token 'Credit' is similar to keyword 'credits' (Similarity: 0.62)
# Doc token 'monthly' is similar to keyword 'monthly' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'quarterly' (Similarity: 0.73)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'monthly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'fee' is similar to keyword 'fee' (Similarity: 1.00)
# Doc token 'fee' is similar to keyword 'refund' (Similarity: 0.68)
# Doc token 'refund' is similar to keyword 'receipt' (Similarity: 0.66)
# Doc token 'refund' is similar to keyword 'fee' (Similarity: 0.68)
# Doc token 'refund' is similar to keyword 'invoice' (Similarity: 0.61)
# Doc token 'refund' is similar to keyword 'refund' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'monthly' (Similarity: 1.00)
# Doc token 'monthly' is similar to keyword 'quarterly' (Similarity: 0.73)
# Doc token 'monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'monthly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'fee' is similar to keyword 'fee' (Similarity: 1.00)
# Doc token 'fee' is similar to keyword 'refund' (Similarity: 0.68)
# Doc token 'Reporting' is similar to keyword 'reporting' (Similarity: 1.00)
# Doc token 'Reporting' is similar to keyword 'reports' (Similarity: 0.80)
# Doc token 'Reporting' is similar to keyword 'report' (Similarity: 0.70)
# Doc token 'Frequency' is similar to keyword 'frequency' (Similarity: 1.00)
# Doc token 'Monthly' is similar to keyword 'monthly' (Similarity: 1.00)
# Doc token 'Monthly' is similar to keyword 'quarterly' (Similarity: 0.73)
# Doc token 'Monthly' is similar to keyword 'month' (Similarity: 0.64)
# Doc token 'Monthly' is similar to keyword 'annual' (Similarity: 0.64)
# Doc token 'Format' is similar to keyword 'file' (Similarity: 0.66)
# Doc token 'Format' is similar to keyword 'format' (Similarity: 1.00)
# Doc token 'PDF' is similar to keyword 'pdf' (Similarity: 1.00)
# Doc token 'Email' is similar to keyword 'contact' (Similarity: 0.64)
# Doc token 'Email' is similar to keyword 'email' (Similarity: 1.00)
# Doc token 'customer' is similar to keyword 'service' (Similarity: 0.67)
# Doc token 'customer' is similar to keyword 'customer' (Similarity: 1.00)
# Doc token 'customer' is similar to keyword 'client' (Similarity: 0.62)
# Doc token 'recipient' is similar to keyword 'recipient' (Similarity: 1.00)
# Doc token 'Contact' is similar to keyword 'information' (Similarity: 0.65)
# Doc token 'Contact' is similar to keyword 'contact' (Similarity: 1.00)
# Doc token 'Contact' is similar to keyword 'email' (Similarity: 0.64)
# Doc token 'Information' is similar to keyword 'specific' (Similarity: 0.64)
# Doc token 'Information' is similar to keyword 'information' (Similarity: 1.00)
# Doc token 'Information' is similar to keyword 'data' (Similarity: 0.62)
# Doc token 'Information' is similar to keyword 'contact' (Similarity: 0.65)
# Doc token 'Terms' is similar to keyword 'terms' (Similarity: 1.00)
# Doc token 'Terms' is similar to keyword 'general' (Similarity: 0.62)
# Doc token 'Terms' is similar to keyword 'specific' (Similarity: 0.61)
# Doc token 'Termination' is similar to keyword 'termination' (Similarity: 1.00)
# Doc token 'days' is similar to keyword 'months' (Similarity: 0.80)
# Doc token 'days' is similar to keyword 'month' (Similarity: 0.70)
# Doc token 'days' is similar to keyword 'hours' (Similarity: 0.77)
# Doc token 'days' is similar to keyword 'hour' (Similarity: 0.64)
# Doc token 'days' is similar to keyword 'days' (Similarity: 1.00)
# Doc token 'days' is similar to keyword 'time' (Similarity: 0.65)
# Doc token 'Renewal' is similar to keyword 'renewal' (Similarity: 1.00)
# Doc token 'Auto' is similar to keyword 'auto' (Similarity: 1.00)
# Doc token 'renewal' is similar to keyword 'renewal' (Similarity: 1.00)
# Doc token 'annually' is similar to keyword 'annual' (Similarity: 0.68)
# Doc token 'unless' is similar to keyword 'notice' (Similarity: 0.66)
# Doc token 'terminated' is similar to keyword 'termination' (Similarity: 0.76)
